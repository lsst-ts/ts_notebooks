# %% [markdown]
# ## This notebook performs a single science visit for this run for a target HD
# ### This should be run AFTER performing focus on nearby star HD 185975
# ##### The script, slews and acquires the target, applies focus correction, takes sequence of data

# %% [markdown]
# #### WARNING: This currently requires ts_externalscripts branch **tickets/DM-29061**

# %%
TARGET="HD115169" #"HD105070" #

# %%
import os
import sys
import asyncio
import time

import numpy as np
import logging 
import yaml
import matplotlib.pyplot as plt
import astropy

from lsst.ts import salobj
from lsst.ts.externalscripts.auxtel.latiss_cwfs_align import LatissCWFSAlign
from lsst.ts.externalscripts.auxtel.latiss_acquire_and_take_sequence import LatissAcquireAndTakeSequence

from lsst.ts.idl.enums.Script import ScriptState
from lsst.ts.observatory.control.utils import RotType
from astropy import time as astropytime

# %%
print(os.environ["OSPL_URI"])
print(os.environ["LSST_DDS_PARTITION_PREFIX"])
# Out:
# file:///opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.6.0/lib/python3.8/config/ospl-shmem-debug.xml
# ncsa

# %%
# for autocompleted to work
# %config IPCompleter.use_jedi = False

# %%
stream_handler = logging.StreamHandler(sys.stdout)
# if you want logging
logger = logging.getLogger()
logger.addHandler(stream_handler)
logger.level = logging.DEBUG

# turn off logging for matplotlib
mpl_logger = logging.getLogger('matplotlib')
mpl_logger.setLevel(logging.WARNING)

# %%
# make sure all remotes etc are running
script = LatissAcquireAndTakeSequence(index=os.getuid())  # this essentially calls the init method of the script
await script.start_task
# Out:
# DEBUG:Script.ATCS:atmcs: Adding all resources.
# atmcs: Adding all resources.
# DEBUG:Script.ATCS:atptg: Adding all resources.
# atptg: Adding all resources.
# DEBUG:Script.ATCS:ataos: Adding all resources.
# ataos: Adding all resources.
# DEBUG:Script.ATCS:atpneumatics: Adding all resources.
# atpneumatics: Adding all resources.
# DEBUG:Script.ATCS:athexapod: Adding all resources.
# athexapod: Adding all resources.
# DEBUG:Script.ATCS:atdome: Adding all resources.
# atdome: Adding all resources.
# DEBUG:Script.ATCS:atdometrajectory: Adding all resources.
# atdometrajectory: Adding all resources.
# DEBUG:Script.LATISS:atcamera: Adding all resources.
# atcamera: Adding all resources.
# DEBUG:Script.LATISS:atspectrograph: Adding all resources.
# atspectrograph: Adding all resources.
# DEBUG:Script.LATISS:atheaderservice: Adding all resources.
# atheaderservice: Adding all resources.
# DEBUG:Script.LATISS:atarchiver: Adding all resources.
# atarchiver: Adding all resources.
# INFO:ATDomeTrajectory:Read historical data in 0.01 sec
# Read historical data in 0.01 sec
# DEBUG:ATDomeTrajectory:Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, algorithm)
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, algorithm)
# DEBUG:ATDomeTrajectory:Read 2 history items for RemoteEvent(ATDomeTrajectory, 0, appliedSettingsMatchStart)
# Read 2 history items for RemoteEvent(ATDomeTrajectory, 0, appliedSettingsMatchStart)
# DEBUG:ATDomeTrajectory:Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, authList)
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, authList)
# DEBUG:ATDomeTrajectory:Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, followingMode)
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, followingMode)
# DEBUG:ATDomeTrajectory:Read 100 history items for RemoteEvent(ATDomeTrajectory, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATDomeTrajectory, 0, heartbeat)
# DEBUG:ATDomeTrajectory:Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, logLevel)
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, logLevel)
# DEBUG:ATDomeTrajectory:Read 5 history items for RemoteEvent(ATDomeTrajectory, 0, logMessage)
# Read 5 history items for RemoteEvent(ATDomeTrajectory, 0, logMessage)
# DEBUG:ATDomeTrajectory:Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, settingVersions)
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, settingVersions)
# DEBUG:ATDomeTrajectory:Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, settingsApplied)
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, settingsApplied)
# DEBUG:ATDomeTrajectory:Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, simulationMode)
# DEBUG:ATDomeTrajectory:Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, softwareVersions)
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, softwareVersions)
# DEBUG:ATDomeTrajectory:Read 7 history items for RemoteEvent(ATDomeTrajectory, 0, summaryState)
# Read 7 history items for RemoteEvent(ATDomeTrajectory, 0, summaryState)
# INFO:ATSpectrograph:Read historical data in 0.05 sec
# Read historical data in 0.05 sec
# DEBUG:ATSpectrograph:Read 1 history items for RemoteEvent(ATSpectrograph, 0, appliedSettingsMatchStart)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, appliedSettingsMatchStart)
# DEBUG:ATSpectrograph:Read 1 history items for RemoteEvent(ATSpectrograph, 0, authList)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, authList)
# DEBUG:ATSpectrograph:Read 100 history items for RemoteEvent(ATSpectrograph, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATSpectrograph, 0, heartbeat)
# DEBUG:ATSpectrograph:Read 1 history items for RemoteEvent(ATSpectrograph, 0, logLevel)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, logLevel)
# DEBUG:ATSpectrograph:Read 2 history items for RemoteEvent(ATSpectrograph, 0, logMessage)
# Read 2 history items for RemoteEvent(ATSpectrograph, 0, logMessage)
# DEBUG:ATSpectrograph:Read 1 history items for RemoteEvent(ATSpectrograph, 0, reportedDisperserPosition)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, reportedDisperserPosition)
# DEBUG:ATSpectrograph:Read 1 history items for RemoteEvent(ATSpectrograph, 0, reportedFilterPosition)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, reportedFilterPosition)
# DEBUG:ATSpectrograph:Read 1 history items for RemoteEvent(ATSpectrograph, 0, reportedLinearStagePosition)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, reportedLinearStagePosition)
# DEBUG:ATSpectrograph:Read 1 history items for RemoteEvent(ATSpectrograph, 0, settingVersions)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, settingVersions)
# DEBUG:ATSpectrograph:Read 1 history items for RemoteEvent(ATSpectrograph, 0, settingsApplied)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, settingsApplied)
# DEBUG:ATSpectrograph:Read 1 history items for RemoteEvent(ATSpectrograph, 0, settingsAppliedValues)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, settingsAppliedValues)
# DEBUG:ATSpectrograph:Read 1 history items for RemoteEvent(ATSpectrograph, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, simulationMode)
# DEBUG:ATSpectrograph:Read 1 history items for RemoteEvent(ATSpectrograph, 0, softwareVersions)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, softwareVersions)
# DEBUG:ATSpectrograph:Read 3 history items for RemoteEvent(ATSpectrograph, 0, summaryState)
# Read 3 history items for RemoteEvent(ATSpectrograph, 0, summaryState)
# INFO:ATHexapod:Read historical data in 0.08 sec
# Read historical data in 0.08 sec
# DEBUG:ATHexapod:Read 2 history items for RemoteEvent(ATHexapod, 0, appliedSettingsMatchStart)
# Read 2 history items for RemoteEvent(ATHexapod, 0, appliedSettingsMatchStart)
# DEBUG:ATHexapod:Read 1 history items for RemoteEvent(ATHexapod, 0, authList)
# Read 1 history items for RemoteEvent(ATHexapod, 0, authList)
# DEBUG:ATHexapod:Read 3 history items for RemoteEvent(ATHexapod, 0, detailedState)
# Read 3 history items for RemoteEvent(ATHexapod, 0, detailedState)
# DEBUG:ATHexapod:Read 100 history items for RemoteEvent(ATHexapod, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATHexapod, 0, heartbeat)
# DEBUG:ATHexapod:Read 1 history items for RemoteEvent(ATHexapod, 0, logLevel)
# Read 1 history items for RemoteEvent(ATHexapod, 0, logLevel)
# DEBUG:ATHexapod:Read 4 history items for RemoteEvent(ATHexapod, 0, logMessage)
# Read 4 history items for RemoteEvent(ATHexapod, 0, logMessage)
# DEBUG:ATHexapod:Read 1 history items for RemoteEvent(ATHexapod, 0, positionUpdate)
# Read 1 history items for RemoteEvent(ATHexapod, 0, positionUpdate)
# DEBUG:ATHexapod:Read 1 history items for RemoteEvent(ATHexapod, 0, readyForCommand)
# Read 1 history items for RemoteEvent(ATHexapod, 0, readyForCommand)
# DEBUG:ATHexapod:Read 1 history items for RemoteEvent(ATHexapod, 0, settingVersions)
# Read 1 history items for RemoteEvent(ATHexapod, 0, settingVersions)
# DEBUG:ATHexapod:Read 1 history items for RemoteEvent(ATHexapod, 0, settingsApplied)
# Read 1 history items for RemoteEvent(ATHexapod, 0, settingsApplied)
# DEBUG:ATHexapod:Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedPivot)
# Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedPivot)
# DEBUG:ATHexapod:Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedPositionLimits)
# Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedPositionLimits)
# DEBUG:ATHexapod:Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedTcp)
# Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedTcp)
# DEBUG:ATHexapod:Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedVelocities)
# Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedVelocities)
# DEBUG:ATHexapod:Read 1 history items for RemoteEvent(ATHexapod, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATHexapod, 0, simulationMode)
# DEBUG:ATHexapod:Read 1 history items for RemoteEvent(ATHexapod, 0, softwareVersions)
# Read 1 history items for RemoteEvent(ATHexapod, 0, softwareVersions)
# DEBUG:ATHexapod:Read 7 history items for RemoteEvent(ATHexapod, 0, summaryState)
# Read 7 history items for RemoteEvent(ATHexapod, 0, summaryState)
# INFO:ATHeaderService:Read historical data in 0.11 sec
# Read historical data in 0.11 sec
# DEBUG:ATHeaderService:Read 1 history items for RemoteEvent(ATHeaderService, 0, authList)
# Read 1 history items for RemoteEvent(ATHeaderService, 0, authList)
# DEBUG:ATHeaderService:Read 100 history items for RemoteEvent(ATHeaderService, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATHeaderService, 0, heartbeat)
# DEBUG:ATHeaderService:Read 4 history items for RemoteEvent(ATHeaderService, 0, largeFileObjectAvailable)
# Read 4 history items for RemoteEvent(ATHeaderService, 0, largeFileObjectAvailable)
# DEBUG:ATHeaderService:Read 1 history items for RemoteEvent(ATHeaderService, 0, logLevel)
# Read 1 history items for RemoteEvent(ATHeaderService, 0, logLevel)
# DEBUG:ATHeaderService:Read 100 history items for RemoteEvent(ATHeaderService, 0, logMessage)
# Read 100 history items for RemoteEvent(ATHeaderService, 0, logMessage)
# DEBUG:ATHeaderService:Read 1 history items for RemoteEvent(ATHeaderService, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATHeaderService, 0, simulationMode)
# DEBUG:ATHeaderService:Read 1 history items for RemoteEvent(ATHeaderService, 0, softwareVersions)
# Read 1 history items for RemoteEvent(ATHeaderService, 0, softwareVersions)
# DEBUG:ATHeaderService:Read 3 history items for RemoteEvent(ATHeaderService, 0, summaryState)
# Read 3 history items for RemoteEvent(ATHeaderService, 0, summaryState)
# INFO:ATArchiver:Read historical data in 0.13 sec
# Read historical data in 0.13 sec
# DEBUG:ATArchiver:Read 1 history items for RemoteEvent(ATArchiver, 0, authList)
# Read 1 history items for RemoteEvent(ATArchiver, 0, authList)
# DEBUG:ATArchiver:Read 1 history items for RemoteEvent(ATArchiver, 0, errorCode)
# Read 1 history items for RemoteEvent(ATArchiver, 0, errorCode)
# DEBUG:ATArchiver:Read 100 history items for RemoteEvent(ATArchiver, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATArchiver, 0, heartbeat)
# DEBUG:ATArchiver:Read 11 history items for RemoteEvent(ATArchiver, 0, imageInOODS)
# Read 11 history items for RemoteEvent(ATArchiver, 0, imageInOODS)
# DEBUG:ATArchiver:Read 11 history items for RemoteEvent(ATArchiver, 0, imageRetrievalForArchiving)
# Read 11 history items for RemoteEvent(ATArchiver, 0, imageRetrievalForArchiving)
# DEBUG:ATArchiver:Read 1 history items for RemoteEvent(ATArchiver, 0, logLevel)
# Read 1 history items for RemoteEvent(ATArchiver, 0, logLevel)
# DEBUG:ATArchiver:Read 1 history items for RemoteEvent(ATArchiver, 0, logMessage)
# Read 1 history items for RemoteEvent(ATArchiver, 0, logMessage)
# DEBUG:ATArchiver:Read 1 history items for RemoteEvent(ATArchiver, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATArchiver, 0, simulationMode)
# DEBUG:ATArchiver:Read 1 history items for RemoteEvent(ATArchiver, 0, softwareVersions)
# Read 1 history items for RemoteEvent(ATArchiver, 0, softwareVersions)
# DEBUG:ATArchiver:Read 7 history items for RemoteEvent(ATArchiver, 0, summaryState)
# Read 7 history items for RemoteEvent(ATArchiver, 0, summaryState)
# INFO:ATPneumatics:Read historical data in 0.16 sec
# Read historical data in 0.16 sec
# DEBUG:ATPneumatics:Read 1 history items for RemoteEvent(ATPneumatics, 0, authList)
# Read 1 history items for RemoteEvent(ATPneumatics, 0, authList)
# DEBUG:ATPneumatics:Read 5 history items for RemoteEvent(ATPneumatics, 0, cellVentsState)
# Read 5 history items for RemoteEvent(ATPneumatics, 0, cellVentsState)
# DEBUG:ATPneumatics:Read 1 history items for RemoteEvent(ATPneumatics, 0, eStop)
# Read 1 history items for RemoteEvent(ATPneumatics, 0, eStop)
# DEBUG:ATPneumatics:Read 100 history items for RemoteEvent(ATPneumatics, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATPneumatics, 0, heartbeat)
# DEBUG:ATPneumatics:Read 1 history items for RemoteEvent(ATPneumatics, 0, instrumentState)
# Read 1 history items for RemoteEvent(ATPneumatics, 0, instrumentState)
# DEBUG:ATPneumatics:Read 1 history items for RemoteEvent(ATPneumatics, 0, logLevel)
# Read 1 history items for RemoteEvent(ATPneumatics, 0, logLevel)
# DEBUG:ATPneumatics:Read 1 history items for RemoteEvent(ATPneumatics, 0, logMessage)
# Read 1 history items for RemoteEvent(ATPneumatics, 0, logMessage)
# DEBUG:ATPneumatics:Read 9 history items for RemoteEvent(ATPneumatics, 0, m1CoverLimitSwitches)
# Read 9 history items for RemoteEvent(ATPneumatics, 0, m1CoverLimitSwitches)
# DEBUG:ATPneumatics:Read 9 history items for RemoteEvent(ATPneumatics, 0, m1CoverState)
# Read 9 history items for RemoteEvent(ATPneumatics, 0, m1CoverState)
# DEBUG:ATPneumatics:Read 36 history items for RemoteEvent(ATPneumatics, 0, m1SetPressure)
# Read 36 history items for RemoteEvent(ATPneumatics, 0, m1SetPressure)
# DEBUG:ATPneumatics:Read 1 history items for RemoteEvent(ATPneumatics, 0, m1State)
# Read 1 history items for RemoteEvent(ATPneumatics, 0, m1State)
# DEBUG:ATPneumatics:Read 5 history items for RemoteEvent(ATPneumatics, 0, m1VentsLimitSwitches)
# Read 5 history items for RemoteEvent(ATPneumatics, 0, m1VentsLimitSwitches)
# DEBUG:ATPneumatics:Read 5 history items for RemoteEvent(ATPneumatics, 0, m1VentsPosition)
# Read 5 history items for RemoteEvent(ATPneumatics, 0, m1VentsPosition)
# DEBUG:ATPneumatics:Read 1 history items for RemoteEvent(ATPneumatics, 0, m2SetPressure)
# Read 1 history items for RemoteEvent(ATPneumatics, 0, m2SetPressure)
# DEBUG:ATPneumatics:Read 1 history items for RemoteEvent(ATPneumatics, 0, m2State)
# Read 1 history items for RemoteEvent(ATPneumatics, 0, m2State)
# DEBUG:ATPneumatics:Read 1 history items for RemoteEvent(ATPneumatics, 0, mainValveState)
# Read 1 history items for RemoteEvent(ATPneumatics, 0, mainValveState)
# DEBUG:ATPneumatics:Read 1 history items for RemoteEvent(ATPneumatics, 0, powerStatus)
# Read 1 history items for RemoteEvent(ATPneumatics, 0, powerStatus)
# DEBUG:ATPneumatics:Read 1 history items for RemoteEvent(ATPneumatics, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATPneumatics, 0, simulationMode)
# DEBUG:ATPneumatics:Read 1 history items for RemoteEvent(ATPneumatics, 0, softwareVersions)
# Read 1 history items for RemoteEvent(ATPneumatics, 0, softwareVersions)
# DEBUG:ATPneumatics:Read 11 history items for RemoteEvent(ATPneumatics, 0, summaryState)
# Read 11 history items for RemoteEvent(ATPneumatics, 0, summaryState)
# INFO:ATCamera:Read historical data in 0.20 sec
# Read historical data in 0.20 sec
# DEBUG:ATCamera:Read 1 history items for RemoteEvent(ATCamera, 0, appliedSettingsMatchStart)
# Read 1 history items for RemoteEvent(ATCamera, 0, appliedSettingsMatchStart)
# DEBUG:ATCamera:Read 21 history items for RemoteEvent(ATCamera, 0, ccsCommandState)
# Read 21 history items for RemoteEvent(ATCamera, 0, ccsCommandState)
# DEBUG:ATCamera:Read 4 history items for RemoteEvent(ATCamera, 0, endOfImageTelemetry)
# Read 4 history items for RemoteEvent(ATCamera, 0, endOfImageTelemetry)
# DEBUG:ATCamera:Read 4 history items for RemoteEvent(ATCamera, 0, endReadout)
# Read 4 history items for RemoteEvent(ATCamera, 0, endReadout)
# DEBUG:ATCamera:Read 3 history items for RemoteEvent(ATCamera, 0, focalPlaneHardwareIdSettingsApplied)
# Read 3 history items for RemoteEvent(ATCamera, 0, focalPlaneHardwareIdSettingsApplied)
# DEBUG:ATCamera:Read 3 history items for RemoteEvent(ATCamera, 0, focalPlaneSummaryInfo)
# Read 3 history items for RemoteEvent(ATCamera, 0, focalPlaneSummaryInfo)
# DEBUG:ATCamera:Read 100 history items for RemoteEvent(ATCamera, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATCamera, 0, heartbeat)
# DEBUG:ATCamera:Read 18 history items for RemoteEvent(ATCamera, 0, imageReadinessDetailedState)
# Read 18 history items for RemoteEvent(ATCamera, 0, imageReadinessDetailedState)
# DEBUG:ATCamera:Read 4 history items for RemoteEvent(ATCamera, 0, imageReadoutParameters)
# Read 4 history items for RemoteEvent(ATCamera, 0, imageReadoutParameters)
# DEBUG:ATCamera:Read 2 history items for RemoteEvent(ATCamera, 0, offlineDetailedState)
# Read 2 history items for RemoteEvent(ATCamera, 0, offlineDetailedState)
# DEBUG:ATCamera:Read 25 history items for RemoteEvent(ATCamera, 0, raftsDetailedState)
# Read 25 history items for RemoteEvent(ATCamera, 0, raftsDetailedState)
# DEBUG:ATCamera:Read 1 history items for RemoteEvent(ATCamera, 0, settingVersions)
# Read 1 history items for RemoteEvent(ATCamera, 0, settingVersions)
# DEBUG:ATCamera:Read 1 history items for RemoteEvent(ATCamera, 0, softwareVersions)
# Read 1 history items for RemoteEvent(ATCamera, 0, softwareVersions)
# DEBUG:ATCamera:Read 4 history items for RemoteEvent(ATCamera, 0, startIntegration)
# Read 4 history items for RemoteEvent(ATCamera, 0, startIntegration)
# DEBUG:ATCamera:Read 4 history items for RemoteEvent(ATCamera, 0, startReadout)
# Read 4 history items for RemoteEvent(ATCamera, 0, startReadout)
# DEBUG:ATCamera:Read 4 history items for RemoteEvent(ATCamera, 0, summaryState)
# Read 4 history items for RemoteEvent(ATCamera, 0, summaryState)
# INFO:ATAOS:Read historical data in 0.23 sec
# Read historical data in 0.23 sec
# DEBUG:ATAOS:Read 2 history items for RemoteEvent(ATAOS, 0, appliedSettingsMatchStart)
# Read 2 history items for RemoteEvent(ATAOS, 0, appliedSettingsMatchStart)
# DEBUG:ATAOS:Read 1 history items for RemoteEvent(ATAOS, 0, authList)
# Read 1 history items for RemoteEvent(ATAOS, 0, authList)
# DEBUG:ATAOS:Read 1 history items for RemoteEvent(ATAOS, 0, correctionEnabled)
# Read 1 history items for RemoteEvent(ATAOS, 0, correctionEnabled)
# DEBUG:ATAOS:Read 2 history items for RemoteEvent(ATAOS, 0, correctionOffsets)
# Read 2 history items for RemoteEvent(ATAOS, 0, correctionOffsets)
# DEBUG:ATAOS:Read 1 history items for RemoteEvent(ATAOS, 0, detailedState)
# Read 1 history items for RemoteEvent(ATAOS, 0, detailedState)
# DEBUG:ATAOS:Read 2 history items for RemoteEvent(ATAOS, 0, focusOffsetSummary)
# Read 2 history items for RemoteEvent(ATAOS, 0, focusOffsetSummary)
# DEBUG:ATAOS:Read 100 history items for RemoteEvent(ATAOS, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATAOS, 0, heartbeat)
# DEBUG:ATAOS:Read 1 history items for RemoteEvent(ATAOS, 0, logLevel)
# Read 1 history items for RemoteEvent(ATAOS, 0, logLevel)
# DEBUG:ATAOS:Read 5 history items for RemoteEvent(ATAOS, 0, logMessage)
# Read 5 history items for RemoteEvent(ATAOS, 0, logMessage)
# DEBUG:ATAOS:Read 1 history items for RemoteEvent(ATAOS, 0, settingVersions)
# Read 1 history items for RemoteEvent(ATAOS, 0, settingVersions)
# DEBUG:ATAOS:Read 1 history items for RemoteEvent(ATAOS, 0, settingsApplied)
# Read 1 history items for RemoteEvent(ATAOS, 0, settingsApplied)
# DEBUG:ATAOS:Read 1 history items for RemoteEvent(ATAOS, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATAOS, 0, simulationMode)
# DEBUG:ATAOS:Read 1 history items for RemoteEvent(ATAOS, 0, softwareVersions)
# Read 1 history items for RemoteEvent(ATAOS, 0, softwareVersions)
# DEBUG:ATAOS:Read 7 history items for RemoteEvent(ATAOS, 0, summaryState)
# Read 7 history items for RemoteEvent(ATAOS, 0, summaryState)
# INFO:ATDome:Read historical data in 0.25 sec
# Read historical data in 0.25 sec
# DEBUG:ATDome:Read 1 history items for RemoteEvent(ATDome, 0, allAxesInPosition)
# Read 1 history items for RemoteEvent(ATDome, 0, allAxesInPosition)
# DEBUG:ATDome:Read 2 history items for RemoteEvent(ATDome, 0, appliedSettingsMatchStart)
# Read 2 history items for RemoteEvent(ATDome, 0, appliedSettingsMatchStart)
# DEBUG:ATDome:Read 1 history items for RemoteEvent(ATDome, 0, authList)
# Read 1 history items for RemoteEvent(ATDome, 0, authList)
# DEBUG:ATDome:Read 4 history items for RemoteEvent(ATDome, 0, azimuthCommandedState)
# Read 4 history items for RemoteEvent(ATDome, 0, azimuthCommandedState)
# DEBUG:ATDome:Read 5 history items for RemoteEvent(ATDome, 0, azimuthInPosition)
# Read 5 history items for RemoteEvent(ATDome, 0, azimuthInPosition)
# DEBUG:ATDome:Read 7 history items for RemoteEvent(ATDome, 0, azimuthState)
# Read 7 history items for RemoteEvent(ATDome, 0, azimuthState)
# DEBUG:ATDome:Read 1 history items for RemoteEvent(ATDome, 0, doorEncoderExtremes)
# Read 1 history items for RemoteEvent(ATDome, 0, doorEncoderExtremes)
# DEBUG:ATDome:Read 2 history items for RemoteEvent(ATDome, 0, dropoutDoorCommandedState)
# Read 2 history items for RemoteEvent(ATDome, 0, dropoutDoorCommandedState)
# DEBUG:ATDome:Read 1 history items for RemoteEvent(ATDome, 0, dropoutDoorState)
# Read 1 history items for RemoteEvent(ATDome, 0, dropoutDoorState)
# DEBUG:ATDome:Read 1 history items for RemoteEvent(ATDome, 0, emergencyStop)
# Read 1 history items for RemoteEvent(ATDome, 0, emergencyStop)
# DEBUG:ATDome:Read 100 history items for RemoteEvent(ATDome, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATDome, 0, heartbeat)
# DEBUG:ATDome:Read 3 history items for RemoteEvent(ATDome, 0, lastAzimuthGoTo)
# Read 3 history items for RemoteEvent(ATDome, 0, lastAzimuthGoTo)
# DEBUG:ATDome:Read 1 history items for RemoteEvent(ATDome, 0, logLevel)
# Read 1 history items for RemoteEvent(ATDome, 0, logLevel)
# DEBUG:ATDome:Read 3 history items for RemoteEvent(ATDome, 0, logMessage)
# Read 3 history items for RemoteEvent(ATDome, 0, logMessage)
# DEBUG:ATDome:Read 2 history items for RemoteEvent(ATDome, 0, mainDoorCommandedState)
# Read 2 history items for RemoteEvent(ATDome, 0, mainDoorCommandedState)
# DEBUG:ATDome:Read 1 history items for RemoteEvent(ATDome, 0, mainDoorState)
# Read 1 history items for RemoteEvent(ATDome, 0, mainDoorState)
# DEBUG:ATDome:Read 5 history items for RemoteEvent(ATDome, 0, moveCode)
# Read 5 history items for RemoteEvent(ATDome, 0, moveCode)
# DEBUG:ATDome:Read 1 history items for RemoteEvent(ATDome, 0, scbLink)
# Read 1 history items for RemoteEvent(ATDome, 0, scbLink)
# DEBUG:ATDome:Read 1 history items for RemoteEvent(ATDome, 0, settingVersions)
# Read 1 history items for RemoteEvent(ATDome, 0, settingVersions)
# DEBUG:ATDome:Read 1 history items for RemoteEvent(ATDome, 0, settingsApplied)
# Read 1 history items for RemoteEvent(ATDome, 0, settingsApplied)
# DEBUG:ATDome:Read 1 history items for RemoteEvent(ATDome, 0, settingsAppliedDomeController)
# Read 1 history items for RemoteEvent(ATDome, 0, settingsAppliedDomeController)
# DEBUG:ATDome:Read 2 history items for RemoteEvent(ATDome, 0, settingsAppliedDomeTcp)
# Read 2 history items for RemoteEvent(ATDome, 0, settingsAppliedDomeTcp)
# DEBUG:ATDome:Read 2 history items for RemoteEvent(ATDome, 0, shutterInPosition)
# Read 2 history items for RemoteEvent(ATDome, 0, shutterInPosition)
# DEBUG:ATDome:Read 1 history items for RemoteEvent(ATDome, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATDome, 0, simulationMode)
# DEBUG:ATDome:Read 1 history items for RemoteEvent(ATDome, 0, softwareVersions)
# Read 1 history items for RemoteEvent(ATDome, 0, softwareVersions)
# DEBUG:ATDome:Read 7 history items for RemoteEvent(ATDome, 0, summaryState)
# Read 7 history items for RemoteEvent(ATDome, 0, summaryState)
# INFO:ATPtg:Read historical data in 0.29 sec
# Read historical data in 0.29 sec
# DEBUG:ATPtg:Read 1 history items for RemoteEvent(ATPtg, 0, airmassWarning)
# Read 1 history items for RemoteEvent(ATPtg, 0, airmassWarning)
# DEBUG:ATPtg:Read 1 history items for RemoteEvent(ATPtg, 0, azWrapWarning)
# Read 1 history items for RemoteEvent(ATPtg, 0, azWrapWarning)
# DEBUG:ATPtg:Read 3 history items for RemoteEvent(ATPtg, 0, currentDebugLevel)
# Read 3 history items for RemoteEvent(ATPtg, 0, currentDebugLevel)
# DEBUG:ATPtg:Read 3 history items for RemoteEvent(ATPtg, 0, currentTarget)
# Read 3 history items for RemoteEvent(ATPtg, 0, currentTarget)
# DEBUG:ATPtg:Read 7 history items for RemoteEvent(ATPtg, 0, detailedState)
# Read 7 history items for RemoteEvent(ATPtg, 0, detailedState)
# DEBUG:ATPtg:Read 1 history items for RemoteEvent(ATPtg, 0, elLimitWarning)
# Read 1 history items for RemoteEvent(ATPtg, 0, elLimitWarning)
# DEBUG:ATPtg:Read 2 history items for RemoteEvent(ATPtg, 0, errorCode)
# Read 2 history items for RemoteEvent(ATPtg, 0, errorCode)
# DEBUG:ATPtg:Read 1 history items for RemoteEvent(ATPtg, 0, focusNameInconsistentWarning)
# Read 1 history items for RemoteEvent(ATPtg, 0, focusNameInconsistentWarning)
# DEBUG:ATPtg:Read 2 history items for RemoteEvent(ATPtg, 0, focusNameSelected)
# Read 2 history items for RemoteEvent(ATPtg, 0, focusNameSelected)
# DEBUG:ATPtg:Read 100 history items for RemoteEvent(ATPtg, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATPtg, 0, heartbeat)
# DEBUG:ATPtg:Read 4 history items for RemoteEvent(ATPtg, 0, iers)
# Read 4 history items for RemoteEvent(ATPtg, 0, iers)
# DEBUG:ATPtg:Read 3 history items for RemoteEvent(ATPtg, 0, iersOutOfDate)
# Read 3 history items for RemoteEvent(ATPtg, 0, iersOutOfDate)
# DEBUG:ATPtg:Read 1 history items for RemoteEvent(ATPtg, 0, moonProximityWarning)
# Read 1 history items for RemoteEvent(ATPtg, 0, moonProximityWarning)
# DEBUG:ATPtg:Read 100 history items for RemoteEvent(ATPtg, 0, mountDataWarning)
# Read 100 history items for RemoteEvent(ATPtg, 0, mountDataWarning)
# DEBUG:ATPtg:Read 1 history items for RemoteEvent(ATPtg, 0, objectSetWarning)
# Read 1 history items for RemoteEvent(ATPtg, 0, objectSetWarning)
# DEBUG:ATPtg:Read 1 history items for RemoteEvent(ATPtg, 0, offsetSummary)
# Read 1 history items for RemoteEvent(ATPtg, 0, offsetSummary)
# DEBUG:ATPtg:Read 1 history items for RemoteEvent(ATPtg, 0, pointingFile)
# Read 1 history items for RemoteEvent(ATPtg, 0, pointingFile)
# DEBUG:ATPtg:Read 2 history items for RemoteEvent(ATPtg, 0, pointingModel)
# Read 2 history items for RemoteEvent(ATPtg, 0, pointingModel)
# DEBUG:ATPtg:Read 1 history items for RemoteEvent(ATPtg, 0, ptgAzCurrentWrap)
# Read 1 history items for RemoteEvent(ATPtg, 0, ptgAzCurrentWrap)
# DEBUG:ATPtg:Read 1 history items for RemoteEvent(ATPtg, 0, ptgRotCurrentWrap)
# Read 1 history items for RemoteEvent(ATPtg, 0, ptgRotCurrentWrap)
# DEBUG:ATPtg:Read 1 history items for RemoteEvent(ATPtg, 0, rotWrapWarning)
# Read 1 history items for RemoteEvent(ATPtg, 0, rotWrapWarning)
# DEBUG:ATPtg:Read 7 history items for RemoteEvent(ATPtg, 0, summaryState)
# Read 7 history items for RemoteEvent(ATPtg, 0, summaryState)
# DEBUG:ATPtg:Read 1 history items for RemoteEvent(ATPtg, 0, sunProximityWarning)
# Read 1 history items for RemoteEvent(ATPtg, 0, sunProximityWarning)
# DEBUG:ATPtg:Read 5 history items for RemoteEvent(ATPtg, 0, timesOfLimits)
# Read 5 history items for RemoteEvent(ATPtg, 0, timesOfLimits)
# DEBUG:ATPtg:Read 7 history items for RemoteEvent(ATPtg, 0, trackPosting)
# Read 7 history items for RemoteEvent(ATPtg, 0, trackPosting)
# DEBUG:ATPtg:Read 2 history items for RemoteEvent(ATPtg, 0, wavelength)
# Read 2 history items for RemoteEvent(ATPtg, 0, wavelength)
# DEBUG:ATPtg:Read 100 history items for RemoteEvent(ATPtg, 0, weatherDataApplied)
# Read 100 history items for RemoteEvent(ATPtg, 0, weatherDataApplied)
# DEBUG:ATPtg:Read 2 history items for RemoteEvent(ATPtg, 0, weatherDataInvalid)
# Read 2 history items for RemoteEvent(ATPtg, 0, weatherDataInvalid)
# INFO:ATMCS:Read historical data in 0.33 sec
# Read historical data in 0.33 sec
# DEBUG:ATMCS:Read 23 history items for RemoteEvent(ATMCS, 0, allAxesInPosition)
# Read 23 history items for RemoteEvent(ATMCS, 0, allAxesInPosition)
# DEBUG:ATMCS:Read 28 history items for RemoteEvent(ATMCS, 0, atMountState)
# Read 28 history items for RemoteEvent(ATMCS, 0, atMountState)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, authList)
# Read 1 history items for RemoteEvent(ATMCS, 0, authList)
# DEBUG:ATMCS:Read 6 history items for RemoteEvent(ATMCS, 0, azimuthBrake1)
# Read 6 history items for RemoteEvent(ATMCS, 0, azimuthBrake1)
# DEBUG:ATMCS:Read 6 history items for RemoteEvent(ATMCS, 0, azimuthBrake2)
# Read 6 history items for RemoteEvent(ATMCS, 0, azimuthBrake2)
# DEBUG:ATMCS:Read 6 history items for RemoteEvent(ATMCS, 0, azimuthDrive1Status)
# Read 6 history items for RemoteEvent(ATMCS, 0, azimuthDrive1Status)
# DEBUG:ATMCS:Read 6 history items for RemoteEvent(ATMCS, 0, azimuthDrive2Status)
# Read 6 history items for RemoteEvent(ATMCS, 0, azimuthDrive2Status)
# DEBUG:ATMCS:Read 23 history items for RemoteEvent(ATMCS, 0, azimuthInPosition)
# Read 23 history items for RemoteEvent(ATMCS, 0, azimuthInPosition)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, azimuthLimitSwitchCCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, azimuthLimitSwitchCCW)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, azimuthLimitSwitchCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, azimuthLimitSwitchCW)
# DEBUG:ATMCS:Read 5 history items for RemoteEvent(ATMCS, 0, azimuthToppleBlockCCW)
# Read 5 history items for RemoteEvent(ATMCS, 0, azimuthToppleBlockCCW)
# DEBUG:ATMCS:Read 5 history items for RemoteEvent(ATMCS, 0, azimuthToppleBlockCW)
# Read 5 history items for RemoteEvent(ATMCS, 0, azimuthToppleBlockCW)
# DEBUG:ATMCS:Read 6 history items for RemoteEvent(ATMCS, 0, elevationBrake)
# Read 6 history items for RemoteEvent(ATMCS, 0, elevationBrake)
# DEBUG:ATMCS:Read 6 history items for RemoteEvent(ATMCS, 0, elevationDriveStatus)
# Read 6 history items for RemoteEvent(ATMCS, 0, elevationDriveStatus)
# DEBUG:ATMCS:Read 23 history items for RemoteEvent(ATMCS, 0, elevationInPosition)
# Read 23 history items for RemoteEvent(ATMCS, 0, elevationInPosition)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, elevationLimitSwitchLower)
# Read 1 history items for RemoteEvent(ATMCS, 0, elevationLimitSwitchLower)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, elevationLimitSwitchUpper)
# Read 1 history items for RemoteEvent(ATMCS, 0, elevationLimitSwitchUpper)
# DEBUG:ATMCS:Read 100 history items for RemoteEvent(ATMCS, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATMCS, 0, heartbeat)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, logLevel)
# Read 1 history items for RemoteEvent(ATMCS, 0, logLevel)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, logMessage)
# Read 1 history items for RemoteEvent(ATMCS, 0, logMessage)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, m3DriveStatus)
# Read 1 history items for RemoteEvent(ATMCS, 0, m3DriveStatus)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, m3InPosition)
# Read 1 history items for RemoteEvent(ATMCS, 0, m3InPosition)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, m3RotatorDetentSwitches)
# Read 1 history items for RemoteEvent(ATMCS, 0, m3RotatorDetentSwitches)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, m3RotatorLimitSwitchCCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, m3RotatorLimitSwitchCCW)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, m3RotatorLimitSwitchCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, m3RotatorLimitSwitchCW)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, m3State)
# Read 1 history items for RemoteEvent(ATMCS, 0, m3State)
# DEBUG:ATMCS:Read 6 history items for RemoteEvent(ATMCS, 0, nasmyth1Brake)
# Read 6 history items for RemoteEvent(ATMCS, 0, nasmyth1Brake)
# DEBUG:ATMCS:Read 6 history items for RemoteEvent(ATMCS, 0, nasmyth1DriveStatus)
# Read 6 history items for RemoteEvent(ATMCS, 0, nasmyth1DriveStatus)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth1LimitSwitchCCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth1LimitSwitchCCW)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth1LimitSwitchCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth1LimitSwitchCW)
# DEBUG:ATMCS:Read 19 history items for RemoteEvent(ATMCS, 0, nasmyth1RotatorInPosition)
# Read 19 history items for RemoteEvent(ATMCS, 0, nasmyth1RotatorInPosition)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth2Brake)
# Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth2Brake)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth2DriveStatus)
# Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth2DriveStatus)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth2LimitSwitchCCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth2LimitSwitchCCW)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth2LimitSwitchCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth2LimitSwitchCW)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth2RotatorInPosition)
# Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth2RotatorInPosition)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, positionLimits)
# Read 1 history items for RemoteEvent(ATMCS, 0, positionLimits)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATMCS, 0, simulationMode)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, softwareVersions)
# Read 1 history items for RemoteEvent(ATMCS, 0, softwareVersions)
# DEBUG:ATMCS:Read 11 history items for RemoteEvent(ATMCS, 0, summaryState)
# Read 11 history items for RemoteEvent(ATMCS, 0, summaryState)
# DEBUG:ATMCS:Read 100 history items for RemoteEvent(ATMCS, 0, target)
# Read 100 history items for RemoteEvent(ATMCS, 0, target)
# WARNING:ATHexapod.positionStatus:positionStatus DDS read queue is filling: 16 of 100 elements
# positionStatus DDS read queue is filling: 16 of 100 elements
# WARNING:ATPneumatics.mainAirSourcePressure:mainAirSourcePressure DDS read queue is filling: 18 of 100 elements
# mainAirSourcePressure DDS read queue is filling: 18 of 100 elements
# WARNING:ATDome.position:position DDS read queue is filling: 65 of 100 elements
# position DDS read queue is filling: 65 of 100 elements
# ERROR:ATPtg.timeAndDate:timeAndDate DDS read queue is full (100 elements); data may be lost
# timeAndDate DDS read queue is full (100 elements); data may be lost
# WARNING:ATPneumatics.m2AirPressure:m2AirPressure DDS read queue is filling: 18 of 100 elements
# WARNING:ATMCS.trajectory:trajectory DDS read queue is filling: 31 of 100 elements
# m2AirPressure DDS read queue is filling: 18 of 100 elements
# trajectory DDS read queue is filling: 31 of 100 elements
# INFO:Script:Read historical data in 0.02 sec
# Read historical data in 0.02 sec
# ERROR:ATPtg.mountStatus:mountStatus DDS read queue is full (100 elements); data may be lost
# WARNING:ATPneumatics.m1AirPressure:m1AirPressure DDS read queue is filling: 18 of 100 elements
# mountStatus DDS read queue is full (100 elements); data may be lost
# WARNING:ATMCS.torqueDemand:torqueDemand DDS read queue is filling: 32 of 100 elements
# m1AirPressure DDS read queue is filling: 18 of 100 elements
# WARNING:ATPtg.mountPositions:mountPositions DDS read queue is filling: 36 of 100 elements
# WARNING:ATPneumatics.loadCell:loadCell DDS read queue is filling: 18 of 100 elements
# torqueDemand DDS read queue is filling: 32 of 100 elements
# mountPositions DDS read queue is filling: 36 of 100 elements
# loadCell DDS read queue is filling: 18 of 100 elements
# WARNING:ATMCS.nasymth_m3_mountMotorEncoders:nasymth_m3_mountMotorEncoders DDS read queue is filling: 32 of 100 elements
# ERROR:ATPtg.currentTargetStatus:currentTargetStatus DDS read queue is full (100 elements); data may be lost
# nasymth_m3_mountMotorEncoders DDS read queue is filling: 32 of 100 elements
# currentTargetStatus DDS read queue is full (100 elements); data may be lost
# WARNING:ATMCS.mount_Nasmyth_Encoders:mount_Nasmyth_Encoders DDS read queue is filling: 32 of 100 elements
# mount_Nasmyth_Encoders DDS read queue is filling: 32 of 100 elements
# WARNING:ATMCS.mount_AzEl_Encoders:mount_AzEl_Encoders DDS read queue is filling: 32 of 100 elements
# mount_AzEl_Encoders DDS read queue is filling: 32 of 100 elements
# WARNING:ATMCS.mount_AzEl_Encoders:mount_AzEl_Encoders python read queue is filling: 31 of 100 elements
# mount_AzEl_Encoders python read queue is filling: 31 of 100 elements
# WARNING:ATMCS.measuredTorque:measuredTorque DDS read queue is filling: 32 of 100 elements
# measuredTorque DDS read queue is filling: 32 of 100 elements
# WARNING:ATMCS.measuredMotorVelocity:measuredMotorVelocity DDS read queue is filling: 32 of 100 elements
# measuredMotorVelocity DDS read queue is filling: 32 of 100 elements
# WARNING:ATMCS.azEl_mountMotorEncoders:azEl_mountMotorEncoders DDS read queue is filling: 32 of 100 elements
# azEl_mountMotorEncoders DDS read queue is filling: 32 of 100 elements

# %%
# set wrap strategy
# this is required until the ATPtg is updated to not configure the mount for maximum time on target
# script.atcs.rem.atptg.cmd_raDecTarget.set(azWrapStrategy=1)  # 1 does not unwrap, 0 unwraps

# %%
# Do acquisition in the same mode we'll use to focus afterwards

# %% [markdown]
# ### Acquire using the hologram grating
# ##### This is the same position as the ronchi170lpmm grating

# %%
acq2_yaml = yaml.safe_dump({"object_name": TARGET,
                            "do_acquire": True,
                            "do_take_sequence": False,
                            "acq_filter" : 'RG610',
                            "acq_grating" : 'holo4_003', 
                            "acq_exposure_time": 0.5,
                            "max_acq_iter": 4,
                            "target_pointing_tolerance": 2,
                            "do_pointing_model": False,
                            "dataPath": '/project/shared/auxTel/rerun/quickLook',
                            "target_pointing_verification": False})
print(acq2_yaml)

# %%
# Set script state to UNCONFIGURED
# this is required to run the script a 2nd time but otherwise is a no-op
script.set_state(ScriptState.UNCONFIGURED)
# Configure the script, which puts the ScriptState to CONFIGURED
acq2_configuration = script.cmd_configure.DataType()
acq2_configuration.config = acq2_yaml
await script.do_configure(acq2_configuration)

# %%
# This take the acquisition sequence for the hologram (and Ronchi170lpmm grating)
acq2_results = await script.arun()

# %%
# await script.atcs.stop_tracking()

# %%
# await script.atcs.point_azel(az=265, el=75)

# %%
# script above defaults to paralactic angle = 0, but normally we use it at 90
# look at offsets from previous acquisition and add them here
# 29.9, 177.7
await script.atcs.slew_object(TARGET, offset_x=29.9, offset_y=177.7, rot_type=RotType.Parallactic, rot=0)

# %%
await script.latiss.take_object(exptime=2., grating='holo4_003', filter='empty_1')

# %%
target = np.array((1750, 300))
# Grab current position manually from firefly
curr = np.array((1770,135))

# %%
(target-curr)*0.1

# %%
await script.atcs.offset_xy(x=2,y=-16.5)

# %%
# cells below updated by marc
dx=80*2 # +/- offset range in x [arcsec]
xstep_size=60 # +/- step size in x [arcsec]
xoffset=np.arange(-dx,dx+1,xstep_size)
print(xoffset)

# %%
ystep_size=60 # +/- step size in x [arcsec]
# go from -15 arcsec to ~
yoffset=np.arange(-15,60*5,ystep_size)
yoffset=np.arange(-280, 25, ystep_size)
print(yoffset)

# %%
# Only run this when target is on the [X,Y] pixel of 1750, 300 (middle left, bottom of detector)
group_id = astropytime.Time.now().tai.isot
for i, yoff in enumerate(yoffset):
    for j, xoff in enumerate(xoffset):
        print(f'yoff is {yoff}, xoff is {xoff}')
        # offset the telescope, using ABSOLUTE offsets
        await script.atcs.offset_xy(x=xoff, y=yoff, relative=False)
        # take 20s image
        await script.latiss.take_object(exptime=20, n=1, group_id=group_id, grating='holo4_003', filter='empty_1')

# %%
# Now the fine mesh

# %%
dx=30 # +/- offset range in x [arcsec]
xstep_size=10 # +/- step size in x [arcsec]
xoffset=np.arange(-dx,dx+1,xstep_size)
print(xoffset)

# %%
ystep_size=10 # +/- step size in x [arcsec]
# go from -15 arcsec to ~
# yoffset=np.arange(-15,65,ystep_size) # backwards
yoffset=np.arange(-30,31,ystep_size)
print(yoffset)

# %%
# Only run this when target is on the [X,Y] pixel of 1750, 300 (middle left, bottom of detector)
group_id = astropytime.Time.now().tai.isot
for i, yoff in enumerate(yoffset):
    for j, xoff in enumerate(xoffset):
        print(f'yoff is {yoff}, xoff is {xoff}')
        # offset the telescope, using ABSOLUTE offsets
        await script.atcs.offset_xy(x=xoff, y=yoff, relative=False)
        # take 20s image
        await script.latiss.take_object(exptime=20, n=1, group_id=group_id)

# %%
yoff

# %%
xoff

# %%
ystep_size=8 # +/- step size in x [arcsec]
# go from -15 arcsec to ~
# yoffset=np.arange(-15,65,ystep_size) # backwards
yoffset=np.arange(10,32,ystep_size)
print(yoffset)

# %%
# Only run this when target is on the [X,Y] pixel of 1750, 300 (middle left, bottom of detector)
group_id = astropytime.Time.now().tai.isot
for i, yoff in enumerate(yoffset):
    for j, xoff in enumerate(xoffset):
        print(f'yoff is {yoff}, xoff is {xoff}')
        # offset the telescope, using ABSOLUTE offsets
        await script.atcs.offset_xy(x=xoff, y=yoff, relative=False)
        # take 20s image
        await script.latiss.take_object(exptime=20, n=1, group_id=group_id)

# %% [markdown]
# ### Now do test 2

# %%
# First Acquire
TARGET="HD160617"

# %%
acq2_yaml = yaml.safe_dump({"object_name": TARGET,
                            "do_acquire": True,
                            "do_take_sequence": False,
                            "acq_filter" : 'empty_1',
                            "acq_grating" : 'holo4_003', 
                            "acq_exposure_time": 1.0,
                            "max_acq_iter": 4,
                            "target_pointing_tolerance": 2,
                            "do_pointing_model": False,
                            "dataPath": '/project/shared/auxTel/rerun/quickLook',
                            "target_pointing_verification": False})
print(acq2_yaml)

# %%
# Set script state to UNCONFIGURED
# this is required to run the script a 2nd time but otherwise is a no-op
script.set_state(ScriptState.UNCONFIGURED)
# Configure the script, which puts the ScriptState to CONFIGURED
acq2_configuration = script.cmd_configure.DataType()
acq2_configuration.config = acq2_yaml
await script.do_configure(acq2_configuration)

# %%
# This take the acquisition sequence for the hologram (and Ronchi170lpmm grating)
acq2_results = await script.arun()

# %%
seq2_yaml = yaml.safe_dump({"object_name": TARGET,
                                "do_acquire": False,
                                "do_take_sequence": True,
                                "exposure_time_sequence" : [20, 20, 20,
                                                            20, 20, 20,
                                                            20, 20, 20], 
                                "filter_sequence": ['RG610','RG610', 'RG610',
                                                    'BG40','BG40', 'BG40',
                                                    'empty_1','empty_1', 'empty_1'], 
                                # RG610 and Ronchi
                                "grating_sequence": ['holo4_003', 'holo4_003', 'holo4_003',
                                                     'holo4_003', 'holo4_003', 'holo4_003',
                                                     'holo4_003', 'holo4_003', 'holo4_003'],
                                "do_pointing_model": False,
                                "dataPath": '/project/shared/auxTel/rerun/quickLook',
                                "target_pointing_verification": False})
print(seq2_yaml)

# %%
# Set script state to UNCONFIGURED
# this is required to run the script a 2nd time but otherwise is a no-op
script.set_state(ScriptState.UNCONFIGURED)
# Configure the script, which puts the ScriptState to CONFIGURED
seq2_configuration = script.cmd_configure.DataType()
seq2_configuration.config = seq2_yaml
await script.do_configure(seq2_configuration)

# %%
# This take the sequence of images with the Ronchi
seq2_results = await script.arun()

# %% [markdown]
# # Test3: Now to PNE

# %%
# First Acquire
target_ra="17:21:04"
target_dec="-29:02:59"

# %%
await script.atcs.slew_icrs(ra=target_ra, dec=target_dec, offset_x=29.9, offset_y=177.7, rot_type=RotType.Parallactic, rot=90)

# %%
group_id = astropytime.Time.now().tai.isot
await script.latiss.take_object(exptime=60, n=1, group_id=group_id, grating='empty_1', filter='empty_1')

# %%
seq2_yaml = yaml.safe_dump({"object_ra": target_ra, "object_dec": target_dec,
                                "do_acquire": False,
                                "do_take_sequence": True,
                                "exposure_time_sequence" : [60, 60, 60,
                                                            60, 60, 60,
                                                            60, 60, 60], 
                                "filter_sequence": ['empty_1','empty_1', 'empty_1',
                                                    'empty_1','empty_1', 'empty_1',
                                                    'empty_1','empty_1', 'empty_1'], 
                                # RG610 and Ronchi
                                "grating_sequence": ['holo4_003', 'holo4_003', 'holo4_003',
                                                     'holo4_003', 'holo4_003', 'holo4_003',
                                                     'holo4_003', 'holo4_003', 'holo4_003'],
                                "do_pointing_model": False,
                                "dataPath": '/project/shared/auxTel/rerun/quickLook',
                                "target_pointing_verification": False})
print(seq2_yaml)

# %%
# Set script state to UNCONFIGURED
# this is required to run the script a 2nd time but otherwise is a no-op
script.set_state(ScriptState.UNCONFIGURED)
# Configure the script, which puts the ScriptState to CONFIGURED
seq2_configuration = script.cmd_configure.DataType()
seq2_configuration.config = seq2_yaml
await script.do_configure(seq2_configuration)

# %%
# This take the sequence of images with the Ronchi
seq2_results = await script.arun()
