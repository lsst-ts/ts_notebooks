# %%
# Run the LATISS monitor

# %%
import os
import lsst.daf.persistence as dafPersist
import lsst.afw.display as afwDisplay
from lsst.rapid.analysis.monitoring import Monitor
repoDir = '/project/shared/auxTel/'
afwDisplay.setDefaultBackend('lsst.display.firefly')
display1 = afwDisplay.getDisplay(frame=1, name='LATISS_monitor',
                                 url=os.environ['FIREFLY_URL'])
display1.getClient().display_url()
monitor = Monitor(repoDir, display1)
monitor.overlayAmps = False
monitor.writeQuickLookImages = False
monitor.run()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /tmp/ipykernel_59579/2372306298.py in <module>
#       5 repoDir = '/project/shared/auxTel/'
#       6 afwDisplay.setDefaultBackend('lsst.display.firefly')
# ----> 7 display1 = afwDisplay.getDisplay(frame=1, name='LATISS_monitor',
#       8                                  url=os.environ['FIREFLY_URL'])
#       9 display1.getClient().display_url()
#
# /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-0.6.0/Linux64/afw/21.0.0-45-g119a6608a+532d44eec1/python/lsst/afw/display/interface.py in getDisplay(frame, backend, create, verbose, *args, **kwargs)
#     936     """
#     937
# --> 938     return Display.getDisplay(frame, backend, create, verbose, *args, **kwargs)
#     939
#     940
#
# ...
