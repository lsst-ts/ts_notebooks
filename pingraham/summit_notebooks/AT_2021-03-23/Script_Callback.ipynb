# %%
from lsst.ts import salobj
import asyncio

# %%
domain = salobj.Domain()
await asyncio.sleep(10)

# %%
remote = salobj.Remote(name="Script", domain=domain, index=0)
await remote.start_task

# %%
def print_logMessage(id_data):
    print(id_data.message)

# %%
remote.evt_logMessage.callback = print_logMessage

# %%
#asyncio.get_event_loop().run_forever()
# Out:
# Moving hexapod back to zero offset (in-focus) position
# intraImage expId for target: 2021032300566
# extraImage expId for target: 2021032300567
# Running source detection algorithm
# Found 10 sources. Selecting the brightest for CWFS analysis
# Selected source 8 @ [1536.5808529213916, 2282.16059902008]
# Creating stamps of centroid [y,x] = [340,378] with a side length of 112 pixels
# intra_square shape is (112, 112)
# extra_square shape is (112, 112)
# Running CWFS code using images binned by 2 in each dimension.
# TODO: Negative sign being used infront of calculated Coma-X Zernike! Artifact tha appeared while checking at NCSA. Needs investigation on other platforms!
# ==============================
# Measured [coma-X, coma-Y, focus] zernike coefficients in nm : [24.92681266451299, 0.7439290070626635, 74.29885717548946]
# De-rotated zernike coefficients: [-15.62540837  19.43568968  74.29885718]
# Hexapod offset : [-0.0758515  -0.09434801 -0.01524165]
# Telescope offsets: [-4.55108982 -5.66088049  0.        ]
# ==============================
#
# Applying offset: x=-0.07585149692852748, y=-0.09434800815507208, z=-0.015241648639663477.
# Applying telescope offset x/y: -4.551089815711649/5.660880489304325.
# CWFS iteration 3 starting...
# Intra/Extra images not taken. Running take image sequence.
# Moving to intra-focal position
# Moving to extra-focal position
# Taking extra-focal image
# Moving hexapod back to zero offset (in-focus) position
# intraImage expId for target: 2021032300568
# extraImage expId for target: 2021032300569
# Running source detection algorithm
# Found 10 sources. Selecting the brightest for CWFS analysis
# Selected source 7 @ [1643.0562212287116, 2249.016931252013]
# CWFS iteration 1 starting...
# Intra/Extra images not taken. Running take image sequence.
# Moving to intra-focal position
# Moving to extra-focal position
# Taking extra-focal image
# Moving hexapod back to zero offset (in-focus) position
# intraImage expId for target: 2021032300570
# extraImage expId for target: 2021032300571
# Running source detection algorithm
# Found 10 sources. Selecting the brightest for CWFS analysis
# Selected source 12 @ [1633.8645770212454, 2375.8148331772527]
# Creating stamps of centroid [y,x] = [186,186] with a side length of 112 pixels
# intra_square shape is (112, 112)
# extra_square shape is (112, 112)
# Running CWFS code using images binned by 2 in each dimension.
# TODO: Negative sign being used infront of calculated Coma-X Zernike! Artifact tha appeared while checking at NCSA. Needs investigation on other platforms!
# ==============================
# Measured [coma-X, coma-Y, focus] zernike coefficients in nm : [-20.814123500356608, -3.6227543568025515, -21.25795961402878]
# De-rotated zernike coefficients: [ 18.02137878 -11.0264225  -21.25795961]
# Hexapod offset : [0.08748242 0.05352632 0.00367228]
# Telescope offsets: [5.24894528 3.21157937 0.        ]
# ==============================
#
# Focus (0.0036722834349096458) and comma (0.1025584772827486) offsets inside tolerance level (0.01). Total focus correction: 0.0036722834349096458 mm. Total comma-x correction: 0.0 mm. Total comma-y correction: 0.0 mm.
# Applying telescope offset x/y: 5.248945275046292/-3.2115793692155608.
# Hexapod LUT Datapoint - HD  88803 - reported hexapod position is, [-3.59712052291, 1.09736100185, 0.161646103839, 0.34999987416, 0.220000457373, 2.44412129266e-06].
# Taking in focus acquisition image.
# CWFS iteration 1 starting...
# Intra/Extra images not taken. Running take image sequence.
# Moving to intra-focal position
# Moving to extra-focal position
# Taking extra-focal image
# Moving hexapod back to zero offset (in-focus) position
# intraImage expId for target: 2021032300573
# extraImage expId for target: 2021032300574
# Running source detection algorithm
# Found 10 sources. Selecting the brightest for CWFS analysis
# Selected source 10 @ [1670.4110572230813, 2570.2676016156397]
# Creating stamps of centroid [y,x] = [211,210] with a side length of 112 pixels
# intra_square shape is (112, 112)
# extra_square shape is (112, 112)
# Running CWFS code using images binned by 2 in each dimension.
# TODO: Negative sign being used infront of calculated Coma-X Zernike! Artifact tha appeared while checking at NCSA. Needs investigation on other platforms!
# ==============================
# Measured [coma-X, coma-Y, focus] zernike coefficients in nm : [-26.24979313705793, -11.705799312257083, 209.35261354034094]
# De-rotated zernike coefficients: [ 28.3651823   -4.63614175 209.35261354]
# Hexapod offset : [ 0.13769506  0.02250554 -0.05042993]
# Telescope offsets: [8.26170358 1.35033255 0.        ]
# ==============================
#
# Applying offset: x=0.13769505971353102, y=0.022505542466739314, z=-0.05042993277838465.
# Applying telescope offset x/y: 8.261703582811862/-1.3503325480043589.
# CWFS iteration 2 starting...
# Intra/Extra images not taken. Running take image sequence.
# Moving to intra-focal position
# Moving to extra-focal position
# Taking extra-focal image
# Moving hexapod back to zero offset (in-focus) position
# intraImage expId for target: 2021032300575
# extraImage expId for target: 2021032300576
# Running source detection algorithm
# Found 10 sources. Selecting the brightest for CWFS analysis
# Selected source 11 @ [1612.5523409310922, 2485.7204523453315]
# Creating stamps of centroid [y,x] = [219,212] with a side length of 112 pixels
# intra_square shape is (112, 112)
# extra_square shape is (112, 112)
# Running CWFS code using images binned by 2 in each dimension.
# TODO: Negative sign being used infront of calculated Coma-X Zernike! Artifact tha appeared while checking at NCSA. Needs investigation on other platforms!
# ==============================
# Measured [coma-X, coma-Y, focus] zernike coefficients in nm : [-11.860903352980005, -3.5702736078409347, -10.374566661800516]
# De-rotated zernike coefficients: [ 11.85656987  -3.58463848 -10.37456666]
# Hexapod offset : [0.05755616 0.01740116 0.00201853]
# Telescope offsets: [3.45336986 1.04406946 0.        ]
# ==============================
#
# Focus (0.0020185334470404666) and comma (0.06012913060754681) offsets inside tolerance level (0.01). Total focus correction: -0.04841139933134418 mm. Total comma-x correction: 0.13769505971353102 mm. Total comma-y correction: 0.022505542466739314 mm.
# Applying telescope offset x/y: 3.4533698637383083/-1.0440694592094804.
# Hexapod LUT Datapoint - HD  98631 - reported hexapod position is, [-3.86237741634, 1.03507229123, 0.148938297986, 0.349997759694, 0.220001033278, 3.03331647011e-06].
# Taking in focus acquisition image.
# CWFS iteration 1 starting...
# Intra/Extra images not taken. Running take image sequence.
# Moving to intra-focal position
# Moving to extra-focal position
# Taking extra-focal image
# Moving hexapod back to zero offset (in-focus) position
# intraImage expId for target: 2021032300578
# extraImage expId for target: 2021032300579
# Running source detection algorithm
# Found 10 sources. Selecting the brightest for CWFS analysis
# Selected source 4 @ [2181.785341816964, 1834.5808257187964]
# Creating stamps of centroid [y,x] = [186,185] with a side length of 112 pixels
# intra_square shape is (112, 112)
# extra_square shape is (112, 112)
# Running CWFS code using images binned by 2 in each dimension.
# TODO: Negative sign being used infront of calculated Coma-X Zernike! Artifact tha appeared while checking at NCSA. Needs investigation on other platforms!
# ==============================
# Measured [coma-X, coma-Y, focus] zernike coefficients in nm : [34.72936956005005, -209.77681999359572, -198.03242755358397]
# De-rotated zernike coefficients: [  42.51588714  208.33828899 -198.03242755]
# Hexapod offset : [ 0.2063878  -1.01135092  0.07339754]
# Telescope offsets: [ 12.3832681  -60.68105504   0.        ]
# ==============================
#
# Applying offset: x=0.20638780163673826, y=-1.011350917407645, z=0.07339754227405174.
# Applying telescope offset x/y: 12.383268098204296/60.681055044458695.
# CWFS iteration 2 starting...
# Intra/Extra images not taken. Running take image sequence.
# Moving to intra-focal position
# Moving to extra-focal position
# Taking extra-focal image
# Moving hexapod back to zero offset (in-focus) position
# intraImage expId for target: 2021032300580
# extraImage expId for target: 2021032300581
# Running source detection algorithm
# Found 10 sources. Selecting the brightest for CWFS analysis
# Selected source 1 @ [2573.198854476029, 1312.4004921510395]
# Creating stamps of centroid [y,x] = [207,188] with a side length of 112 pixels
# intra_square shape is (112, 112)
# extra_square shape is (112, 112)
# Running CWFS code using images binned by 2 in each dimension.
# TODO: Negative sign being used infront of calculated Coma-X Zernike! Artifact tha appeared while checking at NCSA. Needs investigation on other platforms!
# ==============================
# Measured [coma-X, coma-Y, focus] zernike coefficients in nm : [-0.0, 0.0, 51.600193641752945]
# De-rotated zernike coefficients: [ 0.          0.         51.60019364]
# Hexapod offset : [ 0.          0.         -0.01228576]
# Telescope offsets: [0. 0. 0.]
# ==============================
#
# Applying offset: x=0.0, y=0.0, z=-0.012285760390893559.
# Applying telescope offset x/y: 0.0/-0.0.
# CWFS iteration 3 starting...
# Intra/Extra images not taken. Running take image sequence.
# Moving to intra-focal position
# Moving to extra-focal position
# Taking extra-focal image
# Moving hexapod back to zero offset (in-focus) position
# intraImage expId for target: 2021032300582
# extraImage expId for target: 2021032300583
# Running source detection algorithm
# Found 10 sources. Selecting the brightest for CWFS analysis
# Selected source 1 @ [2562.393979799036, 1358.171002291999]
# Creating stamps of centroid [y,x] = [201,186] with a side length of 112 pixels
# intra_square shape is (112, 112)
# extra_square shape is (112, 112)
# Running CWFS code using images binned by 2 in each dimension.
# TODO: Negative sign being used infront of calculated Coma-X Zernike! Artifact tha appeared while checking at NCSA. Needs investigation on other platforms!
# ==============================
# Measured [coma-X, coma-Y, focus] zernike coefficients in nm : [-0.0, 0.0, 36.908951428514726]
# De-rotated zernike coefficients: [ 0.          0.         36.90895143]
# Hexapod offset : [ 0.          0.         -0.00878785]
# Telescope offsets: [0. 0. 0.]
# ==============================
#
# Focus (-0.008787845578217792) and comma (0.0) offsets inside tolerance level (0.01). Total focus correction: 0.05232393630494038 mm. Total comma-x correction: 0.20638780163673826 mm. Total comma-y correction: -1.011350917407645 mm.
# Applying telescope offset x/y: 0.0/-0.0.
# Hexapod LUT Datapoint - HD 110261 - reported hexapod position is, [-4.66188619714, -0.141558826165, 0.353146917521, 0.350000318198, 0.220000265223, 4.86525359422e-07].
# Taking in focus acquisition image.
# CWFS iteration 1 starting...
# Intra/Extra images not taken. Running take image sequence.
# Moving to intra-focal position
# Moving to extra-focal position
# Taking extra-focal image
# Moving hexapod back to zero offset (in-focus) position
# intraImage expId for target: 2021032300585
# extraImage expId for target: 2021032300586
# Running source detection algorithm
# Found 10 sources. Selecting the brightest for CWFS analysis
# Selected source 3 @ [2646.004071601289, 1066.3443815866221]
# Creating stamps of centroid [y,x] = [238,254] with a side length of 112 pixels
# intra_square shape is (112, 112)
# extra_square shape is (112, 112)
# Running CWFS code using images binned by 2 in each dimension.
# TODO: Negative sign being used infront of calculated Coma-X Zernike! Artifact tha appeared while checking at NCSA. Needs investigation on other platforms!
# ==============================
# Measured [coma-X, coma-Y, focus] zernike coefficients in nm : [-0.0, 0.0, 95.75472501092007]
# De-rotated zernike coefficients: [ 0.          0.         95.75472501]
# Hexapod offset : [ 0.          0.         -0.02279874]
# Telescope offsets: [0. 0. 0.]
# ==============================
#
# Applying offset: x=0.0, y=0.0, z=-0.022798744050219064.
# Applying telescope offset x/y: 0.0/-0.0.
# CWFS iteration 2 starting...
# Intra/Extra images not taken. Running take image sequence.
# Moving to intra-focal position
# Moving to extra-focal position
# Taking extra-focal image
# Moving hexapod back to zero offset (in-focus) position
# intraImage expId for target: 2021032300587
# extraImage expId for target: 2021032300588
# CWFS iteration 1 starting...
# Intra/Extra images not taken. Running take image sequence.
# Moving to intra-focal position
# Moving to extra-focal position
# Taking extra-focal image
# Moving hexapod back to zero offset (in-focus) position
# intraImage expId for target: 2021032300589
# extraImage expId for target: 2021032300590
# Running source detection algorithm
# Found 10 sources. Selecting the brightest for CWFS analysis
# Selected source 1 @ [2037.6093417215504, 1207.165350546654]
# Creating stamps of centroid [y,x] = [248,265] with a side length of 112 pixels
# intra_square shape is (112, 112)
# extra_square shape is (112, 112)
# Running CWFS code using images binned by 2 in each dimension.
# TODO: Negative sign being used infront of calculated Coma-X Zernike! Artifact tha appeared while checking at NCSA. Needs investigation on other platforms!
# ==============================
# Measured [coma-X, coma-Y, focus] zernike coefficients in nm : [-0.0, 0.0, 83.474938857803]
# De-rotated zernike coefficients: [ 0.          0.         83.47493886]
# Hexapod offset : [ 0.          0.         -0.01987499]
# Telescope offsets: [0. 0. 0.]
# ==============================
#
# Applying offset: x=0.0, y=0.0, z=-0.019874985442334046.
# Applying telescope offset x/y: 0.0/-0.0.
# CWFS iteration 2 starting...
# Intra/Extra images not taken. Running take image sequence.
# Moving to intra-focal position
# Moving to extra-focal position
# Taking extra-focal image
# Moving hexapod back to zero offset (in-focus) position
# intraImage expId for target: 2021032300591
# extraImage expId for target: 2021032300592
# Running source detection algorithm
# Found 10 sources. Selecting the brightest for CWFS analysis
# Selected source 0 @ [2034.930539725109, 1211.3164487652252]
# Creating stamps of centroid [y,x] = [242,265] with a side length of 112 pixels
# intra_square shape is (112, 112)
# extra_square shape is (112, 112)
# Running CWFS code using images binned by 2 in each dimension.
# TODO: Negative sign being used infront of calculated Coma-X Zernike! Artifact tha appeared while checking at NCSA. Needs investigation on other platforms!
# ==============================
# Measured [coma-X, coma-Y, focus] zernike coefficients in nm : [-0.0, 0.0, 7.98998757711223]
# De-rotated zernike coefficients: [0.         0.         7.98998758]
# Hexapod offset : [ 0.          0.         -0.00190238]
# Telescope offsets: [0. 0. 0.]
# ==============================
#
# Focus (-0.001902377994550531) and comma (0.0) offsets inside tolerance level (0.01). Total focus correction: -0.021777363436884578 mm. Total comma-x correction: 0.0 mm. Total comma-y correction: 0.0 mm.
# Applying telescope offset x/y: 0.0/-0.0.
# Hexapod LUT Datapoint - HD 121865 - reported hexapod position is, [-5.2327889634, 0.736716625561, 0.335909308058, 0.349999711846, 0.21999981956, -3.97346837928e-07].
# Taking in focus acquisition image.
# Using binning factor of 2
# CWFS iteration 1 starting...
# Intra/Extra images not taken. Running take image sequence.
# Moving to intra-focal position
# Moving to extra-focal position
# Taking extra-focal image
# Moving hexapod back to zero offset (in-focus) position
# intraImage expId for target: 2021032300612
# extraImage expId for target: 2021032300613
# Running source detection algorithm
# Found 10 sources. Selecting the brightest for CWFS analysis
# Selected source 2 @ [1222.6044549222934, 1634.2567778584882]
# Creating stamps of centroid [y,x] = [276,340] with a side length of 112 pixels
# intra_square shape is (112, 112)
# extra_square shape is (112, 112)
# Running CWFS code using images binned by 2 in each dimension.
# TODO: Negative sign being used infront of calculated Coma-X Zernike! Artifact tha appeared while checking at NCSA. Needs investigation on other platforms!
# ==============================
# Measured [coma-X, coma-Y, focus] zernike coefficients in nm : [22.80684680902492, -6.990206148092155, -21.9229664844538]
# De-rotated zernike coefficients: [-12.59999453  20.25476194 -21.92296648]
# Hexapod offset : [-0.06116502 -0.09832409  0.0077715 ]
# Telescope offsets: [-3.66990132 -5.89944523  0.        ]
# ==============================
#
# Focus (0.007771498089995219) and comma (0.11579631261711855) offsets inside tolerance level (0.01). Total focus correction: 0.007771498089995219 mm. Total comma-x correction: 0.0 mm. Total comma-y correction: 0.0 mm.
# Applying telescope offset x/y: -3.669901318080813/5.899445225794196.
# Hexapod LUT Datapoint - HD 102649 - reported hexapod position is, [-3.49626538897, 1.14114832464, 0.146360129675, 0.349999330372, 0.21999916132, -9.28032049895e-07].
# Taking in focus acquisition image.
# Read historical data in 0.00 sec
# Disabling ATAOS corrections
# Disabling ATAOS corrections.
# Closing M1 cover vent gates.
# Cover state <MirrorCoverState.OPENED: 7>
# Closing M1 cover.
# Using nasmyth port <Foci.NASMYTH2: 3>
# Sending command
# Stop tracking.
# Tracking state: <AtMountState.TRACKINGENABLED: 9>
# Tracking state: <AtMountState.STOPPING: 10>
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# [Telescope] delta Alt = +040.045 deg; delta Az= -000.001 deg; delta N1 = +000.000 deg; delta N2 = +000.070 deg
# [Telescope] delta Alt = +039.339 deg; delta Az= -000.001 deg; delta N1 = +000.000 deg; delta N2 = +000.006 deg
# [Telescope] delta Alt = +035.623 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +029.620 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +025.622 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +021.664 deg; delta Az= +000.000 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +017.806 deg; delta Az= +000.000 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +014.141 deg; delta Az= +000.000 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +009.197 deg; delta Az= +000.000 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +005.188 deg; delta Az= +000.000 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +004.097 deg; delta Az= +000.000 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +001.642 deg; delta Az= +000.000 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.671 deg; delta Az= +000.000 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.058 deg; delta Az= +000.000 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +000.000 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# Got True
# Waiting for telescope to settle.
# Axes in position.
# Cover state <MirrorCoverState.OPENED: 7>
# Cover state <MirrorCoverState.INMOTION: 8>
# Cover state <MirrorCoverState.CLOSED: 6>
# M1 vent state <VentsPosition.OPENED: 0>
# Closing M1 vents.
# M1 vent state <VentsPosition.PARTIALLYOPENED: 2>
# M1 vent state <VentsPosition.CLOSED: 1>
# Close dome.
# Closing dome shutter...
# process as completed...
# atdome: <State.ENABLED: 2>
# Waiting for ATDome mainDoorState: <ShutterDoorState.CLOSED: 1>. Current state: <ShutterDoorState.OPENED: 2>.
# mainDoorState: <ShutterDoorState.CLOSING: 5>
# mainDoorState: <ShutterDoorState.CLOSED: 1>
# Finishing ATDome shutter command task.
# ATDome shutter command task not done. Cancelling.
# ATDome shutter command task cancelled.
# Slew dome to Park position.
# Sending ATDomeTrajectory to DISABED state. Component will be left in DISABLEDstate or else it may send the ATDome back to alignment with the telescope.
# process as completed...
# atdometrajectory: <State.DISABLED: 1>
# [Dome] delta Az = +102.120 deg
# [Dome] delta Az = +102.010 deg
# [Dome] delta Az = +101.660 deg
# [Dome] delta Az = +101.080 deg
# [Dome] delta Az = +100.260 deg
# [Dome] delta Az = +099.220 deg
# [Dome] delta Az = +097.930 deg
# [Dome] delta Az = +096.420 deg
# [Dome] delta Az = +094.660 deg
# [Dome] delta Az = +092.680 deg
# [Dome] delta Az = +090.470 deg
# [Dome] delta Az = +088.010 deg
# [Dome] delta Az = +085.340 deg
# [Dome] delta Az = +082.430 deg
# [Dome] delta Az = +079.300 deg
# [Dome] delta Az = +075.950 deg
# [Dome] delta Az = +072.480 deg
# [Dome] delta Az = +069.020 deg
# [Dome] delta Az = +065.540 deg
# [Dome] delta Az = +062.100 deg
# [Dome] delta Az = +058.620 deg
# [Dome] delta Az = +055.140 deg
# [Dome] delta Az = +051.650 deg
# [Dome] delta Az = +048.190 deg
# [Dome] delta Az = +044.730 deg
# [Dome] delta Az = +041.240 deg
# [Dome] delta Az = +037.800 deg
# [Dome] delta Az = +034.340 deg
# [Dome] delta Az = +030.840 deg
# [Dome] delta Az = +027.390 deg
# [Dome] delta Az = +023.910 deg
# [Dome] delta Az = +020.450 deg
# [Dome] delta Az = +017.000 deg
# [Dome] delta Az = +013.520 deg
# [Dome] delta Az = +010.060 deg
# [Dome] delta Az = +006.610 deg
# [Dome] delta Az = +003.180 deg
# Axes in position.
# Disable ATDomeTrajectory
# Slew telescope to Park position.
# Sending command
# Stop tracking.
# Tracking state: <AtMountState.TRACKINGENABLED: 9>
# Tracking state: <AtMountState.STOPPING: 10>
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# [Telescope] delta Alt = +010.000 deg; delta Az= +179.697 deg; delta N1 = -000.000 deg; delta N2 = +010.435 deg
# [Telescope] delta Alt = +009.165 deg; delta Az= -178.306 deg; delta N1 = -000.000 deg; delta N2 = +008.270 deg
# [Telescope] delta Alt = +004.082 deg; delta Az= -172.313 deg; delta N1 = +000.000 deg; delta N2 = +002.654 deg
# [Telescope] delta Alt = +000.186 deg; delta Az= -166.314 deg; delta N1 = +000.000 deg; delta N2 = +000.321 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -162.313 deg; delta N1 = +000.000 deg; delta N2 = -000.001 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -158.312 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -154.314 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -150.312 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -146.313 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -142.313 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -138.313 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -134.314 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -130.313 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -126.312 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -124.312 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -120.314 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -116.313 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -112.313 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -108.313 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -102.312 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -098.314 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -092.312 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -088.313 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -082.312 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -078.313 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -072.313 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -070.311 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -066.313 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -062.313 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -058.311 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -054.313 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -050.313 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -046.312 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -042.314 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -038.313 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -034.312 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -030.312 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -026.309 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -022.338 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -018.456 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -014.744 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -011.300 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -008.214 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -004.437 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -002.571 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -001.253 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.452 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.084 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.001 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# Got True
# Waiting for telescope to settle.
# Axes in position.
# Stop tracking.
# Tracking state: <AtMountState.TRACKINGENABLED: 9>
# Tracking state: <AtMountState.STOPPING: 10>
# In Position: True.
# Put CSCs in standby
# [atmcs]::[<State.ENABLED: 2>, <State.DISABLED: 1>, <State.STANDBY: 5>]
# [atptg]::[<State.ENABLED: 2>, <State.DISABLED: 1>, <State.STANDBY: 5>]
# [ataos]::[<State.ENABLED: 2>, <State.DISABLED: 1>, <State.STANDBY: 5>]
# [atpneumatics]::[<State.ENABLED: 2>, <State.DISABLED: 1>, <State.STANDBY: 5>]
# [athexapod]::[<State.ENABLED: 2>, <State.DISABLED: 1>, <State.STANDBY: 5>]
# [atdome]::[<State.ENABLED: 2>, <State.DISABLED: 1>, <State.STANDBY: 5>]
# [atdometrajectory]::[<State.DISABLED: 1>, <State.STANDBY: 5>]
# All components in <State.STANDBY: 5>.
# Setting final state to <ScriptState.DONE: 8>
# Read historical data in 0.00 sec
# [atcamera]::[<State.ENABLED: 2>, <State.DISABLED: 1>, <State.STANDBY: 5>]
# [atspectrograph]::[<State.ENABLED: 2>, <State.DISABLED: 1>, <State.STANDBY: 5>]
# [atheaderservice]::[<State.ENABLED: 2>, <State.DISABLED: 1>, <State.STANDBY: 5>]
# [atarchiver]::[<State.ENABLED: 2>, <State.DISABLED: 1>, <State.STANDBY: 5>]
# All components in <State.STANDBY: 5>.
# Setting final state to <ScriptState.DONE: 8>
# Read historical data in 0.00 sec
# Configure started
