# %% [markdown]
# # Logging and Reporting

# %% [markdown]
# ## Table of contents
# * [Parameters](#params)
# * [Imports and setup](#imports)
# * [Try every server](#every-server)
# * [Report](#report)

# %% [markdown]
# <a class="anchor" id="params"></a>
# ## Parameters
# The first code cell must contain parameters with string values for compatibility with Times Square.
#
# See: https://rsp.lsst.io/v/usdfdev/guides/times-square/index.html

# %%
#Parameters
env = 'usdf-dev'  # usdf-dev, tucson, slac, summit
record_limit = '9999'
response_timeout = '3.05'  # seconds, how long to wait for connection
read_timeout = '20'  # seconds

# %% [markdown]
# <a class="anchor" id="imports"></a>
# ## Imports and Setup

# %%
import requests
from collections import defaultdict
import pandas as pd
from pprint import pp

# %%
limit = int(record_limit)
timeout = (float(response_timeout), float(read_timeout))

# Env list comes from drop-down menu top of:
# https://rsp.lsst.io/v/usdfdev/guides/times-square/
envs = dict(
    #rubin_usdf_dev = '',
    #data_lsst_cloud = '',
    #usdf = '',
    #base_data_facility = '',
    summit = 'https://summit-lsp.lsst.codes',
    usdf_dev = 'https://usdf-rsp-dev.slac.stanford.edu',
    #rubin_idf_int = '',
    tucson = 'https://tucson-teststand.lsst.codes',
)
envs
# Out:
# {'summit': 'https://summit-lsp.lsst.codes',
#  'usdf_dev': 'https://usdf-rsp-dev.slac.stanford.edu',
#  'tucson': 'https://tucson-teststand.lsst.codes'}

# %% [markdown]
# <a class="anchor" id="every-server"></a>
# ## Try to access every Server, every Log in our list
# We call the combination of a specific Server and specific Log a "service".
# This is a First Look.  As such, we don't try to get a useful list of records.
# Instead, we save a few pieces of data from each service.  A more tailored web-service call should be done to get useful records.  For each service, we save:
# 1. The number of records retrieved
# 1. The list of fields found in a record (we assume all records from a service have the same fields)
# 1. An example of 1-2 records.
# 1. The [Facets](https://en.wikipedia.org/wiki/Faceted_search) of the service for all service fields that are not explictly excluded.

# %%
verbose=False
fields = defaultdict(set) # fields[(env,log)] = {field1, field2, ...}
examples = defaultdict(list) # examples[(env,log)] = [rec1, rec2]
results = defaultdict(dict) # results[(env,log)] = dict(server,url, ok, numfields, numrecs)
facets = defaultdict(dict) # facets[(env,log)] = dict(field) = set(value-1, value-2, ...)

# Dumb! Using same ignore set for all LOGS.
ignore_fields = set(['tags', 'urls', 'message_text', 'id', 'date_added', 
                     'obs_id', 'day_obs', 'seq_num', 'parent_id', 'user_id',
                     'date_invalidated', 'date_begin', 'date_end',
                     'time_lost', # float
                     #'systems','subsystems','cscs',  # values are lists, special handling
                    ])
for env,server in envs.items():
    ok = True
    try:
        recs = None
        log = 'exposurelog'
        #!url = f'{server}/{log}/messages?is_human=either&is_valid=either&offset=0&{limit=}'
        url = f'{server}/{log}/messages?is_human=either&is_valid=either&{limit=}'
        print(f'\nAttempt to get logs from {url=}')
        response = requests.get(url, timeout=timeout)
        response.raise_for_status()
        recs = response.json()
        flds = set(recs[0].keys())
        if verbose:
            print(f'Number of {log} records: {len(recs):,}')
            print(f'Got {log} fields: {flds}')
            print(f'Example record: {recs[0]}')    
        fields[(env,log)] = flds
        examples[(env,log)] = recs[:2]  

        facflds = flds - ignore_fields
        # Fails when r[fld] is a LIST instead of singleton
        # I think when that happens occasionaly, its a BUG in the data! It happens.
        facets[(env,log)] = {fld: set([str(r[fld])
                                       for r in recs if not isinstance(r[fld], list)]) 
                             for fld in facflds}
    except Exception as err:
        ok = False
        print(f'ERROR getting {log} from {env=} using {url=}: {err=}')
    numf = len(flds) if ok else 0
    numr = len(recs) if ok else 0
    results[(env,log)] = dict(ok=ok, server=server, url=url,numfields=numf, numrecs=numr)

    print()
    try:
        recs = None
        log = 'narrativelog'
        #! url = f'{server}/{log}/messages?is_human=either&is_valid=true&offset=0&{limit=}'
        url = f'{server}/{log}/messages?is_human=either&is_valid=either&{limit=}'
        print(f'\nAttempt to get logs from {url=}')
        response = requests.get(url, timeout=timeout)
        response.raise_for_status()
        recs = response.json()
        flds = set(recs[0].keys())
        if verbose:
            print(f'Number of {log} records: {len(recs):,}')
            print(f'Got {log} fields: {flds}')
            print(f'Example record: {recs[0]}')
        fields[(env,log)] = flds    
        examples[(env,log)] = recs[:2] 

        facflds = flds - ignore_fields
        # Fails when r[fld] is a LIST instead of singleton
        # I think when that happens occasionaly, its a BUG in the data! It happens.
        # Look for BAD facet values like: {'None', None}
        facets[(env,log)] = {fld: set([r[fld] 
                                       for r in recs if not isinstance(r[fld], list)]) 
                             for fld in facflds}
    except Exception as err:
        ok = False
        print(f'ERROR getting {log} from {env=} using {url=}: {err=}')
    numf = len(flds) if ok else 0
    numr = len(recs) if ok else 0
    results[(env,log)] = dict(ok=ok, server=server, url=url,numfields=numf, numrecs=numr)
# Out:
# Attempt to get logs from url='https://summit-lsp.lsst.codes/exposurelog/messages?is_human=either&is_valid=either&limit=9999'
#
#
# Attempt to get logs from url='https://summit-lsp.lsst.codes/narrativelog/messages?is_human=either&is_valid=either&limit=9999'
#
# Attempt to get logs from url='https://usdf-rsp-dev.slac.stanford.edu/exposurelog/messages?is_human=either&is_valid=either&limit=9999'
#
#
# Attempt to get logs from url='https://usdf-rsp-dev.slac.stanford.edu/narrativelog/messages?is_human=either&is_valid=either&limit=9999'
#
# Attempt to get logs from url='https://tucson-teststand.lsst.codes/exposurelog/messages?is_human=either&is_valid=either&limit=9999'
#
#
# Attempt to get logs from url='https://tucson-teststand.lsst.codes/narrativelog/messages?is_human=either&is_valid=either&limit=9999'

# %% [markdown]
# <a class="anchor" id="report"></a>
# ## Report
# This is a silly report that may be useful for developers. Not so much for astronomers.

# %% [markdown]
# <a class="anchor" id="ok_table"></a>
# ### Success/Failure table

# %%
show_columns = ['ok', 'server', 'numfields', 'numrecs']
df = pd.DataFrame(data=dict(results)).T.loc[:,show_columns]
print(f'Got results from {df["ok"].values.sum()} of {len(df)} env/logs')
df
# Out:
# Got results from 6 of 6 env/logs
#                          ok                                  server numfields  \
# summit   exposurelog   True           https://summit-lsp.lsst.codes        18
#          narrativelog  True           https://summit-lsp.lsst.codes        24
# usdf_dev exposurelog   True  https://usdf-rsp-dev.slac.stanford.edu        18
#          narrativelog  True  https://usdf-rsp-dev.slac.stanford.edu        24
# tucson   exposurelog   True     https://tucson-teststand.lsst.codes        18
#          narrativelog  True     https://tucson-teststand.lsst.codes        24
#
#                       numrecs
# summit   exposurelog     7895
#          narrativelog    7463
# usdf_dev exposurelog     7895
#          narrativelog    7463
# tucson   exposurelog       20
#          narrativelog      63

# %% [markdown]
# <a class="anchor" id="field_names"></a>
# ### Field Names

# %%
print('Field names for each Environment/Log source:')
for (env,log),flds in fields.items():
    field_names = ', '.join(flds)
    print(f'\n{env}/{log}: {field_names}')
#!dict(fields)
# Out:
# Field names for each Environment/Log source:
#
# summit/exposurelog: id, message_text, exposure_flag, level, user_id, parent_id, is_valid, instrument, obs_id, day_obs, site_id, urls, date_added, user_agent, date_invalidated, tags, is_human, seq_num
#
# summit/narrativelog: id, message_text, category, user_id, parent_id, subsystems, date_begin, primary_software_components, time_lost_type, is_valid, site_id, date_invalidated, tags, date_end, systems, components, time_lost, primary_hardware_components, urls, level, cscs, date_added, user_agent, is_human
#
# usdf_dev/exposurelog: id, message_text, exposure_flag, level, user_id, parent_id, is_valid, instrument, obs_id, day_obs, site_id, urls, date_added, user_agent, date_invalidated, tags, is_human, seq_num
#
# usdf_dev/narrativelog: id, message_text, category, user_id, parent_id, subsystems, date_begin, primary_software_components, time_lost_type, is_valid, site_id, date_invalidated, tags, date_end, systems, components, time_lost, primary_hardware_components, urls, level, cscs, date_added, user_agent, is_human
#
# tucson/exposurelog: id, message_text, exposure_flag, level, user_id, parent_id, is_valid, instrument, obs_id, day_obs, site_id, urls, date_added, user_agent, date_invalidated, tags, is_human, seq_num
#
# tucson/narrativelog: id, message_text, category, user_id, parent_id, subsystems, date_begin, primary_software_components, time_lost_type, is_valid, site_id, date_invalidated, tags, date_end, systems, components, time_lost, primary_hardware_components, urls, level, cscs, date_added, user_agent, is_human

# %% [markdown]
# <a class="anchor" id="facets"></a>
# ### Facets

# %%
dict(facets)
for (env,log),flds in facets.items():
    print(f'{env}/{log}:')
    for fld,vals in flds.items():
        print(f'  {fld}: \t{vals}')
# Out:
# summit/exposurelog:
#   exposure_flag: 	{'junk', 'questionable', 'none'}
#   level: 	{'10', '20'}
#   is_valid: 	{'False', 'True'}
#   instrument: 	{'LATISS', 'LSSTComCam'}
#   site_id: 	{'summit'}
#   user_agent: 	{'notebook:nublado', 'LOVE'}
#   is_human: 	{'True'}
# summit/narrativelog:
#   category: 	{'None', 'SCIENCE', 'ENG', None}
#   components: 	{None}
#   level: 	{0, 100}
#   cscs: 	{None}
#   is_human: 	{True}
#   time_lost_type: 	{'fault', 'weather', None}
#   primary_hardware_components: 	{None}
#   is_valid: 	{False, True}
#   site_id: 	{'summit'}
#   user_agent: 	{'string', 'LOVE'}
#   subsystems: 	{None}
#   primary_software_components: 	{None}
#   systems: 	{None}
# usdf_dev/exposurelog:
#   exposure_flag: 	{'junk', 'questionable', 'none'}
#   level: 	{'10', '20'}
#   is_valid: 	{'False', 'True'}
#   instrument: 	{'LATISS', 'LSSTComCam'}
#   site_id: 	{'summit'}
#   user_agent: 	{'notebook:nublado', 'LOVE'}
#   is_human: 	{'True'}
# usdf_dev/narrativelog:
#   category: 	{'None', 'SCIENCE', 'ENG', None}
#   components: 	{None}
#   level: 	{0, 100}
#   cscs: 	{None}
#   is_human: 	{True}
#   time_lost_type: 	{'fault', 'weather', None}
#   primary_hardware_components: 	{None}
#   is_valid: 	{False, True}
#   site_id: 	{'summit'}
#   user_agent: 	{'string', 'LOVE'}
#   subsystems: 	{None}
#   primary_software_components: 	{None}
#   systems: 	{None}
# tucson/exposurelog:
#   exposure_flag: 	{'junk', 'questionable', 'none'}
#   level: 	{'10'}
#   is_valid: 	{'False', 'True'}
#   instrument: 	{'LATISS', 'LSSTComCam'}
#   site_id: 	{'tucson'}
#   user_agent: 	{'LOVE'}
#   is_human: 	{'True'}
# tucson/narrativelog:
#   category: 	{'None', None}
#   components: 	{None}
#   level: 	{0, 100}
#   cscs: 	{None}
#   is_human: 	{True}
#   time_lost_type: 	{'fault', None}
#   primary_hardware_components: 	{None}
#   is_valid: 	{False, True}
#   site_id: 	{'tucson'}
#   user_agent: 	{'string', 'LOVE'}
#   subsystems: 	{None}
#   primary_software_components: 	{None}
#   systems: 	{None}

# %% [markdown]
# <a class="anchor" id="examples"></a>
# ### Example Records

# %%
for (env,log),recs in examples.items():
    print(f'\n{env=}, {log=}: ')
    print('  Example records: ')
    pp(recs)
# Out:
# env='summit', log='exposurelog':
#   Example records:
# [{'id': '0005ebfa-1832-4e53-bc7a-a69254deef88',
#   'site_id': 'summit',
#   'obs_id': 'AT_O_20230118_000113',
#   'instrument': 'LATISS',
#   'day_obs': 20230118,
#   'seq_num': 113,
#   'message_text': ' ',
#   'level': 20,
#   'tags': [],
#   'urls': [],
#   'user_id': 'dsanmartim',
#   'user_agent': 'notebook:nublado',
#   'is_human': True,
#   'is_valid': False,
#   'exposure_flag': 'junk',
#   'date_added': '2023-01-19T07:26:28.887152',
#   'date_invalidated': '2023-01-19T07:32:32.435376',
#   'parent_id': '18345e26-3c8c-4472-864f-68257ced64f4'},
#  {'id': '0007f3e6-ac70-4cf3-8edd-70d4a311aa4e',
#   'site_id': 'summit',
#   'obs_id': 'AT_O_20230118_000215',
#   'instrument': 'LATISS',
#   'day_obs': 20230118,
#   'seq_num': 215,
#   'message_text': '',
#   'level': 20,
#   'tags': [],
#   'urls': [],
#   'user_id': 'dsanmartim',
#   'user_agent': 'notebook:nublado',
#   'is_human': True,
#   'is_valid': False,
#   'exposure_flag': 'none',
#   'date_added': '2023-01-19T07:00:11.295541',
#   'date_invalidated': '2023-01-19T07:32:03.334049',
#   'parent_id': 'cde04ee9-01b3-4428-8e4a-09c5bb25a0e3'}]
#
# env='summit', log='narrativelog':
#   Example records:
# [{'id': '0005d0e0-6de7-4857-b658-cfca7147374a',
#   'site_id': 'summit',
#   'message_text': 'The moveShutterMainDoor command Fail\r\n'
#                   '\r\n'
#                   '\r\n'
#                   'we try the parameter with uppercase now\r\n'
#                   '\r\n'
#                   '\r\n'
#                   ' open: False\r\n'
#                   '\r\n'
#                   '\r\n'
#                   '\r\n'
#                   '\r\n'
#                   'Error in run\r\n'
#                   'Traceback (most recent call last):\r\n'
#                   '  File '
#                   '"/opt/lsst/software/stack/conda/envs/lsst-scipipe-8.0.0/lib/python3.11/asyncio/tasks.py", '
#                   'line 500, in wait_for\r\n'
#                   '    return fut.result()\r\n'
#                   '           ^^^^^^^^^^^^\r\n'
#                   '  File '
#                   '"/opt/lsst/software/stack/conda/envs/lsst-scipipe-8.0.0/lib/python3.11/site-packages/lsst/ts/salobj/topics/remote_command.py", '
#                   'line 239, in _get_next_ackcmd\r\n'
#                   '    await self._next_ack_event.wait()\r\n'
#                   '  File '
#                   '"/opt/lsst/software/stack/conda/envs/lsst-scipipe-8.0.0/lib/python3.11/asyncio/locks.py", '
#                   'line 213, in wait\r\n'
#                   '    await fut\r\n'
#                   'asyncio.exceptions.CancelledError\r\n'
#                   '\r\n'
#                   '\r\n'
#                   'The above exception was the direct cause of the following '
#                   'exception:\r\n'
#                   '\r\n'
#                   '\r\n'
#                   'Traceback (most recent call last):\r\n'
#                   '  File '
#                   '"/opt/lsst/software/stack/conda/envs/lsst-scipipe-8.0.0/lib/python3.11/site-packages/lsst/ts/salobj/topics/remote_command.py", '
#                   'line 189, in next_ackcmd\r\n'
#                   '    ackcmd = await self._wait_task\r\n'
#                   '             ^^^^^^^^^^^^^^^^^^^^^\r\n'
#                   '  File '
#                   '"/opt/lsst/software/stack/conda/envs/lsst-scipipe-8.0.0/lib/python3.11/site-packages/lsst/ts/salobj/topics/remote_command.py", '
#                   'line 214, in _basic_next_ackcmd\r\n'
#                   '    ackcmd = await asyncio.wait_for(\r\n'
#                   '             ^^^^^^^^^^^^^^^^^^^^^^^\r\n'
#                   '  File '
#                   '"/opt/lsst/software/stack/conda/envs/lsst-scipipe-8.0.0/lib/python3.11/asyncio/tasks.py", '
#                   'line 502, in wait_for\r\n'
#                   '    raise exceptions.TimeoutError() from exc\r\n'
#                   'TimeoutError\r\n'
#                   '\r\n'
#                   '\r\n'
#                   'During handling of the above exception, another exception '
#                   'occurred:\r\n'
#                   '\r\n'
#                   '\r\n'
#                   'Traceback (most recent call last):\r\n'
#                   '  File '
#                   '"/opt/lsst/software/stack/conda/envs/lsst-scipipe-8.0.0/lib/python3.11/site-packages/lsst/ts/salobj/base_script.py", '
#                   'line 603, in do_run\r\n'
#                   '    await self._run_task\r\n'
#                   '  File '
#                   '"/net/obs-env/auto_base_packages/ts_standardscripts/python/lsst/ts/standardscripts/run_command.py", '
#                   'line 170, in run\r\n'
#                   '    await getattr(self.remote, f"cmd_{self.cmd}").start(\r\n'
#                   '  File '
#                   '"/opt/lsst/software/stack/conda/envs/lsst-scipipe-8.0.0/lib/python3.11/site-packages/lsst/ts/salobj/topics/remote_command.py", '
#                   'line 487, in start\r\n'
#                   '    return await cmd_info.next_ackcmd(timeout=timeout)\r\n'
#                   '           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\r\n'
#                   '  File '
#                   '"/opt/lsst/software/stack/conda/envs/lsst-scipipe-8.0.0/lib/python3.11/site-packages/lsst/ts/salobj/topics/remote_command.py", '
#                   'line 205, in next_ackcmd\r\n'
#                   '    raise base.AckTimeoutError(\r\n'
#                   "lsst.ts.salobj.base.AckTimeoutError: msg='Timed out waiting "
#                   "for command acknowledgement', ackcmd=(ackcmd "
#                   'private_seqNum=1142844592, ack=&lt;SalRetCode.CMD_NOACK: '
#                   "-301&gt;, error=0, result='No command acknowledgement "
#                   "seen')\r\n",
#   'level': 0,
#   'tags': [],
#   'urls': [],
#   'time_lost': 0.0,
#   'date_begin': '2024-03-20T04:15:26.769000',
#   'user_id': 'cmorales@summit-lsp.lsst.codes',
#   'user_agent': 'LOVE',
#   'is_human': True,
#   'is_valid': True,
#   'date_added': '2024-03-20T04:16:06.976595',
#   'date_invalidated': None,
#   'parent_id': None,
#   'systems': None,
#   'subsystems': None,
#   'cscs': None,
#   'date_end': '2024-03-20T04:15:26.769000',
#   'components': ['AuxTel'],
#   'primary_software_components': ['None'],
#   'primary_hardware_components': ['None'],
#   'category': 'None',
#   'time_lost_type': 'fault'},
#  {'id': '00067b6a-1741-41f3-87af-57261dff30ac',
#   'site_id': 'summit',
#   'message_text': 'David updated environment. But no need to cycle Scheduler '
#                   '1. Waiting for completion of the current block. \r\n',
#   'level': 0,
#   'tags': [],
#   'urls': [],
#   'time_lost': 0.0,
#   'date_begin': '2024-04-24T20:53:41.843000',
#   'user_id': 'ykang@summit-lsp.lsst.codes',
#   'user_agent': 'LOVE',
#   'is_human': True,
#   'is_valid': True,
#   'date_added': '2024-04-24T20:54:19.346646',
#   'date_invalidated': None,
#   'parent_id': None,
#   'systems': None,
#   'subsystems': None,
#   'cscs': None,
#   'date_end': '2024-04-24T20:53:41.843000',
#   'components': ['MainTel'],
#   'primary_software_components': ['None'],
#   'primary_hardware_components': ['None'],
#   'category': 'None',
#   'time_lost_type': 'fault'}]
#
# env='usdf_dev', log='exposurelog':
#   Example records:
# [{'id': '0005ebfa-1832-4e53-bc7a-a69254deef88',
#   'site_id': 'summit',
#   'obs_id': 'AT_O_20230118_000113',
#   'instrument': 'LATISS',
#   'day_obs': 20230118,
#   'seq_num': 113,
#   'message_text': ' ',
#   'level': 20,
#   'tags': [],
#   'urls': [],
#   'user_id': 'dsanmartim',
#   'user_agent': 'notebook:nublado',
#   'is_human': True,
#   'is_valid': False,
#   'exposure_flag': 'junk',
#   'date_added': '2023-01-19T07:26:28.887152',
#   'date_invalidated': '2023-01-19T07:32:32.435376',
#   'parent_id': '18345e26-3c8c-4472-864f-68257ced64f4'},
#  {'id': '0007f3e6-ac70-4cf3-8edd-70d4a311aa4e',
#   'site_id': 'summit',
#   'obs_id': 'AT_O_20230118_000215',
#   'instrument': 'LATISS',
#   'day_obs': 20230118,
#   'seq_num': 215,
#   'message_text': '',
#   'level': 20,
#   'tags': [],
#   'urls': [],
#   'user_id': 'dsanmartim',
#   'user_agent': 'notebook:nublado',
#   'is_human': True,
#   'is_valid': False,
#   'exposure_flag': 'none',
#   'date_added': '2023-01-19T07:00:11.295541',
#   'date_invalidated': '2023-01-19T07:32:03.334049',
#   'parent_id': 'cde04ee9-01b3-4428-8e4a-09c5bb25a0e3'}]
#
# env='usdf_dev', log='narrativelog':
#   Example records:
# [{'id': '0005d0e0-6de7-4857-b658-cfca7147374a',
#   'site_id': 'summit',
#   'message_text': 'The moveShutterMainDoor command Fail\r\n'
#                   '\r\n'
#                   '\r\n'
#                   'we try the parameter with uppercase now\r\n'
#                   '\r\n'
#                   '\r\n'
#                   ' open: False\r\n'
#                   '\r\n'
#                   '\r\n'
#                   '\r\n'
#                   '\r\n'
#                   'Error in run\r\n'
#                   'Traceback (most recent call last):\r\n'
#                   '  File '
#                   '"/opt/lsst/software/stack/conda/envs/lsst-scipipe-8.0.0/lib/python3.11/asyncio/tasks.py", '
#                   'line 500, in wait_for\r\n'
#                   '    return fut.result()\r\n'
#                   '           ^^^^^^^^^^^^\r\n'
#                   '  File '
#                   '"/opt/lsst/software/stack/conda/envs/lsst-scipipe-8.0.0/lib/python3.11/site-packages/lsst/ts/salobj/topics/remote_command.py", '
#                   'line 239, in _get_next_ackcmd\r\n'
#                   '    await self._next_ack_event.wait()\r\n'
#                   '  File '
#                   '"/opt/lsst/software/stack/conda/envs/lsst-scipipe-8.0.0/lib/python3.11/asyncio/locks.py", '
#                   'line 213, in wait\r\n'
#                   '    await fut\r\n'
#                   'asyncio.exceptions.CancelledError\r\n'
#                   '\r\n'
#                   '\r\n'
#                   'The above exception was the direct cause of the following '
#                   'exception:\r\n'
#                   '\r\n'
#                   '\r\n'
#                   'Traceback (most recent call last):\r\n'
#                   '  File '
#                   '"/opt/lsst/software/stack/conda/envs/lsst-scipipe-8.0.0/lib/python3.11/site-packages/lsst/ts/salobj/topics/remote_command.py", '
#                   'line 189, in next_ackcmd\r\n'
#                   '    ackcmd = await self._wait_task\r\n'
#                   '             ^^^^^^^^^^^^^^^^^^^^^\r\n'
#                   '  File '
#                   '"/opt/lsst/software/stack/conda/envs/lsst-scipipe-8.0.0/lib/python3.11/site-packages/lsst/ts/salobj/topics/remote_command.py", '
#                   'line 214, in _basic_next_ackcmd\r\n'
#                   '    ackcmd = await asyncio.wait_for(\r\n'
#                   '             ^^^^^^^^^^^^^^^^^^^^^^^\r\n'
#                   '  File '
#                   '"/opt/lsst/software/stack/conda/envs/lsst-scipipe-8.0.0/lib/python3.11/asyncio/tasks.py", '
#                   'line 502, in wait_for\r\n'
#                   '    raise exceptions.TimeoutError() from exc\r\n'
#                   'TimeoutError\r\n'
#                   '\r\n'
#                   '\r\n'
#                   'During handling of the above exception, another exception '
#                   'occurred:\r\n'
#                   '\r\n'
#                   '\r\n'
#                   'Traceback (most recent call last):\r\n'
#                   '  File '
#                   '"/opt/lsst/software/stack/conda/envs/lsst-scipipe-8.0.0/lib/python3.11/site-packages/lsst/ts/salobj/base_script.py", '
#                   'line 603, in do_run\r\n'
#                   '    await self._run_task\r\n'
#                   '  File '
#                   '"/net/obs-env/auto_base_packages/ts_standardscripts/python/lsst/ts/standardscripts/run_command.py", '
#                   'line 170, in run\r\n'
#                   '    await getattr(self.remote, f"cmd_{self.cmd}").start(\r\n'
#                   '  File '
#                   '"/opt/lsst/software/stack/conda/envs/lsst-scipipe-8.0.0/lib/python3.11/site-packages/lsst/ts/salobj/topics/remote_command.py", '
#                   'line 487, in start\r\n'
#                   '    return await cmd_info.next_ackcmd(timeout=timeout)\r\n'
#                   '           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\r\n'
#                   '  File '
#                   '"/opt/lsst/software/stack/conda/envs/lsst-scipipe-8.0.0/lib/python3.11/site-packages/lsst/ts/salobj/topics/remote_command.py", '
#                   'line 205, in next_ackcmd\r\n'
#                   '    raise base.AckTimeoutError(\r\n'
#                   "lsst.ts.salobj.base.AckTimeoutError: msg='Timed out waiting "
#                   "for command acknowledgement', ackcmd=(ackcmd "
#                   'private_seqNum=1142844592, ack=&lt;SalRetCode.CMD_NOACK: '
#                   "-301&gt;, error=0, result='No command acknowledgement "
#                   "seen')\r\n",
#   'level': 0,
#   'tags': [],
#   'urls': [],
#   'time_lost': 0.0,
#   'date_begin': '2024-03-20T04:15:26.769000',
#   'user_id': 'cmorales@summit-lsp.lsst.codes',
#   'user_agent': 'LOVE',
#   'is_human': True,
#   'is_valid': True,
#   'date_added': '2024-03-20T04:16:06.976595',
#   'date_invalidated': None,
#   'parent_id': None,
#   'systems': None,
#   'subsystems': None,
#   'cscs': None,
#   'date_end': '2024-03-20T04:15:26.769000',
#   'components': ['AuxTel'],
#   'primary_software_components': ['None'],
#   'primary_hardware_components': ['None'],
#   'category': 'None',
#   'time_lost_type': 'fault'},
#  {'id': '00067b6a-1741-41f3-87af-57261dff30ac',
#   'site_id': 'summit',
#   'message_text': 'David updated environment. But no need to cycle Scheduler '
#                   '1. Waiting for completion of the current block. \r\n',
#   'level': 0,
#   'tags': [],
#   'urls': [],
#   'time_lost': 0.0,
#   'date_begin': '2024-04-24T20:53:41.843000',
#   'user_id': 'ykang@summit-lsp.lsst.codes',
#   'user_agent': 'LOVE',
#   'is_human': True,
#   'is_valid': True,
#   'date_added': '2024-04-24T20:54:19.346646',
#   'date_invalidated': None,
#   'parent_id': None,
#   'systems': None,
#   'subsystems': None,
#   'cscs': None,
#   'date_end': '2024-04-24T20:53:41.843000',
#   'components': ['MainTel'],
#   'primary_software_components': ['None'],
#   'primary_hardware_components': ['None'],
#   'category': 'None',
#   'time_lost_type': 'fault'}]
#
# env='tucson', log='exposurelog':
#   Example records:
# [{'id': '0076ce05-752f-46df-b8a5-90ffd51d612e',
#   'site_id': 'tucson',
#   'obs_id': 'AT_O_20221129_000001',
#   'instrument': 'LSSTComCam',
#   'day_obs': 20221129,
#   'seq_num': 1,
#   'message_text': 'this was a test image for LOVE LVV November test cycle',
#   'level': 10,
#   'tags': ['undefined'],
#   'urls': [],
#   'user_id': 'admin@love1.tu.lsst.org',
#   'user_agent': 'LOVE',
#   'is_human': True,
#   'is_valid': True,
#   'exposure_flag': 'junk',
#   'date_added': '2022-11-30T02:13:46.847038',
#   'date_invalidated': None,
#   'parent_id': None},
#  {'id': '1e61fbbe-cb87-45f2-88be-cb6647b0cd43',
#   'site_id': 'tucson',
#   'obs_id': 'AT_C_20230613_000001',
#   'instrument': 'LATISS',
#   'day_obs': 20230613,
#   'seq_num': 1,
#   'message_text': 'Exposure log creation test',
#   'level': 10,
#   'tags': ['undefined'],
#   'urls': [],
#   'user_id': 'admin@love1.tu.lsst.org',
#   'user_agent': 'LOVE',
#   'is_human': True,
#   'is_valid': False,
#   'exposure_flag': 'none',
#   'date_added': '2023-07-18T22:13:41.228510',
#   'date_invalidated': '2023-07-18T22:15:14.006037',
#   'parent_id': None}]
#
# env='tucson', log='narrativelog':
#   Example records:
# [{'id': '05b046b7-1266-47a9-b1de-93b6d44af242',
#   'site_id': 'tucson',
#   'message_text': '',
#   'level': 0,
#   'tags': [],
#   'urls': [],
#   'time_lost': 0.0,
#   'date_begin': '2023-01-19T22:50:03.167000',
#   'user_id': 'admin@love1.tu.lsst.org',
#   'user_agent': 'LOVE',
#   'is_human': True,
#   'is_valid': True,
#   'date_added': '2023-01-19T22:57:39.561293',
#   'date_invalidated': None,
#   'parent_id': None,
#   'systems': [],
#   'subsystems': [],
#   'cscs': [],
#   'date_end': '2023-01-19T22:50:03.167000',
#   'components': None,
#   'primary_software_components': None,
#   'primary_hardware_components': None,
#   'category': None,
#   'time_lost_type': None},
#  {'id': '0829537a-9cef-4f93-8566-7d66532e2184',
#   'site_id': 'tucson',
#   'message_text': 'Narrative log test',
#   'level': 0,
#   'tags': ['observatorysoftwaretools', 'love'],
#   'urls': [],
#   'time_lost': 24.0,
#   'date_begin': '2023-07-18T15:24:01.754000',
#   'user_id': 'admin@love1.tu.lsst.org',
#   'user_agent': 'LOVE',
#   'is_human': True,
#   'is_valid': True,
#   'date_added': '2023-07-19T15:28:22.027900',
#   'date_invalidated': None,
#   'parent_id': None,
#   'systems': ['ObservatorySoftwareTools'],
#   'subsystems': ['LOVE'],
#   'cscs': [],
#   'date_end': '2023-07-19T15:24:01.754000',
#   'components': None,
#   'primary_software_components': None,
#   'primary_hardware_components': None,
#   'category': None,
#   'time_lost_type': None}]
