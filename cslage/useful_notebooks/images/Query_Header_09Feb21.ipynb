# %% [markdown]
# ## Query header
#
# In this notebook, we show several ways to query the fits headers\
# Craig Lage - 13-Mar-21

# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as pf
from lsst.daf.persistence import Butler
import lsst.afw.cameraGeom.utils as camGeomUtils
import lsst.afw.display as afwDisplay

# %%
# Either of these should work
REPO_DIR = '/readonly/lsstdata/auxtel/base/auxtel/oods/butler/repo'
#REPO_DIR = '/project/shared/auxTel'
butler = Butler(REPO_DIR)
dayObs = '2021-03-11'

# %%
# This queries the header information in the butler metadata
# This is a limited amount of information, but returns very quickly
visits = butler.queryMetadata('raw', ['expId', 'EXPTIME', 'imagetype', 'object', 'filter', 'DATE'],\
                              detector=0, dayObs=dayObs)
for visit in visits:
    print(visit)

# %%
# This returns all of the information in the header, but takes longer
expId=2021031100119
exp = butler.get('raw', detector=0, expId=expId)
mData = exp.getMetadata()
for key in mData.keys():
    print(key, mData[key])
# Out:
# SIMPLE True
# EXTEND True
# COMMENT ---- Geometry from Camera ----
# ORIGIN LSST DM Header Service
# TIMESYS TAI
# DATE 2021-03-11T23:54:11.982
# DATE-OBS 2021-03-11T23:54:36.114
# DATE-BEG 2021-03-11T23:54:36.114
# DATE-END 2021-03-11T23:54:46.353
# MJD 59284.9959720147
# MJD-OBS 59284.9962513161
# MJD-BEG 59284.9962513161
# MJD-END 59284.9963698209
# OBSID AT_O_20210311_000119
# GROUPID 2021-03-11T23:54:35.819
# IMGTYPE OBJECT
# BUNIT adu
# FACILITY Vera C. Rubin Observatory
# TELESCOP LSST AuxTelescope
# INSTRUME LATISS
# OBSERVER LSST
# OBS-LONG -70.749417
# OBS-LAT -30.244639
# OBS-ELEV 2663.0
# OBSGEO-X 1818938.94
# OBSGEO-Y -5208470.95
# OBSGEO-Z -3195172.08
# RA 127.987259583333
# DEC -39.0662630555556
# RASTART 128.44970351331168
# DECSTART -39.0666175411298
# RAEND 128.44969436821566
# DECEND -39.0666256371882
# ROTPA -13.456224827899
# ROTCOORD sky
# HASTART -2.03890349216909
# ELSTART 63.5344397111767
# AZSTART 117.816880275001
# AMSTART 1.11676278292271
# HAEND -2.03527486418109
# ELEND 63.575892804467
# AZEND 117.833515335311
# AMEND 1.11636121894984
# INSTPORT 2
# ATM3PORT None
# TRACKSYS SIDEREAL
# RADESYS ICRS
# FOCUSZ -0.200000002980232
# OBJECT HD72514
# DOMEAZ 118.76
# SHUTLOWR 0.0
# SHUTUPPR 100.0
# WCSAXES 2
# CTYPE1 RA---TAN
# CTYPE2 DEC--TAN
# CUNIT1 deg
# CUNIT2 deg
# CRVAL1 127.987259583333
# CRVAL2 -39.0662630555556
# CRPIX1 2000.0
# CRPIX2 2036.0
# CD1_1 0.0661001571745198
# CD1_2 0.0815828978493886
# CD2_1 -0.0815828978493886
# CD2_2 0.0661001571745198
# EQUINOX 2000.0
# CAMCODE AT
# CONTRLLR O
# DAYOBS 20210311
# SEQNUM 119
# TESTTYPE None
# TSTAND None
# IMAGETAG 81526c544127d720
# OBSANNOT
# TEMP_SET -94.1500015258789
# CCDTEMP -89.943473815918
# FILTBAND Empty
# FILTER RG610
# FILTSLOT 3
# GRATING empty_1
# GRATBAND Empty
# GRATSLOT 0
# LINSPOS 59.9980010986328
# EXPTIME 10.0
# SHUTTIME None
# DARKTIME 10.3300302028656
# AIRTEMP 11.8
# PRESSURE 742.55
# HUMIDITY 60.0
# WINDSPD 1.3
# WINDDIR 234.0
# SEEING 0.608921825885773
# FILENAME AT_O_20210311_000119.fits
# HEADVER 2.8.1
# CHECKSUM None
# DATASUM None
# CCD_MANU ITL
# CCD_TYPE 2
# CCD_SERN 20862
# LSST_NUM ITL-3800C-068
# SEQCKSUM 2552520002
# SEQNAME FP_ITL_2s_ir2_v25.seq
# REBNAME Unknown
# CONTNUM 412227310
# CCDSLOT S00
# RAFTBAY R00
# OVERH 64
# OVERV 48
# PREH 0
# XTENSION IMAGE
# BITPIX 32
# NAXIS 2
# NAXIS1 576
# NAXIS2 2048
# PCOUNT 0
# GCOUNT 1
# INHERIT True
# EXTNAME Segment10
# DATASEC [1:509,1:2000]
# DETSEC [509:1,1:2000]
# DETSIZE [1:4072,1:4000]
# DTV1 510
# DTV2 0
# DTM1_1 -1.0
# DTM2_2 1.0
# DTM1_2 0
# DTM2_1 0

# %%
# This way goes directly to the fits files without using the butler
import glob
files = glob.glob(REPO_DIR+'/_parent/raw/2021-03-11/*')
print(len(files))
hduList = pf.open(files[184])
hdr = hduList[0].header
for key in hdr.keys():
    print(key, hdr[key])
