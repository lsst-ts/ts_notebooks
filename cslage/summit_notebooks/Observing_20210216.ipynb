# %%
import sys
import asyncio
import time
import os

import numpy as np

from lsst.ts import salobj

from lsst.ts.observatory.control.auxtel.atcs import ATCS
from lsst.ts.observatory.control.auxtel.latiss import LATISS

# %%
# Observing 16-Feb-21

# %%
# for tab completion to work in current notebook instance
# %config IPCompleter.use_jedi = False

# %%
import logging
stream_handler = logging.StreamHandler(sys.stdout)
logger = logging.getLogger()
logger.addHandler(stream_handler)
logger.level = logging.DEBUG
# Make matplotlib less chatty
logging.getLogger("matplotlib").setLevel(logging.WARNING)

# %%
#Start classes
domain = salobj.Domain()
await asyncio.sleep(10) # This can be removed in the future...
atcs = ATCS(domain)
latiss = LATISS(domain)
await asyncio.gather(atcs.start_task, latiss.start_task)
# Out:
# atmcs: Adding all resources.
# atptg: Adding all resources.
# ataos: Adding all resources.
# atpneumatics: Adding all resources.
# athexapod: Adding all resources.
# atdome: Adding all resources.
# atdometrajectory: Adding all resources.
# atcamera: Adding all resources.
# atspectrograph: Adding all resources.
# atheaderservice: Adding all resources.
# atarchiver: Adding all resources.
# Read historical data in 0.01 sec
# Read 17 history items for RemoteEvent(ATHexapod, 0, appliedSettingsMatchStart)
# Read 1 history items for RemoteEvent(ATHexapod, 0, authList)
# Read 100 history items for RemoteEvent(ATHexapod, 0, detailedState)
# Read 1 history items for RemoteEvent(ATHexapod, 0, errorCode)
# Read 100 history items for RemoteEvent(ATHexapod, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATHexapod, 0, inPosition)
# Read 1 history items for RemoteEvent(ATHexapod, 0, logLevel)
# Read 67 history items for RemoteEvent(ATHexapod, 0, logMessage)
# ...

# %%
#                               "filter_sequence": ['RG610','empty_1', 'RG610', 'quadnotch1',
#                                                    'BG40','RG610'], 
#                                    # RG610 and Ronchi
#                                "grating_sequence": ['empty_1', 'ronchi90lpmm','ronchi90lpmm','ronchi90lpmm',
#                                                     'empty_1','empty_1'],

# %%
await latiss.take_object(20.0, 1, filter='RG610', grating='empty_1')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021021600172])

# %%
await latiss.take_object(2.0, 1, filter='RG610', grating='empty_1')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021021600173])

# %%
await latiss.take_object(20.0, 1, filter='empty_1', grating='ronchi90lpmm')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021021600174])

# %%
await latiss.take_object(20.0, 1, filter='RG610', grating='ronchi90lpmm')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021021600175])

# %%
await latiss.take_object(20.0, 1, filter='quadnotch1', grating='ronchi90lpmm')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021021600176])

# %%
await latiss.take_object(2.0, 1, filter='BG40', grating='empty_1')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021021600177])

# %%
await latiss.take_object(20.0, 1, filter='RG610', grating='empty_1')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021021600178])

# %%
await latiss.take_object(2.0, 1, filter='RG610', grating='empty_1')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021021600179])

# %%
await atcs.offset_xy(x=0,y=-500)
# Out:
# Calculating x/y offset: 0/-500
# Applying Az/El offset: -304.76046170792574/-396.3849908606176
# Telescope not in position.
# Timed out waiting for offset done events.
# Waiting for telescope to settle.
# Done

# %%
await latiss.take_object(2.0, 1, filter='RG610', grating='holo4_003')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021021600180])

# %%
await latiss.take_object(90.0, 1, filter='RG610', grating='holo4_003')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021021600181])

# %%
await atcs.offset_xy(x=0,y=0)
# Out:
# Calculating x/y offset: 0/0
# Applying Az/El offset: 0.0/0.0
# Telescope not in position.
# All axes in position.
# Waiting for telescope to settle.
# Done

# %%
await atcs.rem.ataos.cmd_enableCorrection.set_start(
                m1=True, hexapod=True, atspectrograph=True, timeout=atcs.long_timeout)

# %%
await latiss.take_object(2.0, 1, filter='empty_1', grating='empty_1')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021021600195])

# %%
await latiss.take_object(20.0, 1, filter='empty_1', grating='ronchi90lpmm')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021021600196])
# logMessage DDS read queue is filling: 12 of 100 elements

# %%
await latiss.take_object(20.0, 1, filter='empty_1', grating='ronchi90lpmm')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021021600184])
# logMessage DDS read queue is filling: 16 of 100 elements

# %%
await latiss.take_object(2.0, 1, filter='empty_1', grating='empty_1')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021021600188])

# %%
await latiss.take_object(2.0, 1, filter='empty_1', grating='empty_1')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021021600189])
# logMessage DDS read queue is filling: 12 of 100 elements
# logMessage DDS read queue is filling: 16 of 100 elements

# %%
await latiss.take_object(2.0, 1, filter='empty_1', grating='empty_1')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021021600190])

# %%
await latiss.take_object(20.0, 1, filter='empty_1', grating='ronchi90lpmm')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021021600191])

# %%
await latiss.take_object(2.0, 1, filter='empty_1', grating='empty_1')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021021600192])

# %%
await latiss.take_object(20.0, 1, filter='empty_1', grating='ronchi90lpmm')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021021600193])

# %%
await latiss.take_object(20.0, 1, filter='empty_1', grating='ronchi90lpmm')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021021600194])

# %%
await atcs.slew_object('HD 50896')
# Out:
# Starting new HTTP connection (1): simbad.u-strasbg.fr:80
# http://simbad.u-strasbg.fr:80 "POST /simbad/sim-script HTTP/1.1" 200 None
# Slewing to HD 50896: 06 54 13.0440 -23 55 42.020
# logMessage DDS read queue is filling: 10 of 100 elements
# logMessage DDS read queue is filling: 14 of 100 elements
# Auto sky angle: 0.0 deg
# Sending command
# Stop tracking.
# mount_AzEl_Encoders python read queue is filling: 19 of 100 elements
# Unknown tracking state: 10
# logMessage DDS read queue is filling: 11 of 100 elements
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# atdome: <State.ENABLED: 2>
# atdometrajectory: <State.ENABLED: 2>
# [Telescope] delta Alt = +000.225 deg; delta Az = -004.320 deg; delta N1 = +000.000 deg; delta N2 = +028.817 deg [Dome] delta Az = -000.243 deg
# ATDome in position.
# ...

# %%
await latiss.setup_instrument(filter='empty_1', grating='empty_1')

# %%
await latiss.take_object(2.0, 1, filter='empty_1', grating='empty_1')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021021600199])

# %%
await latiss.setup_instrument(filter='empty_1', grating='ronchi90lpmm')

# %%
await latiss.take_object(20.0, 1, filter='empty_1', grating='ronchi90lpmm')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021021600201])

# %%
await latiss.setup_instrument(filter='empty_1', grating='empty_1')

# %%
await latiss.take_object(2.0, 1, filter='empty_1', grating='empty_1')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021021600202])

# %%
await latiss.setup_instrument(filter='empty_1', grating='ronchi90lpmm')

# %%
await latiss.take_object(20.0, 1, filter='empty_1', grating='ronchi90lpmm')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021021600203])
# logMessage DDS read queue is filling: 10 of 100 elements

# %%
await latiss.setup_instrument(filter='empty_1', grating='empty_1')

# %%
await latiss.take_object(2.0, 1, filter='empty_1', grating='empty_1')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021021600204])

# %%
await latiss.setup_instrument(filter='empty_1', grating='ronchi90lpmm')

# %%
await latiss.take_object(20.0, 1, filter='empty_1', grating='ronchi90lpmm')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021021600205])

# %%
await atcs.offset_xy(x=0,y=180)
# Out:
# Calculating x/y offset: 0/180
# Applying Az/El offset: 168.30453617032208/63.82462772702046
# Telescope not in position.
# All axes in position.
# Waiting for telescope to settle.
# Done

# %%
await latiss.setup_instrument(filter='empty_1', grating='empty_1')

# %%
await latiss.take_object(2.0, 1, filter='empty_1', grating='empty_1')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021021600208])

# %%
await latiss.setup_instrument(filter='empty_1', grating='holo4_003')

# %%
await latiss.take_object(90.0, 1, filter='empty_1', grating='holo4_003')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021021600209])
# logMessage DDS read queue is filling: 10 of 100 elements
# target DDS read queue is filling: 41 of 100 elements
# target python read queue is filling: 40 of 100 elements
# target python read queue is filling: 36 of 100 elements
# logMessage DDS read queue is filling: 10 of 100 elements
# logMessage DDS read queue is filling: 13 of 100 elements
# logMessage DDS read queue is filling: 10 of 100 elements
# logMessage DDS read queue is filling: 10 of 100 elements
# logMessage DDS read queue is filling: 10 of 100 elements

# %%
await latiss.setup_instrument(filter='RG610', grating='ronchi90lpmm')

# %%
await atcs.offset_xy(x=0,y=60)
# Out:
# Calculating x/y offset: 0/60
# Applying Az/El offset: -55.493674772534405/22.81341842513258
# Telescope not in position.
# All axes in position.
# Waiting for telescope to settle.
# Done

# %%
await latiss.take_object(30.0, 5, filter='RG610', grating='ronchi90lpmm')
# Out:
# Generating group_id
# OBJECT 0001 - 0005
# OBJECT 0002 - 0005
# OBJECT 0003 - 0005
# OBJECT 0004 - 0005
# OBJECT 0005 - 0005
# logMessage DDS read queue is filling: 10 of 100 elements
# array([2021021600245, 2021021600246, 2021021600247, 2021021600248,
#        2021021600249])

# %%
await latiss.setup_instrument(filter='empty_1', grating='empty_1')
# Out:
# target DDS read queue is filling: 10 of 100 elements
# target DDS read queue is filling: 78 of 100 elements
# target python read queue is filling: 77 of 100 elements
# target DDS read queue is filling: 17 of 100 elements
# target python read queue is filling: 16 of 100 elements
# target DDS read queue is filling: 58 of 100 elements
# target python read queue is filling: 57 of 100 elements
# target DDS read queue is filling: 23 of 100 elements
# target python read queue is filling: 22 of 100 elements
# target DDS read queue is filling: 61 of 100 elements
# target python read queue is filling: 60 of 100 elements
# target DDS read queue is filling: 79 of 100 elements
# target python read queue is filling: 78 of 100 elements
# target python read queue is filling: 12 of 100 elements
# target DDS read queue is filling: 52 of 100 elements
# target python read queue is filling: 51 of 100 elements

# %%
await atcs.open_m1_vent()

# %%
await atcs.enable()

# %%
await atcs.rem.ataos.cmd_enableCorrection.set_start(
                m1=True, hexapod=True, atspectrograph=True, timeout=atcs.long_timeout)

# %%
await latiss.take_flats(1.0, 1, filter='empty_1', grating='holo4_003')

# %%
await latiss.take_flats(20.0, 1, filter='empty_1', grating='holo4_003')

# %%
await latiss.take_flats(20.0, 1, filter='empty_1', grating='holo4_003')

# %%
# Ensure we're using Nasmyth 2
await atcs.rem.atptg.cmd_focusName.set_start(focus=3)

# %%
# Disable the dome
await salobj.set_summary_state(atcs.rem.atdome, salobj.State.DISABLED, settingsToApply="test")
await salobj.set_summary_state(atcs.rem.atdometrajectory, salobj.State.DISABLED)

# %%
# Take event checking out the slew commands to test telescope only
atcs.check.atdome = False
atcs.check.atdometrajectory = False

# %%
# Run 1 bias as a test
await latiss.take_bias(1)

# %%
# Move telescope to park position (az=0, el=80, rot=0)
current_az = 0.0
current_el = 80.0
current_rot = 0.0
await atcs.point_azel(current_az, current_el, rot_tel=current_rot)

# %%
# Move telescope to (az=180, el=80, rot=0). More convenient positioning for photos
current_az = 180.0
current_el = 80.0
current_rot = 0.0
await atcs.point_azel(current_az, current_el, rot_tel=current_rot)

# %%
# Move the rot to one end of the travel
current_rot = 150.0
await atcs.point_azel(current_az, current_el, rot_tel=current_rot)

# %%
# Move the rot to other end of the travel
current_rot = -150.0
await atcs.point_azel(current_az, current_el, rot_tel=current_rot)

# %%
# Move the rot to other end of the travel
current_rot = 0.0
await atcs.point_azel(current_az, current_el, rot_tel=current_rot)

# %%
# Now run 50 biases, with 2 second delay. Images 2-51
for i in range(50):
    await atcs.point_azel(current_az, current_el, rot_tel=current_rot)
    await asyncio.sleep(2)
    await latiss.take_bias(1)

# %%
# Move the rot to +150
current_rot = 150.0
await atcs.point_azel(current_az, current_el, rot_tel=current_rot)

# %%
# Now run 50 biases, with 2 sec delay between telescope rot changes
# but moving through the whole range.  There was some indication in the on-sky tests
# that negative rot angles were worse.
# Images 52-101
current_rot = 150.0
for i in range(50):
    final_delay = 2.0
    current_rot -= 6.0
    await atcs.point_azel(current_az, current_el, rot_tel=current_rot)
    await asyncio.sleep(final_delay)
    await latiss.take_bias(1)

# %%
# Move the rot to 0
current_rot = 0.0
await atcs.point_azel(current_az, current_el, rot_tel=current_rot)

# %%
# Re-enable the dome
# take event checking out the slew commands to test telescope only
# otherwise it'll wait for the dome before completing slew command
atcs.check.atdome = True
atcs.check.atdometrajectory = True

# %%
await salobj.set_summary_state(atcs.rem.atdome, salobj.State.ENABLED, settingsToApply="test")

# %%
await salobj.set_summary_state(atcs.rem.atdometrajectory, salobj.State.ENABLED)

# %%
await atcs.prepare_for_flatfield()

# %%
await latiss.take_flats(2.0, 10, filter='RG610', grating='empty_1')

# %%
for i in range(20):
    exp = 0.2 * float(i+1)
    await latiss.take_flats(exp, 2, filter='empty_1', grating='empty_1')

# %%
# Putting everything back in standby.
await atcs.shutdown()

# %%
# take event checking out the slew commands to test telescope only
# otherwise it'll wait for the dome before completing slew command
atcs.check.atdome = False
atcs.check.atdometrajectory = False

# %%
await atcs.rem.atdome.cmd_start.set_start(settingsToApply="test", timeout=30)

# %%
await salobj.set_summary_state(atcs.rem.atdome, salobj.State.STANDBY, settingsToApply="test")

# %%
await salobj.set_summary_state(atcs.rem.atdometrajectory, salobj.State.STANDBY)

# %%
await salobj.set_summary_state(latiss.rem.atspectrograph, salobj.State.STANDBY)
await salobj.set_summary_state(latiss.rem.atcamera, salobj.State.STANDBY)
await salobj.set_summary_state(latiss.rem.atheaderservice, salobj.State.STANDBY)
await salobj.set_summary_state(latiss.rem.atarchiver, salobj.State.STANDBY)
