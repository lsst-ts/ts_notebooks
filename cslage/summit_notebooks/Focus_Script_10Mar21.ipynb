# %%
import sys
import asyncio
import time
import os

import numpy as np
import matplotlib.pyplot as plt

from lsst.rapid.analysis.focusAnalysis import NonSpectralFocusAnalyzer

# %%
repoDir = '/project/shared/auxTel/rerun/quickLook/'
analyzer = NonSpectralFocusAnalyzer(repoDir)
# %matplotlib inline
dayObs = '2021-03-11'
seqNums = [s for s in range(115, 127+1)]
offset = analyzer.run(dayObs, seqNums)
# Out:
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210311_000115: 'MJD-OBS not found'
# Centroid adjusted by [-7  5] pixels
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210311_000115: 'MJD-OBS not found'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210311_000116: 'MJD-OBS not found'
# Centroid adjusted by [1 2] pixels
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210311_000116: 'MJD-OBS not found'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210311_000117: 'MJD-OBS not found'
# Centroid adjusted by [ 2 -5] pixels
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210311_000117: 'MJD-OBS not found'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210311_000118: 'MJD-OBS not found'
# Centroid adjusted by [-2  1] pixels
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210311_000118: 'MJD-OBS not found'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210311_000119: 'MJD-OBS not found'
# Centroid adjusted by [4 2] pixels
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210311_000119: 'MJD-OBS not found'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210311_000120: 'MJD-OBS not found'
# Centroid adjusted by [-1  2] pixels
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210311_000120: 'MJD-OBS not found'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210311_000121: 'MJD-OBS not found'
# Centroid adjusted by [0 1] pixels
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210311_000121: 'MJD-OBS not found'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210311_000122: 'MJD-OBS not found'
# Centroid adjusted by [-5 -5] pixels
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210311_000122: 'MJD-OBS not found'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210311_000123: 'MJD-OBS not found'
# Centroid adjusted by [-5  6] pixels
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210311_000123: 'MJD-OBS not found'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210311_000124: 'MJD-OBS not found'
# Centroid adjusted by [4 1] pixels
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210311_000124: 'MJD-OBS not found'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210311_000125: 'MJD-OBS not found'
# Centroid adjusted by [-4 -9] pixels
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210311_000125: 'MJD-OBS not found'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210311_000126: 'MJD-OBS not found'
# Centroid adjusted by [  6 -20] pixels
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210311_000126: 'MJD-OBS not found'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210311_000127: 'MJD-OBS not found'
# Centroid adjusted by [ -2 -14] pixels
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210311_000127: 'MJD-OBS not found'

# %%
from lsst.rapid.analysis.focusAnalysis import SpectralFocusAnalyzer
repoDir = '/project/shared/auxTel/'
analyzer = SpectralFocusAnalyzer(repoDir)
# %matplotlib inline
dayObs = '2021-03-11'
seqNums = [156,157,158,161,162,163,164]#range(156, 164+1)
analyzer._spectrumBoxOffsets = [1000, 1200, 1400]
analyzer.spectrumHalfWidth = 150
bestFit = analyzer.run(dayObs, seqNums, doDisplay=True)
# Out:
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210311_000156: 'MJD-OBS not found'
# /home/craiglagegit/auto-op-env-packages/rapid_analysis/python/lsst/rapid/analysis/focusAnalysis.py:125: FutureWarning: Call to deprecated method getFilter. (Replaced by getFilterLabel. Will be removed after v22.) -- Deprecated since version v22.0.
#   filt = exp.getFilter().getName()
# /home/craiglagegit/auto-op-env-packages/rapid_analysis/python/lsst/rapid/analysis/focusAnalysis.py:145: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   circle = Circle(centroid, radius=25, facecolor='none', color='red')
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210311_000157: 'MJD-OBS not found'
# /home/craiglagegit/auto-op-env-packages/rapid_analysis/python/lsst/rapid/analysis/focusAnalysis.py:125: FutureWarning: Call to deprecated method getFilter. (Replaced by getFilterLabel. Will be removed after v22.) -- Deprecated since version v22.0.
#   filt = exp.getFilter().getName()
# /home/craiglagegit/auto-op-env-packages/rapid_analysis/python/lsst/rapid/analysis/focusAnalysis.py:145: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   circle = Circle(centroid, radius=25, facecolor='none', color='red')
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210311_000158: 'MJD-OBS not found'
# /home/craiglagegit/auto-op-env-packages/rapid_analysis/python/lsst/rapid/analysis/focusAnalysis.py:125: FutureWarning: Call to deprecated method getFilter. (Replaced by getFilterLabel. Will be removed after v22.) -- Deprecated since version v22.0.
#   filt = exp.getFilter().getName()
# /home/craiglagegit/auto-op-env-packages/rapid_analysis/python/lsst/rapid/analysis/focusAnalysis.py:145: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   circle = Circle(centroid, radius=25, facecolor='none', color='red')
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210311_000161: 'MJD-OBS not found'
# /home/craiglagegit/auto-op-env-packages/rapid_analysis/python/lsst/rapid/analysis/focusAnalysis.py:125: FutureWarning: Call to deprecated method getFilter. (Replaced by getFilterLabel. Will be removed after v22.) -- Deprecated since version v22.0.
#   filt = exp.getFilter().getName()
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-4-bd696a54642c> in <module>
#       7 analyzer._spectrumBoxOffsets = [1000, 1200, 1400]
#       8 analyzer.spectrumHalfWidth = 150
# ----> 9 bestFit = analyzer.run(dayObs, seqNums, doDisplay=True)
#
# ~/auto-op-env-packages/rapid_analysis/python/lsst/rapid/analysis/focusAnalysis.py in run(self, dayObs, seqNums, doDisplay, hideFit)
#     106
#     107     def run(self, dayObs, seqNums, doDisplay=False, hideFit=False):
# --> 108         self.getFocusData(dayObs, seqNums, doDisplay=doDisplay)
#     109         bestFits = self.fitDataAndPlot(hideFit=hideFit)
#     110         return bestFits
#
# ~/auto-op-env-packages/rapid_analysis/python/lsst/rapid/analysis/focusAnalysis.py in getFocusData(self, dayObs, seqNums, doDisplay)
#     128             filters.add(filt)
#     129             assert isExpDispersed(exp), f"Image is not dispersed! (filter = {filt})"
# --> 130             assert len(filters) == 1, "You accidentally mixed filters!"
#     131             assert len(objects) == 1, "You accidentally mixed objects!"
#     132
#
# AssertionError: You accidentally mixed filters!
