# %%
import sys
import asyncio
import time
import os

import numpy as np

from lsst.ts import salobj

from lsst.ts.observatory.control.auxtel.atcs import ATCS
from lsst.ts.observatory.control.auxtel.latiss import LATISS
from lsst.ts.observatory.control.utils import RotType
# Out:
# /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/jose/backends/cryptography_backend.py:23: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes, int_to_bytes

# %%
# for tab completion to work in current notebook instance
# %config IPCompleter.use_jedi = False

# %%
# !eups list -s lsst_distrib
# Out:
#    21.0.0-1-g00ce914+aad3ba2940 	current w_2021_10 setup

# %%
import logging
stream_handler = logging.StreamHandler(sys.stdout)
logger = logging.getLogger()
logger.addHandler(stream_handler)
logger.level = logging.DEBUG
# Make matplotlib less chatty
logging.getLogger("matplotlib").setLevel(logging.WARNING)

# %%
#Start classes
domain = salobj.Domain()
await asyncio.sleep(10) # This can be removed in the future...
atcs = ATCS(domain)
latiss = LATISS(domain)
await asyncio.gather(atcs.start_task, latiss.start_task)
# Out:
# atmcs: Adding all resources.
# atptg: Adding all resources.
# ataos: Adding all resources.
# atpneumatics: Adding all resources.
# athexapod: Adding all resources.
# atdome: Adding all resources.
# atdometrajectory: Adding all resources.
# atcamera: Adding all resources.
# atspectrograph: Adding all resources.
# atheaderservice: Adding all resources.
# atarchiver: Adding all resources.
# Read historical data in 0.05 sec
# Read 1 history items for RemoteEvent(ATHeaderService, 0, authList)
# Read 100 history items for RemoteEvent(ATHeaderService, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATHeaderService, 0, largeFileObjectAvailable)
# Read 1 history items for RemoteEvent(ATHeaderService, 0, logLevel)
# Read 100 history items for RemoteEvent(ATHeaderService, 0, logMessage)
# Read 1 history items for RemoteEvent(ATHeaderService, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATHeaderService, 0, softwareVersions)
# Read 61 history items for RemoteEvent(ATHeaderService, 0, summaryState)
# Read historical data in 0.12 sec
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, algorithm)
# Read 34 history items for RemoteEvent(ATDomeTrajectory, 0, appliedSettingsMatchStart)
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, authList)
# Read 100 history items for RemoteEvent(ATDomeTrajectory, 0, heartbeat)
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, logLevel)
# Read 100 history items for RemoteEvent(ATDomeTrajectory, 0, logMessage)
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, settingVersions)
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, settingsApplied)
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, softwareVersions)
# Read 100 history items for RemoteEvent(ATDomeTrajectory, 0, summaryState)
# Read historical data in 0.15 sec
# Read 32 history items for RemoteEvent(ATHexapod, 0, appliedSettingsMatchStart)
# Read 1 history items for RemoteEvent(ATHexapod, 0, authList)
# Read 100 history items for RemoteEvent(ATHexapod, 0, detailedState)
# Read 1 history items for RemoteEvent(ATHexapod, 0, errorCode)
# Read 100 history items for RemoteEvent(ATHexapod, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATHexapod, 0, inPosition)
# Read 1 history items for RemoteEvent(ATHexapod, 0, logLevel)
# Read 100 history items for RemoteEvent(ATHexapod, 0, logMessage)
# Read 100 history items for RemoteEvent(ATHexapod, 0, positionUpdate)
# Read 1 history items for RemoteEvent(ATHexapod, 0, readyForCommand)
# Read 1 history items for RemoteEvent(ATHexapod, 0, settingVersions)
# Read 1 history items for RemoteEvent(ATHexapod, 0, settingsApplied)
# Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedPivot)
# Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedPositionLimits)
# Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedTcp)
# Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedVelocities)
# Read 1 history items for RemoteEvent(ATHexapod, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATHexapod, 0, softwareVersions)
# Read 100 history items for RemoteEvent(ATHexapod, 0, summaryState)
# Read historical data in 0.20 sec
# Read 30 history items for RemoteEvent(ATSpectrograph, 0, appliedSettingsMatchStart)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, authList)
# Read 100 history items for RemoteEvent(ATSpectrograph, 0, disperserInPosition)
# Read 2 history items for RemoteEvent(ATSpectrograph, 0, errorCode)
# Read 100 history items for RemoteEvent(ATSpectrograph, 0, filterInPosition)
# Read 100 history items for RemoteEvent(ATSpectrograph, 0, fwState)
# Read 100 history items for RemoteEvent(ATSpectrograph, 0, gwState)
# Read 100 history items for RemoteEvent(ATSpectrograph, 0, heartbeat)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, logLevel)
# Read 20 history items for RemoteEvent(ATSpectrograph, 0, logMessage)
# Read 100 history items for RemoteEvent(ATSpectrograph, 0, reportedDisperserPosition)
# Read 100 history items for RemoteEvent(ATSpectrograph, 0, reportedFilterPosition)
# Read 2 history items for RemoteEvent(ATSpectrograph, 0, reportedLinearStagePosition)
# Read 6 history items for RemoteEvent(ATSpectrograph, 0, settingVersions)
# Read 8 history items for RemoteEvent(ATSpectrograph, 0, settingsApplied)
# Read 10 history items for RemoteEvent(ATSpectrograph, 0, settingsAppliedValues)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, softwareVersions)
# Read 100 history items for RemoteEvent(ATSpectrograph, 0, summaryState)
# Read historical data in 0.25 sec
# Read 39 history items for RemoteEvent(ATPneumatics, 0, appliedSettingsMatchStart)
# Read 60 history items for RemoteEvent(ATPneumatics, 0, cellVentsState)
# Read 5 history items for RemoteEvent(ATPneumatics, 0, eStop)
# Read 100 history items for RemoteEvent(ATPneumatics, 0, heartbeat)
# Read 48 history items for RemoteEvent(ATPneumatics, 0, instrumentState)
# Read 100 history items for RemoteEvent(ATPneumatics, 0, m1CoverLimitSwitches)
# Read 100 history items for RemoteEvent(ATPneumatics, 0, m1CoverState)
# Read 100 history items for RemoteEvent(ATPneumatics, 0, m1SetPressure)
# Read 76 history items for RemoteEvent(ATPneumatics, 0, m1State)
# Read 10 history items for RemoteEvent(ATPneumatics, 0, m1VentsLimitSwitches)
# Read 21 history items for RemoteEvent(ATPneumatics, 0, m1VentsPosition)
# Read 78 history items for RemoteEvent(ATPneumatics, 0, m2State)
# Read 48 history items for RemoteEvent(ATPneumatics, 0, mainValveState)
# Read 1 history items for RemoteEvent(ATPneumatics, 0, powerStatus)
# Read 39 history items for RemoteEvent(ATPneumatics, 0, settingVersions)
# Read 100 history items for RemoteEvent(ATPneumatics, 0, summaryState)
# Read historical data in 0.29 sec
# Read 8 history items for RemoteEvent(ATCamera, 0, appliedSettingsMatchStart)
# Read 100 history items for RemoteEvent(ATCamera, 0, ccsCommandState)
# Read 100 history items for RemoteEvent(ATCamera, 0, endOfImageTelemetry)
# Read 100 history items for RemoteEvent(ATCamera, 0, endReadout)
# Read 100 history items for RemoteEvent(ATCamera, 0, endShutterClose)
# Read 100 history items for RemoteEvent(ATCamera, 0, endShutterOpen)
# Read 10 history items for RemoteEvent(ATCamera, 0, focalPlaneHardwareIdSettingsApplied)
# Read 10 history items for RemoteEvent(ATCamera, 0, focalPlaneSummaryInfo)
# Read 100 history items for RemoteEvent(ATCamera, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATCamera, 0, imageReadinessDetailedState)
# Read 100 history items for RemoteEvent(ATCamera, 0, imageReadoutParameters)
# Read 100 history items for RemoteEvent(ATCamera, 0, raftsDetailedState)
# Read 8 history items for RemoteEvent(ATCamera, 0, settingVersions)
# Read 100 history items for RemoteEvent(ATCamera, 0, shutterDetailedState)
# Read 100 history items for RemoteEvent(ATCamera, 0, shutterMotionProfile)
# Read 8 history items for RemoteEvent(ATCamera, 0, softwareVersions)
# Read 100 history items for RemoteEvent(ATCamera, 0, startIntegration)
# Read 100 history items for RemoteEvent(ATCamera, 0, startReadout)
# Read 32 history items for RemoteEvent(ATCamera, 0, summaryState)
# Read historical data in 0.36 sec
# Read 9 history items for RemoteEvent(ATAOS, 0, appliedSettingsMatchStart)
# Read 100 history items for RemoteEvent(ATAOS, 0, atspectrographCorrectionCompleted)
# Read 100 history items for RemoteEvent(ATAOS, 0, atspectrographCorrectionStarted)
# Read 1 history items for RemoteEvent(ATAOS, 0, authList)
# Read 9 history items for RemoteEvent(ATAOS, 0, correctionEnabled)
# Read 100 history items for RemoteEvent(ATAOS, 0, correctionOffsets)
# Read 100 history items for RemoteEvent(ATAOS, 0, detailedState)
# Read 1 history items for RemoteEvent(ATAOS, 0, errorCode)
# Read 100 history items for RemoteEvent(ATAOS, 0, focusOffsetSummary)
# Read 100 history items for RemoteEvent(ATAOS, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATAOS, 0, hexapodCorrectionCompleted)
# Read 100 history items for RemoteEvent(ATAOS, 0, hexapodCorrectionStarted)
# Read 1 history items for RemoteEvent(ATAOS, 0, logLevel)
# Read 100 history items for RemoteEvent(ATAOS, 0, logMessage)
# Read 100 history items for RemoteEvent(ATAOS, 0, m1CorrectionCompleted)
# Read 100 history items for RemoteEvent(ATAOS, 0, m1CorrectionStarted)
# Read 100 history items for RemoteEvent(ATAOS, 0, pointingOffsetSummary)
# Read 1 history items for RemoteEvent(ATAOS, 0, settingVersions)
# Read 4 history items for RemoteEvent(ATAOS, 0, settingsApplied)
# Read 1 history items for RemoteEvent(ATAOS, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATAOS, 0, softwareVersions)
# Read 37 history items for RemoteEvent(ATAOS, 0, summaryState)
# Read historical data in 0.42 sec
# Read 100 history items for RemoteEvent(ATDome, 0, allAxesInPosition)
# Read 43 history items for RemoteEvent(ATDome, 0, appliedSettingsMatchStart)
# Read 1 history items for RemoteEvent(ATDome, 0, authList)
# Read 100 history items for RemoteEvent(ATDome, 0, azimuthCommandedState)
# Read 100 history items for RemoteEvent(ATDome, 0, azimuthInPosition)
# Read 100 history items for RemoteEvent(ATDome, 0, azimuthState)
# Read 100 history items for RemoteEvent(ATDome, 0, doorEncoderExtremes)
# Read 36 history items for RemoteEvent(ATDome, 0, dropoutDoorCommandedState)
# Read 11 history items for RemoteEvent(ATDome, 0, dropoutDoorState)
# Read 5 history items for RemoteEvent(ATDome, 0, emergencyStop)
# Read 100 history items for RemoteEvent(ATDome, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATDome, 0, lastAzimuthGoTo)
# Read 1 history items for RemoteEvent(ATDome, 0, logLevel)
# Read 100 history items for RemoteEvent(ATDome, 0, logMessage)
# Read 38 history items for RemoteEvent(ATDome, 0, mainDoorCommandedState)
# Read 21 history items for RemoteEvent(ATDome, 0, mainDoorState)
# Read 74 history items for RemoteEvent(ATDome, 0, scbLink)
# Read 1 history items for RemoteEvent(ATDome, 0, settingVersions)
# Read 1 history items for RemoteEvent(ATDome, 0, settingsApplied)
# Read 72 history items for RemoteEvent(ATDome, 0, settingsAppliedDomeController)
# Read 43 history items for RemoteEvent(ATDome, 0, settingsAppliedDomeTcp)
# Read 26 history items for RemoteEvent(ATDome, 0, shutterInPosition)
# Read 1 history items for RemoteEvent(ATDome, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATDome, 0, softwareVersions)
# Read 100 history items for RemoteEvent(ATDome, 0, summaryState)
# Read historical data in 0.48 sec
# Read 100 history items for RemoteEvent(ATMCS, 0, allAxesInPosition)
# Read 100 history items for RemoteEvent(ATMCS, 0, appliedSettingsMatchStart)
# Read 100 history items for RemoteEvent(ATMCS, 0, atMountState)
# Read 100 history items for RemoteEvent(ATMCS, 0, azimuthBrake1)
# Read 100 history items for RemoteEvent(ATMCS, 0, azimuthBrake2)
# Read 100 history items for RemoteEvent(ATMCS, 0, azimuthDrive1Status)
# Read 100 history items for RemoteEvent(ATMCS, 0, azimuthDrive2Status)
# Read 100 history items for RemoteEvent(ATMCS, 0, azimuthInPosition)
# Read 6 history items for RemoteEvent(ATMCS, 0, azimuthToppleBlockCCW)
# Read 4 history items for RemoteEvent(ATMCS, 0, azimuthToppleBlockCW)
# Read 100 history items for RemoteEvent(ATMCS, 0, elevationBrake)
# Read 100 history items for RemoteEvent(ATMCS, 0, elevationDriveStatus)
# Read 100 history items for RemoteEvent(ATMCS, 0, elevationInPosition)
# Read 10 history items for RemoteEvent(ATMCS, 0, elevationLimitSwitchLower)
# Read 10 history items for RemoteEvent(ATMCS, 0, elevationLimitSwitchUpper)
# Read 94 history items for RemoteEvent(ATMCS, 0, errorCode)
# Read 100 history items for RemoteEvent(ATMCS, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATMCS, 0, m3State)
# Read 100 history items for RemoteEvent(ATMCS, 0, nasmyth1Brake)
# Read 100 history items for RemoteEvent(ATMCS, 0, nasmyth1DriveStatus)
# Read 100 history items for RemoteEvent(ATMCS, 0, nasmyth1RotatorInPosition)
# Read 100 history items for RemoteEvent(ATMCS, 0, nasmyth2Brake)
# Read 100 history items for RemoteEvent(ATMCS, 0, nasmyth2DriveStatus)
# Read 100 history items for RemoteEvent(ATMCS, 0, nasmyth2RotatorInPosition)
# Read 100 history items for RemoteEvent(ATMCS, 0, positionLimits)
# Read 100 history items for RemoteEvent(ATMCS, 0, settingVersions)
# Read 100 history items for RemoteEvent(ATMCS, 0, summaryState)
# Read 100 history items for RemoteEvent(ATMCS, 0, target)
# Read historical data in 0.58 sec
# Read 55 history items for RemoteEvent(ATPtg, 0, airmassWarning)
# Read 1 history items for RemoteEvent(ATPtg, 0, azWrapWarning)
# Read 65 history items for RemoteEvent(ATPtg, 0, currentDebugLevel)
# Read 100 history items for RemoteEvent(ATPtg, 0, currentTarget)
# Read 100 history items for RemoteEvent(ATPtg, 0, detailedState)
# Read 4 history items for RemoteEvent(ATPtg, 0, elLimitWarning)
# Read 100 history items for RemoteEvent(ATPtg, 0, errorCode)
# Read 1 history items for RemoteEvent(ATPtg, 0, focusNameInconsistentWarning)
# Read 66 history items for RemoteEvent(ATPtg, 0, focusNameSelected)
# Read 100 history items for RemoteEvent(ATPtg, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATPtg, 0, iers)
# Read 3 history items for RemoteEvent(ATPtg, 0, iersOutOfDate)
# Read 1 history items for RemoteEvent(ATPtg, 0, moonProximityWarning)
# Read 2 history items for RemoteEvent(ATPtg, 0, mountDataWarning)
# Read 1 history items for RemoteEvent(ATPtg, 0, objectSetWarning)
# Read 65 history items for RemoteEvent(ATPtg, 0, pointingModel)
# Read 1 history items for RemoteEvent(ATPtg, 0, pointing_file)
# Read 1 history items for RemoteEvent(ATPtg, 0, ptgAzCurrentWrap)
# Read 1 history items for RemoteEvent(ATPtg, 0, ptgRotCurrentWrap)
# Read 1 history items for RemoteEvent(ATPtg, 0, rotWrapWarning)
# Read 100 history items for RemoteEvent(ATPtg, 0, summaryState)
# Read 1 history items for RemoteEvent(ATPtg, 0, sunProximityWarning)
# Read 100 history items for RemoteEvent(ATPtg, 0, timesOfLimits)
# Read 100 history items for RemoteEvent(ATPtg, 0, trackPosting)
# Read 64 history items for RemoteEvent(ATPtg, 0, wavelength)
# Read 100 history items for RemoteEvent(ATPtg, 0, weatherDataApplied)
# Read 100 history items for RemoteEvent(ATPtg, 0, weatherDataInvalid)
# Read historical data in 0.64 sec
# timeAndDate DDS read queue is full (100 elements); data may be lost
# Read 1 history items for RemoteEvent(ATArchiver, 0, authList)
# Read 1 history items for RemoteEvent(ATArchiver, 0, errorCode)
# mount_positions DDS read queue is full (100 elements); data may be lost
# Read 100 history items for RemoteEvent(ATArchiver, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATArchiver, 0, imageInOODS)
# Read 100 history items for RemoteEvent(ATArchiver, 0, imageRetrievalForArchiving)
# Read 1 history items for RemoteEvent(ATArchiver, 0, logLevel)
# Read 1 history items for RemoteEvent(ATArchiver, 0, logMessage)
# Read 1 history items for RemoteEvent(ATArchiver, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATArchiver, 0, softwareVersions)
# Read 29 history items for RemoteEvent(ATArchiver, 0, summaryState)
# [[None, None, None, None, None, None, None], [None, None, None, None]]

# %%
# enable components
await atcs.enable()
await latiss.enable()
# Out:
# Enabling all components
# Gathering settings.
# Couldn't get settingVersions event. Using empty settings.
# Complete settings for atmcs.
# Complete settings for atptg.
# Complete settings for ataos.
# Complete settings for atpneumatics.
# Complete settings for athexapod.
# Complete settings for atdome.
# Complete settings for atdometrajectory.
# Settings versions: {'atmcs': '                                                                                                                               ', 'atptg': '', 'ataos': 'current', 'atpneumatics': '                                                                                                                               ', 'athexapod': 'summit', 'atdome': 'test', 'atdometrajectory': ''}
# [atmcs]::[<State.STANDBY: 5>, <State.DISABLED: 1>, <State.ENABLED: 2>]
# [atptg]::[<State.STANDBY: 5>, <State.DISABLED: 1>, <State.ENABLED: 2>]
# [ataos]::[<State.STANDBY: 5>, <State.DISABLED: 1>, <State.ENABLED: 2>]
# [atpneumatics]::[<State.STANDBY: 5>, <State.DISABLED: 1>, <State.ENABLED: 2>]
# [athexapod]::[<State.STANDBY: 5>, <State.DISABLED: 1>, <State.ENABLED: 2>]
# [atdome]::[<State.STANDBY: 5>, <State.DISABLED: 1>, <State.ENABLED: 2>]
# [atdometrajectory]::[<State.STANDBY: 5>, <State.DISABLED: 1>, <State.ENABLED: 2>]
# All components in <State.ENABLED: 2>.
# Enabling all components
# Gathering settings.
# Couldn't get settingVersions event. Using empty settings.
# Couldn't get settingVersions event. Using empty settings.
# Complete settings for atcamera.
# Complete settings for atspectrograph.
# Complete settings for atheaderservice.
# Complete settings for atarchiver.
# Settings versions: {'atcamera': '', 'atspectrograph': 'current', 'atheaderservice': '', 'atarchiver': ''}
# [atcamera]::[<State.STANDBY: 5>, <State.DISABLED: 1>, <State.ENABLED: 2>]
# [atspectrograph]::[<State.STANDBY: 5>, <State.DISABLED: 1>, <State.ENABLED: 2>]
# [atheaderservice]::[<State.STANDBY: 5>, <State.DISABLED: 1>, <State.ENABLED: 2>]
# [atarchiver]::[<State.STANDBY: 5>, <State.DISABLED: 1>, <State.ENABLED: 2>]
# All components in <State.ENABLED: 2>.

# %%
await latiss.take_bias(1)
# Out:
# Generating group_id
# BIAS 0001 - 0001
# array([2021031100001])

# %%
# Take 50 biases seq # 2-51
# Added wait to stop killing the recent images
for i in range(50):
    await asyncio.sleep(2.0)
    await latiss.take_bias(1)
# Out:
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# logMessage DDS read queue is filling: 18 of 100 elements
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# logMessage DDS read queue is filling: 28 of 100 elements
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# logMessage DDS read queue is filling: 11 of 100 elements
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001

# %%
# Take 10 10 second darks 52-61
await latiss.take_darks(10.0, 10)
# Out:
# Generating group_id
# DARK 0001 - 0010
# DARK 0002 - 0010
# DARK 0003 - 0010
# DARK 0004 - 0010
# DARK 0005 - 0010
# DARK 0006 - 0010
# DARK 0007 - 0010
# DARK 0008 - 0010
# DARK 0009 - 0010
# DARK 0010 - 0010
# array([2021031100052, 2021031100053, 2021031100054, 2021031100055,
#        2021031100056, 2021031100057, 2021031100058, 2021031100059,
#        2021031100060, 2021031100061])

# %%
await atcs.prepare_for_flatfield()
# Out:
# Cover state <MirrorCoverState.CLOSED: 6>
# Opening M1 cover.
# Cover state <MirrorCoverState.CLOSED: 6>
# Cover state <MirrorCoverState.CLOSED: 6>
# Cover state <MirrorCoverState.INMOTION: 8>
# Cover state <MirrorCoverState.OPENED: 7>
# Sending command
# Stop tracking.
# Unknown tracking state: 10
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got False
# Telescope not in position
# [Telescope] delta Alt = -041.000 deg; delta Az= -154.301 deg; delta N1 = +000.000 deg; delta N2 = -000.025 deg
# [Telescope] delta Alt = -038.097 deg; delta Az= -157.530 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -032.099 deg; delta Az= -163.527 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -026.094 deg; delta Az= -169.528 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -022.127 deg; delta Az= -173.527 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -018.251 deg; delta Az= -177.526 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -014.552 deg; delta Az= +178.472 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -009.541 deg; delta Az= +172.473 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -005.444 deg; delta Az= +166.473 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -003.337 deg; delta Az= +162.473 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -001.773 deg; delta Az= +158.474 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -000.752 deg; delta Az= +154.472 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -000.201 deg; delta Az= +150.473 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +144.472 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= +138.473 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= +132.472 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +126.474 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= +120.472 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= +114.473 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= +108.473 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +102.473 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +098.472 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= +094.473 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= +088.473 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +084.473 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +080.473 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= +074.473 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= +068.474 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= +064.472 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= +058.473 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +052.473 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +046.473 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +042.472 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= +036.474 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +030.471 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +024.476 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= +020.535 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= +014.889 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= +011.431 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +006.938 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= +003.512 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= +001.296 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= +000.235 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= +000.001 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# Got True
# Waiting for telescope to settle.
# Axes in position.
# Stop tracking.
# Unknown tracking state: 9
# Unknown tracking state: 10
# In Position: True.
# Sending ATDomeTrajectory to DISABED state. Component will be left in DISABLEDstate or else it may send the ATDome back to alignment with the telescope.
# process as completed...
# atdometrajectory: <State.DISABLED: 1>
# [Dome] delta Az = +019.790 deg
# [Dome] delta Az = +019.680 deg
# [Dome] delta Az = +019.320 deg
# [Dome] delta Az = +018.730 deg
# [Dome] delta Az = +017.910 deg
# [Dome] delta Az = +016.850 deg
# [Dome] delta Az = +015.550 deg
# [Dome] delta Az = +014.030 deg
# [Dome] delta Az = +012.260 deg
# [Dome] delta Az = +010.260 deg
# [Dome] delta Az = +008.050 deg
# [Dome] delta Az = +005.590 deg
# [Dome] delta Az = +003.120 deg
# Axes in position.

# %%
# Take 10 2 second flats 62-71
await latiss.take_flats(2.0, 10, filter='RG610', grating='empty_1')
# Out:
# Generating group_id
# FLAT 0001 - 0010
# FLAT 0002 - 0010
# FLAT 0003 - 0010
# FLAT 0004 - 0010
# FLAT 0005 - 0010
# FLAT 0006 - 0010
# FLAT 0007 - 0010
# FLAT 0008 - 0010
# FLAT 0009 - 0010
# FLAT 0010 - 0010
# array([2021031100062, 2021031100063, 2021031100064, 2021031100065,
#        2021031100066, 2021031100067, 2021031100068, 2021031100069,
#        2021031100070, 2021031100071])

# %%
# Take flats for PTC 72-111
# Added wait to stop killing the recent images
for i in range(20):
    exp = 0.2 * float(i+1)
    await latiss.take_flats(exp, 1, filter='empty_1', grating='empty_1')
    if exp < 2.0:
        await asyncio.sleep(2.0)
    await latiss.take_flats(exp, 1, filter='empty_1', grating='empty_1')
# Out:
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# logMessage DDS read queue is filling: 11 of 100 elements
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# logMessage DDS read queue is filling: 11 of 100 elements
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# logMessage DDS read queue is filling: 10 of 100 elements
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001

# %%
await latiss.take_bias(1)
# Out:
# Generating group_id
# BIAS 0001 - 0001
# array([2021031100112])

# %%
await atcs.stop_tracking()
# Out:
# Stop tracking.

# %%
atcs.atdome = True
atcs.atdometrajectory = True

# %%
await atcs.slew_dome_to(az=0.0)

# %%
await atcs.prepare_for_onsky()
# Out:
# Enabling all components
# Gathering settings.
# Couldn't get settingVersions event. Using empty settings.
# Complete settings for atmcs.
# Complete settings for atptg.
# Complete settings for ataos.
# Complete settings for atpneumatics.
# Complete settings for athexapod.
# Complete settings for atdome.
# Complete settings for atdometrajectory.
# Settings versions: {'atmcs': '                                                                                                                               ', 'atptg': '', 'ataos': 'current', 'atpneumatics': '                                                                                                                               ', 'athexapod': 'summit', 'atdome': 'test', 'atdometrajectory': ''}
# [atmcs]::[<State.ENABLED: 2>]
# [atptg]::[<State.ENABLED: 2>]
# [ataos]::[<State.ENABLED: 2>]
# [atpneumatics]::[<State.ENABLED: 2>]
# [athexapod]::[<State.ENABLED: 2>]
# [atdome]::[<State.ENABLED: 2>]
# [atdometrajectory]::[<State.ENABLED: 2>]
# All components in <State.ENABLED: 2>.
# Slew telescope to park position.
# Sending command
# Stop tracking.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# [Telescope] delta Alt = +041.000 deg; delta Az= +154.301 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +038.225 deg; delta Az= +157.423 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +032.224 deg; delta Az= +163.419 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +026.221 deg; delta Az= +169.419 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +020.296 deg; delta Az= +175.420 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +014.668 deg; delta Az= -178.582 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +009.642 deg; delta Az= -172.580 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +005.522 deg; delta Az= -166.582 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +002.540 deg; delta Az= -160.580 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +001.232 deg; delta Az= -156.581 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.442 deg; delta Az= -152.581 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.081 deg; delta Az= -148.579 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -142.581 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -136.580 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -130.580 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -126.580 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -120.582 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -116.581 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -112.580 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -106.581 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -100.582 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -094.580 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -088.582 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -082.581 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -076.582 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -072.581 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -068.580 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -062.582 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -056.580 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -050.581 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -044.581 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -038.581 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -032.581 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -026.578 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -022.604 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -016.827 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -011.528 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -008.417 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -004.591 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -002.689 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -001.332 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.251 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.002 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# Axes in position.
# Stop tracking.
# Unknown tracking state: 9
# Unknown tracking state: 10
# In Position: True.
# Cover state <MirrorCoverState.OPENED: 7>
# Closing M1 cover.
# Cover state <MirrorCoverState.INMOTION: 8>
# Cover state <MirrorCoverState.CLOSED: 6>
# Homing dome azimuth.
# Dome azimuth still homing.
# Dome azimuth still homing.
# Dome azimuth still homing.
# Moving dome to 90 degrees.
# Sending ATDomeTrajectory to DISABED state. Component will be left in DISABLEDstate or else it may send the ATDome back to alignment with the telescope.
# process as completed...
# atdometrajectory: <State.DISABLED: 1>
# [Dome] delta Az = +089.950 deg
# [Dome] delta Az = +089.340 deg
# [Dome] delta Az = +088.530 deg
# [Dome] delta Az = +087.490 deg
# [Dome] delta Az = +086.200 deg
# [Dome] delta Az = +084.690 deg
# [Dome] delta Az = +082.930 deg
# [Dome] delta Az = +080.950 deg
# [Dome] delta Az = +078.750 deg
# [Dome] delta Az = +076.310 deg
# [Dome] delta Az = +073.650 deg
# [Dome] delta Az = +070.730 deg
# [Dome] delta Az = +067.580 deg
# [Dome] delta Az = +064.230 deg
# [Dome] delta Az = +060.780 deg
# [Dome] delta Az = +057.310 deg
# [Dome] delta Az = +053.870 deg
# [Dome] delta Az = +050.430 deg
# [Dome] delta Az = +046.960 deg
# [Dome] delta Az = +043.540 deg
# [Dome] delta Az = +040.060 deg
# [Dome] delta Az = +036.630 deg
# [Dome] delta Az = +033.150 deg
# [Dome] delta Az = +029.710 deg
# [Dome] delta Az = +026.240 deg
# [Dome] delta Az = +022.770 deg
# [Dome] delta Az = +019.320 deg
# [Dome] delta Az = +015.850 deg
# [Dome] delta Az = +012.410 deg
# [Dome] delta Az = +008.940 deg
# [Dome] delta Az = +005.490 deg
# [Dome] delta Az = +002.200 deg
# ATDome in position.
# Axes in position.
# Check that dome CSC can communicate with shutter control box.
# Opening dome.
# Opening dome shutter...
# process as completed...
# atdome: <State.ENABLED: 2>
# Waiting for ATDome mainDoorState: <ShutterDoorState.OPENED: 2>. Current state: <ShutterDoorState.CLOSED: 1>.
# mainDoorState: <ShutterDoorState.OPENING: 4>
# mainDoorState: <ShutterDoorState.OPENED: 2>
# Finishing ATDome shutter command task.
# ATDome shutter command task not done. Cancelling.
# ATDome shutter command task cancelled.
# Open telescope cover.
# Cover state <MirrorCoverState.CLOSED: 6>
# Opening M1 cover.
# Cover state <MirrorCoverState.INMOTION: 8>
# Cover state <MirrorCoverState.OPENED: 7>
# M1 vent state <VentsPosition.CLOSED: 1>
# Opening M1 vents.
# M1 vent state <VentsPosition.PARTIALLYOPENED: 2>
# M1 vent state <VentsPosition.OPENED: 0>
# Enabling all components
# Gathering settings.
# atdometrajectory check is disabled, skipping.
# Couldn't get settingVersions event. Using empty settings.
# Complete settings for atmcs.
# Complete settings for atptg.
# Complete settings for ataos.
# Complete settings for atpneumatics.
# Complete settings for athexapod.
# Complete settings for atdome.
# Settings versions: {'atmcs': '                                                                                                                               ', 'atptg': '', 'ataos': 'current', 'atpneumatics': '                                                                                                                               ', 'athexapod': 'summit', 'atdome': 'test'}
# [atmcs]::[<State.ENABLED: 2>]
# [atptg]::[<State.ENABLED: 2>]
# [ataos]::[<State.ENABLED: 2>]
# [atpneumatics]::[<State.ENABLED: 2>]
# [athexapod]::[<State.ENABLED: 2>]
# [atdome]::[<State.ENABLED: 2>]
# [atdometrajectory]::<State.DISABLED: 1>
# All components in <State.ENABLED: 2>.
# Enable ATAOS corrections.

# %%
await salobj.set_summary_state(atcs.rem.ataos, salobj.State.STANDBY)

# %%
# Don't forget the 'settingsToApply='current' or it won't work!!
await salobj.set_summary_state(atcs.rem.ataos, salobj.State.ENABLED, settingsToApply='current')

# %%
await atcs.rem.ataos.cmd_enableCorrection.set_start(
    m1=True, hexapod=True, atspectrograph=True, timeout=atcs.long_timeout
)

# %%
# HD72514 Az~120, Alt~65 m=8.05

# %%
current_az = 120.0
current_el = 65.0
current_rot = -50.0
await atcs.point_azel(current_az, current_el, rot_tel=current_rot)

# %%
await salobj.set_summary_state(atcs.rem.atptg, salobj.State.ENABLED)

# %%
await salobj.set_summary_state(atcs.rem.atdometrajectory, salobj.State.ENABLED)
# Out:
# [<State.DISABLED: 1>, <State.ENABLED: 2>]

# %%
#await latiss.setup_instrument()
# Out:
# Signature: latiss.setup_instrument(**kwargs)
# Docstring:
# Implements abstract method to setup instrument.
#
# This method will call `setup_atspec` to set filter, grating and
# linear_stage.
#
# Parameters
# ----------
# **kwargs
#     Arbitrary keyword arguments.
#
# See Also
# --------
# setup_atspec: Setup spectrograph.
# take_bias: Take series of bias.
# take_darks: Take series of darks.
# take_flats: Take series of flat-field images.
# take_object: Take series of object observations.
# take_engtest: Take series of engineering test observations.
# take_imgtype: Take series of images by image type.
# expose: Low level expose method.
# File:      ~/auto-op-env-packages/ts_observatory_control/python/lsst/ts/observatory/control/auxtel/latiss.py
# Type:      method

# %%
#await latiss.setup_instrument

# %%
await latiss.setup_atspec(filter='RG610')

# %%
# HD55070 m = 5.45, Az = +85, Alt = +74
# HD78876 m = 7.2, Az = +90, Alt = +60
# HD72514 m = 
await atcs.slew_object('HD72514', rot=-50.0, rot_type=RotType.PhysicalSky)
# Out:
# Slewing to HD72514: 08 31 56.9423 -39 03 58.547
# Setting rotator physical position to -50.0 deg. Rotator will track sky.
# Parallactic angle: -81.11100579559889 | Sky Angle: -13.456224827899007
# xml 7 compatibility mode: rotPA=-13.456224827899007, rotFrame=1
# Sending command
# Stop tracking.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# atdome: <State.ENABLED: 2>
# [Telescope] delta Alt = -017.576 deg; delta Az = +117.410 deg; delta N1 = +000.000 deg; delta N2 = +060.162 deg [Dome] delta Az = -002.910 deg
# ATDome in position.
# [Telescope] delta Alt = -017.331 deg; delta Az = +116.060 deg; delta N1 = +000.000 deg; delta N2 = +057.193 deg [Dome] delta Az = -002.910 deg
# [Telescope] delta Alt = -014.674 deg; delta Az = +110.125 deg; delta N1 = +000.000 deg; delta N2 = +051.194 deg [Dome] delta Az = -002.910 deg
# [Telescope] delta Alt = -009.324 deg; delta Az = +104.128 deg; delta N1 = +000.000 deg; delta N2 = +047.190 deg [Dome] delta Az = -002.910 deg
# [Telescope] delta Alt = -005.423 deg; delta Az = +100.129 deg; delta N1 = +000.000 deg; delta N2 = +041.191 deg [Dome] delta Az = -002.910 deg
# [Telescope] delta Alt = -001.198 deg; delta Az = +094.134 deg; delta N1 = +000.000 deg; delta N2 = +035.192 deg [Dome] delta Az = -002.910 deg
# [Telescope] delta Alt = -000.127 deg; delta Az = +090.136 deg; delta N1 = +000.000 deg; delta N2 = +031.190 deg [Dome] delta Az = -002.910 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +084.139 deg; delta N1 = -000.000 deg; delta N2 = +025.199 deg [Dome] delta Az = -002.910 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +078.142 deg; delta N1 = +000.000 deg; delta N2 = +019.295 deg [Dome] delta Az = -002.910 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +072.145 deg; delta N1 = +000.000 deg; delta N2 = +013.744 deg [Dome] delta Az = -002.910 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +066.148 deg; delta N1 = -000.000 deg; delta N2 = +008.859 deg [Dome] delta Az = -002.910 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +060.152 deg; delta N1 = +000.000 deg; delta N2 = +004.927 deg [Dome] delta Az = -002.910 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +054.155 deg; delta N1 = +000.000 deg; delta N2 = +002.153 deg [Dome] delta Az = -002.910 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +048.158 deg; delta N1 = +000.000 deg; delta N2 = +000.590 deg [Dome] delta Az = -002.910 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +042.161 deg; delta N1 = +000.000 deg; delta N2 = +000.136 deg [Dome] delta Az = -002.910 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +038.164 deg; delta N1 = -000.000 deg; delta N2 = +000.005 deg [Dome] delta Az = -002.910 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +034.165 deg; delta N1 = -000.000 deg; delta N2 = -000.001 deg [Dome] delta Az = -002.910 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +028.166 deg; delta N1 = -000.000 deg; delta N2 = -000.001 deg [Dome] delta Az = -002.910 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +022.199 deg; delta N1 = -000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -002.910 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +016.448 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg [Dome] delta Az = -002.910 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +011.194 deg; delta N1 = -000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -002.910 deg
# [Telescope] delta Alt = -000.002 deg; delta Az = +006.752 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -002.910 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +003.382 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg [Dome] delta Az = -002.910 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +001.808 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -002.910 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.436 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -002.910 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.017 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg [Dome] delta Az = -002.910 deg
# Got True
# Waiting for telescope to settle.
# [Telescope] delta Alt = -000.001 deg; delta Az = -000.001 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -002.910 deg
# Axes in position.

# %%
await latiss.take_object(10.0, 1, filter='RG610', grating='empty_1')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021031100114])

# %%
#await latiss.take_object(10.0, 1, filter='empty_1', grating='empty_1')

# %%
#await latiss.setup_atspec

# %%
# Ran this command after re-starting notebook, but it was too much.  
# The cell had put the offset back to the starting point (which was -0.20),
# So I only should have applied -0.09.  So image 137 was way out of focus.
await atcs.rem.ataos.cmd_offset.set_start(z=-0.19)

# %%
await latiss.take_object(10.0, 1, filter='RG610', grating='empty_1')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021031100132])
# logMessage DDS read queue is filling: 12 of 100 elements
# logMessage DDS read queue is filling: 16 of 100 elements

# %%
# await latiss.take_object(10.0, 1, filter='empty_1', grating='empty_1')

# %%
atcs.

# %%
# 199 had -0.06363
# Now at -0.10363
await atcs.rem.ataos.cmd_offset.set_start(z=0.04)

# %%
atcs.offset_xy?
# Out:
# Signature: atcs.offset_xy(x, y, relative=False, persistent=False)
# Docstring:
# Offset telescope in x and y.
#
# This will move the field in the x and y direction.
#
# Parameters
# ----------
# x : `float`
#     Offset in camera x-axis (arcsec).
# y : `float`
#     Offset in camera y-axis (arcsec).
# relative : `bool`
#     If `True` offset is applied relative to the current position, if
#     `False` (default) offset replaces any existing offsets.
# persistent : `bool`
#     Should the offset be absorbed and persisted between slews?
#
# See Also
# --------
# offset_azel : Offset in local AzEl coordinates.
# offset_radec : Offset in sky coordinates.
# File:      ~/auto-op-env-packages/ts_observatory_control/python/lsst/ts/observatory/control/base_tcs.py
# Type:      method

# %%
# Move the star to the bottom of the field
await atcs.offset_xy(y=140, x=0)
# Out:
# Calculating x/y offset: 0/140
# Applying Az/El offset: 12.595805437506172/-139.4322261365015
# Telescope not in position.
# All axes in position.
# Waiting for telescope to settle.
# Done

# %%
# Currently at 2224, 162
# Want 1750, 300
# Shift x=47, y=135
await atcs.offset_xy(y=126, x=55)
# Out:
# Calculating x/y offset: 55/126
# Applying Az/El offset: -4.32147951822351/-137.41297178495768
# Telescope not in position.
# All axes in position.
# Waiting for telescope to settle.
# Done

# %%
# Take a set of images on both sides of current best focus
# ran with -0.40 and 0.05, which gave twice as many as needed

starting_z_offset = -0.30
z_offset_increment = 0.03
nsteps = int((-2 * starting_z_offset) / z_offset_increment) + 1
total_z_offset = 0.0
await atcs.rem.ataos.cmd_offset.set_start(z=starting_z_offset)
total_z_offset += starting_z_offset
print(f"Total z offset = {total_z_offset}")
await asyncio.sleep(2)
for i in range(nsteps):
    await latiss.take_object(25.0, 1, filter='RG610', grating='holo4_003')
    await atcs.rem.ataos.cmd_offset.set_start(z=z_offset_increment)
    total_z_offset += z_offset_increment
    print(f"Total z offset = {total_z_offset}")
    
# Put offset back where it was
await atcs.rem.ataos.cmd_offset.set_start(z=-total_z_offset)
total_z_offset -= total_z_offset
print(f"Total z offset = {total_z_offset}")
# Out:
# Total z offset = -0.3
# Generating group_id
# OBJECT 0001 - 0001
# Total z offset = -0.27
# Generating group_id
# OBJECT 0001 - 0001
# Total z offset = -0.24000000000000002
# Generating group_id
# OBJECT 0001 - 0001
# Total z offset = -0.21000000000000002
# Generating group_id
# OBJECT 0001 - 0001
# Total z offset = -0.18000000000000002
# Generating group_id
# OBJECT 0001 - 0001
# logMessage DDS read queue is filling: 15 of 100 elements
# logMessage DDS read queue is filling: 14 of 100 elements
# Total z offset = -0.15000000000000002
# Generating group_id
# OBJECT 0001 - 0001
# Total z offset = -0.12000000000000002
# Generating group_id
# OBJECT 0001 - 0001
# Total z offset = -0.09000000000000002
# Generating group_id
# OBJECT 0001 - 0001
# Total z offset = -0.060000000000000026
# Generating group_id
# OBJECT 0001 - 0001
# Total z offset = -0.030000000000000027
# Generating group_id
# OBJECT 0001 - 0001
# Total z offset = -2.7755575615628914e-17
# Generating group_id
# OBJECT 0001 - 0001
# Total z offset = 0.02999999999999997
# Generating group_id
# OBJECT 0001 - 0001
# Total z offset = 0.05999999999999997
# Generating group_id
# OBJECT 0001 - 0001
# Total z offset = 0.08999999999999997
# Generating group_id
# OBJECT 0001 - 0001
# Total z offset = 0.11999999999999997
# Generating group_id
# OBJECT 0001 - 0001
# Total z offset = 0.14999999999999997
# Generating group_id
# OBJECT 0001 - 0001
# Total z offset = 0.17999999999999997
# Generating group_id
# OBJECT 0001 - 0001
# Total z offset = 0.20999999999999996
# Generating group_id
# OBJECT 0001 - 0001
# Total z offset = 0.23999999999999996
# Generating group_id
# OBJECT 0001 - 0001
# Total z offset = 0.26999999999999996
# Generating group_id
# OBJECT 0001 - 0001
# Total z offset = 0.29999999999999993
# Generating group_id
# OBJECT 0001 - 0001
# Total z offset = 0.32999999999999996
# Total z offset = 0.0

# %%
# To reset all offsets
tmp = await atcs.rem.ataos.cmd_resetOffset.set_start(axis='z')

# %%
atcs.rem.ataos.cmd_disableCorrection.set_start?
# Out:
# Signature:
# atcs.rem.ataos.cmd_disableCorrection.set_start(
#     timeout=3600,
#     wait_done=True,
#     **kwargs,
# )
# Docstring:
# Create a new ``self.data``, set zero or more fields,
# and start the command.
#
# Parameters
# ----------
# timeout : `float`, optional
#     Time limit, in seconds. If None then use ``DEFAULT_TIMEOUT``.
#     This time limit is for the entire command if ``wait_done``
#     is true, else it is for the first acknowledgement
#     after the initial ``CMD_ACK``.
#     If the command is acknowledged with ``CMD_INPROGRESS`` then the
#     timeout is extended by the timeout value in the acknowledgement.
#     Thus a slow command will not need a long timeout, so long as
#     the command issues a ``CMD_INPROGRESS`` acknowledgement
#     with a reasonable ``timeout`` value.
# wait_done : `bool`, optional
#     If True then wait for final command acknowledgement.
#     If False then wait for the first acknowledgement after the
#     initial "CMD_ACK"; if that acknowledgement is not final
#     (the ack code is not in done_ack_codes), then you will almost
#     certainly want to await `next_ackcmd`.
# **kwargs : `dict` [`str`, ``any``]
#     The remaining keyword arguments are
#     field name = new value for that field.
#     See `set` for more information about values.
#
# Returns
# -------
# ackcmd : `SalInfo.AckCmdType`
#     Command acknowledgement.
#
# Raises
# ------
# salobj.AckError
#     If the command fails.
# salobj.AckTimeoutError
#     If the command times out.
# TypeError
#     If ``data`` is not None and not an instance of `DataType`.
# File:      /opt/lsst/src/ts_salobj/python/lsst/ts/salobj/topics/remote_command.py
# Type:      method
# logMessage DDS read queue is filling: 11 of 100 elements

# %%
# await atcs.slew_object('HD72514', rot=-50.0, rot_type=RotType.PhysicalSky)

# %%
#await latiss.setup_atspec(filter='RG610', grating='empty_1')

# %%
await latiss.take_object(5.0, 1, filter='RG610', grating='holo4_003')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021031100283])

# %%
await atcs.rem.ataos.cmd_disableCorrection.set_start(atspectrograph=True)

# %%
await atcs.rem.ataos.cmd_enableCorrection.set_start(atspectrograph=True)

# %%
# ronch190lpm, ronchi170lpm, holo4_003
await latiss.setup_atspec(filter='RG610', grating='holo4_003')
# Out:
# [<ddsutil.ATSpectrograph_ackcmd_6d105732 at 0x7fd45c7e4ee0>,
#  <ddsutil.ATSpectrograph_ackcmd_6d105732 at 0x7fd414c653a0>]

# %%
# ronch190lpmm, ronchi170lpmm, holo4_003
await latiss.setup_atspec(filter='RG610', grating='holo4_003')
# Out:
# [<ddsutil.ATSpectrograph_ackcmd_6d105732 at 0x7fd4141fdb80>,
#  <ddsutil.ATSpectrograph_ackcmd_6d105732 at 0x7fd45c7d5b20>]

# %%
await latiss.take_object(5.0, 1, filter='RG610', grating='holo4_003')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021031100193])

# %%
await latiss.take_object(1.0, 1, filter='empty_1', grating='empty_1')

# %%
await atcs.shutdown()

# %%
await salobj.set_summary_state(atcs.rem.atdome, salobj.State.STANDBY, settingsToApply="test")

# %%
# Putting everything back in standby.
await latiss.standby()
# Out:
# [atcamera]::[<State.ENABLED: 2>, <State.DISABLED: 1>, <State.STANDBY: 5>]
# [atspectrograph]::[<State.ENABLED: 2>, <State.DISABLED: 1>, <State.STANDBY: 5>]
# [atheaderservice]::[<State.ENABLED: 2>, <State.DISABLED: 1>, <State.STANDBY: 5>]
# [atarchiver]::[<State.ENABLED: 2>, <State.DISABLED: 1>, <State.STANDBY: 5>]
# All components in <State.STANDBY: 5>.

# %%
for i in range(10):
    await latiss.take_object(0.2, 1, filter='RG610', grating='empty_1')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# Generating group_id
# OBJECT 0001 - 0001
# Generating group_id
# OBJECT 0001 - 0001
# Generating group_id
# OBJECT 0001 - 0001
# Generating group_id
# OBJECT 0001 - 0001
# Generating group_id
# OBJECT 0001 - 0001
# Generating group_id
# OBJECT 0001 - 0001
# Generating group_id
# OBJECT 0001 - 0001
# Generating group_id
# OBJECT 0001 - 0001
# Generating group_id
# OBJECT 0001 - 0001

# %%
await latiss.take_object(1.0, 1, filter='RG610', grating='empty_1')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021031100331])
# logMessage DDS read queue is filling: 11 of 100 elements
# logMessage DDS read queue is filling: 14 of 100 elements
