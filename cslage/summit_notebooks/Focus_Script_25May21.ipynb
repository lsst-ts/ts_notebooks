# %%
import sys
import asyncio
import time
import os

import numpy as np
import matplotlib.pyplot as plt

from lsst.rapid.analysis.focusAnalysis import NonSpectralFocusAnalyzer

# %%
repoDir = '/project/shared/auxTel/rerun/quickLook/'
analyzer = NonSpectralFocusAnalyzer(repoDir)
# %matplotlib inline
dayObs = '2021-03-23'
seqNums = [s for s in range(295, 303+1)]
offset = analyzer.run(dayObs, seqNums)
# Out:
# /home/craiglagegit/auto-op-env-packages/rapid_analysis/python/lsst/rapid/analysis/focusAnalysis.py:268: FutureWarning: Gen2 Butler has been deprecated (Butler). It will be removed sometime after v23.0 but no earlier than the end of 2021.
#   self._butler = dafPersist.Butler(repoDir)
# /home/craiglagegit/auto-op-env-packages/rapid_analysis/python/lsst/rapid/analysis/focusAnalysis.py:268: FutureWarning: Gen2 Butler has been deprecated (LatissMapper). It will be removed sometime after v23.0 but no earlier than the end of 2021.
#   self._butler = dafPersist.Butler(repoDir)
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210323_000295: 'MJD-OBS not found'
# Using CoM for centroid (because was forced to, or multiple max pixels, or saturated
# Centroid adjusted by [-0.33103952  1.59089226] pixels
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210323_000296: 'MJD-OBS not found'
# Using CoM for centroid (because was forced to, or multiple max pixels, or saturated
# Centroid adjusted by [0.97200019 1.06727553] pixels
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210323_000297: 'MJD-OBS not found'
# Using CoM for centroid (because was forced to, or multiple max pixels, or saturated
# Centroid adjusted by [ 1.65743581 -5.34799588] pixels
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210323_000298: 'MJD-OBS not found'
# Using CoM for centroid (because was forced to, or multiple max pixels, or saturated
# Centroid adjusted by [1.14921126 0.32360758] pixels
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210323_000299: 'MJD-OBS not found'
# Using CoM for centroid (because was forced to, or multiple max pixels, or saturated
# Centroid adjusted by [3.5127193  1.16966135] pixels
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210323_000300: 'MJD-OBS not found'
# Using CoM for centroid (because was forced to, or multiple max pixels, or saturated
# Centroid adjusted by [-3.21690584  0.34880205] pixels
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210323_000301: 'MJD-OBS not found'
# Centroid adjusted by [-5 -9] pixels
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210323_000302: 'MJD-OBS not found'
# Centroid adjusted by [3 5] pixels
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210323_000303: 'MJD-OBS not found'
# Centroid adjusted by [23 -8] pixels

# %%
offset
# Out:
# {'fwhmFitMin': -0.0844114351631961,
#  'ee90FitMin': -0.059372187011893125,
#  'ee80FitMin': -0.0602382570295301,
#  'ee50FitMin': -0.005231038704895689}

# %%
from lsst.rapid.analysis.focusAnalysis import SpectralFocusAnalyzer
repoDir = '/project/shared/auxTel/'
analyzer = SpectralFocusAnalyzer(repoDir)
# %matplotlib inline
dayObs = '2021-05-25'
seqNums = range(234, 242+1)
analyzer._spectrumBoxOffsets = [1200,1500,1800]
analyzer.spectrumHalfWidth = 150
bestFit = analyzer.run(dayObs, seqNums, doDisplay=True)
# Out:
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210525_000234: 'MJD-OBS not found'
# /home/craiglagegit/auto-op-env-packages/rapid_analysis/python/lsst/rapid/analysis/focusAnalysis.py:127: FutureWarning: Call to deprecated method getFilter. (Replaced by getFilterLabel. Will be removed after v22.) -- Deprecated since version v22.0.
#   filt = exp.getFilter().getName()
# /home/craiglagegit/auto-op-env-packages/rapid_analysis/python/lsst/rapid/analysis/focusAnalysis.py:147: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   circle = Circle(centroid, radius=25, facecolor='none', color='red')
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210525_000235: 'MJD-OBS not found'
# /home/craiglagegit/auto-op-env-packages/rapid_analysis/python/lsst/rapid/analysis/focusAnalysis.py:127: FutureWarning: Call to deprecated method getFilter. (Replaced by getFilterLabel. Will be removed after v22.) -- Deprecated since version v22.0.
#   filt = exp.getFilter().getName()
# /home/craiglagegit/auto-op-env-packages/rapid_analysis/python/lsst/rapid/analysis/focusAnalysis.py:147: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   circle = Circle(centroid, radius=25, facecolor='none', color='red')
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# Running best effort isr...
# Running with bias subtraction
# Running with dark correction subtraction
# Running with defect correction
# Running cosmic ray repair
# /home/craiglagegit/auto-op-env-packages/rapid_analysis/python/lsst/rapid/analysis/focusAnalysis.py:127: FutureWarning: Call to deprecated method getFilter. (Replaced by getFilterLabel. Will be removed after v22.) -- Deprecated since version v22.0.
#   filt = exp.getFilter().getName()
# /home/craiglagegit/auto-op-env-packages/rapid_analysis/python/lsst/rapid/analysis/focusAnalysis.py:147: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   circle = Circle(centroid, radius=25, facecolor='none', color='red')
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210525_000237: 'MJD-OBS not found'
# /home/craiglagegit/auto-op-env-packages/rapid_analysis/python/lsst/rapid/analysis/focusAnalysis.py:127: FutureWarning: Call to deprecated method getFilter. (Replaced by getFilterLabel. Will be removed after v22.) -- Deprecated since version v22.0.
#   filt = exp.getFilter().getName()
# /home/craiglagegit/auto-op-env-packages/rapid_analysis/python/lsst/rapid/analysis/focusAnalysis.py:147: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   circle = Circle(centroid, radius=25, facecolor='none', color='red')
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210525_000238: 'MJD-OBS not found'
# /home/craiglagegit/auto-op-env-packages/rapid_analysis/python/lsst/rapid/analysis/focusAnalysis.py:127: FutureWarning: Call to deprecated method getFilter. (Replaced by getFilterLabel. Will be removed after v22.) -- Deprecated since version v22.0.
#   filt = exp.getFilter().getName()
# /home/craiglagegit/auto-op-env-packages/rapid_analysis/python/lsst/rapid/analysis/focusAnalysis.py:147: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   circle = Circle(centroid, radius=25, facecolor='none', color='red')
# Using bias from cache...
# Using dark from cache...
# Using defects from cache...
# Running best effort isr...
# Running with bias subtraction
# Running with dark correction subtraction
# Running with defect correction
# Running cosmic ray repair
# /home/craiglagegit/auto-op-env-packages/rapid_analysis/python/lsst/rapid/analysis/focusAnalysis.py:127: FutureWarning: Call to deprecated method getFilter. (Replaced by getFilterLabel. Will be removed after v22.) -- Deprecated since version v22.0.
#   filt = exp.getFilter().getName()
# /home/craiglagegit/auto-op-env-packages/rapid_analysis/python/lsst/rapid/analysis/focusAnalysis.py:147: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   circle = Circle(centroid, radius=25, facecolor='none', color='red')
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210525_000240: 'MJD-OBS not found'
# /home/craiglagegit/auto-op-env-packages/rapid_analysis/python/lsst/rapid/analysis/focusAnalysis.py:127: FutureWarning: Call to deprecated method getFilter. (Replaced by getFilterLabel. Will be removed after v22.) -- Deprecated since version v22.0.
#   filt = exp.getFilter().getName()
# /home/craiglagegit/auto-op-env-packages/rapid_analysis/python/lsst/rapid/analysis/focusAnalysis.py:147: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   circle = Circle(centroid, radius=25, facecolor='none', color='red')
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210525_000241: 'MJD-OBS not found'
# /home/craiglagegit/auto-op-env-packages/rapid_analysis/python/lsst/rapid/analysis/focusAnalysis.py:127: FutureWarning: Call to deprecated method getFilter. (Replaced by getFilterLabel. Will be removed after v22.) -- Deprecated since version v22.0.
#   filt = exp.getFilter().getName()
# /home/craiglagegit/auto-op-env-packages/rapid_analysis/python/lsst/rapid/analysis/focusAnalysis.py:147: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   circle = Circle(centroid, radius=25, facecolor='none', color='red')
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS AT_O_20210525_000242: 'MJD-OBS not found'
# /home/craiglagegit/auto-op-env-packages/rapid_analysis/python/lsst/rapid/analysis/focusAnalysis.py:127: FutureWarning: Call to deprecated method getFilter. (Replaced by getFilterLabel. Will be removed after v22.) -- Deprecated since version v22.0.
#   filt = exp.getFilter().getName()
# /home/craiglagegit/auto-op-env-packages/rapid_analysis/python/lsst/rapid/analysis/focusAnalysis.py:147: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   circle = Circle(centroid, radius=25, facecolor='none', color='red')
# Best fit for spectrum slice 0 = -0.0223mm
# Best fit for spectrum slice 1 = -0.0129mm
# Best fit for spectrum slice 2 = -0.0022mm
