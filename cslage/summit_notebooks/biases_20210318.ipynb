# %%
import sys
import asyncio
import time
import os

import numpy as np

from lsst.ts import salobj

from lsst.ts.observatory.control.auxtel.atcs import ATCS
from lsst.ts.observatory.control.auxtel.latiss import LATISS
# Out:
# /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/site-packages/jose/backends/cryptography_backend.py:23: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes, int_to_bytes

# %%
print(os.environ["OSPL_URI"])
print(os.environ["LSST_DDS_PARTITION_PREFIX"])
# Out:
# file:///home/craiglagegit/WORK/ts_ddsconfig/config/ospl-shmem.xml
# summit

# %%
import logging
stream_handler = logging.StreamHandler(sys.stdout)
logger = logging.getLogger()
logger.addHandler(stream_handler)
logger.level = logging.DEBUG

# %%
#Start classes
domain = salobj.Domain()
await asyncio.sleep(10) # This can be removed in the future...
#atcs = ATCS(domain)
latiss = LATISS(domain)
#await asyncio.gather(atcs.start_task, latiss.start_task)
await asyncio.gather(latiss.start_task)
# Out:
# atcamera: Adding all resources.
# atspectrograph: Adding all resources.
# atheaderservice: Adding all resources.
# atarchiver: Adding all resources.
# Read historical data in 0.00 sec
# Read 100 history items for RemoteEvent(ATHeaderService, 0, heartbeat)
# Read historical data in 0.01 sec
# Read 100 history items for RemoteEvent(ATArchiver, 0, heartbeat)
# Read historical data in 0.02 sec
# Read 100 history items for RemoteEvent(ATSpectrograph, 0, heartbeat)
# Read historical data in 0.03 sec
# Read 3 history items for RemoteEvent(ATCamera, 0, ccsCommandState)
# Read 1 history items for RemoteEvent(ATCamera, 0, focalPlaneHardwareIdSettingsApplied)
# Read 1 history items for RemoteEvent(ATCamera, 0, focalPlaneSummaryInfo)
# Read 100 history items for RemoteEvent(ATCamera, 0, heartbeat)
# Read 2 history items for RemoteEvent(ATCamera, 0, offlineDetailedState)
# Read 1 history items for RemoteEvent(ATCamera, 0, settingVersions)
# Read 2 history items for RemoteEvent(ATCamera, 0, summaryState)
# [[None, None, None, None]]

# %%
# enable components
#await atcs.enable()
await latiss.enable()
# Out:
# Enabling all components
# Gathering settings.
# Couldn't get settingVersions event. Using empty settings.
# Couldn't get settingVersions event. Using empty settings.
# Couldn't get settingVersions event. Using empty settings.
# Complete settings for atcamera.
# Complete settings for atspectrograph.
# Complete settings for atheaderservice.
# Complete settings for atarchiver.
# Settings versions: {'atcamera': 'Normal', 'atspectrograph': '', 'atheaderservice': '', 'atarchiver': ''}
# [atcamera]::[<State.STANDBY: 5>, <State.DISABLED: 1>, <State.ENABLED: 2>]
# Unable to transition atspectrograph to <State.ENABLED: 2> NoneType: None
# .
# Traceback (most recent call last):
#   File "/opt/lsst/src/ts_salobj/python/lsst/ts/salobj/csc_utils.py", line 129, in set_summary_state
#     state_data = await remote.evt_summaryState.aget(timeout=timeout)
#   File "/opt/lsst/src/ts_salobj/python/lsst/ts/salobj/topics/read_topic.py", line 495, in aget
#     await asyncio.wait_for(self._next_task, timeout=timeout)
#   File "/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/asyncio/tasks.py", line 498, in wait_for
#     raise exceptions.TimeoutError()
# asyncio.exceptions.TimeoutError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/lsst/src/ts_salobj/python/lsst/ts/salobj/csc_utils.py", line 131, in set_summary_state
#     raise RuntimeError(f"Cannot get summaryState from {remote.salinfo.name}")
# RuntimeError: Cannot get summaryState from ATSpectrograph
#
# Unable to transition atheaderservice to <State.ENABLED: 2> NoneType: None
# .
# Traceback (most recent call last):
#   File "/opt/lsst/src/ts_salobj/python/lsst/ts/salobj/csc_utils.py", line 129, in set_summary_state
#     state_data = await remote.evt_summaryState.aget(timeout=timeout)
#   File "/opt/lsst/src/ts_salobj/python/lsst/ts/salobj/topics/read_topic.py", line 495, in aget
#     await asyncio.wait_for(self._next_task, timeout=timeout)
#   File "/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/asyncio/tasks.py", line 498, in wait_for
#     raise exceptions.TimeoutError()
# asyncio.exceptions.TimeoutError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/lsst/src/ts_salobj/python/lsst/ts/salobj/csc_utils.py", line 131, in set_summary_state
#     raise RuntimeError(f"Cannot get summaryState from {remote.salinfo.name}")
# RuntimeError: Cannot get summaryState from ATHeaderService
#
# Unable to transition atarchiver to <State.ENABLED: 2> NoneType: None
# .
# Traceback (most recent call last):
#   File "/opt/lsst/src/ts_salobj/python/lsst/ts/salobj/csc_utils.py", line 129, in set_summary_state
#     state_data = await remote.evt_summaryState.aget(timeout=timeout)
#   File "/opt/lsst/src/ts_salobj/python/lsst/ts/salobj/topics/read_topic.py", line 495, in aget
#     await asyncio.wait_for(self._next_task, timeout=timeout)
#   File "/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/asyncio/tasks.py", line 498, in wait_for
#     raise exceptions.TimeoutError()
# asyncio.exceptions.TimeoutError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/lsst/src/ts_salobj/python/lsst/ts/salobj/csc_utils.py", line 131, in set_summary_state
#     raise RuntimeError(f"Cannot get summaryState from {remote.salinfo.name}")
# RuntimeError: Cannot get summaryState from ATArchiver
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-7-212ff7614794> in <module>
#       1 # enable components, then take 50 more biases
#       2 #await atcs.enable()
# ----> 3 await latiss.enable()
#
# ~/auto-op-env-packages/ts_observatory_control/python/lsst/ts/observatory/control/remote_group.py in enable(self, settings)
#     717         settings_all = await self.expand_settings(settings)
#     718
# --> 719         await self.set_state(salobj.State.ENABLED, settings=settings_all)
#     720
#     721     async def standby(self):
#
# ~/auto-op-env-packages/ts_observatory_control/python/lsst/ts/observatory/control/remote_group.py in set_state(self, state, settings, components)
#     691
#     692         if error_flag:
# --> 693             raise RuntimeError(
#     694                 f"Failed to transition {failed_components} to "
#     695                 f"{salobj.State(state)!r}."
#
# RuntimeError: Failed to transition ['atspectrograph', 'atheaderservice', 'atarchiver'] to <State.ENABLED: 2>.

# %%
tmp=await latiss.rem.atheaderservice.cmd_start.set_start()
print(tmp)
# Out:
# private_revCode: 5907d2d0, private_sndStamp: 1616082667.8605673, private_rcvStamp: 1616082667.8610966, private_seqNum: 2136525741, private_identity: ATHeaderService, private_origin: 235510, private_host: 0, ack: 303, error: 0, result: Done, host: 0, identity: craiglagegit@nb-craiglagegit-w-2021-10, origin: 6294, cmdtype: 10, timeout: 0.0

# %%
tmp = await latiss.rem.atheaderservice.evt_heartbeat.next(flush=True)
print(tmp)
# Out:
# private_revCode: 22bcf3c9, private_sndStamp: 1616082693.3141448, private_rcvStamp: 1616082693.3147542, private_seqNum: 51625, private_identity: ATHeaderService, private_origin: 235510, private_host: 0, heartbeat: False, priority: 0

# %%
await salobj.set_summary_state(latiss.rem.atheaderservice, salobj.State.ENABLED)
# Out:
# [<State.DISABLED: 1>, <State.ENABLED: 2>]

# %%
tmp=await latiss.rem.atarchiver.cmd_start.set_start()
print(tmp)
# Out:
# private_revCode: bf6d10f2, private_sndStamp: 1616082743.5530136, private_rcvStamp: 1616082743.5536366, private_seqNum: 2036813165, private_identity: ATArchiver, private_origin: 139631, private_host: 0, ack: 303, error: 0, result: Done, host: 0, identity: craiglagegit@nb-craiglagegit-w-2021-10, origin: 6294, cmdtype: 11, timeout: 0.0

# %%
tmp = await latiss.rem.atarchiver.evt_heartbeat.next(flush=True)
print(tmp)
# Out:
# private_revCode: 97c147ae, private_sndStamp: 1616082750.9672418, private_rcvStamp: 1616082750.9677162, private_seqNum: 51452, private_identity: ATArchiver, private_origin: 139631, private_host: 0, heartbeat: False, priority: 0

# %%
await salobj.set_summary_state(latiss.rem.atarchiver, salobj.State.ENABLED)
# Out:
# [<State.DISABLED: 1>, <State.ENABLED: 2>]

# %%
# Run 1 bias as a test
await latiss.take_bias(1)
# Out:
# Generating group_id
# BIAS 0001 - 0001
# array([2021031800001])

# %%
# Run 5 more
for i in range(5):
    await asyncio.sleep(2)
    await latiss.take_bias(1)
# Out:
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# logMessage DDS read queue is filling: 16 of 100 elements
# logMessage DDS read queue is filling: 21 of 100 elements
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# logMessage DDS read queue is filling: 10 of 100 elements
# logMessage DDS read queue is filling: 12 of 100 elements
# Generating group_id
# BIAS 0001 - 0001

# %%
await latiss.standby()
# Out:
# [atcamera]::[<State.STANDBY: 5>]
# Unable to transition atspectrograph to <State.STANDBY: 5> NoneType: None
# .
# Traceback (most recent call last):
#   File "/opt/lsst/src/ts_salobj/python/lsst/ts/salobj/csc_utils.py", line 129, in set_summary_state
#     state_data = await remote.evt_summaryState.aget(timeout=timeout)
#   File "/opt/lsst/src/ts_salobj/python/lsst/ts/salobj/topics/read_topic.py", line 495, in aget
#     await asyncio.wait_for(self._next_task, timeout=timeout)
#   File "/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-0.4.1/lib/python3.8/asyncio/tasks.py", line 498, in wait_for
#     raise exceptions.TimeoutError()
# asyncio.exceptions.TimeoutError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/lsst/src/ts_salobj/python/lsst/ts/salobj/csc_utils.py", line 131, in set_summary_state
#     raise RuntimeError(f"Cannot get summaryState from {remote.salinfo.name}")
# RuntimeError: Cannot get summaryState from ATSpectrograph
#
# [atheaderservice]::[<State.ENABLED: 2>, <State.DISABLED: 1>, <State.STANDBY: 5>]
# [atarchiver]::[<State.ENABLED: 2>, <State.DISABLED: 1>, <State.STANDBY: 5>]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-17-f9bd0e22ebe4> in <module>
# ----> 1 await latiss.standby()
#
# ~/auto-op-env-packages/ts_observatory_control/python/lsst/ts/observatory/control/remote_group.py in standby(self)
#     723         """
#     724
# --> 725         await self.set_state(salobj.State.STANDBY)
#     726
#     727     def set_rem_loglevel(self, level):
#
# ~/auto-op-env-packages/ts_observatory_control/python/lsst/ts/observatory/control/remote_group.py in set_state(self, state, settings, components)
#     691
#     692         if error_flag:
# --> 693             raise RuntimeError(
#     694                 f"Failed to transition {failed_components} to "
#     695                 f"{salobj.State(state)!r}."
#
# RuntimeError: Failed to transition ['atspectrograph'] to <State.STANDBY: 5>.
