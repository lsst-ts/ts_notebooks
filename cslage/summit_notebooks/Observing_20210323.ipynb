# %%
import sys
import asyncio
import time
import os

import numpy as np

from lsst.ts import salobj

from lsst.ts.observatory.control.auxtel.atcs import ATCS
from lsst.ts.observatory.control.auxtel.latiss import LATISS
from lsst.ts.observatory.control.utils import RotType

# %%
# for tab completion to work in current notebook instance
# %config IPCompleter.use_jedi = False

# %%
import logging
stream_handler = logging.StreamHandler(sys.stdout)
logger = logging.getLogger()
logger.addHandler(stream_handler)
logger.level = logging.DEBUG
# Make matplotlib less chatty
logging.getLogger("matplotlib").setLevel(logging.WARNING)

# %%
#Start classes
domain = salobj.Domain()
await asyncio.sleep(10) # This can be removed in the future...
atcs = ATCS(domain)
latiss = LATISS(domain)
await asyncio.gather(atcs.start_task, latiss.start_task)
# Out:
# atmcs: Adding all resources.
# atptg: Adding all resources.
# ataos: Adding all resources.
# atpneumatics: Adding all resources.
# athexapod: Adding all resources.
# atdome: Adding all resources.
# atdometrajectory: Adding all resources.
# atcamera: Adding all resources.
# atspectrograph: Adding all resources.
# atheaderservice: Adding all resources.
# atarchiver: Adding all resources.
# Read historical data in 0.01 sec
# Read 8 history items for RemoteEvent(ATHexapod, 0, appliedSettingsMatchStart)
# Read 100 history items for RemoteEvent(ATHexapod, 0, detailedState)
# Read 100 history items for RemoteEvent(ATHexapod, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATHexapod, 0, inPosition)
# Read 62 history items for RemoteEvent(ATHexapod, 0, logMessage)
# Read 100 history items for RemoteEvent(ATHexapod, 0, positionUpdate)
# Read 1 history items for RemoteEvent(ATHexapod, 0, readyForCommand)
# Read 7 history items for RemoteEvent(ATHexapod, 0, settingsApplied)
# Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedPivot)
# Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedPositionLimits)
# Read 7 history items for RemoteEvent(ATHexapod, 0, settingsAppliedTcp)
# Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedVelocities)
# Read 14 history items for RemoteEvent(ATHexapod, 0, summaryState)
# Read historical data in 0.07 sec
# positionStatus DDS read queue is filling: 17 of 100 elements
# Read 100 history items for RemoteEvent(ATHeaderService, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATHeaderService, 0, largeFileObjectAvailable)
# Read 100 history items for RemoteEvent(ATHeaderService, 0, logMessage)
# Read 10 history items for RemoteEvent(ATHeaderService, 0, summaryState)
# Read historical data in 0.09 sec
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, algorithm)
# Read 6 history items for RemoteEvent(ATDomeTrajectory, 0, appliedSettingsMatchStart)
# Read 100 history items for RemoteEvent(ATDomeTrajectory, 0, heartbeat)
# Read 28 history items for RemoteEvent(ATDomeTrajectory, 0, logMessage)
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, settingsApplied)
# Read 25 history items for RemoteEvent(ATDomeTrajectory, 0, summaryState)
# Read historical data in 0.10 sec
# Read 100 history items for RemoteEvent(ATArchiver, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATArchiver, 0, imageInOODS)
# Read 100 history items for RemoteEvent(ATArchiver, 0, imageRetrievalForArchiving)
# Read 4 history items for RemoteEvent(ATArchiver, 0, summaryState)
# Read historical data in 0.12 sec
# Read 5 history items for RemoteEvent(ATSpectrograph, 0, appliedSettingsMatchStart)
# Read 82 history items for RemoteEvent(ATSpectrograph, 0, disperserInPosition)
# Read 2 history items for RemoteEvent(ATSpectrograph, 0, errorCode)
# Read 82 history items for RemoteEvent(ATSpectrograph, 0, filterInPosition)
# Read 3 history items for RemoteEvent(ATSpectrograph, 0, fwState)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, gwState)
# Read 100 history items for RemoteEvent(ATSpectrograph, 0, heartbeat)
# Read 4 history items for RemoteEvent(ATSpectrograph, 0, logMessage)
# Read 42 history items for RemoteEvent(ATSpectrograph, 0, reportedDisperserPosition)
# Read 42 history items for RemoteEvent(ATSpectrograph, 0, reportedFilterPosition)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, reportedLinearStagePosition)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, settingVersions)
# Read 5 history items for RemoteEvent(ATSpectrograph, 0, settingsApplied)
# Read 5 history items for RemoteEvent(ATSpectrograph, 0, settingsAppliedValues)
# Read 16 history items for RemoteEvent(ATSpectrograph, 0, summaryState)
# Read historical data in 0.16 sec
# Read 7 history items for RemoteEvent(ATAOS, 0, appliedSettingsMatchStart)
# Read 92 history items for RemoteEvent(ATAOS, 0, atspectrographCorrectionCompleted)
# Read 92 history items for RemoteEvent(ATAOS, 0, atspectrographCorrectionStarted)
# Read 7 history items for RemoteEvent(ATAOS, 0, correctionEnabled)
# Read 99 history items for RemoteEvent(ATAOS, 0, correctionOffsets)
# Read 100 history items for RemoteEvent(ATAOS, 0, detailedState)
# Read 2 history items for RemoteEvent(ATAOS, 0, errorCode)
# Read 99 history items for RemoteEvent(ATAOS, 0, focusOffsetSummary)
# Read 100 history items for RemoteEvent(ATAOS, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATAOS, 0, hexapodCorrectionCompleted)
# Read 100 history items for RemoteEvent(ATAOS, 0, hexapodCorrectionStarted)
# Read 100 history items for RemoteEvent(ATAOS, 0, logMessage)
# Read 100 history items for RemoteEvent(ATAOS, 0, m1CorrectionCompleted)
# Read 100 history items for RemoteEvent(ATAOS, 0, m1CorrectionStarted)
# Read 92 history items for RemoteEvent(ATAOS, 0, pointingOffsetSummary)
# Read 3 history items for RemoteEvent(ATAOS, 0, settingsApplied)
# Read 26 history items for RemoteEvent(ATAOS, 0, summaryState)
# Read historical data in 0.22 sec
# Read 47 history items for RemoteEvent(ATDome, 0, allAxesInPosition)
# Read 11 history items for RemoteEvent(ATDome, 0, appliedSettingsMatchStart)
# Read 28 history items for RemoteEvent(ATDome, 0, azimuthCommandedState)
# Read 51 history items for RemoteEvent(ATDome, 0, azimuthInPosition)
# Read 49 history items for RemoteEvent(ATDome, 0, azimuthState)
# Read 100 history items for RemoteEvent(ATDome, 0, doorEncoderExtremes)
# Read 3 history items for RemoteEvent(ATDome, 0, dropoutDoorCommandedState)
# Read 1 history items for RemoteEvent(ATDome, 0, dropoutDoorState)
# Read 1 history items for RemoteEvent(ATDome, 0, emergencyStop)
# Read 7 history items for RemoteEvent(ATDome, 0, errorCode)
# Read 100 history items for RemoteEvent(ATDome, 0, heartbeat)
# Read 22 history items for RemoteEvent(ATDome, 0, lastAzimuthGoTo)
# Read 7 history items for RemoteEvent(ATDome, 0, logMessage)
# Read 4 history items for RemoteEvent(ATDome, 0, mainDoorCommandedState)
# Read 3 history items for RemoteEvent(ATDome, 0, mainDoorState)
# Read 51 history items for RemoteEvent(ATDome, 0, moveCode)
# Read 8 history items for RemoteEvent(ATDome, 0, scbLink)
# Read 7 history items for RemoteEvent(ATDome, 0, settingsApplied)
# Read 8 history items for RemoteEvent(ATDome, 0, settingsAppliedDomeController)
# Read 11 history items for RemoteEvent(ATDome, 0, settingsAppliedDomeTcp)
# Read 4 history items for RemoteEvent(ATDome, 0, shutterInPosition)
# Read 28 history items for RemoteEvent(ATDome, 0, summaryState)
# Read historical data in 0.27 sec
# Read 4 history items for RemoteEvent(ATPneumatics, 0, appliedSettingsMatchStart)
# Read 6 history items for RemoteEvent(ATPneumatics, 0, cellVentsState)
# Read 1 history items for RemoteEvent(ATPneumatics, 0, eStop)
# Read 100 history items for RemoteEvent(ATPneumatics, 0, heartbeat)
# Read 5 history items for RemoteEvent(ATPneumatics, 0, instrumentState)
# Read 17 history items for RemoteEvent(ATPneumatics, 0, m1CoverLimitSwitches)
# Read 10 history items for RemoteEvent(ATPneumatics, 0, m1CoverState)
# Read 100 history items for RemoteEvent(ATPneumatics, 0, m1SetPressure)
# Read 6 history items for RemoteEvent(ATPneumatics, 0, m1State)
# Read 1 history items for RemoteEvent(ATPneumatics, 0, m1VentsLimitSwitches)
# Read 3 history items for RemoteEvent(ATPneumatics, 0, m1VentsPosition)
# Read 7 history items for RemoteEvent(ATPneumatics, 0, m2State)
# Read 5 history items for RemoteEvent(ATPneumatics, 0, mainValveState)
# Read 4 history items for RemoteEvent(ATPneumatics, 0, settingVersions)
# Read 15 history items for RemoteEvent(ATPneumatics, 0, summaryState)
# Read historical data in 0.30 sec
# Read 1 history items for RemoteEvent(ATCamera, 0, appliedSettingsMatchStart)
# Read 100 history items for RemoteEvent(ATCamera, 0, ccsCommandState)
# Read 100 history items for RemoteEvent(ATCamera, 0, endOfImageTelemetry)
# Read 100 history items for RemoteEvent(ATCamera, 0, endReadout)
# Read 50 history items for RemoteEvent(ATCamera, 0, endShutterClose)
# Read 49 history items for RemoteEvent(ATCamera, 0, endShutterOpen)
# Read 1 history items for RemoteEvent(ATCamera, 0, focalPlaneHardwareIdSettingsApplied)
# Read 1 history items for RemoteEvent(ATCamera, 0, focalPlaneSummaryInfo)
# Read 100 history items for RemoteEvent(ATCamera, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATCamera, 0, imageReadinessDetailedState)
# Read 100 history items for RemoteEvent(ATCamera, 0, imageReadoutParameters)
# Read 100 history items for RemoteEvent(ATCamera, 0, raftsDetailedState)
# Read 1 history items for RemoteEvent(ATCamera, 0, settingVersions)
# Read 100 history items for RemoteEvent(ATCamera, 0, shutterDetailedState)
# Read 50 history items for RemoteEvent(ATCamera, 0, shutterMotionProfile)
# Read 1 history items for RemoteEvent(ATCamera, 0, softwareVersions)
# Read 100 history items for RemoteEvent(ATCamera, 0, startIntegration)
# Read 100 history items for RemoteEvent(ATCamera, 0, startReadout)
# Read 4 history items for RemoteEvent(ATCamera, 0, summaryState)
# Read historical data in 0.37 sec
# Read 16 history items for RemoteEvent(ATPtg, 0, airmassWarning)
# Read 5 history items for RemoteEvent(ATPtg, 0, currentDebugLevel)
# Read 100 history items for RemoteEvent(ATPtg, 0, currentTarget)
# Read 84 history items for RemoteEvent(ATPtg, 0, detailedState)
# Read 4 history items for RemoteEvent(ATPtg, 0, errorCode)
# Read 5 history items for RemoteEvent(ATPtg, 0, focusNameSelected)
# Read 100 history items for RemoteEvent(ATPtg, 0, heartbeat)
# Read 11 history items for RemoteEvent(ATPtg, 0, iers)
# Read 2 history items for RemoteEvent(ATPtg, 0, iersOutOfDate)
# Read 1 history items for RemoteEvent(ATPtg, 0, mountDataWarning)
# Read 5 history items for RemoteEvent(ATPtg, 0, pointingModel)
# Read 1 history items for RemoteEvent(ATPtg, 0, ptgAzCurrentWrap)
# Read 1 history items for RemoteEvent(ATPtg, 0, ptgRotCurrentWrap)
# Read 18 history items for RemoteEvent(ATPtg, 0, summaryState)
# Read 100 history items for RemoteEvent(ATPtg, 0, timesOfLimits)
# Read 80 history items for RemoteEvent(ATPtg, 0, trackPosting)
# Read 5 history items for RemoteEvent(ATPtg, 0, wavelength)
# Read 100 history items for RemoteEvent(ATPtg, 0, weatherDataApplied)
# Read 100 history items for RemoteEvent(ATPtg, 0, weatherDataInvalid)
# Read historical data in 0.43 sec
# Read 100 history items for RemoteEvent(ATMCS, 0, allAxesInPosition)
# Read 4 history items for RemoteEvent(ATMCS, 0, appliedSettingsMatchStart)
# Read 100 history items for RemoteEvent(ATMCS, 0, atMountState)
# Read 8 history items for RemoteEvent(ATMCS, 0, azimuthBrake1)
# Read 8 history items for RemoteEvent(ATMCS, 0, azimuthBrake2)
# Read 8 history items for RemoteEvent(ATMCS, 0, azimuthDrive1Status)
# Read 8 history items for RemoteEvent(ATMCS, 0, azimuthDrive2Status)
# Read 100 history items for RemoteEvent(ATMCS, 0, azimuthInPosition)
# Read 1 history items for RemoteEvent(ATMCS, 0, azimuthLimitSwitchCCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, azimuthLimitSwitchCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, azimuthToppleBlockCCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, azimuthToppleBlockCW)
# Read 8 history items for RemoteEvent(ATMCS, 0, elevationBrake)
# Read 8 history items for RemoteEvent(ATMCS, 0, elevationDriveStatus)
# Read 100 history items for RemoteEvent(ATMCS, 0, elevationInPosition)
# Read 1 history items for RemoteEvent(ATMCS, 0, elevationLimitSwitchLower)
# Read 1 history items for RemoteEvent(ATMCS, 0, elevationLimitSwitchUpper)
# Read 100 history items for RemoteEvent(ATMCS, 0, heartbeat)
# Read 1 history items for RemoteEvent(ATMCS, 0, m3DriveStatus)
# Read 1 history items for RemoteEvent(ATMCS, 0, m3InPosition)
# Read 1 history items for RemoteEvent(ATMCS, 0, m3RotatorDetentSwitches)
# Read 1 history items for RemoteEvent(ATMCS, 0, m3RotatorLimitSwitchCCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, m3RotatorLimitSwitchCW)
# Read 8 history items for RemoteEvent(ATMCS, 0, m3State)
# Read 8 history items for RemoteEvent(ATMCS, 0, nasmyth1Brake)
# Read 8 history items for RemoteEvent(ATMCS, 0, nasmyth1DriveStatus)
# Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth1LimitSwitchCCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth1LimitSwitchCW)
# Read 4 history items for RemoteEvent(ATMCS, 0, nasmyth1RotatorInPosition)
# Read 8 history items for RemoteEvent(ATMCS, 0, nasmyth2Brake)
# Read 8 history items for RemoteEvent(ATMCS, 0, nasmyth2DriveStatus)
# Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth2LimitSwitchCCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth2LimitSwitchCW)
# Read 100 history items for RemoteEvent(ATMCS, 0, nasmyth2RotatorInPosition)
# Read 4 history items for RemoteEvent(ATMCS, 0, positionLimits)
# Read 4 history items for RemoteEvent(ATMCS, 0, settingVersions)
# Read 15 history items for RemoteEvent(ATMCS, 0, summaryState)
# Read 100 history items for RemoteEvent(ATMCS, 0, target)
# position DDS read queue is filling: 69 of 100 elements
# mainAirSourcePressure DDS read queue is filling: 19 of 100 elements
# timeAndDate DDS read queue is full (100 elements); data may be lost
# [[None, None, None, None, None, None, None], [None, None, None, None]]
# m2AirPressure DDS read queue is filling: 19 of 100 elements
# trajectory DDS read queue is filling: 33 of 100 elements
# m1AirPressure DDS read queue is filling: 19 of 100 elements
# mountStatus DDS read queue is full (100 elements); data may be lost
# torqueDemand DDS read queue is filling: 33 of 100 elements
# loadCell DDS read queue is filling: 19 of 100 elements
# mountPositions DDS read queue is filling: 32 of 100 elements
# nasymth_m3_mountMotorEncoders DDS read queue is filling: 33 of 100 elements
# guidingAndOffsets DDS read queue is full (100 elements); data may be lost
# mount_Nasmyth_Encoders DDS read queue is filling: 33 of 100 elements
# currentTargetStatus DDS read queue is full (100 elements); data may be lost
# mount_AzEl_Encoders DDS read queue is filling: 33 of 100 elements
# measuredTorque DDS read queue is filling: 34 of 100 elements
# mount_AzEl_Encoders python read queue is filling: 32 of 100 elements
# measuredMotorVelocity DDS read queue is filling: 34 of 100 elements
# azEl_mountMotorEncoders DDS read queue is filling: 34 of 100 elements

# %%
# enable components
# already enabled
#await atcs.enable({"atdome": "current", "ataos": "current", "athexapod": "current"})
#await latiss.enable()

# %%
await latiss.take_bias(1)
# Out:
# Generating group_id
# BIAS 0001 - 0001
# array([2021032300173])

# %%
# Take 50 biases seq # 174-223
# Added wait to stop killing the recent images
for i in range(50):
    await asyncio.sleep(2.0)
    await latiss.take_bias(1)
# Out:
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# logMessage DDS read queue is filling: 10 of 100 elements
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# logMessage DDS read queue is filling: 12 of 100 elements
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001

# %%
# Take 10 10 second darks 224-233
await latiss.take_darks(10.0, 10)
# Out:
# Generating group_id
# DARK 0001 - 0010
# DARK 0002 - 0010
# logMessage DDS read queue is filling: 16 of 100 elements
# DARK 0003 - 0010
# DARK 0004 - 0010
# DARK 0005 - 0010
# DARK 0006 - 0010
# DARK 0007 - 0010
# DARK 0008 - 0010
# DARK 0009 - 0010
# DARK 0010 - 0010
# array([2021032300224, 2021032300225, 2021032300226, 2021032300227,
#        2021032300228, 2021032300229, 2021032300230, 2021032300231,
#        2021032300232, 2021032300233])

# %%
atcs.check.atdome = True
atcs.check.atdometrajectory = True

# %%
await salobj.set_summary_state(atcs.rem.atdome, salobj.State.ENABLED, settingsToApply='current')
# Out:
# [<State.DISABLED: 1>, <State.ENABLED: 2>]

# %%
await salobj.set_summary_state(atcs.rem.atdometrajectory, salobj.State.ENABLED, settingsToApply='current')
# Out:
# [<State.DISABLED: 1>, <State.ENABLED: 2>]

# %%
await atcs.prepare_for_flatfield()
# Out:
# Cover state <MirrorCoverState.OPENED: 7>
# M1 cover already opened.
# Sending command
# Stop tracking.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got True
# Waiting for telescope to settle.
# [Telescope] delta Alt = -000.001 deg; delta Az= +000.001 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# Axes in position.
# Stop tracking.
# Tracking state: <AtMountState.TRACKINGENABLED: 9>
# Tracking state: <AtMountState.STOPPING: 10>
# Sending ATDomeTrajectory to DISABED state. Component will be left in DISABLEDstate or else it may send the ATDome back to alignment with the telescope.
# process as completed...
# atdometrajectory: <State.DISABLED: 1>
# [Dome] delta Az = +002.970 deg
# Axes in position.

# %%
# Take 10 2 second flats 234-243
await latiss.take_flats(2.0, 10, filter='RG610', grating='empty_1')
# Out:
# Generating group_id
# FLAT 0001 - 0010
# FLAT 0002 - 0010
# FLAT 0003 - 0010
# FLAT 0004 - 0010
# FLAT 0005 - 0010
# FLAT 0006 - 0010
# FLAT 0007 - 0010
# FLAT 0008 - 0010
# FLAT 0009 - 0010
# FLAT 0010 - 0010
# array([2021032300234, 2021032300235, 2021032300236, 2021032300237,
#        2021032300238, 2021032300239, 2021032300240, 2021032300241,
#        2021032300242, 2021032300243])

# %%
# Take flats for PTC 244-283
# Added wait to stop killing the recent images
for i in range(20):
    exp = 0.2 * float(i+1)
    await latiss.take_flats(exp, 1, filter='empty_1', grating='empty_1')
    if exp < 2.0:
        await asyncio.sleep(2.0)
    await latiss.take_flats(exp, 1, filter='empty_1', grating='empty_1')
# Out:
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# logMessage DDS read queue is filling: 14 of 100 elements
# logMessage DDS read queue is filling: 10 of 100 elements
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# logMessage DDS read queue is filling: 10 of 100 elements
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001
# Generating group_id
# FLAT 0001 - 0001

# %%
await atcs.prepare_for_onsky()
# Out:
# Enabling all components
# Gathering settings.
# Couldn't get settingVersions event. Using empty settings.
# Couldn't get settingVersions event. Using empty settings.
# Couldn't get settingVersions event. Using empty settings.
# Couldn't get settingVersions event. Using empty settings.
# Couldn't get settingVersions event. Using empty settings.
# Complete settings for atmcs.
# Complete settings for atptg.
# Complete settings for ataos.
# Complete settings for atpneumatics.
# Complete settings for athexapod.
# Complete settings for atdome.
# Complete settings for atdometrajectory.
# Settings versions: {'atmcs': '', 'atptg': '', 'ataos': '', 'atpneumatics': '', 'athexapod': '', 'atdome': '', 'atdometrajectory': ''}
# [atmcs]::[<State.ENABLED: 2>]
# [atptg]::[<State.ENABLED: 2>]
# [ataos]::[<State.ENABLED: 2>]
# [atpneumatics]::[<State.ENABLED: 2>]
# [athexapod]::[<State.ENABLED: 2>]
# [atdome]::[<State.ENABLED: 2>]
# [atdometrajectory]::[<State.ENABLED: 2>]
# All components in <State.ENABLED: 2>.
# Slew telescope to park position.
# Sending command
# Stop tracking.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# [Telescope] delta Alt = +040.999 deg; delta Az= +154.301 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +037.416 deg; delta Az= +157.887 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +031.417 deg; delta Az= +163.886 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +025.415 deg; delta Az= +169.886 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +019.514 deg; delta Az= +175.887 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +013.946 deg; delta Az= -178.114 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +009.027 deg; delta Az= -172.113 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +005.049 deg; delta Az= -166.114 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +002.229 deg; delta Az= -160.112 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +001.031 deg; delta Az= -156.114 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.151 deg; delta Az= -150.113 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.007 deg; delta Az= -146.114 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -140.114 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -134.114 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -130.114 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -126.112 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -122.114 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -116.113 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -110.114 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -104.113 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -100.114 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -094.113 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -090.113 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -086.113 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -080.113 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -074.114 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -070.112 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -066.114 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -060.113 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -056.114 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -052.114 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -048.112 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -046.113 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -040.115 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -034.113 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -030.113 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -024.117 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -020.187 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -014.565 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -011.137 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -008.072 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -006.702 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -004.332 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -002.493 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -001.202 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.204 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# Got True
# Waiting for telescope to settle.
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.001 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# Axes in position.
# Stop tracking.
# Tracking state: <AtMountState.TRACKINGENABLED: 9>
# Tracking state: <AtMountState.STOPPING: 10>
# In Position: True.
# Cover state <MirrorCoverState.OPENED: 7>
# Closing M1 cover.
# Using nasmyth port <Foci.NASMYTH2: 3>
# Cover state <MirrorCoverState.INMOTION: 8>
# Cover state <MirrorCoverState.CLOSED: 6>
# Homing dome azimuth.
# Dome azimuth still homing.
# Dome azimuth still homing.
# Dome azimuth still homing.
# Dome azimuth homed successfully.
# Moving dome to 90 degrees.
# Sending ATDomeTrajectory to DISABED state. Component will be left in DISABLEDstate or else it may send the ATDome back to alignment with the telescope.
# process as completed...
# atdometrajectory: <State.DISABLED: 1>
# [Dome] delta Az = +089.970 deg
# [Dome] delta Az = +089.330 deg
# [Dome] delta Az = +088.490 deg
# [Dome] delta Az = +087.390 deg
# [Dome] delta Az = +086.060 deg
# [Dome] delta Az = +084.510 deg
# [Dome] delta Az = +082.710 deg
# [Dome] delta Az = +080.700 deg
# [Dome] delta Az = +078.430 deg
# [Dome] delta Az = +075.960 deg
# [Dome] delta Az = +073.250 deg
# [Dome] delta Az = +070.290 deg
# [Dome] delta Az = +067.110 deg
# [Dome] delta Az = +063.730 deg
# [Dome] delta Az = +060.280 deg
# [Dome] delta Az = +056.790 deg
# [Dome] delta Az = +053.330 deg
# [Dome] delta Az = +049.850 deg
# [Dome] delta Az = +046.420 deg
# [Dome] delta Az = +042.950 deg
# [Dome] delta Az = +039.500 deg
# [Dome] delta Az = +036.030 deg
# [Dome] delta Az = +032.540 deg
# [Dome] delta Az = +029.090 deg
# [Dome] delta Az = +025.620 deg
# [Dome] delta Az = +022.190 deg
# [Dome] delta Az = +018.740 deg
# [Dome] delta Az = +015.260 deg
# [Dome] delta Az = +011.820 deg
# [Dome] delta Az = +008.340 deg
# [Dome] delta Az = +004.890 deg
# ATDome in position.
# Axes in position.
# Check that dome CSC can communicate with shutter control box.
# Opening dome.
# Opening dome shutter...
# process as completed...
# atdome: <State.ENABLED: 2>
# Waiting for ATDome mainDoorState: <ShutterDoorState.OPENED: 2>. Current state: <ShutterDoorState.CLOSED: 1>.
# mainDoorState: <ShutterDoorState.OPENING: 4>
# mainDoorState: <ShutterDoorState.OPENED: 2>
# Finishing ATDome shutter command task.
# ATDome shutter command task not done. Cancelling.
# ATDome shutter command task cancelled.
# Open telescope cover.
# Cover state <MirrorCoverState.CLOSED: 6>
# Opening M1 cover.
# Cover state <MirrorCoverState.INMOTION: 8>
# Cover state <MirrorCoverState.OPENED: 7>
# M1 vent state <VentsPosition.CLOSED: 1>
# Opening M1 vents.
# M1 vent state <VentsPosition.PARTIALLYOPENED: 2>
# M1 vent state <VentsPosition.OPENED: 0>
# Enabling all components
# Gathering settings.
# atdometrajectory check is disabled, skipping.
# Couldn't get settingVersions event. Using empty settings.
# Couldn't get settingVersions event. Using empty settings.
# Couldn't get settingVersions event. Using empty settings.
# Couldn't get settingVersions event. Using empty settings.
# Complete settings for atmcs.
# Complete settings for atptg.
# Complete settings for ataos.
# Complete settings for atpneumatics.
# Complete settings for athexapod.
# Complete settings for atdome.
# Settings versions: {'atmcs': '', 'atptg': '', 'ataos': '', 'atpneumatics': '', 'athexapod': '', 'atdome': ''}
# [atmcs]::[<State.ENABLED: 2>]
# [atptg]::[<State.ENABLED: 2>]
# [ataos]::[<State.ENABLED: 2>]
# [atpneumatics]::[<State.ENABLED: 2>]
# [athexapod]::[<State.ENABLED: 2>]
# [atdome]::[<State.ENABLED: 2>]
# [atdometrajectory]::<State.DISABLED: 1>
# All components in <State.ENABLED: 2>.
# Enable ATAOS corrections.

# %%
# Opens/Closes dropout shutter
await atcs.rem.atdome.cmd_moveShutterDropoutDoor.set_start(open=False)

# %%
# Don't forget the 'settingsToApply='current' or it won't work!!
#await salobj.set_summary_state(atcs.rem.ataos, salobj.State.ENABLED, settingsToApply='current')

# %%
await atcs.rem.ataos.cmd_enableCorrection.set_start(
    m1=True, hexapod=True, atspectrograph=True, timeout=atcs.long_timeout
)

# %%
# HD72514 Az~120, Alt~65 m=8.05

# %%
current_az = 120.0
current_el = 65.0
current_rot = -50.0
await atcs.point_azel(current_az, current_el, rot_tel=current_rot)

# %%
await salobj.set_summary_state(atcs.rem.atptg, salobj.State.ENABLED)
# Out:
# [<State.STANDBY: 5>, <State.DISABLED: 1>, <State.ENABLED: 2>]

# %%
await salobj.set_summary_state(atcs.rem.atmcs, salobj.State.ENABLED)
# Out:
# [<State.STANDBY: 5>, <State.DISABLED: 1>, <State.ENABLED: 2>]

# %%
await salobj.set_summary_state(atcs.rem.atdometrajectory, salobj.State.ENABLED)
# Out:
# [<State.DISABLED: 1>, <State.ENABLED: 2>]

# %%
#await latiss.setup_instrument()

# %%
#await latiss.setup_instrument

# %%
await latiss.setup_atspec(filter='RG610')

# %%
# HD55070 m = 5.45, Az = +85, Alt = +74
# HD78876 m = 7.2, Az = +90, Alt = +60
# HD72514 m = 7.6
await atcs.slew_object('HD 90105', rot=-110.0, rot_type=RotType.PhysicalSky)
# Out:
# Resetting dropped connection: simbad.u-strasbg.fr
# http://simbad.u-strasbg.fr:80 "POST /simbad/sim-script HTTP/1.1" 200 None
# Slewing to HD 90105: 08 42 05.4696 -89 27 37.932
# Setting rotator physical position to -110.0 deg. Rotator will track sky.
# Parallactic angle: 113.38997235631588 | Sky Angle: 153.40357165375008
# Sending command
# Stop tracking.
# target python read queue is filling: 16 of 100 elements
# Tracking state: <AtMountState.TRACKINGENABLED: 9>
# Tracking state: <AtMountState.STOPPING: 10>
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# atdome: <State.ENABLED: 2>
# atdometrajectory: <State.ENABLED: 2>
# [Telescope] delta Alt = -001.345 deg; delta Az = +030.748 deg; delta N1 = -000.000 deg; delta N2 = +000.622 deg [Dome] delta Az = +028.507 deg
# [Telescope] delta Alt = -000.666 deg; delta Az = +030.422 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = +027.197 deg
# [Telescope] delta Alt = +000.000 deg; delta Az = +028.181 deg; delta N1 = -000.000 deg; delta N2 = +000.004 deg [Dome] delta Az = +023.737 deg
# [Telescope] delta Alt = +000.000 deg; delta Az = +024.005 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg [Dome] delta Az = +020.257 deg
# [Telescope] delta Alt = -000.000 deg; delta Az = +020.439 deg; delta N1 = -000.000 deg; delta N2 = +000.005 deg [Dome] delta Az = +013.327 deg
# [Telescope] delta Alt = -000.000 deg; delta Az = +014.557 deg; delta N1 = -000.000 deg; delta N2 = +000.004 deg [Dome] delta Az = +004.977 deg
# ATDome in position.
# [Telescope] delta Alt = -000.000 deg; delta Az = +008.889 deg; delta N1 = +000.000 deg; delta N2 = +000.004 deg [Dome] delta Az = -001.823 deg
# [Telescope] delta Alt = +000.000 deg; delta Az = +004.298 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg [Dome] delta Az = -002.503 deg
# [Telescope] delta Alt = -000.000 deg; delta Az = +002.139 deg; delta N1 = +000.000 deg; delta N2 = -000.001 deg [Dome] delta Az = -002.503 deg
# [Telescope] delta Alt = -000.000 deg; delta Az = +000.776 deg; delta N1 = -000.000 deg; delta N2 = +000.005 deg [Dome] delta Az = -002.503 deg
# [Telescope] delta Alt = +000.000 deg; delta Az = +000.029 deg; delta N1 = -000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -002.503 deg
# Got True
# Waiting for telescope to settle.
# [Telescope] delta Alt = -000.000 deg; delta Az = -000.000 deg; delta N1 = -000.000 deg; delta N2 = +000.005 deg [Dome] delta Az = -002.503 deg
# Telescope in position.

# %%
await latiss.take_object(5.0, 1, filter='RG610', grating='empty_1')
# Out:
# Generating group_id
# OBJECT 0001 - 0001
# array([2021032300643])

# %%
await atcs.add_point_data()

# %%
#await latiss.setup_atspec(filter='RG610', grating='empty_1')
# Out:
# [<ddsutil.ATSpectrograph_ackcmd_6d105732 at 0x7fad6c53ccd0>,
#  <ddsutil.ATSpectrograph_ackcmd_6d105732 at 0x7fad6c53cf40>]

# %%
# Take a set of images on both sides of current best focus
# ran with -0.40 and 0.05, which gave twice as many as needed

starting_z_offset = -0.20
z_offset_increment = 0.05
nsteps = int((-2 * starting_z_offset) / z_offset_increment) + 1
total_z_offset = 0.0
await atcs.rem.ataos.cmd_offset.set_start(z=starting_z_offset)
total_z_offset += starting_z_offset
print(f"Total z offset = {total_z_offset}")
await asyncio.sleep(2)
for i in range(nsteps):
    await latiss.take_object(5.0, 1, filter='RG610', grating='empty_1')
    await atcs.rem.ataos.cmd_offset.set_start(z=z_offset_increment)
    total_z_offset += z_offset_increment
    print(f"Total z offset = {total_z_offset}")
    
# Put offset back where it was
await atcs.rem.ataos.cmd_offset.set_start(z=-total_z_offset)
total_z_offset -= total_z_offset
print(f"Total z offset = {total_z_offset}")
# Out:
# Total z offset = -0.2
# Generating group_id
# OBJECT 0001 - 0001
# Total z offset = -0.15000000000000002
# Generating group_id
# OBJECT 0001 - 0001
# Total z offset = -0.10000000000000002
# Generating group_id
# OBJECT 0001 - 0001
# Total z offset = -0.05000000000000002
# Generating group_id
# OBJECT 0001 - 0001
# Total z offset = -1.3877787807814457e-17
# Generating group_id
# OBJECT 0001 - 0001
# Total z offset = 0.04999999999999999
# Generating group_id
# OBJECT 0001 - 0001
# Total z offset = 0.09999999999999999
# Generating group_id
# OBJECT 0001 - 0001
# Total z offset = 0.15
# Generating group_id
# OBJECT 0001 - 0001
# Total z offset = 0.2
# Generating group_id
# OBJECT 0001 - 0001
# Total z offset = 0.25
# Total z offset = 0.0

# %%
await atcs.rem.ataos.cmd_offset.set_start(z=-0.095)

# %%
atcs.offset_xy?

# %%
# Move the star to the bottom of the field
await atcs.offset_xy(y=140, x=0)

# %%
# Currently at 2224, 162
# Want 1750, 300
# Shift x=47, y=135
await atcs.offset_xy(y=126, x=55)

# %%
# Take a set of images on both sides of current best focus
# ran with -0.40 and 0.05, which gave twice as many as needed

starting_z_offset = -0.30
z_offset_increment = 0.03
nsteps = int((-2 * starting_z_offset) / z_offset_increment) + 1
total_z_offset = 0.0
await atcs.rem.ataos.cmd_offset.set_start(z=starting_z_offset)
total_z_offset += starting_z_offset
print(f"Total z offset = {total_z_offset}")
await asyncio.sleep(2)
for i in range(nsteps):
    await latiss.take_object(25.0, 1, filter='RG610', grating='holo4_003')
    await atcs.rem.ataos.cmd_offset.set_start(z=z_offset_increment)
    total_z_offset += z_offset_increment
    print(f"Total z offset = {total_z_offset}")
    
# Put offset back where it was
await atcs.rem.ataos.cmd_offset.set_start(z=-total_z_offset)
total_z_offset -= total_z_offset
print(f"Total z offset = {total_z_offset}")

# %%
# To reset all offsets
tmp = await atcs.rem.ataos.cmd_resetOffset.set_start(axis='y')

# %%
atcs.rem.ataos.cmd_disableCorrection.set_start?

# %%
# await atcs.slew_object('HD72514', rot=-50.0, rot_type=RotType.PhysicalSky)

# %%
#await latiss.setup_atspec(filter='RG610', grating='empty_1')

# %%
await latiss.take_object(5.0, 1, filter='RG610', grating='holo4_003')

# %%
await atcs.rem.ataos.cmd_disableCorrection.set_start(atspectrograph=True)

# %%
await atcs.rem.ataos.cmd_enableCorrection.set_start(atspectrograph=True)

# %%
# ronch190lpm, ronchi170lpm, holo4_003
await latiss.setup_atspec(filter='RG610', grating='holo4_003')

# %%
# ronch190lpmm, ronchi170lpmm, holo4_003
await latiss.setup_atspec(filter='RG610', grating='holo4_003')

# %%
await latiss.take_object(5.0, 1, filter='RG610', grating='holo4_003')

# %%
await latiss.take_object(1.0, 1, filter='empty_1', grating='empty_1')

# %%
await atcs.shutdown()

# %%
await salobj.set_summary_state(atcs.rem.atdome, salobj.State.STANDBY, settingsToApply="test")

# %%
# Putting everything back in standby.
await latiss.standby()

# %%
for i in range(10):
    await latiss.take_object(0.2, 1, filter='RG610', grating='empty_1')

# %%
await latiss.take_object(1.0, 1, filter='RG610', grating='empty_1')
