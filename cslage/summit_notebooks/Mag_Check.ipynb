# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Measured [coma-X, coma-Y, focus] zernike coefficients in nm : [327.7134135805695, -42.54488551342555, -2.3900504937566893]
#De-rotated zernike coefficients: [ 280.36833908 -174.92782274   -2.39005049]

# %%
r = [327.7134135805695, -42.54488551342555, -2.3900504937]
rp = [ 280.36833908, -174.92782274,   -2.39005049]
mr = np.sqrt(r[0]**2 + r[1]**2)
mrp = np.sqrt(rp[0]**2 + rp[1]**2)
print(f"mr={mr}, mrp={mrp}")
# Out:
# mr=330.4635361488161, mrp=330.46353615343816

# %%
#Measured [coma-X, coma-Y, focus] zernike coefficients in nm : [127.50152638818119, 253.04170586388094, -211.157481730013]
#De-rotated zernike coefficients: [ 224.02647931  173.49028995 -211.15748173]

# %%
r = [127.50152638818119, 253.04170586388094, -211.157481730013]
rp = [ 224.02647931,  173.49028995, -211.15748173]
mr = np.sqrt(r[0]**2 + r[1]**2)
mrp = np.sqrt(rp[0]**2 + rp[1]**2)
print(f"mr={mr}, mrp={mrp}")
# Out:
# mr=283.3491558798418, mrp=283.3491558818712
