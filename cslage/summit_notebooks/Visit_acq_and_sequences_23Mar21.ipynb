# %% [markdown]
# ## This notebook performs a single science visit for this run for a given target
# ### This should be run AFTER performing focus on nearby star
# ##### The script, slews and acquires the target, applies focus correction, takes sequence of data

# %%
TARGET="HD60228"

# %%
import os
import sys
import asyncio
import time

import numpy as np
import logging 
import yaml
import matplotlib.pyplot as plt
import astropy

from lsst.ts import salobj
from lsst.ts.externalscripts.auxtel.latiss_cwfs_align import LatissCWFSAlign
from lsst.ts.externalscripts.auxtel.latiss_acquire_and_take_sequence import LatissAcquireAndTakeSequence

from lsst.ts.idl.enums.Script import ScriptState

# %%
print(os.environ["OSPL_URI"])
print(os.environ["LSST_DDS_PARTITION_PREFIX"])
# Out:
# file:///home/craiglagegit/WORK/ts_ddsconfig/config/ospl-shmem.xml
# summit

# %%
# for autocompleted to work
# %config IPCompleter.use_jedi = False

# %%
stream_handler = logging.StreamHandler(sys.stdout)
# if you want logging
logger = logging.getLogger()
logger.addHandler(stream_handler)
logger.level = logging.DEBUG

# turn off logging for matplotlib
mpl_logger = logging.getLogger('matplotlib')
mpl_logger.setLevel(logging.WARNING)

# %%
# make sure all remotes etc are running
script = LatissAcquireAndTakeSequence(index=1)  # this essentially calls the init method of the script
#await asyncio.sleep(10) # This can be removed in the future...
await script.start_task
# Out:
# DEBUG:Script.ATCS:atmcs: Adding all resources.
# atmcs: Adding all resources.
# DEBUG:Script.ATCS:atptg: Adding all resources.
# atptg: Adding all resources.
# DEBUG:Script.ATCS:ataos: Adding all resources.
# ataos: Adding all resources.
# DEBUG:Script.ATCS:atpneumatics: Adding all resources.
# atpneumatics: Adding all resources.
# DEBUG:Script.ATCS:athexapod: Adding all resources.
# athexapod: Adding all resources.
# DEBUG:Script.ATCS:atdome: Adding all resources.
# atdome: Adding all resources.
# DEBUG:Script.ATCS:atdometrajectory: Adding all resources.
# atdometrajectory: Adding all resources.
# DEBUG:Script.LATISS:atcamera: Adding all resources.
# atcamera: Adding all resources.
# DEBUG:Script.LATISS:atspectrograph: Adding all resources.
# atspectrograph: Adding all resources.
# DEBUG:Script.LATISS:atheaderservice: Adding all resources.
# atheaderservice: Adding all resources.
# DEBUG:Script.LATISS:atarchiver: Adding all resources.
# atarchiver: Adding all resources.
# INFO:ATPneumatics:Read historical data in 0.02 sec
# Read historical data in 0.02 sec
# DEBUG:ATPneumatics:Read 4 history items for RemoteEvent(ATPneumatics, 0, appliedSettingsMatchStart)
# Read 4 history items for RemoteEvent(ATPneumatics, 0, appliedSettingsMatchStart)
# DEBUG:ATPneumatics:Read 6 history items for RemoteEvent(ATPneumatics, 0, cellVentsState)
# Read 6 history items for RemoteEvent(ATPneumatics, 0, cellVentsState)
# DEBUG:ATPneumatics:Read 1 history items for RemoteEvent(ATPneumatics, 0, eStop)
# Read 1 history items for RemoteEvent(ATPneumatics, 0, eStop)
# DEBUG:ATPneumatics:Read 100 history items for RemoteEvent(ATPneumatics, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATPneumatics, 0, heartbeat)
# DEBUG:ATPneumatics:Read 5 history items for RemoteEvent(ATPneumatics, 0, instrumentState)
# Read 5 history items for RemoteEvent(ATPneumatics, 0, instrumentState)
# DEBUG:ATPneumatics:Read 17 history items for RemoteEvent(ATPneumatics, 0, m1CoverLimitSwitches)
# Read 17 history items for RemoteEvent(ATPneumatics, 0, m1CoverLimitSwitches)
# DEBUG:ATPneumatics:Read 10 history items for RemoteEvent(ATPneumatics, 0, m1CoverState)
# Read 10 history items for RemoteEvent(ATPneumatics, 0, m1CoverState)
# DEBUG:ATPneumatics:Read 100 history items for RemoteEvent(ATPneumatics, 0, m1SetPressure)
# Read 100 history items for RemoteEvent(ATPneumatics, 0, m1SetPressure)
# DEBUG:ATPneumatics:Read 6 history items for RemoteEvent(ATPneumatics, 0, m1State)
# Read 6 history items for RemoteEvent(ATPneumatics, 0, m1State)
# DEBUG:ATPneumatics:Read 1 history items for RemoteEvent(ATPneumatics, 0, m1VentsLimitSwitches)
# Read 1 history items for RemoteEvent(ATPneumatics, 0, m1VentsLimitSwitches)
# DEBUG:ATPneumatics:Read 3 history items for RemoteEvent(ATPneumatics, 0, m1VentsPosition)
# Read 3 history items for RemoteEvent(ATPneumatics, 0, m1VentsPosition)
# DEBUG:ATPneumatics:Read 7 history items for RemoteEvent(ATPneumatics, 0, m2State)
# Read 7 history items for RemoteEvent(ATPneumatics, 0, m2State)
# DEBUG:ATPneumatics:Read 5 history items for RemoteEvent(ATPneumatics, 0, mainValveState)
# Read 5 history items for RemoteEvent(ATPneumatics, 0, mainValveState)
# DEBUG:ATPneumatics:Read 4 history items for RemoteEvent(ATPneumatics, 0, settingVersions)
# Read 4 history items for RemoteEvent(ATPneumatics, 0, settingVersions)
# DEBUG:ATPneumatics:Read 15 history items for RemoteEvent(ATPneumatics, 0, summaryState)
# Read 15 history items for RemoteEvent(ATPneumatics, 0, summaryState)
# INFO:ATDomeTrajectory:Read historical data in 0.09 sec
# Read historical data in 0.09 sec
# WARNING:ATPneumatics.mainAirSourcePressure:mainAirSourcePressure DDS read queue is filling: 21 of 100 elements
# mainAirSourcePressure DDS read queue is filling: 21 of 100 elements
# DEBUG:ATDomeTrajectory:Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, algorithm)
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, algorithm)
# WARNING:ATPneumatics.m2AirPressure:m2AirPressure DDS read queue is filling: 21 of 100 elements
# m2AirPressure DDS read queue is filling: 21 of 100 elements
# DEBUG:ATDomeTrajectory:Read 6 history items for RemoteEvent(ATDomeTrajectory, 0, appliedSettingsMatchStart)
# Read 6 history items for RemoteEvent(ATDomeTrajectory, 0, appliedSettingsMatchStart)
# WARNING:ATPneumatics.m1AirPressure:m1AirPressure DDS read queue is filling: 21 of 100 elements
# m1AirPressure DDS read queue is filling: 21 of 100 elements
# DEBUG:ATDomeTrajectory:Read 100 history items for RemoteEvent(ATDomeTrajectory, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATDomeTrajectory, 0, heartbeat)
# WARNING:ATPneumatics.loadCell:loadCell DDS read queue is filling: 21 of 100 elements
# loadCell DDS read queue is filling: 21 of 100 elements
# DEBUG:ATDomeTrajectory:Read 29 history items for RemoteEvent(ATDomeTrajectory, 0, logMessage)
# Read 29 history items for RemoteEvent(ATDomeTrajectory, 0, logMessage)
# DEBUG:ATDomeTrajectory:Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, settingsApplied)
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, settingsApplied)
# DEBUG:ATDomeTrajectory:Read 26 history items for RemoteEvent(ATDomeTrajectory, 0, summaryState)
# Read 26 history items for RemoteEvent(ATDomeTrajectory, 0, summaryState)
# INFO:ATHeaderService:Read historical data in 0.12 sec
# Read historical data in 0.12 sec
# DEBUG:ATHeaderService:Read 100 history items for RemoteEvent(ATHeaderService, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATHeaderService, 0, heartbeat)
# DEBUG:ATHeaderService:Read 100 history items for RemoteEvent(ATHeaderService, 0, largeFileObjectAvailable)
# Read 100 history items for RemoteEvent(ATHeaderService, 0, largeFileObjectAvailable)
# DEBUG:ATHeaderService:Read 100 history items for RemoteEvent(ATHeaderService, 0, logMessage)
# Read 100 history items for RemoteEvent(ATHeaderService, 0, logMessage)
# DEBUG:ATHeaderService:Read 10 history items for RemoteEvent(ATHeaderService, 0, summaryState)
# Read 10 history items for RemoteEvent(ATHeaderService, 0, summaryState)
# INFO:ATSpectrograph:Read historical data in 0.15 sec
# Read historical data in 0.15 sec
# DEBUG:ATSpectrograph:Read 5 history items for RemoteEvent(ATSpectrograph, 0, appliedSettingsMatchStart)
# Read 5 history items for RemoteEvent(ATSpectrograph, 0, appliedSettingsMatchStart)
# DEBUG:ATSpectrograph:Read 100 history items for RemoteEvent(ATSpectrograph, 0, disperserInPosition)
# Read 100 history items for RemoteEvent(ATSpectrograph, 0, disperserInPosition)
# DEBUG:ATSpectrograph:Read 2 history items for RemoteEvent(ATSpectrograph, 0, errorCode)
# Read 2 history items for RemoteEvent(ATSpectrograph, 0, errorCode)
# DEBUG:ATSpectrograph:Read 100 history items for RemoteEvent(ATSpectrograph, 0, filterInPosition)
# Read 100 history items for RemoteEvent(ATSpectrograph, 0, filterInPosition)
# DEBUG:ATSpectrograph:Read 5 history items for RemoteEvent(ATSpectrograph, 0, fwState)
# Read 5 history items for RemoteEvent(ATSpectrograph, 0, fwState)
# DEBUG:ATSpectrograph:Read 1 history items for RemoteEvent(ATSpectrograph, 0, gwState)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, gwState)
# DEBUG:ATSpectrograph:Read 100 history items for RemoteEvent(ATSpectrograph, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATSpectrograph, 0, heartbeat)
# DEBUG:ATSpectrograph:Read 4 history items for RemoteEvent(ATSpectrograph, 0, logMessage)
# Read 4 history items for RemoteEvent(ATSpectrograph, 0, logMessage)
# DEBUG:ATSpectrograph:Read 69 history items for RemoteEvent(ATSpectrograph, 0, reportedDisperserPosition)
# Read 69 history items for RemoteEvent(ATSpectrograph, 0, reportedDisperserPosition)
# DEBUG:ATSpectrograph:Read 70 history items for RemoteEvent(ATSpectrograph, 0, reportedFilterPosition)
# Read 70 history items for RemoteEvent(ATSpectrograph, 0, reportedFilterPosition)
# DEBUG:ATSpectrograph:Read 1 history items for RemoteEvent(ATSpectrograph, 0, reportedLinearStagePosition)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, reportedLinearStagePosition)
# DEBUG:ATSpectrograph:Read 1 history items for RemoteEvent(ATSpectrograph, 0, settingVersions)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, settingVersions)
# DEBUG:ATSpectrograph:Read 5 history items for RemoteEvent(ATSpectrograph, 0, settingsApplied)
# Read 5 history items for RemoteEvent(ATSpectrograph, 0, settingsApplied)
# DEBUG:ATSpectrograph:Read 5 history items for RemoteEvent(ATSpectrograph, 0, settingsAppliedValues)
# Read 5 history items for RemoteEvent(ATSpectrograph, 0, settingsAppliedValues)
# DEBUG:ATSpectrograph:Read 16 history items for RemoteEvent(ATSpectrograph, 0, summaryState)
# Read 16 history items for RemoteEvent(ATSpectrograph, 0, summaryState)
# INFO:ATArchiver:Read historical data in 0.20 sec
# Read historical data in 0.20 sec
# DEBUG:ATArchiver:Read 100 history items for RemoteEvent(ATArchiver, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATArchiver, 0, heartbeat)
# DEBUG:ATArchiver:Read 100 history items for RemoteEvent(ATArchiver, 0, imageInOODS)
# Read 100 history items for RemoteEvent(ATArchiver, 0, imageInOODS)
# DEBUG:ATArchiver:Read 100 history items for RemoteEvent(ATArchiver, 0, imageRetrievalForArchiving)
# Read 100 history items for RemoteEvent(ATArchiver, 0, imageRetrievalForArchiving)
# DEBUG:ATArchiver:Read 4 history items for RemoteEvent(ATArchiver, 0, summaryState)
# Read 4 history items for RemoteEvent(ATArchiver, 0, summaryState)
# INFO:ATAOS:Read historical data in 0.23 sec
# Read historical data in 0.23 sec
# DEBUG:ATAOS:Read 7 history items for RemoteEvent(ATAOS, 0, appliedSettingsMatchStart)
# Read 7 history items for RemoteEvent(ATAOS, 0, appliedSettingsMatchStart)
# DEBUG:ATAOS:Read 100 history items for RemoteEvent(ATAOS, 0, atspectrographCorrectionCompleted)
# Read 100 history items for RemoteEvent(ATAOS, 0, atspectrographCorrectionCompleted)
# DEBUG:ATAOS:Read 100 history items for RemoteEvent(ATAOS, 0, atspectrographCorrectionStarted)
# Read 100 history items for RemoteEvent(ATAOS, 0, atspectrographCorrectionStarted)
# DEBUG:ATAOS:Read 7 history items for RemoteEvent(ATAOS, 0, correctionEnabled)
# Read 7 history items for RemoteEvent(ATAOS, 0, correctionEnabled)
# DEBUG:ATAOS:Read 100 history items for RemoteEvent(ATAOS, 0, correctionOffsets)
# Read 100 history items for RemoteEvent(ATAOS, 0, correctionOffsets)
# DEBUG:ATAOS:Read 100 history items for RemoteEvent(ATAOS, 0, detailedState)
# Read 100 history items for RemoteEvent(ATAOS, 0, detailedState)
# DEBUG:ATAOS:Read 2 history items for RemoteEvent(ATAOS, 0, errorCode)
# Read 2 history items for RemoteEvent(ATAOS, 0, errorCode)
# DEBUG:ATAOS:Read 100 history items for RemoteEvent(ATAOS, 0, focusOffsetSummary)
# Read 100 history items for RemoteEvent(ATAOS, 0, focusOffsetSummary)
# DEBUG:ATAOS:Read 100 history items for RemoteEvent(ATAOS, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATAOS, 0, heartbeat)
# DEBUG:ATAOS:Read 100 history items for RemoteEvent(ATAOS, 0, hexapodCorrectionCompleted)
# Read 100 history items for RemoteEvent(ATAOS, 0, hexapodCorrectionCompleted)
# DEBUG:ATAOS:Read 100 history items for RemoteEvent(ATAOS, 0, hexapodCorrectionStarted)
# Read 100 history items for RemoteEvent(ATAOS, 0, hexapodCorrectionStarted)
# DEBUG:ATAOS:Read 100 history items for RemoteEvent(ATAOS, 0, logMessage)
# Read 100 history items for RemoteEvent(ATAOS, 0, logMessage)
# DEBUG:ATAOS:Read 100 history items for RemoteEvent(ATAOS, 0, m1CorrectionCompleted)
# Read 100 history items for RemoteEvent(ATAOS, 0, m1CorrectionCompleted)
# DEBUG:ATAOS:Read 100 history items for RemoteEvent(ATAOS, 0, m1CorrectionStarted)
# Read 100 history items for RemoteEvent(ATAOS, 0, m1CorrectionStarted)
# DEBUG:ATAOS:Read 100 history items for RemoteEvent(ATAOS, 0, pointingOffsetSummary)
# Read 100 history items for RemoteEvent(ATAOS, 0, pointingOffsetSummary)
# DEBUG:ATAOS:Read 3 history items for RemoteEvent(ATAOS, 0, settingsApplied)
# Read 3 history items for RemoteEvent(ATAOS, 0, settingsApplied)
# DEBUG:ATAOS:Read 26 history items for RemoteEvent(ATAOS, 0, summaryState)
# Read 26 history items for RemoteEvent(ATAOS, 0, summaryState)
# INFO:ATHexapod:Read historical data in 0.31 sec
# Read historical data in 0.31 sec
# DEBUG:ATHexapod:Read 8 history items for RemoteEvent(ATHexapod, 0, appliedSettingsMatchStart)
# Read 8 history items for RemoteEvent(ATHexapod, 0, appliedSettingsMatchStart)
# DEBUG:ATHexapod:Read 100 history items for RemoteEvent(ATHexapod, 0, detailedState)
# Read 100 history items for RemoteEvent(ATHexapod, 0, detailedState)
# DEBUG:ATHexapod:Read 100 history items for RemoteEvent(ATHexapod, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATHexapod, 0, heartbeat)
# DEBUG:ATHexapod:Read 100 history items for RemoteEvent(ATHexapod, 0, inPosition)
# Read 100 history items for RemoteEvent(ATHexapod, 0, inPosition)
# DEBUG:ATHexapod:Read 100 history items for RemoteEvent(ATHexapod, 0, logMessage)
# Read 100 history items for RemoteEvent(ATHexapod, 0, logMessage)
# DEBUG:ATHexapod:Read 100 history items for RemoteEvent(ATHexapod, 0, positionUpdate)
# Read 100 history items for RemoteEvent(ATHexapod, 0, positionUpdate)
# DEBUG:ATHexapod:Read 1 history items for RemoteEvent(ATHexapod, 0, readyForCommand)
# Read 1 history items for RemoteEvent(ATHexapod, 0, readyForCommand)
# DEBUG:ATHexapod:Read 7 history items for RemoteEvent(ATHexapod, 0, settingsApplied)
# Read 7 history items for RemoteEvent(ATHexapod, 0, settingsApplied)
# DEBUG:ATHexapod:Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedPivot)
# Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedPivot)
# DEBUG:ATHexapod:Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedPositionLimits)
# Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedPositionLimits)
# DEBUG:ATHexapod:Read 7 history items for RemoteEvent(ATHexapod, 0, settingsAppliedTcp)
# Read 7 history items for RemoteEvent(ATHexapod, 0, settingsAppliedTcp)
# DEBUG:ATHexapod:Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedVelocities)
# Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedVelocities)
# DEBUG:ATHexapod:Read 14 history items for RemoteEvent(ATHexapod, 0, summaryState)
# Read 14 history items for RemoteEvent(ATHexapod, 0, summaryState)
# INFO:ATDome:Read historical data in 0.34 sec
# Read historical data in 0.34 sec
# DEBUG:ATDome:Read 49 history items for RemoteEvent(ATDome, 0, allAxesInPosition)
# Read 49 history items for RemoteEvent(ATDome, 0, allAxesInPosition)
# DEBUG:ATDome:Read 11 history items for RemoteEvent(ATDome, 0, appliedSettingsMatchStart)
# Read 11 history items for RemoteEvent(ATDome, 0, appliedSettingsMatchStart)
# DEBUG:ATDome:Read 29 history items for RemoteEvent(ATDome, 0, azimuthCommandedState)
# Read 29 history items for RemoteEvent(ATDome, 0, azimuthCommandedState)
# DEBUG:ATDome:Read 53 history items for RemoteEvent(ATDome, 0, azimuthInPosition)
# Read 53 history items for RemoteEvent(ATDome, 0, azimuthInPosition)
# DEBUG:ATDome:Read 51 history items for RemoteEvent(ATDome, 0, azimuthState)
# Read 51 history items for RemoteEvent(ATDome, 0, azimuthState)
# DEBUG:ATDome:Read 100 history items for RemoteEvent(ATDome, 0, doorEncoderExtremes)
# Read 100 history items for RemoteEvent(ATDome, 0, doorEncoderExtremes)
# DEBUG:ATDome:Read 3 history items for RemoteEvent(ATDome, 0, dropoutDoorCommandedState)
# Read 3 history items for RemoteEvent(ATDome, 0, dropoutDoorCommandedState)
# DEBUG:ATDome:Read 1 history items for RemoteEvent(ATDome, 0, dropoutDoorState)
# Read 1 history items for RemoteEvent(ATDome, 0, dropoutDoorState)
# DEBUG:ATDome:Read 1 history items for RemoteEvent(ATDome, 0, emergencyStop)
# Read 1 history items for RemoteEvent(ATDome, 0, emergencyStop)
# DEBUG:ATDome:Read 7 history items for RemoteEvent(ATDome, 0, errorCode)
# Read 7 history items for RemoteEvent(ATDome, 0, errorCode)
# DEBUG:ATDome:Read 100 history items for RemoteEvent(ATDome, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATDome, 0, heartbeat)
# DEBUG:ATDome:Read 23 history items for RemoteEvent(ATDome, 0, lastAzimuthGoTo)
# Read 23 history items for RemoteEvent(ATDome, 0, lastAzimuthGoTo)
# DEBUG:ATDome:Read 7 history items for RemoteEvent(ATDome, 0, logMessage)
# Read 7 history items for RemoteEvent(ATDome, 0, logMessage)
# DEBUG:ATDome:Read 4 history items for RemoteEvent(ATDome, 0, mainDoorCommandedState)
# Read 4 history items for RemoteEvent(ATDome, 0, mainDoorCommandedState)
# DEBUG:ATDome:Read 3 history items for RemoteEvent(ATDome, 0, mainDoorState)
# Read 3 history items for RemoteEvent(ATDome, 0, mainDoorState)
# DEBUG:ATDome:Read 53 history items for RemoteEvent(ATDome, 0, moveCode)
# Read 53 history items for RemoteEvent(ATDome, 0, moveCode)
# DEBUG:ATDome:Read 8 history items for RemoteEvent(ATDome, 0, scbLink)
# Read 8 history items for RemoteEvent(ATDome, 0, scbLink)
# DEBUG:ATDome:Read 7 history items for RemoteEvent(ATDome, 0, settingsApplied)
# Read 7 history items for RemoteEvent(ATDome, 0, settingsApplied)
# DEBUG:ATDome:Read 8 history items for RemoteEvent(ATDome, 0, settingsAppliedDomeController)
# Read 8 history items for RemoteEvent(ATDome, 0, settingsAppliedDomeController)
# DEBUG:ATDome:Read 11 history items for RemoteEvent(ATDome, 0, settingsAppliedDomeTcp)
# Read 11 history items for RemoteEvent(ATDome, 0, settingsAppliedDomeTcp)
# DEBUG:ATDome:Read 4 history items for RemoteEvent(ATDome, 0, shutterInPosition)
# Read 4 history items for RemoteEvent(ATDome, 0, shutterInPosition)
# DEBUG:ATDome:Read 28 history items for RemoteEvent(ATDome, 0, summaryState)
# Read 28 history items for RemoteEvent(ATDome, 0, summaryState)
# INFO:ATMCS:Read historical data in 0.41 sec
# Read historical data in 0.41 sec
# DEBUG:ATMCS:Read 100 history items for RemoteEvent(ATMCS, 0, allAxesInPosition)
# Read 100 history items for RemoteEvent(ATMCS, 0, allAxesInPosition)
# DEBUG:ATMCS:Read 4 history items for RemoteEvent(ATMCS, 0, appliedSettingsMatchStart)
# Read 4 history items for RemoteEvent(ATMCS, 0, appliedSettingsMatchStart)
# DEBUG:ATMCS:Read 100 history items for RemoteEvent(ATMCS, 0, atMountState)
# Read 100 history items for RemoteEvent(ATMCS, 0, atMountState)
# DEBUG:ATMCS:Read 8 history items for RemoteEvent(ATMCS, 0, azimuthBrake1)
# Read 8 history items for RemoteEvent(ATMCS, 0, azimuthBrake1)
# DEBUG:ATMCS:Read 8 history items for RemoteEvent(ATMCS, 0, azimuthBrake2)
# Read 8 history items for RemoteEvent(ATMCS, 0, azimuthBrake2)
# DEBUG:ATMCS:Read 8 history items for RemoteEvent(ATMCS, 0, azimuthDrive1Status)
# Read 8 history items for RemoteEvent(ATMCS, 0, azimuthDrive1Status)
# DEBUG:ATMCS:Read 8 history items for RemoteEvent(ATMCS, 0, azimuthDrive2Status)
# Read 8 history items for RemoteEvent(ATMCS, 0, azimuthDrive2Status)
# DEBUG:ATMCS:Read 100 history items for RemoteEvent(ATMCS, 0, azimuthInPosition)
# Read 100 history items for RemoteEvent(ATMCS, 0, azimuthInPosition)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, azimuthLimitSwitchCCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, azimuthLimitSwitchCCW)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, azimuthLimitSwitchCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, azimuthLimitSwitchCW)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, azimuthToppleBlockCCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, azimuthToppleBlockCCW)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, azimuthToppleBlockCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, azimuthToppleBlockCW)
# DEBUG:ATMCS:Read 8 history items for RemoteEvent(ATMCS, 0, elevationBrake)
# Read 8 history items for RemoteEvent(ATMCS, 0, elevationBrake)
# DEBUG:ATMCS:Read 8 history items for RemoteEvent(ATMCS, 0, elevationDriveStatus)
# Read 8 history items for RemoteEvent(ATMCS, 0, elevationDriveStatus)
# DEBUG:ATMCS:Read 100 history items for RemoteEvent(ATMCS, 0, elevationInPosition)
# Read 100 history items for RemoteEvent(ATMCS, 0, elevationInPosition)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, elevationLimitSwitchLower)
# Read 1 history items for RemoteEvent(ATMCS, 0, elevationLimitSwitchLower)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, elevationLimitSwitchUpper)
# Read 1 history items for RemoteEvent(ATMCS, 0, elevationLimitSwitchUpper)
# DEBUG:ATMCS:Read 100 history items for RemoteEvent(ATMCS, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATMCS, 0, heartbeat)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, m3DriveStatus)
# Read 1 history items for RemoteEvent(ATMCS, 0, m3DriveStatus)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, m3InPosition)
# Read 1 history items for RemoteEvent(ATMCS, 0, m3InPosition)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, m3RotatorDetentSwitches)
# Read 1 history items for RemoteEvent(ATMCS, 0, m3RotatorDetentSwitches)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, m3RotatorLimitSwitchCCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, m3RotatorLimitSwitchCCW)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, m3RotatorLimitSwitchCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, m3RotatorLimitSwitchCW)
# DEBUG:ATMCS:Read 8 history items for RemoteEvent(ATMCS, 0, m3State)
# Read 8 history items for RemoteEvent(ATMCS, 0, m3State)
# DEBUG:ATMCS:Read 8 history items for RemoteEvent(ATMCS, 0, nasmyth1Brake)
# Read 8 history items for RemoteEvent(ATMCS, 0, nasmyth1Brake)
# DEBUG:ATMCS:Read 8 history items for RemoteEvent(ATMCS, 0, nasmyth1DriveStatus)
# Read 8 history items for RemoteEvent(ATMCS, 0, nasmyth1DriveStatus)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth1LimitSwitchCCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth1LimitSwitchCCW)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth1LimitSwitchCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth1LimitSwitchCW)
# DEBUG:ATMCS:Read 4 history items for RemoteEvent(ATMCS, 0, nasmyth1RotatorInPosition)
# Read 4 history items for RemoteEvent(ATMCS, 0, nasmyth1RotatorInPosition)
# DEBUG:ATMCS:Read 8 history items for RemoteEvent(ATMCS, 0, nasmyth2Brake)
# Read 8 history items for RemoteEvent(ATMCS, 0, nasmyth2Brake)
# DEBUG:ATMCS:Read 8 history items for RemoteEvent(ATMCS, 0, nasmyth2DriveStatus)
# Read 8 history items for RemoteEvent(ATMCS, 0, nasmyth2DriveStatus)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth2LimitSwitchCCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth2LimitSwitchCCW)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth2LimitSwitchCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth2LimitSwitchCW)
# DEBUG:ATMCS:Read 100 history items for RemoteEvent(ATMCS, 0, nasmyth2RotatorInPosition)
# Read 100 history items for RemoteEvent(ATMCS, 0, nasmyth2RotatorInPosition)
# DEBUG:ATMCS:Read 4 history items for RemoteEvent(ATMCS, 0, positionLimits)
# Read 4 history items for RemoteEvent(ATMCS, 0, positionLimits)
# DEBUG:ATMCS:Read 4 history items for RemoteEvent(ATMCS, 0, settingVersions)
# Read 4 history items for RemoteEvent(ATMCS, 0, settingVersions)
# DEBUG:ATMCS:Read 15 history items for RemoteEvent(ATMCS, 0, summaryState)
# Read 15 history items for RemoteEvent(ATMCS, 0, summaryState)
# DEBUG:ATMCS:Read 100 history items for RemoteEvent(ATMCS, 0, target)
# Read 100 history items for RemoteEvent(ATMCS, 0, target)
# INFO:ATPtg:Read historical data in 0.47 sec
# Read historical data in 0.47 sec
# DEBUG:ATPtg:Read 16 history items for RemoteEvent(ATPtg, 0, airmassWarning)
# Read 16 history items for RemoteEvent(ATPtg, 0, airmassWarning)
# DEBUG:ATPtg:Read 5 history items for RemoteEvent(ATPtg, 0, currentDebugLevel)
# Read 5 history items for RemoteEvent(ATPtg, 0, currentDebugLevel)
# DEBUG:ATPtg:Read 100 history items for RemoteEvent(ATPtg, 0, currentTarget)
# Read 100 history items for RemoteEvent(ATPtg, 0, currentTarget)
# DEBUG:ATPtg:Read 89 history items for RemoteEvent(ATPtg, 0, detailedState)
# Read 89 history items for RemoteEvent(ATPtg, 0, detailedState)
# DEBUG:ATPtg:Read 4 history items for RemoteEvent(ATPtg, 0, errorCode)
# Read 4 history items for RemoteEvent(ATPtg, 0, errorCode)
# DEBUG:ATPtg:Read 5 history items for RemoteEvent(ATPtg, 0, focusNameSelected)
# Read 5 history items for RemoteEvent(ATPtg, 0, focusNameSelected)
# DEBUG:ATPtg:Read 100 history items for RemoteEvent(ATPtg, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATPtg, 0, heartbeat)
# DEBUG:ATPtg:Read 11 history items for RemoteEvent(ATPtg, 0, iers)
# Read 11 history items for RemoteEvent(ATPtg, 0, iers)
# DEBUG:ATPtg:Read 2 history items for RemoteEvent(ATPtg, 0, iersOutOfDate)
# Read 2 history items for RemoteEvent(ATPtg, 0, iersOutOfDate)
# DEBUG:ATPtg:Read 1 history items for RemoteEvent(ATPtg, 0, mountDataWarning)
# Read 1 history items for RemoteEvent(ATPtg, 0, mountDataWarning)
# DEBUG:ATPtg:Read 1 history items for RemoteEvent(ATPtg, 0, pointingFile)
# Read 1 history items for RemoteEvent(ATPtg, 0, pointingFile)
# DEBUG:ATPtg:Read 5 history items for RemoteEvent(ATPtg, 0, pointingModel)
# Read 5 history items for RemoteEvent(ATPtg, 0, pointingModel)
# DEBUG:ATPtg:Read 1 history items for RemoteEvent(ATPtg, 0, ptgAzCurrentWrap)
# Read 1 history items for RemoteEvent(ATPtg, 0, ptgAzCurrentWrap)
# DEBUG:ATPtg:Read 1 history items for RemoteEvent(ATPtg, 0, ptgRotCurrentWrap)
# Read 1 history items for RemoteEvent(ATPtg, 0, ptgRotCurrentWrap)
# DEBUG:ATPtg:Read 18 history items for RemoteEvent(ATPtg, 0, summaryState)
# Read 18 history items for RemoteEvent(ATPtg, 0, summaryState)
# DEBUG:ATPtg:Read 100 history items for RemoteEvent(ATPtg, 0, timesOfLimits)
# Read 100 history items for RemoteEvent(ATPtg, 0, timesOfLimits)
# DEBUG:ATPtg:Read 85 history items for RemoteEvent(ATPtg, 0, trackPosting)
# Read 85 history items for RemoteEvent(ATPtg, 0, trackPosting)
# DEBUG:ATPtg:Read 5 history items for RemoteEvent(ATPtg, 0, wavelength)
# Read 5 history items for RemoteEvent(ATPtg, 0, wavelength)
# DEBUG:ATPtg:Read 100 history items for RemoteEvent(ATPtg, 0, weatherDataApplied)
# Read 100 history items for RemoteEvent(ATPtg, 0, weatherDataApplied)
# DEBUG:ATPtg:Read 100 history items for RemoteEvent(ATPtg, 0, weatherDataInvalid)
# Read 100 history items for RemoteEvent(ATPtg, 0, weatherDataInvalid)
# INFO:ATCamera:Read historical data in 0.52 sec
# Read historical data in 0.52 sec
# DEBUG:ATCamera:Read 1 history items for RemoteEvent(ATCamera, 0, appliedSettingsMatchStart)
# Read 1 history items for RemoteEvent(ATCamera, 0, appliedSettingsMatchStart)
# DEBUG:ATCamera:Read 100 history items for RemoteEvent(ATCamera, 0, ccsCommandState)
# Read 100 history items for RemoteEvent(ATCamera, 0, ccsCommandState)
# DEBUG:ATCamera:Read 100 history items for RemoteEvent(ATCamera, 0, endOfImageTelemetry)
# Read 100 history items for RemoteEvent(ATCamera, 0, endOfImageTelemetry)
# DEBUG:ATCamera:Read 100 history items for RemoteEvent(ATCamera, 0, endReadout)
# Read 100 history items for RemoteEvent(ATCamera, 0, endReadout)
# DEBUG:ATCamera:Read 78 history items for RemoteEvent(ATCamera, 0, endShutterClose)
# Read 78 history items for RemoteEvent(ATCamera, 0, endShutterClose)
# DEBUG:ATCamera:Read 77 history items for RemoteEvent(ATCamera, 0, endShutterOpen)
# Read 77 history items for RemoteEvent(ATCamera, 0, endShutterOpen)
# DEBUG:ATCamera:Read 1 history items for RemoteEvent(ATCamera, 0, focalPlaneHardwareIdSettingsApplied)
# Read 1 history items for RemoteEvent(ATCamera, 0, focalPlaneHardwareIdSettingsApplied)
# DEBUG:ATCamera:Read 1 history items for RemoteEvent(ATCamera, 0, focalPlaneSummaryInfo)
# Read 1 history items for RemoteEvent(ATCamera, 0, focalPlaneSummaryInfo)
# DEBUG:ATCamera:Read 100 history items for RemoteEvent(ATCamera, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATCamera, 0, heartbeat)
# DEBUG:ATCamera:Read 100 history items for RemoteEvent(ATCamera, 0, imageReadinessDetailedState)
# Read 100 history items for RemoteEvent(ATCamera, 0, imageReadinessDetailedState)
# DEBUG:ATCamera:Read 100 history items for RemoteEvent(ATCamera, 0, imageReadoutParameters)
# Read 100 history items for RemoteEvent(ATCamera, 0, imageReadoutParameters)
# DEBUG:ATCamera:Read 100 history items for RemoteEvent(ATCamera, 0, raftsDetailedState)
# Read 100 history items for RemoteEvent(ATCamera, 0, raftsDetailedState)
# DEBUG:ATCamera:Read 1 history items for RemoteEvent(ATCamera, 0, settingVersions)
# Read 1 history items for RemoteEvent(ATCamera, 0, settingVersions)
# DEBUG:ATCamera:Read 100 history items for RemoteEvent(ATCamera, 0, shutterDetailedState)
# Read 100 history items for RemoteEvent(ATCamera, 0, shutterDetailedState)
# DEBUG:ATCamera:Read 78 history items for RemoteEvent(ATCamera, 0, shutterMotionProfile)
# Read 78 history items for RemoteEvent(ATCamera, 0, shutterMotionProfile)
# DEBUG:ATCamera:Read 1 history items for RemoteEvent(ATCamera, 0, softwareVersions)
# Read 1 history items for RemoteEvent(ATCamera, 0, softwareVersions)
# DEBUG:ATCamera:Read 100 history items for RemoteEvent(ATCamera, 0, startIntegration)
# Read 100 history items for RemoteEvent(ATCamera, 0, startIntegration)
# DEBUG:ATCamera:Read 100 history items for RemoteEvent(ATCamera, 0, startReadout)
# Read 100 history items for RemoteEvent(ATCamera, 0, startReadout)
# DEBUG:ATCamera:Read 4 history items for RemoteEvent(ATCamera, 0, summaryState)
# Read 4 history items for RemoteEvent(ATCamera, 0, summaryState)
# WARNING:ATHexapod.positionStatus:positionStatus DDS read queue is filling: 19 of 100 elements
# positionStatus DDS read queue is filling: 19 of 100 elements
# WARNING:ATDome.position:position DDS read queue is filling: 75 of 100 elements
# ERROR:ATPtg.timeAndDate:timeAndDate DDS read queue is full (100 elements); data may be lost
# position DDS read queue is filling: 75 of 100 elements
# INFO:Script:Read historical data in 0.02 sec
# timeAndDate DDS read queue is full (100 elements); data may be lost
# WARNING:ATMCS.trajectory:trajectory DDS read queue is filling: 38 of 100 elements
# Read historical data in 0.02 sec
# trajectory DDS read queue is filling: 38 of 100 elements
# ERROR:ATPtg.mountStatus:mountStatus DDS read queue is full (100 elements); data may be lost
# mountStatus DDS read queue is full (100 elements); data may be lost
# WARNING:ATMCS.torqueDemand:torqueDemand DDS read queue is filling: 38 of 100 elements
# torqueDemand DDS read queue is filling: 38 of 100 elements
# WARNING:ATPtg.mountPositions:mountPositions DDS read queue is filling: 37 of 100 elements
# mountPositions DDS read queue is filling: 37 of 100 elements
# WARNING:ATMCS.nasymth_m3_mountMotorEncoders:nasymth_m3_mountMotorEncoders DDS read queue is filling: 38 of 100 elements
# nasymth_m3_mountMotorEncoders DDS read queue is filling: 38 of 100 elements
# ERROR:ATPtg.guidingAndOffsets:guidingAndOffsets DDS read queue is full (100 elements); data may be lost
# guidingAndOffsets DDS read queue is full (100 elements); data may be lost
# WARNING:ATMCS.mount_Nasmyth_Encoders:mount_Nasmyth_Encoders DDS read queue is filling: 38 of 100 elements
# mount_Nasmyth_Encoders DDS read queue is filling: 38 of 100 elements
# ERROR:ATPtg.currentTargetStatus:currentTargetStatus DDS read queue is full (100 elements); data may be lost
# currentTargetStatus DDS read queue is full (100 elements); data may be lost
# WARNING:ATMCS.mount_AzEl_Encoders:mount_AzEl_Encoders DDS read queue is filling: 38 of 100 elements
# mount_AzEl_Encoders DDS read queue is filling: 38 of 100 elements
# WARNING:ATMCS.mount_AzEl_Encoders:mount_AzEl_Encoders python read queue is filling: 37 of 100 elements
# mount_AzEl_Encoders python read queue is filling: 37 of 100 elements
# WARNING:ATMCS.measuredTorque:measuredTorque DDS read queue is filling: 38 of 100 elements
# measuredTorque DDS read queue is filling: 38 of 100 elements
# WARNING:ATMCS.measuredMotorVelocity:measuredMotorVelocity DDS read queue is filling: 38 of 100 elements
# measuredMotorVelocity DDS read queue is filling: 38 of 100 elements
# WARNING:ATMCS.azEl_mountMotorEncoders:azEl_mountMotorEncoders DDS read queue is filling: 38 of 100 elements
# azEl_mountMotorEncoders DDS read queue is filling: 38 of 100 elements
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 12 of 100 elements
# target DDS read queue is filling: 12 of 100 elements
# WARNING:ATMCS.logevent_target:target python read queue is filling: 11 of 100 elements
# target python read queue is filling: 11 of 100 elements

# %%
# set wrap strategy
# this is required until the ATPtg is updated to not configure the mount for maximum time on target
script.atcs.rem.atptg.cmd_raDecTarget.set(azWrapStrategy=1)  # 1 does not unwrap, 0 unwraps

# %%
# Do acquisition in the same mode we'll use to focus afterwards

# %%
acq1_yaml = yaml.safe_dump({"object_name": TARGET,
                            "do_acquire": True,
                            "acq_filter" : 'RG610',
                            "acq_grating" : 'empty_1', 
                            "acq_exposure_time": 0.5,
                            "max_acq_iter": 4,
                            "target_pointing_tolerance": 2,
                            "do_pointing_model": False,
                            "dataPath": '/project/shared/auxTel/rerun/quickLook',
                            "target_pointing_verification": False})
print(acq1_yaml)
# Out:
# acq_exposure_time: 0.5
# acq_filter: RG610
# acq_grating: empty_1
# dataPath: /project/shared/auxTel/rerun/quickLook
# do_acquire: true
# do_pointing_model: false
# max_acq_iter: 4
# object_name: HD60228
# target_pointing_tolerance: 2
# target_pointing_verification: false

# %%
# Set script state to UNCONFIGURED
# this is required to run the script a 2nd time but otherwise is a no-op
script.set_state(ScriptState.UNCONFIGURED)
# Configure the script, which puts the ScriptState to CONFIGURED
acq1_configuration = script.cmd_configure.DataType()
acq1_configuration.config = acq1_yaml
await script.do_configure(acq1_configuration)

# %%
# ATAOS must be on and corrections enabled, do as follows if required
# await script.atcs.rem.ataos.cmd_enableCorrection.set_start(m1=True, hexapod=True, atspectrograph=True)

# %%
# get group_id_data that will be used for all images for this target
time_for_groupID=astropy.time.Time.now().isot
group_id_data = script.cmd_setGroupId.DataType(
                groupId=time_for_groupID
            )
await script.do_setGroupId(group_id_data)

# %%
# This will align the target 
acq_results = await script.arun()
# Out:
# DEBUG:Script:Beginning target acquisition
# Beginning target acquisition
# DEBUG:urllib3.connectionpool:Resetting dropped connection: simbad.u-strasbg.fr
# Resetting dropped connection: simbad.u-strasbg.fr
# DEBUG:urllib3.connectionpool:http://simbad.u-strasbg.fr:80 "POST /simbad/sim-script HTTP/1.1" 200 None
# http://simbad.u-strasbg.fr:80 "POST /simbad/sim-script HTTP/1.1" 200 None
# INFO:Script.ATCS:Slewing to HD60228: 07 30 30.9197 -54 23 57.711
# Slewing to HD60228: 07 30 30.9197 -54 23 57.711
# DEBUG:Script.ATCS:Setting rotator physical position to -105.0 deg. Rotator will track sky.
# Setting rotator physical position to -105.0 deg. Rotator will track sky.
# DEBUG:Script.ATCS:Parallactic angle: 20.016320503673228 | Sky Angle: 30.178814119590356
# Parallactic angle: 20.016320503673228 | Sky Angle: 30.178814119590356
# DEBUG:Script.ATCS:Sending command
# Sending command
# DEBUG:Script.ATCS:Stop tracking.
# Stop tracking.
# DEBUG:Script.ATCS:Scheduling check coroutines
# Scheduling check coroutines
# DEBUG:Script.ATCS:process as completed...
# process as completed...
# DEBUG:Script.ATCS:atmcs: <State.ENABLED: 2>
# atmcs: <State.ENABLED: 2>
# DEBUG:Script.ATCS:atptg: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# DEBUG:Script.ATCS:ataos: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# DEBUG:Script.ATCS:atpneumatics: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# DEBUG:Script.ATCS:athexapod: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# DEBUG:Script.ATCS:atdome: <State.ENABLED: 2>
# atdome: <State.ENABLED: 2>
# DEBUG:Script.ATCS:atdometrajectory: <State.ENABLED: 2>
# atdometrajectory: <State.ENABLED: 2>
# INFO:Script.ATCS:[Telescope] delta Alt = -002.754 deg; delta Az = +001.095 deg; delta N1 = -000.000 deg; delta N2 = -013.140 deg [Dome] delta Az = +016.692 deg
# [Telescope] delta Alt = -002.754 deg; delta Az = +001.095 deg; delta N1 = -000.000 deg; delta N2 = -013.140 deg [Dome] delta Az = +016.692 deg
# INFO:Script.ATCS:[Telescope] delta Alt = -001.367 deg; delta Az = +000.298 deg; delta N1 = -000.000 deg; delta N2 = -011.293 deg [Dome] delta Az = +014.932 deg
# [Telescope] delta Alt = -001.367 deg; delta Az = +000.298 deg; delta N1 = -000.000 deg; delta N2 = -011.293 deg [Dome] delta Az = +014.932 deg
# INFO:Script.ATCS:[Telescope] delta Alt = +000.000 deg; delta Az = -000.000 deg; delta N1 = -000.000 deg; delta N2 = -005.953 deg [Dome] delta Az = +011.392 deg
# [Telescope] delta Alt = +000.000 deg; delta Az = -000.000 deg; delta N1 = -000.000 deg; delta N2 = -005.953 deg [Dome] delta Az = +011.392 deg
# INFO:Script.ATCS:[Telescope] delta Alt = +000.000 deg; delta Az = -000.001 deg; delta N1 = -000.000 deg; delta N2 = -002.395 deg [Dome] delta Az = +007.752 deg
# [Telescope] delta Alt = +000.000 deg; delta Az = -000.001 deg; delta N1 = -000.000 deg; delta N2 = -002.395 deg [Dome] delta Az = +007.752 deg
# INFO:Script.ATCS:[Telescope] delta Alt = +000.000 deg; delta Az = -000.001 deg; delta N1 = +000.000 deg; delta N2 = -000.365 deg [Dome] delta Az = +003.402 deg
# [Telescope] delta Alt = +000.000 deg; delta Az = -000.001 deg; delta N1 = +000.000 deg; delta N2 = -000.365 deg [Dome] delta Az = +003.402 deg
# INFO:Script.ATCS:ATDome in position.
# ATDome in position.
# INFO:Script.ATCS:Got True
# Got True
# INFO:Script.ATCS:Waiting for telescope to settle.
# Waiting for telescope to settle.
# INFO:Script.ATCS:[Telescope] delta Alt = +000.000 deg; delta Az = -000.001 deg; delta N1 = -000.000 deg; delta N2 = +000.010 deg [Dome] delta Az = +000.692 deg
# [Telescope] delta Alt = +000.000 deg; delta Az = -000.001 deg; delta N1 = -000.000 deg; delta N2 = +000.010 deg [Dome] delta Az = +000.692 deg
# INFO:Script.ATCS:Telescope in position.
# Telescope in position.
# DEBUG:Script:Instrument setup required: False
# Instrument setup required: False
# INFO:Script:Beginning Acquisition Iterative Loop, with a maximum amount of iterations set to 4
# Beginning Acquisition Iterative Loop, with a maximum amount of iterations set to 4
# DEBUG:Script:
# Starting iteration number 1, with a maximum of 4
#
# Starting iteration number 1, with a maximum of 4
# DEBUG:Script.LATISS:Generating group_id
# Generating group_id
# DEBUG:Script.LATISS:OBJECT 0001 - 0001
# OBJECT 0001 - 0001
# INFO:Script:Waiting for image to arrive in OODS for a maximum of 10.5 seconds.
# Waiting for image to arrive in OODS for a maximum of 10.5 seconds.
# INFO:Script:seqNum 347 arrived in OODS
# seqNum 347 arrived in OODS
# DEBUG:lsst.ts.observing.utilities.auxtel.latiss.getters:Pulling data with dataset = quickLookExp and dataId = {'dayObs': '2021-03-23', 'seqNum': 347}
# Pulling data with dataset = quickLookExp and dataId = {'dayObs': '2021-03-23', 'seqNum': 347}
# DEBUG:lsst.ts.observing.utilities.auxtel.latiss.getters:Running bestEffort ISR on {'dayObs': '2021-03-23', 'seqNum': 347} and returning exposure
# Running bestEffort ISR on {'dayObs': '2021-03-23', 'seqNum': 347} and returning exposure
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing SHUTTIME header to be None
# AT_O_20210323_000347: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing SHUTTIME header to be None
# AT_O_20210323_000347: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing SHUTTIME header to be None
# AT_O_20210323_000347: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing SHUTTIME header to be None
# AT_O_20210323_000347: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing SHUTTIME header to be None
# AT_O_20210323_000347: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing SHUTTIME header to be None
# AT_O_20210323_000347: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing SHUTTIME header to be None
# AT_O_20210323_000347: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing SHUTTIME header to be None
# AT_O_20210323_000347: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing SHUTTIME header to be None
# AT_O_20210323_000347: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing SHUTTIME header to be None
# AT_O_20210323_000347: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing SHUTTIME header to be None
# AT_O_20210323_000347: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing SHUTTIME header to be None
# AT_O_20210323_000347: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing SHUTTIME header to be None
# AT_O_20210323_000347: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing SHUTTIME header to be None
# AT_O_20210323_000347: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing SHUTTIME header to be None
# AT_O_20210323_000347: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing SHUTTIME header to be None
# AT_O_20210323_000347: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Received 2 headers for merging
# Received 2 headers for merging
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000347.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000347: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000347: Forcing SHUTTIME header to be None
# AT_O_20210323_000347: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.translator:Using translation class LSST_LATISS
# Using translation class LSST_LATISS
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 28 of 100 elements
# target DDS read queue is filling: 28 of 100 elements
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-None.yaml
# Checking for header correction file named LATISS-None.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:Assigning OBSID to a value of 'None'
# Assigning OBSID to a value of 'None'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-None.yaml
# Checking for header correction file named LATISS-None.yaml
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 28 of 100 elements
# target DDS read queue is filling: 28 of 100 elements
# DEBUG:lsst.obs.lsst.translators.latiss:Assigning OBSID to a value of 'None'
# Assigning OBSID to a value of 'None'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# Running best effort isr...
# Running with bias subtraction
# Running with dark correction subtraction
# Running with defect correction
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 18 of 100 elements
# target DDS read queue is filling: 18 of 100 elements
# Running cosmic ray repair
# WARNING:ATPtg.guidingAndOffsets:guidingAndOffsets DDS read queue is filling: 10 of 100 elements
# guidingAndOffsets DDS read queue is filling: 10 of 100 elements
# WARNING:ATMCS.mount_AzEl_Encoders:mount_AzEl_Encoders python read queue is filling: 12 of 100 elements
# mount_AzEl_Encoders python read queue is filling: 12 of 100 elements
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 38 of 100 elements
# target DDS read queue is filling: 38 of 100 elements
# WARNING:ATMCS.logevent_target:target python read queue is filling: 99 of 100 elements
# target python read queue is filling: 99 of 100 elements
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 17 of 100 elements
# target DDS read queue is filling: 17 of 100 elements
# WARNING:ATMCS.logevent_target:target python read queue is filling: 16 of 100 elements
# target python read queue is filling: 16 of 100 elements
# DEBUG:Script:Current brightest target position is (2529.3, 1626.3) whereas the target position is (1780, 1800)
# Current brightest target position is (2529.3, 1626.3) whereas the target position is (1780, 1800)
# INFO:Script:Calculated offsets [dx,dy] are [78.30, -18.15] arcsec as calculated from sequence number 347 on dayObs of 2021-03-23
# Calculated offsets [dx,dy] are [78.30, -18.15] arcsec as calculated from sequence number 347 on dayObs of 2021-03-23
# INFO:Script:Current radial pointing error of 80.37 arcsec exceeds the tolerance of 2 arcsec.
# Current radial pointing error of 80.37 arcsec exceeds the tolerance of 2 arcsec.
# INFO:Script:Applying x/y offset to telescope pointing.
# Applying x/y offset to telescope pointing.
# DEBUG:Script.ATCS:Calculating x/y offset: 78.29785597147614/-18.14847357154845
# Calculating x/y offset: 78.29785597147614/-18.14847357154845
# DEBUG:Script.ATCS:Applying Az/El offset: -73.79889291540437/31.837788038239907
# Applying Az/El offset: -73.79889291540437/31.837788038239907
# DEBUG:Script.ATCS:Telescope not in position.
# Telescope not in position.
# DEBUG:Script.ATCS:All axes in position.
# All axes in position.
# DEBUG:Script.ATCS:Waiting for telescope to settle.
# Waiting for telescope to settle.
# DEBUG:Script.ATCS:Done
# Done
# INFO:Script:At end of iteration loop, success is False. So moving to next iteration
# At end of iteration loop, success is False. So moving to next iteration
# DEBUG:Script:
# Starting iteration number 2, with a maximum of 4
#
# Starting iteration number 2, with a maximum of 4
# DEBUG:Script.LATISS:Generating group_id
# Generating group_id
# DEBUG:Script.LATISS:OBJECT 0001 - 0001
# OBJECT 0001 - 0001
# INFO:Script:Waiting for image to arrive in OODS for a maximum of 10.5 seconds.
# Waiting for image to arrive in OODS for a maximum of 10.5 seconds.
# WARNING:ATHeaderService.logevent_logMessage:logMessage DDS read queue is filling: 10 of 100 elements
# logMessage DDS read queue is filling: 10 of 100 elements
# INFO:Script:seqNum 348 arrived in OODS
# seqNum 348 arrived in OODS
# DEBUG:lsst.ts.observing.utilities.auxtel.latiss.getters:Pulling data with dataset = quickLookExp and dataId = {'dayObs': '2021-03-23', 'seqNum': 348}
# Pulling data with dataset = quickLookExp and dataId = {'dayObs': '2021-03-23', 'seqNum': 348}
# DEBUG:lsst.ts.observing.utilities.auxtel.latiss.getters:Running bestEffort ISR on {'dayObs': '2021-03-23', 'seqNum': 348} and returning exposure
# Running bestEffort ISR on {'dayObs': '2021-03-23', 'seqNum': 348} and returning exposure
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing SHUTTIME header to be None
# AT_O_20210323_000348: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing SHUTTIME header to be None
# AT_O_20210323_000348: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing SHUTTIME header to be None
# AT_O_20210323_000348: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing SHUTTIME header to be None
# AT_O_20210323_000348: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing SHUTTIME header to be None
# AT_O_20210323_000348: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing SHUTTIME header to be None
# AT_O_20210323_000348: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing SHUTTIME header to be None
# AT_O_20210323_000348: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing SHUTTIME header to be None
# AT_O_20210323_000348: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing SHUTTIME header to be None
# AT_O_20210323_000348: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing SHUTTIME header to be None
# AT_O_20210323_000348: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing SHUTTIME header to be None
# AT_O_20210323_000348: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing SHUTTIME header to be None
# AT_O_20210323_000348: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing SHUTTIME header to be None
# AT_O_20210323_000348: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing SHUTTIME header to be None
# AT_O_20210323_000348: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing SHUTTIME header to be None
# AT_O_20210323_000348: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing SHUTTIME header to be None
# AT_O_20210323_000348: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Received 2 headers for merging
# Received 2 headers for merging
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000348.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000348: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000348: Forcing SHUTTIME header to be None
# AT_O_20210323_000348: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.translator:Using translation class LSST_LATISS
# Using translation class LSST_LATISS
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 28 of 100 elements
# target DDS read queue is filling: 28 of 100 elements
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-None.yaml
# Checking for header correction file named LATISS-None.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:Assigning OBSID to a value of 'None'
# Assigning OBSID to a value of 'None'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 27 of 100 elements
# target DDS read queue is filling: 27 of 100 elements
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-None.yaml
# Checking for header correction file named LATISS-None.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:Assigning OBSID to a value of 'None'
# Assigning OBSID to a value of 'None'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# Running best effort isr...
# Running with bias subtraction
# Running with dark correction subtraction
# Running with defect correction
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 22 of 100 elements
# target DDS read queue is filling: 22 of 100 elements
# Running cosmic ray repair
# WARNING:ATPtg.currentTargetStatus:currentTargetStatus DDS read queue is filling: 10 of 100 elements
# currentTargetStatus DDS read queue is filling: 10 of 100 elements
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 38 of 100 elements
# target DDS read queue is filling: 38 of 100 elements
# WARNING:ATMCS.logevent_target:target python read queue is filling: 99 of 100 elements
# WARNING:ATPtg.timeAndDate:timeAndDate DDS read queue is filling: 10 of 100 elements
# target python read queue is filling: 99 of 100 elements
# timeAndDate DDS read queue is filling: 10 of 100 elements
# WARNING:ATMCS.mount_AzEl_Encoders:mount_AzEl_Encoders python read queue is filling: 13 of 100 elements
# mount_AzEl_Encoders python read queue is filling: 13 of 100 elements
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 17 of 100 elements
# target DDS read queue is filling: 17 of 100 elements
# WARNING:ATMCS.logevent_target:target python read queue is filling: 16 of 100 elements
# target python read queue is filling: 16 of 100 elements
# DEBUG:Script:Current brightest target position is (1715.5, 1827.5) whereas the target position is (1780, 1800)
# Current brightest target position is (1715.5, 1827.5) whereas the target position is (1780, 1800)
# INFO:Script:Calculated offsets [dx,dy] are [-6.74, 2.87] arcsec as calculated from sequence number 348 on dayObs of 2021-03-23
# Calculated offsets [dx,dy] are [-6.74, 2.87] arcsec as calculated from sequence number 348 on dayObs of 2021-03-23
# INFO:Script:Current radial pointing error of 7.33 arcsec exceeds the tolerance of 2 arcsec.
# Current radial pointing error of 7.33 arcsec exceeds the tolerance of 2 arcsec.
# INFO:Script:Applying x/y offset to telescope pointing.
# Applying x/y offset to telescope pointing.
# DEBUG:Script.ATCS:Calculating x/y offset: -6.744213852623731/2.8742152131456646
# Calculating x/y offset: -6.744213852623731/2.8742152131456646
# DEBUG:Script.ATCS:Applying Az/El offset: 6.142838323185542/-4.001383625272993
# Applying Az/El offset: 6.142838323185542/-4.001383625272993
# DEBUG:Script.ATCS:Telescope not in position.
# Telescope not in position.
# DEBUG:Script.ATCS:All axes in position.
# All axes in position.
# DEBUG:Script.ATCS:Waiting for telescope to settle.
# Waiting for telescope to settle.
# DEBUG:Script.ATCS:Done
# Done
# INFO:Script:At end of iteration loop, success is False. So moving to next iteration
# At end of iteration loop, success is False. So moving to next iteration
# DEBUG:Script:
# Starting iteration number 3, with a maximum of 4
#
# Starting iteration number 3, with a maximum of 4
# DEBUG:Script.LATISS:Generating group_id
# Generating group_id
# DEBUG:Script.LATISS:OBJECT 0001 - 0001
# OBJECT 0001 - 0001
# INFO:Script:Waiting for image to arrive in OODS for a maximum of 10.5 seconds.
# Waiting for image to arrive in OODS for a maximum of 10.5 seconds.
# INFO:Script:seqNum 349 arrived in OODS
# seqNum 349 arrived in OODS
# DEBUG:lsst.ts.observing.utilities.auxtel.latiss.getters:Pulling data with dataset = quickLookExp and dataId = {'dayObs': '2021-03-23', 'seqNum': 349}
# Pulling data with dataset = quickLookExp and dataId = {'dayObs': '2021-03-23', 'seqNum': 349}
# DEBUG:lsst.ts.observing.utilities.auxtel.latiss.getters:Running bestEffort ISR on {'dayObs': '2021-03-23', 'seqNum': 349} and returning exposure
# Running bestEffort ISR on {'dayObs': '2021-03-23', 'seqNum': 349} and returning exposure
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing SHUTTIME header to be None
# AT_O_20210323_000349: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing SHUTTIME header to be None
# AT_O_20210323_000349: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing SHUTTIME header to be None
# AT_O_20210323_000349: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing SHUTTIME header to be None
# AT_O_20210323_000349: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing SHUTTIME header to be None
# AT_O_20210323_000349: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing SHUTTIME header to be None
# AT_O_20210323_000349: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing SHUTTIME header to be None
# AT_O_20210323_000349: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing SHUTTIME header to be None
# AT_O_20210323_000349: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing SHUTTIME header to be None
# AT_O_20210323_000349: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing SHUTTIME header to be None
# AT_O_20210323_000349: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing SHUTTIME header to be None
# AT_O_20210323_000349: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing SHUTTIME header to be None
# AT_O_20210323_000349: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing SHUTTIME header to be None
# AT_O_20210323_000349: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing SHUTTIME header to be None
# AT_O_20210323_000349: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing SHUTTIME header to be None
# AT_O_20210323_000349: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing SHUTTIME header to be None
# AT_O_20210323_000349: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Received 2 headers for merging
# Received 2 headers for merging
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000349.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000349: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000349: Forcing SHUTTIME header to be None
# AT_O_20210323_000349: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.translator:Using translation class LSST_LATISS
# Using translation class LSST_LATISS
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-None.yaml
# Checking for header correction file named LATISS-None.yaml
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 30 of 100 elements
# target DDS read queue is filling: 30 of 100 elements
# DEBUG:lsst.obs.lsst.translators.latiss:Assigning OBSID to a value of 'None'
# Assigning OBSID to a value of 'None'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-None.yaml
# Checking for header correction file named LATISS-None.yaml
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 27 of 100 elements
# DEBUG:lsst.obs.lsst.translators.latiss:Assigning OBSID to a value of 'None'
# target DDS read queue is filling: 27 of 100 elements
# Assigning OBSID to a value of 'None'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# Running best effort isr...
# Running with bias subtraction
# Running with dark correction subtraction
# Running with defect correction
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 26 of 100 elements
# target DDS read queue is filling: 26 of 100 elements
# Running cosmic ray repair
# WARNING:ATMCS.logevent_target:target python read queue is filling: 99 of 100 elements
# target python read queue is filling: 99 of 100 elements
# WARNING:ATMCS.mount_AzEl_Encoders:mount_AzEl_Encoders python read queue is filling: 14 of 100 elements
# mount_AzEl_Encoders python read queue is filling: 14 of 100 elements
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 39 of 100 elements
# target DDS read queue is filling: 39 of 100 elements
# WARNING:ATMCS.logevent_target:target python read queue is filling: 38 of 100 elements
# target python read queue is filling: 38 of 100 elements
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 17 of 100 elements
# target DDS read queue is filling: 17 of 100 elements
# WARNING:ATMCS.logevent_target:target python read queue is filling: 16 of 100 elements
# target python read queue is filling: 16 of 100 elements
# DEBUG:Script:Current brightest target position is (1782.5, 1790.6) whereas the target position is (1780, 1800)
# Current brightest target position is (1782.5, 1790.6) whereas the target position is (1780, 1800)
# INFO:Script:Calculated offsets [dx,dy] are [0.26, -0.98] arcsec as calculated from sequence number 349 on dayObs of 2021-03-23
# Calculated offsets [dx,dy] are [0.26, -0.98] arcsec as calculated from sequence number 349 on dayObs of 2021-03-23
# INFO:Script:Acquisition completed successfully.Current radial pointing error of 1.02 arcsec is within the tolerance of 2 arcsec.
# Acquisition completed successfully.Current radial pointing error of 1.02 arcsec is within the tolerance of 2 arcsec.
# INFO:Script:Skipping additional image to verify offset was applied correctly as target_pointing_verification is set to False
# Skipping additional image to verify offset was applied correctly as target_pointing_verification is set to False
# DEBUG:Script:Beginning taking data for target sequence
# Beginning taking data for target sequence
# DEBUG:Script:Must load new filter empty_1 or grating empty_1
# Must load new filter empty_1 or grating empty_1
# DEBUG:Script:Instrument setup in take_sequence now waiting for 2*len[<ddsutil.ATSpectrograph_ackcmd_6d105732 object at 0x7f99129fa6a0>, <ddsutil.ATSpectrograph_ackcmd_6d105732 object at 0x7f99a8ad19a0>] ATAOS events saying correction started/finished
# Instrument setup in take_sequence now waiting for 2*len[<ddsutil.ATSpectrograph_ackcmd_6d105732 object at 0x7f99129fa6a0>, <ddsutil.ATSpectrograph_ackcmd_6d105732 object at 0x7f99a8ad19a0>] ATAOS events saying correction started/finished
# DEBUG:Script:Event #0 - evt_atspectrographCorrectionStarted is: private_revCode: e8ac7ff3, private_sndStamp: 1616546859.0045223, private_rcvStamp: 1616546859.0052345, private_seqNum: 176, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.0, pointingOffsets: [0.0, 0.0], priority: 0
# Event #0 - evt_atspectrographCorrectionStarted is: private_revCode: e8ac7ff3, private_sndStamp: 1616546859.0045223, private_rcvStamp: 1616546859.0052345, private_seqNum: 176, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.0, pointingOffsets: [0.0, 0.0], priority: 0
# DEBUG:Script:Event #1 - evt_atspectrographCorrectionStarted is: private_revCode: e8ac7ff3, private_sndStamp: 1616546860.0102646, private_rcvStamp: 1616546860.011, private_seqNum: 177, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.01600000075995922, pointingOffsets: [0.0, 0.0], priority: 0
# Event #1 - evt_atspectrographCorrectionStarted is: private_revCode: e8ac7ff3, private_sndStamp: 1616546860.0102646, private_rcvStamp: 1616546860.011, private_seqNum: 177, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.01600000075995922, pointingOffsets: [0.0, 0.0], priority: 0
# DEBUG:Script:Event #0 - evt_atspectrographCorrectionCompleted is: private_revCode: 77a05b82, private_sndStamp: 1616546859.0060213, private_rcvStamp: 1616546859.0067184, private_seqNum: 176, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.0, pointingOffsets: [0.0, 0.0], priority: 0
# Event #0 - evt_atspectrographCorrectionCompleted is: private_revCode: 77a05b82, private_sndStamp: 1616546859.0060213, private_rcvStamp: 1616546859.0067184, private_seqNum: 176, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.0, pointingOffsets: [0.0, 0.0], priority: 0
# DEBUG:Script:Event #1 - evt_atspectrographCorrectionCompleted is: private_revCode: 77a05b82, private_sndStamp: 1616546861.047071, private_rcvStamp: 1616546861.0498335, private_seqNum: 177, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.01600000075995922, pointingOffsets: [0.0, 0.0], priority: 0
# Event #1 - evt_atspectrographCorrectionCompleted is: private_revCode: 77a05b82, private_sndStamp: 1616546861.047071, private_rcvStamp: 1616546861.0498335, private_seqNum: 177, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.01600000075995922, pointingOffsets: [0.0, 0.0], priority: 0
# DEBUG:Script:ATAOS atspectrographCorrectionStarted and Completed events arrived
# ATAOS atspectrographCorrectionStarted and Completed events arrived
# INFO:Script:sleeping for 2s after acquisition due to ATAOS issue where corrections might take an extra cycle
# sleeping for 2s after acquisition due to ATAOS issue where corrections might take an extra cycle
# DEBUG:Script.LATISS:OBJECT 0001 - 0001
# OBJECT 0001 - 0001
# INFO:Script:Completed exposure 1 of 1. Exptime =    2.0s, filter=empty_1, grating=empty_1)
# Completed exposure 1 of 1. Exptime =    2.0s, filter=empty_1, grating=empty_1)
# DEBUG:Script:At finally statement in run
# At finally statement in run

# %% [markdown]
# ### Now perform science data with 90lpmm Ronchi

# %%
seq1_yaml = yaml.safe_dump({"object_name": TARGET,
                                "do_acquire": False,
                                "do_take_sequence": True,
                                "exposure_time_sequence" : [10, 10, 10,
                                                            10, 10, 10,
                                                            10, 10, 10], 
                                "filter_sequence": ['RG610','RG610', 'RG610',
                                                    'BG40','BG40', 'BG40',
                                                    'empty_1','empty_1', 'empty_1'], 
                                # RG610 and Ronchi
                                "grating_sequence": ['ronchi90lpmm', 'ronchi90lpmm','ronchi90lpmm',
                                                     'ronchi90lpmm', 'ronchi90lpmm', 'ronchi90lpmm',
                                                     'ronchi90lpmm', 'ronchi90lpmm', 'ronchi90lpmm'],
                                "do_pointing_model": False,
                                "dataPath": '/project/shared/auxTel/rerun/quickLook',
                                "target_pointing_verification": False})
print(seq1_yaml)
# Out:
# dataPath: /project/shared/auxTel/rerun/quickLook
# do_acquire: false
# do_pointing_model: false
# do_take_sequence: true
# exposure_time_sequence:
# - 10
# - 10
# - 10
# - 10
# - 10
# - 10
# - 10
# - 10
# - 10
# filter_sequence:
# - RG610
# - RG610
# - RG610
# - BG40
# - BG40
# - BG40
# - empty_1
# - empty_1
# - empty_1
# grating_sequence:
# - ronchi90lpmm
# - ronchi90lpmm
# - ronchi90lpmm
# - ronchi90lpmm
# - ronchi90lpmm
# - ronchi90lpmm
# - ronchi90lpmm
# - ronchi90lpmm
# - ronchi90lpmm
# object_name: HD60228
# target_pointing_verification: false

# %%
# Set script state to UNCONFIGURED
# this is required to run the script a 2nd time but otherwise is a no-op
script.set_state(ScriptState.UNCONFIGURED)
# Configure the script, which puts the ScriptState to CONFIGURED
seq1_configuration = script.cmd_configure.DataType()
seq1_configuration.config = seq1_yaml
await script.do_configure(seq1_configuration)
# Out:
# WARNING:ATMCS.logevent_target:target python read queue is filling: 29 of 100 elements
# target python read queue is filling: 29 of 100 elements

# %%
# This take the sequence of images with the Ronchi
seq1_results = await script.arun()
# Out:
# DEBUG:Script:Beginning taking data for target sequence
# Beginning taking data for target sequence
# DEBUG:Script:Must load new filter RG610 or grating ronchi90lpmm
# Must load new filter RG610 or grating ronchi90lpmm
# DEBUG:Script:Instrument setup in take_sequence now waiting for 2*len[<ddsutil.ATSpectrograph_ackcmd_6d105732 object at 0x7f992c2b73d0>, <ddsutil.ATSpectrograph_ackcmd_6d105732 object at 0x7f992c2b70d0>] ATAOS events saying correction started/finished
# Instrument setup in take_sequence now waiting for 2*len[<ddsutil.ATSpectrograph_ackcmd_6d105732 object at 0x7f992c2b73d0>, <ddsutil.ATSpectrograph_ackcmd_6d105732 object at 0x7f992c2b70d0>] ATAOS events saying correction started/finished
# DEBUG:Script:Event #0 - evt_atspectrographCorrectionStarted is: private_revCode: e8ac7ff3, private_sndStamp: 1616543959.3212616, private_rcvStamp: 1616543959.321945, private_seqNum: 152, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: -0.04200000315904617, pointingOffsets: [-17.100000381469727, 1.2999999523162842], priority: 0
# Event #0 - evt_atspectrographCorrectionStarted is: private_revCode: e8ac7ff3, private_sndStamp: 1616543959.3212616, private_rcvStamp: 1616543959.321945, private_seqNum: 152, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: -0.04200000315904617, pointingOffsets: [-17.100000381469727, 1.2999999523162842], priority: 0
# DEBUG:Script:Event #1 - evt_atspectrographCorrectionStarted is: private_revCode: e8ac7ff3, private_sndStamp: 1616543965.3558426, private_rcvStamp: 1616543965.3564646, private_seqNum: 153, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.0, pointingOffsets: [0.0, 0.0], priority: 0
# Event #1 - evt_atspectrographCorrectionStarted is: private_revCode: e8ac7ff3, private_sndStamp: 1616543965.3558426, private_rcvStamp: 1616543965.3564646, private_seqNum: 153, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.0, pointingOffsets: [0.0, 0.0], priority: 0
# DEBUG:Script:Event #0 - evt_atspectrographCorrectionCompleted is: private_revCode: 77a05b82, private_sndStamp: 1616543964.9223945, private_rcvStamp: 1616543964.9229655, private_seqNum: 152, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: -0.04200000315904617, pointingOffsets: [-17.100000381469727, 1.2999999523162842], priority: 0
# Event #0 - evt_atspectrographCorrectionCompleted is: private_revCode: 77a05b82, private_sndStamp: 1616543964.9223945, private_rcvStamp: 1616543964.9229655, private_seqNum: 152, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: -0.04200000315904617, pointingOffsets: [-17.100000381469727, 1.2999999523162842], priority: 0
# DEBUG:Script:Event #1 - evt_atspectrographCorrectionCompleted is: private_revCode: 77a05b82, private_sndStamp: 1616543965.357116, private_rcvStamp: 1616543965.3577409, private_seqNum: 153, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.0, pointingOffsets: [0.0, 0.0], priority: 0
# Event #1 - evt_atspectrographCorrectionCompleted is: private_revCode: 77a05b82, private_sndStamp: 1616543965.357116, private_rcvStamp: 1616543965.3577409, private_seqNum: 153, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.0, pointingOffsets: [0.0, 0.0], priority: 0
# DEBUG:Script:ATAOS atspectrographCorrectionStarted and Completed events arrived
# ATAOS atspectrographCorrectionStarted and Completed events arrived
# INFO:Script:sleeping for 2s after acquisition due to ATAOS issue where corrections might take an extra cycle
# sleeping for 2s after acquisition due to ATAOS issue where corrections might take an extra cycle
# DEBUG:Script.LATISS:OBJECT 0001 - 0001
# OBJECT 0001 - 0001
# INFO:Script:Completed exposure 1 of 9. Exptime =   10.0s, filter=RG610, grating=ronchi90lpmm)
# Completed exposure 1 of 9. Exptime =   10.0s, filter=RG610, grating=ronchi90lpmm)
# DEBUG:Script.LATISS:OBJECT 0001 - 0001
# OBJECT 0001 - 0001
# INFO:Script:Completed exposure 2 of 9. Exptime =   10.0s, filter=RG610, grating=ronchi90lpmm)
# Completed exposure 2 of 9. Exptime =   10.0s, filter=RG610, grating=ronchi90lpmm)
# DEBUG:Script.LATISS:OBJECT 0001 - 0001
# OBJECT 0001 - 0001
# WARNING:ATHeaderService.logevent_logMessage:logMessage DDS read queue is filling: 29 of 100 elements
# logMessage DDS read queue is filling: 29 of 100 elements
# INFO:Script:Completed exposure 3 of 9. Exptime =   10.0s, filter=RG610, grating=ronchi90lpmm)
# Completed exposure 3 of 9. Exptime =   10.0s, filter=RG610, grating=ronchi90lpmm)
# DEBUG:Script:Must load new filter BG40 or grating ronchi90lpmm
# Must load new filter BG40 or grating ronchi90lpmm
# DEBUG:Script:Instrument setup in take_sequence now waiting for 2*len[<ddsutil.ATSpectrograph_ackcmd_6d105732 object at 0x7f98f8edeaf0>, <ddsutil.ATSpectrograph_ackcmd_6d105732 object at 0x7f99010db370>] ATAOS events saying correction started/finished
# Instrument setup in take_sequence now waiting for 2*len[<ddsutil.ATSpectrograph_ackcmd_6d105732 object at 0x7f98f8edeaf0>, <ddsutil.ATSpectrograph_ackcmd_6d105732 object at 0x7f99010db370>] ATAOS events saying correction started/finished
# DEBUG:Script:Event #0 - evt_atspectrographCorrectionStarted is: private_revCode: e8ac7ff3, private_sndStamp: 1616544006.3375082, private_rcvStamp: 1616544006.338259, private_seqNum: 154, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.0, pointingOffsets: [0.0, 0.0], priority: 0
# Event #0 - evt_atspectrographCorrectionStarted is: private_revCode: e8ac7ff3, private_sndStamp: 1616544006.3375082, private_rcvStamp: 1616544006.338259, private_seqNum: 154, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.0, pointingOffsets: [0.0, 0.0], priority: 0
# DEBUG:Script:Event #1 - evt_atspectrographCorrectionStarted is: private_revCode: e8ac7ff3, private_sndStamp: 1616544007.353876, private_rcvStamp: 1616544007.35455, private_seqNum: 155, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: -0.00299999862909317, pointingOffsets: [0.0, 0.0], priority: 0
# Event #1 - evt_atspectrographCorrectionStarted is: private_revCode: e8ac7ff3, private_sndStamp: 1616544007.353876, private_rcvStamp: 1616544007.35455, private_seqNum: 155, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: -0.00299999862909317, pointingOffsets: [0.0, 0.0], priority: 0
# DEBUG:Script:Event #0 - evt_atspectrographCorrectionCompleted is: private_revCode: 77a05b82, private_sndStamp: 1616544006.3385346, private_rcvStamp: 1616544006.3391178, private_seqNum: 154, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.0, pointingOffsets: [0.0, 0.0], priority: 0
# Event #0 - evt_atspectrographCorrectionCompleted is: private_revCode: 77a05b82, private_sndStamp: 1616544006.3385346, private_rcvStamp: 1616544006.3391178, private_seqNum: 154, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.0, pointingOffsets: [0.0, 0.0], priority: 0
# DEBUG:Script:Event #1 - evt_atspectrographCorrectionCompleted is: private_revCode: 77a05b82, private_sndStamp: 1616544008.388788, private_rcvStamp: 1616544008.389311, private_seqNum: 155, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: -0.00299999862909317, pointingOffsets: [0.0, 0.0], priority: 0
# Event #1 - evt_atspectrographCorrectionCompleted is: private_revCode: 77a05b82, private_sndStamp: 1616544008.388788, private_rcvStamp: 1616544008.389311, private_seqNum: 155, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: -0.00299999862909317, pointingOffsets: [0.0, 0.0], priority: 0
# DEBUG:Script:ATAOS atspectrographCorrectionStarted and Completed events arrived
# ATAOS atspectrographCorrectionStarted and Completed events arrived
# INFO:Script:sleeping for 2s after acquisition due to ATAOS issue where corrections might take an extra cycle
# sleeping for 2s after acquisition due to ATAOS issue where corrections might take an extra cycle
# DEBUG:Script.LATISS:OBJECT 0001 - 0001
# OBJECT 0001 - 0001
# INFO:Script:Completed exposure 4 of 9. Exptime =   10.0s, filter=BG40, grating=ronchi90lpmm)
# Completed exposure 4 of 9. Exptime =   10.0s, filter=BG40, grating=ronchi90lpmm)
# DEBUG:Script.LATISS:OBJECT 0001 - 0001
# OBJECT 0001 - 0001
# INFO:Script:Completed exposure 5 of 9. Exptime =   10.0s, filter=BG40, grating=ronchi90lpmm)
# Completed exposure 5 of 9. Exptime =   10.0s, filter=BG40, grating=ronchi90lpmm)
# DEBUG:Script.LATISS:OBJECT 0001 - 0001
# OBJECT 0001 - 0001
# INFO:Script:Completed exposure 6 of 9. Exptime =   10.0s, filter=BG40, grating=ronchi90lpmm)
# Completed exposure 6 of 9. Exptime =   10.0s, filter=BG40, grating=ronchi90lpmm)
# DEBUG:Script:Must load new filter empty_1 or grating ronchi90lpmm
# Must load new filter empty_1 or grating ronchi90lpmm
# DEBUG:Script:Instrument setup in take_sequence now waiting for 2*len[<ddsutil.ATSpectrograph_ackcmd_6d105732 object at 0x7f99128fb910>, <ddsutil.ATSpectrograph_ackcmd_6d105732 object at 0x7f9934d016a0>] ATAOS events saying correction started/finished
# Instrument setup in take_sequence now waiting for 2*len[<ddsutil.ATSpectrograph_ackcmd_6d105732 object at 0x7f99128fb910>, <ddsutil.ATSpectrograph_ackcmd_6d105732 object at 0x7f9934d016a0>] ATAOS events saying correction started/finished
# DEBUG:Script:Event #0 - evt_atspectrographCorrectionStarted is: private_revCode: e8ac7ff3, private_sndStamp: 1616544048.7327116, private_rcvStamp: 1616544048.7334101, private_seqNum: 156, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.0, pointingOffsets: [0.0, 0.0], priority: 0
# Event #0 - evt_atspectrographCorrectionStarted is: private_revCode: e8ac7ff3, private_sndStamp: 1616544048.7327116, private_rcvStamp: 1616544048.7334101, private_seqNum: 156, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.0, pointingOffsets: [0.0, 0.0], priority: 0
# DEBUG:Script:Event #1 - evt_atspectrographCorrectionStarted is: private_revCode: e8ac7ff3, private_sndStamp: 1616544051.7548842, private_rcvStamp: 1616544051.755461, private_seqNum: 157, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.01899999938905239, pointingOffsets: [0.0, 0.0], priority: 0
# Event #1 - evt_atspectrographCorrectionStarted is: private_revCode: e8ac7ff3, private_sndStamp: 1616544051.7548842, private_rcvStamp: 1616544051.755461, private_seqNum: 157, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.01899999938905239, pointingOffsets: [0.0, 0.0], priority: 0
# DEBUG:Script:Event #0 - evt_atspectrographCorrectionCompleted is: private_revCode: 77a05b82, private_sndStamp: 1616544048.7343163, private_rcvStamp: 1616544048.7349882, private_seqNum: 156, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.0, pointingOffsets: [0.0, 0.0], priority: 0
# Event #0 - evt_atspectrographCorrectionCompleted is: private_revCode: 77a05b82, private_sndStamp: 1616544048.7343163, private_rcvStamp: 1616544048.7349882, private_seqNum: 156, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.0, pointingOffsets: [0.0, 0.0], priority: 0
# DEBUG:Script:Event #1 - evt_atspectrographCorrectionCompleted is: private_revCode: 77a05b82, private_sndStamp: 1616544052.788432, private_rcvStamp: 1616544052.7890944, private_seqNum: 157, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.01899999938905239, pointingOffsets: [0.0, 0.0], priority: 0
# Event #1 - evt_atspectrographCorrectionCompleted is: private_revCode: 77a05b82, private_sndStamp: 1616544052.788432, private_rcvStamp: 1616544052.7890944, private_seqNum: 157, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.01899999938905239, pointingOffsets: [0.0, 0.0], priority: 0
# DEBUG:Script:ATAOS atspectrographCorrectionStarted and Completed events arrived
# ATAOS atspectrographCorrectionStarted and Completed events arrived
# INFO:Script:sleeping for 2s after acquisition due to ATAOS issue where corrections might take an extra cycle
# sleeping for 2s after acquisition due to ATAOS issue where corrections might take an extra cycle
# DEBUG:Script.LATISS:OBJECT 0001 - 0001
# OBJECT 0001 - 0001
# INFO:Script:Completed exposure 7 of 9. Exptime =   10.0s, filter=empty_1, grating=ronchi90lpmm)
# Completed exposure 7 of 9. Exptime =   10.0s, filter=empty_1, grating=ronchi90lpmm)
# DEBUG:Script.LATISS:OBJECT 0001 - 0001
# OBJECT 0001 - 0001
# INFO:Script:Completed exposure 8 of 9. Exptime =   10.0s, filter=empty_1, grating=ronchi90lpmm)
# Completed exposure 8 of 9. Exptime =   10.0s, filter=empty_1, grating=ronchi90lpmm)
# DEBUG:Script.LATISS:OBJECT 0001 - 0001
# OBJECT 0001 - 0001
# INFO:Script:Completed exposure 9 of 9. Exptime =   10.0s, filter=empty_1, grating=ronchi90lpmm)
# Completed exposure 9 of 9. Exptime =   10.0s, filter=empty_1, grating=ronchi90lpmm)
# DEBUG:Script:At finally statement in run
# At finally statement in run

# %% [markdown]
# ### Now re-acquire but using the hologram grating
# ##### This is the same position as the ronchi170lpmm grating

# %%
acq2_yaml = yaml.safe_dump({"object_name": TARGET,
                            "do_acquire": True,
                            "acq_filter" : 'RG610',
                            "acq_grating" : 'holo4_003', 
                            "acq_exposure_time": 0.5,
                            "max_acq_iter": 4,
                            "target_pointing_tolerance": 2,
                            "do_pointing_model": False,
                            "dataPath": '/project/shared/auxTel/rerun/quickLook',
                            "target_pointing_verification": False})
print(acq2_yaml)
# Out:
# acq_exposure_time: 0.5
# acq_filter: RG610
# acq_grating: holo4_003
# dataPath: /project/shared/auxTel/rerun/quickLook
# do_acquire: true
# do_pointing_model: false
# max_acq_iter: 4
# object_name: HD60228
# target_pointing_tolerance: 2
# target_pointing_verification: false

# %%
# Set script state to UNCONFIGURED
# this is required to run the script a 2nd time but otherwise is a no-op
script.set_state(ScriptState.UNCONFIGURED)
# Configure the script, which puts the ScriptState to CONFIGURED
acq2_configuration = script.cmd_configure.DataType()
acq2_configuration.config = acq2_yaml
await script.do_configure(acq2_configuration)
# Out:
# WARNING:ATMCS.logevent_target:target python read queue is filling: 29 of 100 elements
# target python read queue is filling: 29 of 100 elements

# %%
# This take the acquisition sequence for the hologram (and Ronchi170lpmm grating)
acq2_results = await script.arun()
# Out:
# DEBUG:Script:Beginning target acquisition
# Beginning target acquisition
# INFO:Script.ATCS:Slewing to HD60228: 07 30 30.9197 -54 23 57.711
# Slewing to HD60228: 07 30 30.9197 -54 23 57.711
# DEBUG:Script.ATCS:Setting rotator physical position to -105.0 deg. Rotator will track sky.
# Setting rotator physical position to -105.0 deg. Rotator will track sky.
# DEBUG:Script.ATCS:Parallactic angle: 21.593990863977368 | Sky Angle: 31.91987329450069
# Parallactic angle: 21.593990863977368 | Sky Angle: 31.91987329450069
# DEBUG:Script.ATCS:Sending command
# Sending command
# DEBUG:Script.ATCS:Stop tracking.
# Stop tracking.
# DEBUG:Script.ATCS:Tracking state: <AtMountState.TRACKINGENABLED: 9>
# Tracking state: <AtMountState.TRACKINGENABLED: 9>
# DEBUG:Script.ATCS:Tracking state: <AtMountState.STOPPING: 10>
# Tracking state: <AtMountState.STOPPING: 10>
# DEBUG:Script.ATCS:In Position: True.
# In Position: True.
# DEBUG:Script.ATCS:Scheduling check coroutines
# Scheduling check coroutines
# DEBUG:Script.ATCS:process as completed...
# process as completed...
# DEBUG:Script.ATCS:atmcs: <State.ENABLED: 2>
# atmcs: <State.ENABLED: 2>
# DEBUG:Script.ATCS:atptg: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# DEBUG:Script.ATCS:ataos: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# DEBUG:Script.ATCS:atpneumatics: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# DEBUG:Script.ATCS:athexapod: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# DEBUG:Script.ATCS:atdome: <State.ENABLED: 2>
# atdome: <State.ENABLED: 2>
# DEBUG:Script.ATCS:atdometrajectory: <State.ENABLED: 2>
# atdometrajectory: <State.ENABLED: 2>
# INFO:Script.ATCS:[Telescope] delta Alt = -000.014 deg; delta Az = -000.011 deg; delta N1 = +000.000 deg; delta N2 = +001.484 deg [Dome] delta Az = +000.262 deg
# [Telescope] delta Alt = -000.014 deg; delta Az = -000.011 deg; delta N1 = +000.000 deg; delta N2 = +001.484 deg [Dome] delta Az = +000.262 deg
# INFO:Script.ATCS:ATDome in position.
# ATDome in position.
# INFO:Script.ATCS:Got True
# Got True
# INFO:Script.ATCS:Waiting for telescope to settle.
# Waiting for telescope to settle.
# INFO:Script.ATCS:[Telescope] delta Alt = -000.001 deg; delta Az = +000.006 deg; delta N1 = -000.000 deg; delta N2 = +000.007 deg [Dome] delta Az = +000.262 deg
# [Telescope] delta Alt = -000.001 deg; delta Az = +000.006 deg; delta N1 = -000.000 deg; delta N2 = +000.007 deg [Dome] delta Az = +000.262 deg
# INFO:Script.ATCS:Telescope in position.
# Telescope in position.
# DEBUG:Script:Instrument setup required: True
# Instrument setup required: True
# DEBUG:Script:Must load new filter RG610 or grating holo4_003
# Must load new filter RG610 or grating holo4_003
# DEBUG:Script:Instrument setup in acquisition now waiting for 2*len[<ddsutil.ATSpectrograph_ackcmd_6d105732 object at 0x7f990a34f490>, <ddsutil.ATSpectrograph_ackcmd_6d105732 object at 0x7f990a34faf0>] ATAOS events saying correction started/finished
# Instrument setup in acquisition now waiting for 2*len[<ddsutil.ATSpectrograph_ackcmd_6d105732 object at 0x7f990a34f490>, <ddsutil.ATSpectrograph_ackcmd_6d105732 object at 0x7f990a34faf0>] ATAOS events saying correction started/finished
# DEBUG:Script:Event #0 - evt_atspectrographCorrectionStarted is: private_revCode: e8ac7ff3, private_sndStamp: 1616546967.757657, private_rcvStamp: 1616546967.7583635, private_seqNum: 178, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: -0.12240000069141388, pointingOffsets: [-0.6000000238418579, 1.100000023841858], priority: 0
# Event #0 - evt_atspectrographCorrectionStarted is: private_revCode: e8ac7ff3, private_sndStamp: 1616546967.757657, private_rcvStamp: 1616546967.7583635, private_seqNum: 178, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: -0.12240000069141388, pointingOffsets: [-0.6000000238418579, 1.100000023841858], priority: 0
# DEBUG:Script:Event #1 - evt_atspectrographCorrectionStarted is: private_revCode: e8ac7ff3, private_sndStamp: 1616546975.303114, private_rcvStamp: 1616546975.3047533, private_seqNum: 179, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.0, pointingOffsets: [0.0, 0.0], priority: 0
# Event #1 - evt_atspectrographCorrectionStarted is: private_revCode: e8ac7ff3, private_sndStamp: 1616546975.303114, private_rcvStamp: 1616546975.3047533, private_seqNum: 179, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.0, pointingOffsets: [0.0, 0.0], priority: 0
# DEBUG:Script:Event #0 - evt_atspectrographCorrectionCompleted is: private_revCode: 77a05b82, private_sndStamp: 1616546974.809312, private_rcvStamp: 1616546974.810126, private_seqNum: 178, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: -0.12240000069141388, pointingOffsets: [-0.6000000238418579, 1.100000023841858], priority: 0
# Event #0 - evt_atspectrographCorrectionCompleted is: private_revCode: 77a05b82, private_sndStamp: 1616546974.809312, private_rcvStamp: 1616546974.810126, private_seqNum: 178, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: -0.12240000069141388, pointingOffsets: [-0.6000000238418579, 1.100000023841858], priority: 0
# DEBUG:Script:Event #1 - evt_atspectrographCorrectionCompleted is: private_revCode: 77a05b82, private_sndStamp: 1616546975.3045638, private_rcvStamp: 1616546975.3053825, private_seqNum: 179, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.0, pointingOffsets: [0.0, 0.0], priority: 0
# Event #1 - evt_atspectrographCorrectionCompleted is: private_revCode: 77a05b82, private_sndStamp: 1616546975.3045638, private_rcvStamp: 1616546975.3053825, private_seqNum: 179, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.0, pointingOffsets: [0.0, 0.0], priority: 0
# DEBUG:Script:ATAOS atspectrographCorrectionXXXX events arrived
# ATAOS atspectrographCorrectionXXXX events arrived
# INFO:Script:sleeping for 2s after acquisition due to ATAOS issue where corrections might take an extra cycle
# sleeping for 2s after acquisition due to ATAOS issue where corrections might take an extra cycle
# INFO:Script:Beginning Acquisition Iterative Loop, with a maximum amount of iterations set to 4
# Beginning Acquisition Iterative Loop, with a maximum amount of iterations set to 4
# DEBUG:Script:
# Starting iteration number 1, with a maximum of 4
#
# Starting iteration number 1, with a maximum of 4
# DEBUG:Script.LATISS:Generating group_id
# Generating group_id
# DEBUG:Script.LATISS:OBJECT 0001 - 0001
# OBJECT 0001 - 0001
# INFO:Script:Waiting for image to arrive in OODS for a maximum of 10.5 seconds.
# Waiting for image to arrive in OODS for a maximum of 10.5 seconds.
# INFO:Script:seqNum 351 arrived in OODS
# seqNum 351 arrived in OODS
# DEBUG:lsst.ts.observing.utilities.auxtel.latiss.getters:Pulling data with dataset = quickLookExp and dataId = {'dayObs': '2021-03-23', 'seqNum': 351}
# Pulling data with dataset = quickLookExp and dataId = {'dayObs': '2021-03-23', 'seqNum': 351}
# DEBUG:lsst.ts.observing.utilities.auxtel.latiss.getters:Running bestEffort ISR on {'dayObs': '2021-03-23', 'seqNum': 351} and returning exposure
# Running bestEffort ISR on {'dayObs': '2021-03-23', 'seqNum': 351} and returning exposure
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing SHUTTIME header to be None
# AT_O_20210323_000351: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing SHUTTIME header to be None
# AT_O_20210323_000351: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing SHUTTIME header to be None
# AT_O_20210323_000351: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing SHUTTIME header to be None
# AT_O_20210323_000351: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing SHUTTIME header to be None
# AT_O_20210323_000351: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing SHUTTIME header to be None
# AT_O_20210323_000351: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing SHUTTIME header to be None
# AT_O_20210323_000351: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing SHUTTIME header to be None
# AT_O_20210323_000351: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing SHUTTIME header to be None
# AT_O_20210323_000351: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing SHUTTIME header to be None
# AT_O_20210323_000351: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing SHUTTIME header to be None
# AT_O_20210323_000351: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing SHUTTIME header to be None
# AT_O_20210323_000351: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing SHUTTIME header to be None
# AT_O_20210323_000351: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing SHUTTIME header to be None
# AT_O_20210323_000351: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing SHUTTIME header to be None
# AT_O_20210323_000351: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing SHUTTIME header to be None
# AT_O_20210323_000351: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Received 2 headers for merging
# Received 2 headers for merging
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000351.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000351: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000351: Forcing SHUTTIME header to be None
# AT_O_20210323_000351: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.translator:Using translation class LSST_LATISS
# Using translation class LSST_LATISS
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-None.yaml
# Checking for header correction file named LATISS-None.yaml
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 29 of 100 elements
# DEBUG:lsst.obs.lsst.translators.latiss:Assigning OBSID to a value of 'None'
# target DDS read queue is filling: 29 of 100 elements
# Assigning OBSID to a value of 'None'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-None.yaml
# Checking for header correction file named LATISS-None.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:Assigning OBSID to a value of 'None'
# Assigning OBSID to a value of 'None'
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 28 of 100 elements
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# target DDS read queue is filling: 28 of 100 elements
# Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# Running best effort isr...
# Running with bias subtraction
# Running with dark correction subtraction
# Running with defect correction
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 21 of 100 elements
# target DDS read queue is filling: 21 of 100 elements
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 15 of 100 elements
# Running cosmic ray repair
# target DDS read queue is filling: 15 of 100 elements
# WARNING:ATMCS.logevent_target:target python read queue is filling: 99 of 100 elements
# target python read queue is filling: 99 of 100 elements
# WARNING:ATMCS.mount_AzEl_Encoders:mount_AzEl_Encoders python read queue is filling: 14 of 100 elements
# mount_AzEl_Encoders python read queue is filling: 14 of 100 elements
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 17 of 100 elements
# target DDS read queue is filling: 17 of 100 elements
# WARNING:ATMCS.logevent_target:target python read queue is filling: 16 of 100 elements
# target python read queue is filling: 16 of 100 elements
# DEBUG:Script:Current brightest target position is (2530.7, 1616.4) whereas the target position is (1750, 300)
# Current brightest target position is (2530.7, 1616.4) whereas the target position is (1750, 300)
# INFO:Script:Calculated offsets [dx,dy] are [81.58, 137.56] arcsec as calculated from sequence number 351 on dayObs of 2021-03-23
# Calculated offsets [dx,dy] are [81.58, 137.56] arcsec as calculated from sequence number 351 on dayObs of 2021-03-23
# INFO:Script:Current radial pointing error of 159.93 arcsec exceeds the tolerance of 2 arcsec.
# Current radial pointing error of 159.93 arcsec exceeds the tolerance of 2 arcsec.
# INFO:Script:Applying x/y offset to telescope pointing.
# Applying x/y offset to telescope pointing.
# DEBUG:Script.ATCS:Calculating x/y offset: 81.57981896209492/137.5635647865952
# Calculating x/y offset: 81.57981896209492/137.5635647865952
# DEBUG:Script.ATCS:Applying Az/El offset: -105.11273092054952/-120.54175632165027
# Applying Az/El offset: -105.11273092054952/-120.54175632165027
# DEBUG:Script.ATCS:Telescope not in position.
# Telescope not in position.
# DEBUG:Script.ATCS:All axes in position.
# All axes in position.
# DEBUG:Script.ATCS:Waiting for telescope to settle.
# Waiting for telescope to settle.
# DEBUG:Script.ATCS:Done
# Done
# INFO:Script:At end of iteration loop, success is False. So moving to next iteration
# At end of iteration loop, success is False. So moving to next iteration
# DEBUG:Script:
# Starting iteration number 2, with a maximum of 4
#
# Starting iteration number 2, with a maximum of 4
# DEBUG:Script.LATISS:Generating group_id
# Generating group_id
# DEBUG:Script.LATISS:OBJECT 0001 - 0001
# OBJECT 0001 - 0001
# INFO:Script:Waiting for image to arrive in OODS for a maximum of 10.5 seconds.
# Waiting for image to arrive in OODS for a maximum of 10.5 seconds.
# INFO:Script:seqNum 352 arrived in OODS
# seqNum 352 arrived in OODS
# DEBUG:lsst.ts.observing.utilities.auxtel.latiss.getters:Pulling data with dataset = quickLookExp and dataId = {'dayObs': '2021-03-23', 'seqNum': 352}
# Pulling data with dataset = quickLookExp and dataId = {'dayObs': '2021-03-23', 'seqNum': 352}
# DEBUG:lsst.ts.observing.utilities.auxtel.latiss.getters:Running bestEffort ISR on {'dayObs': '2021-03-23', 'seqNum': 352} and returning exposure
# Running bestEffort ISR on {'dayObs': '2021-03-23', 'seqNum': 352} and returning exposure
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing SHUTTIME header to be None
# AT_O_20210323_000352: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing SHUTTIME header to be None
# AT_O_20210323_000352: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing SHUTTIME header to be None
# AT_O_20210323_000352: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing SHUTTIME header to be None
# AT_O_20210323_000352: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing SHUTTIME header to be None
# AT_O_20210323_000352: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing SHUTTIME header to be None
# AT_O_20210323_000352: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing SHUTTIME header to be None
# AT_O_20210323_000352: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing SHUTTIME header to be None
# AT_O_20210323_000352: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing SHUTTIME header to be None
# AT_O_20210323_000352: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing SHUTTIME header to be None
# AT_O_20210323_000352: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing SHUTTIME header to be None
# AT_O_20210323_000352: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing SHUTTIME header to be None
# AT_O_20210323_000352: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing SHUTTIME header to be None
# AT_O_20210323_000352: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing SHUTTIME header to be None
# AT_O_20210323_000352: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing SHUTTIME header to be None
# AT_O_20210323_000352: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing SHUTTIME header to be None
# AT_O_20210323_000352: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Received 2 headers for merging
# Received 2 headers for merging
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000352.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000352: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000352: Forcing SHUTTIME header to be None
# AT_O_20210323_000352: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.translator:Using translation class LSST_LATISS
# Using translation class LSST_LATISS
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-None.yaml
# Checking for header correction file named LATISS-None.yaml
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 29 of 100 elements
# target DDS read queue is filling: 29 of 100 elements
# DEBUG:lsst.obs.lsst.translators.latiss:Assigning OBSID to a value of 'None'
# Assigning OBSID to a value of 'None'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-None.yaml
# Checking for header correction file named LATISS-None.yaml
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 28 of 100 elements
# target DDS read queue is filling: 28 of 100 elements
# DEBUG:lsst.obs.lsst.translators.latiss:Assigning OBSID to a value of 'None'
# Assigning OBSID to a value of 'None'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# Running best effort isr...
# Running with bias subtraction
# Running with dark correction subtraction
# Running with defect correction
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 28 of 100 elements
# target DDS read queue is filling: 28 of 100 elements
# Running cosmic ray repair
# WARNING:ATMCS.logevent_target:target python read queue is filling: 99 of 100 elements
# target python read queue is filling: 99 of 100 elements
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 36 of 100 elements
# WARNING:ATMCS.mount_AzEl_Encoders:mount_AzEl_Encoders python read queue is filling: 13 of 100 elements
# target DDS read queue is filling: 36 of 100 elements
# mount_AzEl_Encoders python read queue is filling: 13 of 100 elements
# WARNING:ATMCS.logevent_target:target python read queue is filling: 35 of 100 elements
# target python read queue is filling: 35 of 100 elements
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 16 of 100 elements
# target DDS read queue is filling: 16 of 100 elements
# WARNING:ATMCS.logevent_target:target python read queue is filling: 15 of 100 elements
# target python read queue is filling: 15 of 100 elements
# DEBUG:Script:Current brightest target position is (1653.1, 190.27) whereas the target position is (1750, 300)
# Current brightest target position is (1653.1, 190.27) whereas the target position is (1750, 300)
# INFO:Script:Calculated offsets [dx,dy] are [-10.13, -11.47] arcsec as calculated from sequence number 352 on dayObs of 2021-03-23
# Calculated offsets [dx,dy] are [-10.13, -11.47] arcsec as calculated from sequence number 352 on dayObs of 2021-03-23
# INFO:Script:Current radial pointing error of 15.30 arcsec exceeds the tolerance of 2 arcsec.
# Current radial pointing error of 15.30 arcsec exceeds the tolerance of 2 arcsec.
# INFO:Script:Applying x/y offset to telescope pointing.
# Applying x/y offset to telescope pointing.
# DEBUG:Script.ATCS:Calculating x/y offset: -10.130540649383507/-11.46679728736867
# Calculating x/y offset: -10.130540649383507/-11.46679728736867
# DEBUG:Script.ATCS:Applying Az/El offset: 11.981495787027493/9.516252023977694
# Applying Az/El offset: 11.981495787027493/9.516252023977694
# DEBUG:Script.ATCS:Telescope not in position.
# Telescope not in position.
# DEBUG:Script.ATCS:All axes in position.
# All axes in position.
# DEBUG:Script.ATCS:Waiting for telescope to settle.
# Waiting for telescope to settle.
# DEBUG:Script.ATCS:Done
# Done
# INFO:Script:At end of iteration loop, success is False. So moving to next iteration
# At end of iteration loop, success is False. So moving to next iteration
# DEBUG:Script:
# Starting iteration number 3, with a maximum of 4
#
# Starting iteration number 3, with a maximum of 4
# DEBUG:Script.LATISS:Generating group_id
# Generating group_id
# DEBUG:Script.LATISS:OBJECT 0001 - 0001
# OBJECT 0001 - 0001
# INFO:Script:Waiting for image to arrive in OODS for a maximum of 10.5 seconds.
# Waiting for image to arrive in OODS for a maximum of 10.5 seconds.
# INFO:Script:seqNum 353 arrived in OODS
# seqNum 353 arrived in OODS
# DEBUG:lsst.ts.observing.utilities.auxtel.latiss.getters:Pulling data with dataset = quickLookExp and dataId = {'dayObs': '2021-03-23', 'seqNum': 353}
# Pulling data with dataset = quickLookExp and dataId = {'dayObs': '2021-03-23', 'seqNum': 353}
# DEBUG:lsst.ts.observing.utilities.auxtel.latiss.getters:Running bestEffort ISR on {'dayObs': '2021-03-23', 'seqNum': 353} and returning exposure
# Running bestEffort ISR on {'dayObs': '2021-03-23', 'seqNum': 353} and returning exposure
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing SHUTTIME header to be None
# AT_O_20210323_000353: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing SHUTTIME header to be None
# AT_O_20210323_000353: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing SHUTTIME header to be None
# AT_O_20210323_000353: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing SHUTTIME header to be None
# AT_O_20210323_000353: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing SHUTTIME header to be None
# AT_O_20210323_000353: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing SHUTTIME header to be None
# AT_O_20210323_000353: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing SHUTTIME header to be None
# AT_O_20210323_000353: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing SHUTTIME header to be None
# AT_O_20210323_000353: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing SHUTTIME header to be None
# AT_O_20210323_000353: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing SHUTTIME header to be None
# AT_O_20210323_000353: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing SHUTTIME header to be None
# AT_O_20210323_000353: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing SHUTTIME header to be None
# AT_O_20210323_000353: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing SHUTTIME header to be None
# AT_O_20210323_000353: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing SHUTTIME header to be None
# AT_O_20210323_000353: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing SHUTTIME header to be None
# AT_O_20210323_000353: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing SHUTTIME header to be None
# AT_O_20210323_000353: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Received 2 headers for merging
# Received 2 headers for merging
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# Checking for header correction file named LATISS-AT_O_20210323_000353.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# AT_O_20210323_000353: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210323_000353: Forcing SHUTTIME header to be None
# AT_O_20210323_000353: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.translator:Using translation class LSST_LATISS
# Using translation class LSST_LATISS
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 28 of 100 elements
# target DDS read queue is filling: 28 of 100 elements
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-None.yaml
# Checking for header correction file named LATISS-None.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:Assigning OBSID to a value of 'None'
# Assigning OBSID to a value of 'None'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-None.yaml
# Checking for header correction file named LATISS-None.yaml
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 28 of 100 elements
# target DDS read queue is filling: 28 of 100 elements
# DEBUG:lsst.obs.lsst.translators.latiss:Assigning OBSID to a value of 'None'
# Assigning OBSID to a value of 'None'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# Running best effort isr...
# Running with bias subtraction
# Running with dark correction subtraction
# Running with defect correction
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 17 of 100 elements
# target DDS read queue is filling: 17 of 100 elements
# Running cosmic ray repair
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 41 of 100 elements
# target DDS read queue is filling: 41 of 100 elements
# WARNING:ATMCS.logevent_target:target python read queue is filling: 99 of 100 elements
# target python read queue is filling: 99 of 100 elements
# WARNING:ATMCS.mount_AzEl_Encoders:mount_AzEl_Encoders python read queue is filling: 13 of 100 elements
# mount_AzEl_Encoders python read queue is filling: 13 of 100 elements
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 17 of 100 elements
# target DDS read queue is filling: 17 of 100 elements
# WARNING:ATMCS.logevent_target:target python read queue is filling: 16 of 100 elements
# target python read queue is filling: 16 of 100 elements
# DEBUG:Script:Current brightest target position is (1761.1, 307.06) whereas the target position is (1750, 300)
# Current brightest target position is (1761.1, 307.06) whereas the target position is (1750, 300)
# INFO:Script:Calculated offsets [dx,dy] are [1.16, 0.74] arcsec as calculated from sequence number 353 on dayObs of 2021-03-23
# Calculated offsets [dx,dy] are [1.16, 0.74] arcsec as calculated from sequence number 353 on dayObs of 2021-03-23
# INFO:Script:Acquisition completed successfully.Current radial pointing error of 1.38 arcsec is within the tolerance of 2 arcsec.
# Acquisition completed successfully.Current radial pointing error of 1.38 arcsec is within the tolerance of 2 arcsec.
# INFO:Script:Skipping additional image to verify offset was applied correctly as target_pointing_verification is set to False
# Skipping additional image to verify offset was applied correctly as target_pointing_verification is set to False
# DEBUG:Script:Beginning taking data for target sequence
# Beginning taking data for target sequence
# DEBUG:Script:Must load new filter empty_1 or grating empty_1
# Must load new filter empty_1 or grating empty_1
# DEBUG:Script:Instrument setup in take_sequence now waiting for 2*len[<ddsutil.ATSpectrograph_ackcmd_6d105732 object at 0x7f9923f2a9d0>, <ddsutil.ATSpectrograph_ackcmd_6d105732 object at 0x7f9923f2a970>] ATAOS events saying correction started/finished
# Instrument setup in take_sequence now waiting for 2*len[<ddsutil.ATSpectrograph_ackcmd_6d105732 object at 0x7f9923f2a9d0>, <ddsutil.ATSpectrograph_ackcmd_6d105732 object at 0x7f9923f2a970>] ATAOS events saying correction started/finished
# DEBUG:Script:Event #0 - evt_atspectrographCorrectionStarted is: private_revCode: e8ac7ff3, private_sndStamp: 1616547057.0352159, private_rcvStamp: 1616547057.0366805, private_seqNum: 180, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.12240000069141388, pointingOffsets: [0.6000000238418579, -1.100000023841858], priority: 0
# Event #0 - evt_atspectrographCorrectionStarted is: private_revCode: e8ac7ff3, private_sndStamp: 1616547057.0352159, private_rcvStamp: 1616547057.0366805, private_seqNum: 180, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.12240000069141388, pointingOffsets: [0.6000000238418579, -1.100000023841858], priority: 0
# DEBUG:Script:Event #1 - evt_atspectrographCorrectionStarted is: private_revCode: e8ac7ff3, private_sndStamp: 1616547064.1009884, private_rcvStamp: 1616547064.1016426, private_seqNum: 181, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.0, pointingOffsets: [0.0, 0.0], priority: 0
# Event #1 - evt_atspectrographCorrectionStarted is: private_revCode: e8ac7ff3, private_sndStamp: 1616547064.1009884, private_rcvStamp: 1616547064.1016426, private_seqNum: 181, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.0, pointingOffsets: [0.0, 0.0], priority: 0
# DEBUG:Script:Event #0 - evt_atspectrographCorrectionCompleted is: private_revCode: 77a05b82, private_sndStamp: 1616547064.0959182, private_rcvStamp: 1616547064.096632, private_seqNum: 180, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.12240000069141388, pointingOffsets: [0.6000000238418579, -1.100000023841858], priority: 0
# Event #0 - evt_atspectrographCorrectionCompleted is: private_revCode: 77a05b82, private_sndStamp: 1616547064.0959182, private_rcvStamp: 1616547064.096632, private_seqNum: 180, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.12240000069141388, pointingOffsets: [0.6000000238418579, -1.100000023841858], priority: 0
# DEBUG:Script:Event #1 - evt_atspectrographCorrectionCompleted is: private_revCode: 77a05b82, private_sndStamp: 1616547064.1023495, private_rcvStamp: 1616547064.1029904, private_seqNum: 181, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.0, pointingOffsets: [0.0, 0.0], priority: 0
# Event #1 - evt_atspectrographCorrectionCompleted is: private_revCode: 77a05b82, private_sndStamp: 1616547064.1023495, private_rcvStamp: 1616547064.1029904, private_seqNum: 181, private_identity: ATAOS, private_origin: 51167, private_host: 0, focusOffset: 0.0, pointingOffsets: [0.0, 0.0], priority: 0
# DEBUG:Script:ATAOS atspectrographCorrectionStarted and Completed events arrived
# ATAOS atspectrographCorrectionStarted and Completed events arrived
# INFO:Script:sleeping for 2s after acquisition due to ATAOS issue where corrections might take an extra cycle
# sleeping for 2s after acquisition due to ATAOS issue where corrections might take an extra cycle
# DEBUG:Script.LATISS:OBJECT 0001 - 0001
# OBJECT 0001 - 0001
# INFO:Script:Completed exposure 1 of 1. Exptime =    2.0s, filter=empty_1, grating=empty_1)
# Completed exposure 1 of 1. Exptime =    2.0s, filter=empty_1, grating=empty_1)
# DEBUG:Script:At finally statement in run
# At finally statement in run

# %%
await script.latiss.setup_atspec(filter='RG610', grating='ronchi90lpmm')
# Out:
# [<ddsutil.ATSpectrograph_ackcmd_6d105732 at 0x7f991b7994c0>,
#  <ddsutil.ATSpectrograph_ackcmd_6d105732 at 0x7f991b799160>]

# %%
await script.latiss.take_object(1.0, 1, filter='RG610', grating='ronchi90lpmm')
# Out:
# DEBUG:Script.LATISS:Generating group_id
# Generating group_id
# DEBUG:Script.LATISS:OBJECT 0001 - 0001
# OBJECT 0001 - 0001
# array([2021032300357])
# WARNING:ATHeaderService.logevent_logMessage:logMessage DDS read queue is filling: 12 of 100 elements
# logMessage DDS read queue is filling: 12 of 100 elements
# WARNING:ATHeaderService.logevent_logMessage:logMessage DDS read queue is filling: 15 of 100 elements
# logMessage DDS read queue is filling: 15 of 100 elements
# WARNING:ATHeaderService.logevent_logMessage:logMessage DDS read queue is filling: 13 of 100 elements
# logMessage DDS read queue is filling: 13 of 100 elements
# WARNING:ATHeaderService.logevent_logMessage:logMessage DDS read queue is filling: 11 of 100 elements
# logMessage DDS read queue is filling: 11 of 100 elements
# WARNING:ATHeaderService.logevent_logMessage:logMessage DDS read queue is filling: 11 of 100 elements
# logMessage DDS read queue is filling: 11 of 100 elements
# WARNING:ATHeaderService.logevent_logMessage:logMessage DDS read queue is filling: 15 of 100 elements
# logMessage DDS read queue is filling: 15 of 100 elements
# WARNING:ATHeaderService.logevent_logMessage:logMessage DDS read queue is filling: 12 of 100 elements
# logMessage DDS read queue is filling: 12 of 100 elements
# WARNING:ATHeaderService.logevent_logMessage:logMessage DDS read queue is filling: 10 of 100 elements
# logMessage DDS read queue is filling: 10 of 100 elements
# WARNING:ATHeaderService.logevent_logMessage:logMessage DDS read queue is filling: 11 of 100 elements
# logMessage DDS read queue is filling: 11 of 100 elements
# WARNING:ATHeaderService.logevent_logMessage:logMessage DDS read queue is filling: 17 of 100 elements
# logMessage DDS read queue is filling: 17 of 100 elements
# WARNING:ATHeaderService.logevent_logMessage:logMessage DDS read queue is filling: 10 of 100 elements
# logMessage DDS read queue is filling: 10 of 100 elements

# %%
await script.atcs.reset_offsets()
# Out:
# DEBUG:Script.ATCS:Reseting absorbed offsets.
# Reseting absorbed offsets.
# DEBUG:Script.ATCS:Reseting non-absorbed offsets.
# Reseting non-absorbed offsets.
# WARNING:ATHeaderService.logevent_logMessage:logMessage DDS read queue is filling: 10 of 100 elements
# logMessage DDS read queue is filling: 10 of 100 elements

# %% [markdown]
# ### Now perform science data with 90lpmm Ronchi

# %%
seq2_yaml = yaml.safe_dump({"object_name": TARGET,
                                "do_acquire": False,
                                "do_take_sequence": True,
                                "exposure_time_sequence" : [10, 10, 10,
                                                            10, 10, 10,
                                                            10, 10, 10], 
                                "filter_sequence": ['RG610','RG610', 'RG610',
                                                    'BG40','BG40', 'BG40',
                                                    'empty_1','empty_1', 'empty_1'], 
                                # RG610 and Ronchi
                                "grating_sequence": ['ronchi90lpmm', 'ronchi90lpmm','ronchi90lpmm',
                                                     'ronchi90lpmm', 'ronchi90lpmm', 'ronchi90lpmm',
                                                     'ronchi90lpmm', 'ronchi90lpmm', 'ronchi90lpmm'],
                                "do_pointing_model": False,
                                "dataPath": '/project/shared/auxTel/rerun/quickLook',
                                "target_pointing_verification": False})
print(seq2_yaml)

# %%
# Set script state to UNCONFIGURED
# this is required to run the script a 2nd time but otherwise is a no-op
script.set_state(ScriptState.UNCONFIGURED)
# Configure the script, which puts the ScriptState to CONFIGURED
seq2_configuration = script.cmd_configure.DataType()
seq2_configuration.config = seq2_yaml
await script.do_configure(seq2_configuration)

# %%
# This take the sequence of images with the Ronchi
seq2_results = await script.arun()
