# %% [markdown]
# ## This notebook launches the LatissCWFSAlign script, meant for the scriptQueue, but via a notebook.
# ##### This calculates focus offsets for the hexapod (and also decentering corrections)

# %%
import sys
import asyncio
import time
import numpy as np
import logging 
import yaml
import matplotlib.pyplot as plt

import astropy.units as u
from astropy.time import Time
from astropy.coordinates import SkyCoord, AltAz, ICRS, EarthLocation, Angle
from astroquery.vo_conesearch import ConeSearch
from astroquery.simbad import Simbad

# %matplotlib inline
from lsst.ts import salobj
from lsst.ts.externalscripts.auxtel.latiss_cwfs_align import LatissCWFSAlign
from lsst.ts.idl.enums.Script import ScriptState
from lsst.ts.observatory.control.utils import RotType

# %%
stream_handler = logging.StreamHandler(sys.stdout)
# if you want logging
logger = logging.getLogger()
logger.addHandler(stream_handler)
logger.level = logging.DEBUG

# turn off logging for matplotlib
mpl_logger = logging.getLogger('matplotlib')
mpl_logger.setLevel(logging.WARNING)

# %%
script = LatissCWFSAlign(index=1, remotes=True)  # this essentially calls the init method
# make sure all remotes etc are running
await script.start_task
# Out:
# DEBUG:Script.ATCS:atmcs: Adding all resources.
# atmcs: Adding all resources.
# DEBUG:Script.ATCS:atptg: Adding all resources.
# atptg: Adding all resources.
# DEBUG:Script.ATCS:ataos: Adding all resources.
# ataos: Adding all resources.
# DEBUG:Script.ATCS:atpneumatics: Adding all resources.
# atpneumatics: Adding all resources.
# DEBUG:Script.ATCS:athexapod: Adding all resources.
# athexapod: Adding all resources.
# DEBUG:Script.ATCS:atdome: Adding all resources.
# atdome: Adding all resources.
# DEBUG:Script.ATCS:atdometrajectory: Adding all resources.
# atdometrajectory: Adding all resources.
# DEBUG:Script.LATISS:atcamera: Adding all resources.
# atcamera: Adding all resources.
# DEBUG:Script.LATISS:atspectrograph: Adding all resources.
# atspectrograph: Adding all resources.
# DEBUG:Script.LATISS:atheaderservice: Adding all resources.
# atheaderservice: Adding all resources.
# DEBUG:Script.LATISS:atarchiver: Adding all resources.
# atarchiver: Adding all resources.
# INFO:Script:latiss_cwfs_align initialized!
# latiss_cwfs_align initialized!
# INFO:ATDomeTrajectory:Read historical data in 0.01 sec
# Read historical data in 0.01 sec
# DEBUG:ATDomeTrajectory:Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, algorithm)
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, algorithm)
# DEBUG:ATDomeTrajectory:Read 5 history items for RemoteEvent(ATDomeTrajectory, 0, appliedSettingsMatchStart)
# Read 5 history items for RemoteEvent(ATDomeTrajectory, 0, appliedSettingsMatchStart)
# DEBUG:ATDomeTrajectory:Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, authList)
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, authList)
# DEBUG:ATDomeTrajectory:Read 8 history items for RemoteEvent(ATDomeTrajectory, 0, followingMode)
# Read 8 history items for RemoteEvent(ATDomeTrajectory, 0, followingMode)
# DEBUG:ATDomeTrajectory:Read 100 history items for RemoteEvent(ATDomeTrajectory, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATDomeTrajectory, 0, heartbeat)
# DEBUG:ATDomeTrajectory:Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, logLevel)
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, logLevel)
# DEBUG:ATDomeTrajectory:Read 46 history items for RemoteEvent(ATDomeTrajectory, 0, logMessage)
# Read 46 history items for RemoteEvent(ATDomeTrajectory, 0, logMessage)
# DEBUG:ATDomeTrajectory:Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, settingVersions)
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, settingVersions)
# DEBUG:ATDomeTrajectory:Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, settingsApplied)
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, settingsApplied)
# DEBUG:ATDomeTrajectory:Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, simulationMode)
# DEBUG:ATDomeTrajectory:Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, softwareVersions)
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, softwareVersions)
# DEBUG:ATDomeTrajectory:Read 19 history items for RemoteEvent(ATDomeTrajectory, 0, summaryState)
# Read 19 history items for RemoteEvent(ATDomeTrajectory, 0, summaryState)
# INFO:ATHexapod:Read historical data in 0.07 sec
# Read historical data in 0.07 sec
# DEBUG:ATHexapod:Read 5 history items for RemoteEvent(ATHexapod, 0, appliedSettingsMatchStart)
# Read 5 history items for RemoteEvent(ATHexapod, 0, appliedSettingsMatchStart)
# DEBUG:ATHexapod:Read 1 history items for RemoteEvent(ATHexapod, 0, authList)
# Read 1 history items for RemoteEvent(ATHexapod, 0, authList)
# DEBUG:ATHexapod:Read 100 history items for RemoteEvent(ATHexapod, 0, detailedState)
# Read 100 history items for RemoteEvent(ATHexapod, 0, detailedState)
# DEBUG:ATHexapod:Read 100 history items for RemoteEvent(ATHexapod, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATHexapod, 0, heartbeat)
# DEBUG:ATHexapod:Read 100 history items for RemoteEvent(ATHexapod, 0, inPosition)
# Read 100 history items for RemoteEvent(ATHexapod, 0, inPosition)
# DEBUG:ATHexapod:Read 1 history items for RemoteEvent(ATHexapod, 0, logLevel)
# Read 1 history items for RemoteEvent(ATHexapod, 0, logLevel)
# DEBUG:ATHexapod:Read 100 history items for RemoteEvent(ATHexapod, 0, logMessage)
# Read 100 history items for RemoteEvent(ATHexapod, 0, logMessage)
# DEBUG:ATHexapod:Read 100 history items for RemoteEvent(ATHexapod, 0, positionUpdate)
# Read 100 history items for RemoteEvent(ATHexapod, 0, positionUpdate)
# DEBUG:ATHexapod:Read 1 history items for RemoteEvent(ATHexapod, 0, readyForCommand)
# Read 1 history items for RemoteEvent(ATHexapod, 0, readyForCommand)
# DEBUG:ATHexapod:Read 1 history items for RemoteEvent(ATHexapod, 0, settingVersions)
# Read 1 history items for RemoteEvent(ATHexapod, 0, settingVersions)
# DEBUG:ATHexapod:Read 1 history items for RemoteEvent(ATHexapod, 0, settingsApplied)
# Read 1 history items for RemoteEvent(ATHexapod, 0, settingsApplied)
# DEBUG:ATHexapod:Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedPivot)
# Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedPivot)
# DEBUG:ATHexapod:Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedPositionLimits)
# Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedPositionLimits)
# DEBUG:ATHexapod:Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedTcp)
# Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedTcp)
# DEBUG:ATHexapod:Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedVelocities)
# Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedVelocities)
# DEBUG:ATHexapod:Read 1 history items for RemoteEvent(ATHexapod, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATHexapod, 0, simulationMode)
# DEBUG:ATHexapod:Read 1 history items for RemoteEvent(ATHexapod, 0, softwareVersions)
# Read 1 history items for RemoteEvent(ATHexapod, 0, softwareVersions)
# DEBUG:ATHexapod:Read 19 history items for RemoteEvent(ATHexapod, 0, summaryState)
# Read 19 history items for RemoteEvent(ATHexapod, 0, summaryState)
# INFO:ATArchiver:Read historical data in 0.12 sec
# Read historical data in 0.12 sec
# WARNING:ATHexapod.positionStatus:positionStatus DDS read queue is filling: 19 of 100 elements
# positionStatus DDS read queue is filling: 19 of 100 elements
# DEBUG:ATArchiver:Read 1 history items for RemoteEvent(ATArchiver, 0, authList)
# Read 1 history items for RemoteEvent(ATArchiver, 0, authList)
# DEBUG:ATArchiver:Read 100 history items for RemoteEvent(ATArchiver, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATArchiver, 0, heartbeat)
# DEBUG:ATArchiver:Read 100 history items for RemoteEvent(ATArchiver, 0, imageInOODS)
# Read 100 history items for RemoteEvent(ATArchiver, 0, imageInOODS)
# DEBUG:ATArchiver:Read 100 history items for RemoteEvent(ATArchiver, 0, imageRetrievalForArchiving)
# Read 100 history items for RemoteEvent(ATArchiver, 0, imageRetrievalForArchiving)
# DEBUG:ATArchiver:Read 1 history items for RemoteEvent(ATArchiver, 0, logLevel)
# Read 1 history items for RemoteEvent(ATArchiver, 0, logLevel)
# DEBUG:ATArchiver:Read 1 history items for RemoteEvent(ATArchiver, 0, logMessage)
# Read 1 history items for RemoteEvent(ATArchiver, 0, logMessage)
# DEBUG:ATArchiver:Read 1 history items for RemoteEvent(ATArchiver, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATArchiver, 0, simulationMode)
# DEBUG:ATArchiver:Read 1 history items for RemoteEvent(ATArchiver, 0, softwareVersions)
# Read 1 history items for RemoteEvent(ATArchiver, 0, softwareVersions)
# DEBUG:ATArchiver:Read 19 history items for RemoteEvent(ATArchiver, 0, summaryState)
# Read 19 history items for RemoteEvent(ATArchiver, 0, summaryState)
# INFO:ATAOS:Read historical data in 0.16 sec
# Read historical data in 0.16 sec
# DEBUG:ATAOS:Read 5 history items for RemoteEvent(ATAOS, 0, appliedSettingsMatchStart)
# Read 5 history items for RemoteEvent(ATAOS, 0, appliedSettingsMatchStart)
# DEBUG:ATAOS:Read 100 history items for RemoteEvent(ATAOS, 0, atspectrographCorrectionCompleted)
# Read 100 history items for RemoteEvent(ATAOS, 0, atspectrographCorrectionCompleted)
# DEBUG:ATAOS:Read 100 history items for RemoteEvent(ATAOS, 0, atspectrographCorrectionStarted)
# Read 100 history items for RemoteEvent(ATAOS, 0, atspectrographCorrectionStarted)
# DEBUG:ATAOS:Read 1 history items for RemoteEvent(ATAOS, 0, authList)
# Read 1 history items for RemoteEvent(ATAOS, 0, authList)
# DEBUG:ATAOS:Read 3 history items for RemoteEvent(ATAOS, 0, correctionEnabled)
# Read 3 history items for RemoteEvent(ATAOS, 0, correctionEnabled)
# DEBUG:ATAOS:Read 100 history items for RemoteEvent(ATAOS, 0, correctionOffsets)
# Read 100 history items for RemoteEvent(ATAOS, 0, correctionOffsets)
# DEBUG:ATAOS:Read 100 history items for RemoteEvent(ATAOS, 0, detailedState)
# Read 100 history items for RemoteEvent(ATAOS, 0, detailedState)
# DEBUG:ATAOS:Read 100 history items for RemoteEvent(ATAOS, 0, focusOffsetSummary)
# Read 100 history items for RemoteEvent(ATAOS, 0, focusOffsetSummary)
# DEBUG:ATAOS:Read 100 history items for RemoteEvent(ATAOS, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATAOS, 0, heartbeat)
# DEBUG:ATAOS:Read 100 history items for RemoteEvent(ATAOS, 0, hexapodCorrectionCompleted)
# Read 100 history items for RemoteEvent(ATAOS, 0, hexapodCorrectionCompleted)
# DEBUG:ATAOS:Read 100 history items for RemoteEvent(ATAOS, 0, hexapodCorrectionStarted)
# Read 100 history items for RemoteEvent(ATAOS, 0, hexapodCorrectionStarted)
# DEBUG:ATAOS:Read 1 history items for RemoteEvent(ATAOS, 0, logLevel)
# Read 1 history items for RemoteEvent(ATAOS, 0, logLevel)
# DEBUG:ATAOS:Read 100 history items for RemoteEvent(ATAOS, 0, logMessage)
# Read 100 history items for RemoteEvent(ATAOS, 0, logMessage)
# DEBUG:ATAOS:Read 100 history items for RemoteEvent(ATAOS, 0, m1CorrectionCompleted)
# Read 100 history items for RemoteEvent(ATAOS, 0, m1CorrectionCompleted)
# DEBUG:ATAOS:Read 100 history items for RemoteEvent(ATAOS, 0, m1CorrectionStarted)
# Read 100 history items for RemoteEvent(ATAOS, 0, m1CorrectionStarted)
# DEBUG:ATAOS:Read 100 history items for RemoteEvent(ATAOS, 0, pointingOffsetSummary)
# Read 100 history items for RemoteEvent(ATAOS, 0, pointingOffsetSummary)
# DEBUG:ATAOS:Read 1 history items for RemoteEvent(ATAOS, 0, settingVersions)
# Read 1 history items for RemoteEvent(ATAOS, 0, settingVersions)
# DEBUG:ATAOS:Read 1 history items for RemoteEvent(ATAOS, 0, settingsApplied)
# Read 1 history items for RemoteEvent(ATAOS, 0, settingsApplied)
# DEBUG:ATAOS:Read 1 history items for RemoteEvent(ATAOS, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATAOS, 0, simulationMode)
# DEBUG:ATAOS:Read 1 history items for RemoteEvent(ATAOS, 0, softwareVersions)
# Read 1 history items for RemoteEvent(ATAOS, 0, softwareVersions)
# DEBUG:ATAOS:Read 19 history items for RemoteEvent(ATAOS, 0, summaryState)
# Read 19 history items for RemoteEvent(ATAOS, 0, summaryState)
# INFO:ATHeaderService:Read historical data in 0.23 sec
# Read historical data in 0.23 sec
# DEBUG:ATHeaderService:Read 1 history items for RemoteEvent(ATHeaderService, 0, authList)
# Read 1 history items for RemoteEvent(ATHeaderService, 0, authList)
# DEBUG:ATHeaderService:Read 100 history items for RemoteEvent(ATHeaderService, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATHeaderService, 0, heartbeat)
# DEBUG:ATHeaderService:Read 100 history items for RemoteEvent(ATHeaderService, 0, largeFileObjectAvailable)
# Read 100 history items for RemoteEvent(ATHeaderService, 0, largeFileObjectAvailable)
# DEBUG:ATHeaderService:Read 1 history items for RemoteEvent(ATHeaderService, 0, logLevel)
# Read 1 history items for RemoteEvent(ATHeaderService, 0, logLevel)
# DEBUG:ATHeaderService:Read 100 history items for RemoteEvent(ATHeaderService, 0, logMessage)
# Read 100 history items for RemoteEvent(ATHeaderService, 0, logMessage)
# DEBUG:ATHeaderService:Read 1 history items for RemoteEvent(ATHeaderService, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATHeaderService, 0, simulationMode)
# DEBUG:ATHeaderService:Read 1 history items for RemoteEvent(ATHeaderService, 0, softwareVersions)
# Read 1 history items for RemoteEvent(ATHeaderService, 0, softwareVersions)
# DEBUG:ATHeaderService:Read 19 history items for RemoteEvent(ATHeaderService, 0, summaryState)
# Read 19 history items for RemoteEvent(ATHeaderService, 0, summaryState)
# INFO:ATDome:Read historical data in 0.26 sec
# Read historical data in 0.26 sec
# DEBUG:ATDome:Read 15 history items for RemoteEvent(ATDome, 0, allAxesInPosition)
# Read 15 history items for RemoteEvent(ATDome, 0, allAxesInPosition)
# DEBUG:ATDome:Read 5 history items for RemoteEvent(ATDome, 0, appliedSettingsMatchStart)
# Read 5 history items for RemoteEvent(ATDome, 0, appliedSettingsMatchStart)
# DEBUG:ATDome:Read 1 history items for RemoteEvent(ATDome, 0, authList)
# Read 1 history items for RemoteEvent(ATDome, 0, authList)
# DEBUG:ATDome:Read 45 history items for RemoteEvent(ATDome, 0, azimuthCommandedState)
# Read 45 history items for RemoteEvent(ATDome, 0, azimuthCommandedState)
# DEBUG:ATDome:Read 69 history items for RemoteEvent(ATDome, 0, azimuthInPosition)
# Read 69 history items for RemoteEvent(ATDome, 0, azimuthInPosition)
# DEBUG:ATDome:Read 100 history items for RemoteEvent(ATDome, 0, azimuthState)
# Read 100 history items for RemoteEvent(ATDome, 0, azimuthState)
# DEBUG:ATDome:Read 100 history items for RemoteEvent(ATDome, 0, doorEncoderExtremes)
# Read 100 history items for RemoteEvent(ATDome, 0, doorEncoderExtremes)
# DEBUG:ATDome:Read 6 history items for RemoteEvent(ATDome, 0, dropoutDoorCommandedState)
# Read 6 history items for RemoteEvent(ATDome, 0, dropoutDoorCommandedState)
# DEBUG:ATDome:Read 100 history items for RemoteEvent(ATDome, 0, dropoutDoorState)
# Read 100 history items for RemoteEvent(ATDome, 0, dropoutDoorState)
# DEBUG:ATDome:Read 1 history items for RemoteEvent(ATDome, 0, emergencyStop)
# Read 1 history items for RemoteEvent(ATDome, 0, emergencyStop)
# DEBUG:ATDome:Read 100 history items for RemoteEvent(ATDome, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATDome, 0, heartbeat)
# DEBUG:ATDome:Read 36 history items for RemoteEvent(ATDome, 0, lastAzimuthGoTo)
# Read 36 history items for RemoteEvent(ATDome, 0, lastAzimuthGoTo)
# DEBUG:ATDome:Read 1 history items for RemoteEvent(ATDome, 0, logLevel)
# Read 1 history items for RemoteEvent(ATDome, 0, logLevel)
# DEBUG:ATDome:Read 10 history items for RemoteEvent(ATDome, 0, logMessage)
# Read 10 history items for RemoteEvent(ATDome, 0, logMessage)
# DEBUG:ATDome:Read 8 history items for RemoteEvent(ATDome, 0, mainDoorCommandedState)
# Read 8 history items for RemoteEvent(ATDome, 0, mainDoorCommandedState)
# DEBUG:ATDome:Read 13 history items for RemoteEvent(ATDome, 0, mainDoorState)
# Read 13 history items for RemoteEvent(ATDome, 0, mainDoorState)
# DEBUG:ATDome:Read 92 history items for RemoteEvent(ATDome, 0, moveCode)
# Read 92 history items for RemoteEvent(ATDome, 0, moveCode)
# DEBUG:ATDome:Read 16 history items for RemoteEvent(ATDome, 0, scbLink)
# Read 16 history items for RemoteEvent(ATDome, 0, scbLink)
# DEBUG:ATDome:Read 1 history items for RemoteEvent(ATDome, 0, settingVersions)
# Read 1 history items for RemoteEvent(ATDome, 0, settingVersions)
# DEBUG:ATDome:Read 1 history items for RemoteEvent(ATDome, 0, settingsApplied)
# Read 1 history items for RemoteEvent(ATDome, 0, settingsApplied)
# DEBUG:ATDome:Read 16 history items for RemoteEvent(ATDome, 0, settingsAppliedDomeController)
# Read 16 history items for RemoteEvent(ATDome, 0, settingsAppliedDomeController)
# DEBUG:ATDome:Read 5 history items for RemoteEvent(ATDome, 0, settingsAppliedDomeTcp)
# Read 5 history items for RemoteEvent(ATDome, 0, settingsAppliedDomeTcp)
# DEBUG:ATDome:Read 6 history items for RemoteEvent(ATDome, 0, shutterInPosition)
# Read 6 history items for RemoteEvent(ATDome, 0, shutterInPosition)
# DEBUG:ATDome:Read 1 history items for RemoteEvent(ATDome, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATDome, 0, simulationMode)
# DEBUG:ATDome:Read 1 history items for RemoteEvent(ATDome, 0, softwareVersions)
# Read 1 history items for RemoteEvent(ATDome, 0, softwareVersions)
# DEBUG:ATDome:Read 19 history items for RemoteEvent(ATDome, 0, summaryState)
# Read 19 history items for RemoteEvent(ATDome, 0, summaryState)
# INFO:ATPneumatics:Read historical data in 0.33 sec
# Read historical data in 0.33 sec
# DEBUG:ATPneumatics:Read 7 history items for RemoteEvent(ATPneumatics, 0, appliedSettingsMatchStart)
# Read 7 history items for RemoteEvent(ATPneumatics, 0, appliedSettingsMatchStart)
# DEBUG:ATPneumatics:Read 17 history items for RemoteEvent(ATPneumatics, 0, cellVentsState)
# Read 17 history items for RemoteEvent(ATPneumatics, 0, cellVentsState)
# DEBUG:ATPneumatics:Read 1 history items for RemoteEvent(ATPneumatics, 0, eStop)
# Read 1 history items for RemoteEvent(ATPneumatics, 0, eStop)
# DEBUG:ATPneumatics:Read 1 history items for RemoteEvent(ATPneumatics, 0, errorCode)
# Read 1 history items for RemoteEvent(ATPneumatics, 0, errorCode)
# DEBUG:ATPneumatics:Read 100 history items for RemoteEvent(ATPneumatics, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATPneumatics, 0, heartbeat)
# DEBUG:ATPneumatics:Read 10 history items for RemoteEvent(ATPneumatics, 0, instrumentState)
# Read 10 history items for RemoteEvent(ATPneumatics, 0, instrumentState)
# DEBUG:ATPneumatics:Read 65 history items for RemoteEvent(ATPneumatics, 0, m1CoverLimitSwitches)
# Read 65 history items for RemoteEvent(ATPneumatics, 0, m1CoverLimitSwitches)
# DEBUG:ATPneumatics:Read 30 history items for RemoteEvent(ATPneumatics, 0, m1CoverState)
# Read 30 history items for RemoteEvent(ATPneumatics, 0, m1CoverState)
# DEBUG:ATPneumatics:Read 100 history items for RemoteEvent(ATPneumatics, 0, m1SetPressure)
# Read 100 history items for RemoteEvent(ATPneumatics, 0, m1SetPressure)
# DEBUG:ATPneumatics:Read 11 history items for RemoteEvent(ATPneumatics, 0, m1State)
# Read 11 history items for RemoteEvent(ATPneumatics, 0, m1State)
# DEBUG:ATPneumatics:Read 6 history items for RemoteEvent(ATPneumatics, 0, m1VentsLimitSwitches)
# Read 6 history items for RemoteEvent(ATPneumatics, 0, m1VentsLimitSwitches)
# DEBUG:ATPneumatics:Read 12 history items for RemoteEvent(ATPneumatics, 0, m1VentsPosition)
# Read 12 history items for RemoteEvent(ATPneumatics, 0, m1VentsPosition)
# DEBUG:ATPneumatics:Read 13 history items for RemoteEvent(ATPneumatics, 0, m2State)
# Read 13 history items for RemoteEvent(ATPneumatics, 0, m2State)
# DEBUG:ATPneumatics:Read 12 history items for RemoteEvent(ATPneumatics, 0, mainValveState)
# Read 12 history items for RemoteEvent(ATPneumatics, 0, mainValveState)
# DEBUG:ATPneumatics:Read 1 history items for RemoteEvent(ATPneumatics, 0, powerStatus)
# Read 1 history items for RemoteEvent(ATPneumatics, 0, powerStatus)
# DEBUG:ATPneumatics:Read 7 history items for RemoteEvent(ATPneumatics, 0, settingVersions)
# Read 7 history items for RemoteEvent(ATPneumatics, 0, settingVersions)
# DEBUG:ATPneumatics:Read 1 history items for RemoteEvent(ATPneumatics, 0, softwareVersions)
# Read 1 history items for RemoteEvent(ATPneumatics, 0, softwareVersions)
# DEBUG:ATPneumatics:Read 27 history items for RemoteEvent(ATPneumatics, 0, summaryState)
# Read 27 history items for RemoteEvent(ATPneumatics, 0, summaryState)
# INFO:ATSpectrograph:Read historical data in 0.37 sec
# Read historical data in 0.37 sec
# DEBUG:ATSpectrograph:Read 5 history items for RemoteEvent(ATSpectrograph, 0, appliedSettingsMatchStart)
# Read 5 history items for RemoteEvent(ATSpectrograph, 0, appliedSettingsMatchStart)
# DEBUG:ATSpectrograph:Read 1 history items for RemoteEvent(ATSpectrograph, 0, authList)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, authList)
# DEBUG:ATSpectrograph:Read 100 history items for RemoteEvent(ATSpectrograph, 0, disperserInPosition)
# Read 100 history items for RemoteEvent(ATSpectrograph, 0, disperserInPosition)
# DEBUG:ATSpectrograph:Read 100 history items for RemoteEvent(ATSpectrograph, 0, filterInPosition)
# Read 100 history items for RemoteEvent(ATSpectrograph, 0, filterInPosition)
# DEBUG:ATSpectrograph:Read 1 history items for RemoteEvent(ATSpectrograph, 0, fwState)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, fwState)
# DEBUG:ATSpectrograph:Read 7 history items for RemoteEvent(ATSpectrograph, 0, gwState)
# Read 7 history items for RemoteEvent(ATSpectrograph, 0, gwState)
# DEBUG:ATSpectrograph:Read 100 history items for RemoteEvent(ATSpectrograph, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATSpectrograph, 0, heartbeat)
# DEBUG:ATSpectrograph:Read 1 history items for RemoteEvent(ATSpectrograph, 0, logLevel)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, logLevel)
# DEBUG:ATSpectrograph:Read 1 history items for RemoteEvent(ATSpectrograph, 0, logMessage)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, logMessage)
# DEBUG:ATSpectrograph:Read 100 history items for RemoteEvent(ATSpectrograph, 0, reportedDisperserPosition)
# Read 100 history items for RemoteEvent(ATSpectrograph, 0, reportedDisperserPosition)
# DEBUG:ATSpectrograph:Read 100 history items for RemoteEvent(ATSpectrograph, 0, reportedFilterPosition)
# Read 100 history items for RemoteEvent(ATSpectrograph, 0, reportedFilterPosition)
# DEBUG:ATSpectrograph:Read 1 history items for RemoteEvent(ATSpectrograph, 0, reportedLinearStagePosition)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, reportedLinearStagePosition)
# DEBUG:ATSpectrograph:Read 1 history items for RemoteEvent(ATSpectrograph, 0, settingVersions)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, settingVersions)
# DEBUG:ATSpectrograph:Read 1 history items for RemoteEvent(ATSpectrograph, 0, settingsApplied)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, settingsApplied)
# DEBUG:ATSpectrograph:Read 1 history items for RemoteEvent(ATSpectrograph, 0, settingsAppliedValues)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, settingsAppliedValues)
# DEBUG:ATSpectrograph:Read 1 history items for RemoteEvent(ATSpectrograph, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, simulationMode)
# DEBUG:ATSpectrograph:Read 1 history items for RemoteEvent(ATSpectrograph, 0, softwareVersions)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, softwareVersions)
# DEBUG:ATSpectrograph:Read 19 history items for RemoteEvent(ATSpectrograph, 0, summaryState)
# Read 19 history items for RemoteEvent(ATSpectrograph, 0, summaryState)
# INFO:ATMCS:Read historical data in 0.41 sec
# Read historical data in 0.41 sec
# DEBUG:ATMCS:Read 100 history items for RemoteEvent(ATMCS, 0, allAxesInPosition)
# Read 100 history items for RemoteEvent(ATMCS, 0, allAxesInPosition)
# DEBUG:ATMCS:Read 12 history items for RemoteEvent(ATMCS, 0, appliedSettingsMatchStart)
# Read 12 history items for RemoteEvent(ATMCS, 0, appliedSettingsMatchStart)
# DEBUG:ATMCS:Read 100 history items for RemoteEvent(ATMCS, 0, atMountState)
# Read 100 history items for RemoteEvent(ATMCS, 0, atMountState)
# DEBUG:ATMCS:Read 24 history items for RemoteEvent(ATMCS, 0, azimuthBrake1)
# Read 24 history items for RemoteEvent(ATMCS, 0, azimuthBrake1)
# DEBUG:ATMCS:Read 24 history items for RemoteEvent(ATMCS, 0, azimuthBrake2)
# Read 24 history items for RemoteEvent(ATMCS, 0, azimuthBrake2)
# DEBUG:ATMCS:Read 24 history items for RemoteEvent(ATMCS, 0, azimuthDrive1Status)
# Read 24 history items for RemoteEvent(ATMCS, 0, azimuthDrive1Status)
# DEBUG:ATMCS:Read 24 history items for RemoteEvent(ATMCS, 0, azimuthDrive2Status)
# Read 24 history items for RemoteEvent(ATMCS, 0, azimuthDrive2Status)
# DEBUG:ATMCS:Read 100 history items for RemoteEvent(ATMCS, 0, azimuthInPosition)
# Read 100 history items for RemoteEvent(ATMCS, 0, azimuthInPosition)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, azimuthLimitSwitchCCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, azimuthLimitSwitchCCW)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, azimuthLimitSwitchCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, azimuthLimitSwitchCW)
# DEBUG:ATMCS:Read 3 history items for RemoteEvent(ATMCS, 0, azimuthToppleBlockCCW)
# Read 3 history items for RemoteEvent(ATMCS, 0, azimuthToppleBlockCCW)
# DEBUG:ATMCS:Read 3 history items for RemoteEvent(ATMCS, 0, azimuthToppleBlockCW)
# Read 3 history items for RemoteEvent(ATMCS, 0, azimuthToppleBlockCW)
# DEBUG:ATMCS:Read 24 history items for RemoteEvent(ATMCS, 0, elevationBrake)
# Read 24 history items for RemoteEvent(ATMCS, 0, elevationBrake)
# DEBUG:ATMCS:Read 24 history items for RemoteEvent(ATMCS, 0, elevationDriveStatus)
# Read 24 history items for RemoteEvent(ATMCS, 0, elevationDriveStatus)
# DEBUG:ATMCS:Read 100 history items for RemoteEvent(ATMCS, 0, elevationInPosition)
# Read 100 history items for RemoteEvent(ATMCS, 0, elevationInPosition)
# DEBUG:ATMCS:Read 3 history items for RemoteEvent(ATMCS, 0, elevationLimitSwitchLower)
# Read 3 history items for RemoteEvent(ATMCS, 0, elevationLimitSwitchLower)
# DEBUG:ATMCS:Read 3 history items for RemoteEvent(ATMCS, 0, elevationLimitSwitchUpper)
# Read 3 history items for RemoteEvent(ATMCS, 0, elevationLimitSwitchUpper)
# DEBUG:ATMCS:Read 4 history items for RemoteEvent(ATMCS, 0, errorCode)
# Read 4 history items for RemoteEvent(ATMCS, 0, errorCode)
# DEBUG:ATMCS:Read 100 history items for RemoteEvent(ATMCS, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATMCS, 0, heartbeat)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, m3DriveStatus)
# Read 1 history items for RemoteEvent(ATMCS, 0, m3DriveStatus)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, m3InPosition)
# Read 1 history items for RemoteEvent(ATMCS, 0, m3InPosition)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, m3RotatorDetentSwitches)
# Read 1 history items for RemoteEvent(ATMCS, 0, m3RotatorDetentSwitches)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, m3RotatorLimitSwitchCCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, m3RotatorLimitSwitchCCW)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, m3RotatorLimitSwitchCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, m3RotatorLimitSwitchCW)
# DEBUG:ATMCS:Read 23 history items for RemoteEvent(ATMCS, 0, m3State)
# Read 23 history items for RemoteEvent(ATMCS, 0, m3State)
# DEBUG:ATMCS:Read 24 history items for RemoteEvent(ATMCS, 0, nasmyth1Brake)
# Read 24 history items for RemoteEvent(ATMCS, 0, nasmyth1Brake)
# DEBUG:ATMCS:Read 24 history items for RemoteEvent(ATMCS, 0, nasmyth1DriveStatus)
# Read 24 history items for RemoteEvent(ATMCS, 0, nasmyth1DriveStatus)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth1LimitSwitchCCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth1LimitSwitchCCW)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth1LimitSwitchCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth1LimitSwitchCW)
# DEBUG:ATMCS:Read 100 history items for RemoteEvent(ATMCS, 0, nasmyth1RotatorInPosition)
# Read 100 history items for RemoteEvent(ATMCS, 0, nasmyth1RotatorInPosition)
# DEBUG:ATMCS:Read 24 history items for RemoteEvent(ATMCS, 0, nasmyth2Brake)
# Read 24 history items for RemoteEvent(ATMCS, 0, nasmyth2Brake)
# DEBUG:ATMCS:Read 24 history items for RemoteEvent(ATMCS, 0, nasmyth2DriveStatus)
# Read 24 history items for RemoteEvent(ATMCS, 0, nasmyth2DriveStatus)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth2LimitSwitchCCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth2LimitSwitchCCW)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth2LimitSwitchCW)
# Read 1 history items for RemoteEvent(ATMCS, 0, nasmyth2LimitSwitchCW)
# DEBUG:ATMCS:Read 100 history items for RemoteEvent(ATMCS, 0, nasmyth2RotatorInPosition)
# Read 100 history items for RemoteEvent(ATMCS, 0, nasmyth2RotatorInPosition)
# DEBUG:ATMCS:Read 12 history items for RemoteEvent(ATMCS, 0, positionLimits)
# Read 12 history items for RemoteEvent(ATMCS, 0, positionLimits)
# DEBUG:ATMCS:Read 12 history items for RemoteEvent(ATMCS, 0, settingVersions)
# Read 12 history items for RemoteEvent(ATMCS, 0, settingVersions)
# DEBUG:ATMCS:Read 1 history items for RemoteEvent(ATMCS, 0, softwareVersions)
# Read 1 history items for RemoteEvent(ATMCS, 0, softwareVersions)
# DEBUG:ATMCS:Read 45 history items for RemoteEvent(ATMCS, 0, summaryState)
# Read 45 history items for RemoteEvent(ATMCS, 0, summaryState)
# DEBUG:ATMCS:Read 100 history items for RemoteEvent(ATMCS, 0, target)
# Read 100 history items for RemoteEvent(ATMCS, 0, target)
# INFO:ATPtg:Read historical data in 0.50 sec
# Read historical data in 0.50 sec
# DEBUG:ATPtg:Read 16 history items for RemoteEvent(ATPtg, 0, airmassWarning)
# Read 16 history items for RemoteEvent(ATPtg, 0, airmassWarning)
# DEBUG:ATPtg:Read 1 history items for RemoteEvent(ATPtg, 0, azWrapWarning)
# Read 1 history items for RemoteEvent(ATPtg, 0, azWrapWarning)
# DEBUG:ATPtg:Read 9 history items for RemoteEvent(ATPtg, 0, currentDebugLevel)
# Read 9 history items for RemoteEvent(ATPtg, 0, currentDebugLevel)
# DEBUG:ATPtg:Read 83 history items for RemoteEvent(ATPtg, 0, currentTarget)
# Read 83 history items for RemoteEvent(ATPtg, 0, currentTarget)
# DEBUG:ATPtg:Read 100 history items for RemoteEvent(ATPtg, 0, detailedState)
# Read 100 history items for RemoteEvent(ATPtg, 0, detailedState)
# DEBUG:ATPtg:Read 1 history items for RemoteEvent(ATPtg, 0, elLimitWarning)
# Read 1 history items for RemoteEvent(ATPtg, 0, elLimitWarning)
# DEBUG:ATPtg:Read 12 history items for RemoteEvent(ATPtg, 0, errorCode)
# Read 12 history items for RemoteEvent(ATPtg, 0, errorCode)
# DEBUG:ATPtg:Read 1 history items for RemoteEvent(ATPtg, 0, focusNameInconsistentWarning)
# Read 1 history items for RemoteEvent(ATPtg, 0, focusNameInconsistentWarning)
# DEBUG:ATPtg:Read 8 history items for RemoteEvent(ATPtg, 0, focusNameSelected)
# Read 8 history items for RemoteEvent(ATPtg, 0, focusNameSelected)
# DEBUG:ATPtg:Read 100 history items for RemoteEvent(ATPtg, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATPtg, 0, heartbeat)
# DEBUG:ATPtg:Read 16 history items for RemoteEvent(ATPtg, 0, iers)
# Read 16 history items for RemoteEvent(ATPtg, 0, iers)
# DEBUG:ATPtg:Read 3 history items for RemoteEvent(ATPtg, 0, iersOutOfDate)
# Read 3 history items for RemoteEvent(ATPtg, 0, iersOutOfDate)
# DEBUG:ATPtg:Read 1 history items for RemoteEvent(ATPtg, 0, moonProximityWarning)
# Read 1 history items for RemoteEvent(ATPtg, 0, moonProximityWarning)
# DEBUG:ATPtg:Read 19 history items for RemoteEvent(ATPtg, 0, mountDataWarning)
# Read 19 history items for RemoteEvent(ATPtg, 0, mountDataWarning)
# DEBUG:ATPtg:Read 1 history items for RemoteEvent(ATPtg, 0, objectSetWarning)
# Read 1 history items for RemoteEvent(ATPtg, 0, objectSetWarning)
# DEBUG:ATPtg:Read 74 history items for RemoteEvent(ATPtg, 0, offsetSummary)
# Read 74 history items for RemoteEvent(ATPtg, 0, offsetSummary)
# DEBUG:ATPtg:Read 33 history items for RemoteEvent(ATPtg, 0, pointData)
# Read 33 history items for RemoteEvent(ATPtg, 0, pointData)
# DEBUG:ATPtg:Read 4 history items for RemoteEvent(ATPtg, 0, pointingFile)
# Read 4 history items for RemoteEvent(ATPtg, 0, pointingFile)
# DEBUG:ATPtg:Read 10 history items for RemoteEvent(ATPtg, 0, pointingModel)
# Read 10 history items for RemoteEvent(ATPtg, 0, pointingModel)
# DEBUG:ATPtg:Read 4 history items for RemoteEvent(ATPtg, 0, ptgAzCurrentWrap)
# Read 4 history items for RemoteEvent(ATPtg, 0, ptgAzCurrentWrap)
# DEBUG:ATPtg:Read 1 history items for RemoteEvent(ATPtg, 0, ptgRotCurrentWrap)
# Read 1 history items for RemoteEvent(ATPtg, 0, ptgRotCurrentWrap)
# DEBUG:ATPtg:Read 4 history items for RemoteEvent(ATPtg, 0, rotWrapWarning)
# Read 4 history items for RemoteEvent(ATPtg, 0, rotWrapWarning)
# DEBUG:ATPtg:Read 31 history items for RemoteEvent(ATPtg, 0, summaryState)
# Read 31 history items for RemoteEvent(ATPtg, 0, summaryState)
# DEBUG:ATPtg:Read 1 history items for RemoteEvent(ATPtg, 0, sunProximityWarning)
# Read 1 history items for RemoteEvent(ATPtg, 0, sunProximityWarning)
# DEBUG:ATPtg:Read 91 history items for RemoteEvent(ATPtg, 0, timesOfLimits)
# Read 91 history items for RemoteEvent(ATPtg, 0, timesOfLimits)
# DEBUG:ATPtg:Read 100 history items for RemoteEvent(ATPtg, 0, trackPosting)
# Read 100 history items for RemoteEvent(ATPtg, 0, trackPosting)
# DEBUG:ATPtg:Read 8 history items for RemoteEvent(ATPtg, 0, wavelength)
# Read 8 history items for RemoteEvent(ATPtg, 0, wavelength)
# DEBUG:ATPtg:Read 100 history items for RemoteEvent(ATPtg, 0, weatherDataApplied)
# Read 100 history items for RemoteEvent(ATPtg, 0, weatherDataApplied)
# DEBUG:ATPtg:Read 100 history items for RemoteEvent(ATPtg, 0, weatherDataInvalid)
# Read 100 history items for RemoteEvent(ATPtg, 0, weatherDataInvalid)
# INFO:ATCamera:Read historical data in 0.56 sec
# Read historical data in 0.56 sec
# DEBUG:ATCamera:Read 5 history items for RemoteEvent(ATCamera, 0, appliedSettingsMatchStart)
# Read 5 history items for RemoteEvent(ATCamera, 0, appliedSettingsMatchStart)
# DEBUG:ATCamera:Read 12 history items for RemoteEvent(ATCamera, 0, calibrationDetailedState)
# Read 12 history items for RemoteEvent(ATCamera, 0, calibrationDetailedState)
# DEBUG:ATCamera:Read 100 history items for RemoteEvent(ATCamera, 0, ccsCommandState)
# Read 100 history items for RemoteEvent(ATCamera, 0, ccsCommandState)
# DEBUG:ATCamera:Read 100 history items for RemoteEvent(ATCamera, 0, endOfImageTelemetry)
# Read 100 history items for RemoteEvent(ATCamera, 0, endOfImageTelemetry)
# DEBUG:ATCamera:Read 100 history items for RemoteEvent(ATCamera, 0, endReadout)
# Read 100 history items for RemoteEvent(ATCamera, 0, endReadout)
# DEBUG:ATCamera:Read 100 history items for RemoteEvent(ATCamera, 0, endShutterClose)
# Read 100 history items for RemoteEvent(ATCamera, 0, endShutterClose)
# DEBUG:ATCamera:Read 100 history items for RemoteEvent(ATCamera, 0, endShutterOpen)
# Read 100 history items for RemoteEvent(ATCamera, 0, endShutterOpen)
# DEBUG:ATCamera:Read 8 history items for RemoteEvent(ATCamera, 0, focalPlaneHardwareIdSettingsApplied)
# Read 8 history items for RemoteEvent(ATCamera, 0, focalPlaneHardwareIdSettingsApplied)
# DEBUG:ATCamera:Read 8 history items for RemoteEvent(ATCamera, 0, focalPlaneSummaryInfo)
# Read 8 history items for RemoteEvent(ATCamera, 0, focalPlaneSummaryInfo)
# DEBUG:ATCamera:Read 100 history items for RemoteEvent(ATCamera, 0, heartbeat)
# Read 100 history items for RemoteEvent(ATCamera, 0, heartbeat)
# DEBUG:ATCamera:Read 100 history items for RemoteEvent(ATCamera, 0, imageReadinessDetailedState)
# Read 100 history items for RemoteEvent(ATCamera, 0, imageReadinessDetailedState)
# DEBUG:ATCamera:Read 100 history items for RemoteEvent(ATCamera, 0, imageReadoutParameters)
# Read 100 history items for RemoteEvent(ATCamera, 0, imageReadoutParameters)
# DEBUG:ATCamera:Read 2 history items for RemoteEvent(ATCamera, 0, offlineDetailedState)
# Read 2 history items for RemoteEvent(ATCamera, 0, offlineDetailedState)
# DEBUG:ATCamera:Read 100 history items for RemoteEvent(ATCamera, 0, raftsDetailedState)
# Read 100 history items for RemoteEvent(ATCamera, 0, raftsDetailedState)
# DEBUG:ATCamera:Read 5 history items for RemoteEvent(ATCamera, 0, settingVersions)
# Read 5 history items for RemoteEvent(ATCamera, 0, settingVersions)
# DEBUG:ATCamera:Read 100 history items for RemoteEvent(ATCamera, 0, shutterDetailedState)
# Read 100 history items for RemoteEvent(ATCamera, 0, shutterDetailedState)
# DEBUG:ATCamera:Read 100 history items for RemoteEvent(ATCamera, 0, shutterMotionProfile)
# Read 100 history items for RemoteEvent(ATCamera, 0, shutterMotionProfile)
# DEBUG:ATCamera:Read 5 history items for RemoteEvent(ATCamera, 0, softwareVersions)
# Read 5 history items for RemoteEvent(ATCamera, 0, softwareVersions)
# DEBUG:ATCamera:Read 100 history items for RemoteEvent(ATCamera, 0, startIntegration)
# Read 100 history items for RemoteEvent(ATCamera, 0, startIntegration)
# DEBUG:ATCamera:Read 100 history items for RemoteEvent(ATCamera, 0, startReadout)
# Read 100 history items for RemoteEvent(ATCamera, 0, startReadout)
# DEBUG:ATCamera:Read 20 history items for RemoteEvent(ATCamera, 0, summaryState)
# Read 20 history items for RemoteEvent(ATCamera, 0, summaryState)
# WARNING:ATDome.position:position DDS read queue is filling: 79 of 100 elements
# position DDS read queue is filling: 79 of 100 elements
# WARNING:ATPneumatics.mainAirSourcePressure:mainAirSourcePressure DDS read queue is filling: 21 of 100 elements
# ERROR:ATPtg.timeAndDate:timeAndDate DDS read queue is full (100 elements); data may be lost
# mainAirSourcePressure DDS read queue is filling: 21 of 100 elements
# INFO:Script:Read historical data in 0.04 sec
# WARNING:ATMCS.trajectory:trajectory DDS read queue is filling: 38 of 100 elements
# timeAndDate DDS read queue is full (100 elements); data may be lost
# WARNING:ATPneumatics.m2AirPressure:m2AirPressure DDS read queue is filling: 22 of 100 elements
# Read historical data in 0.04 sec
# trajectory DDS read queue is filling: 38 of 100 elements
# m2AirPressure DDS read queue is filling: 22 of 100 elements
# ERROR:ATPtg.mountStatus:mountStatus DDS read queue is full (100 elements); data may be lost
# mountStatus DDS read queue is full (100 elements); data may be lost
# WARNING:ATPneumatics.m1AirPressure:m1AirPressure DDS read queue is filling: 22 of 100 elements
# m1AirPressure DDS read queue is filling: 22 of 100 elements
# WARNING:ATMCS.torqueDemand:torqueDemand DDS read queue is filling: 38 of 100 elements
# torqueDemand DDS read queue is filling: 38 of 100 elements
# WARNING:ATPtg.mountPositions:mountPositions DDS read queue is filling: 29 of 100 elements
# WARNING:ATPneumatics.loadCell:loadCell DDS read queue is filling: 22 of 100 elements
# mountPositions DDS read queue is filling: 29 of 100 elements
# loadCell DDS read queue is filling: 22 of 100 elements
# WARNING:ATMCS.nasymth_m3_mountMotorEncoders:nasymth_m3_mountMotorEncoders DDS read queue is filling: 38 of 100 elements
# nasymth_m3_mountMotorEncoders DDS read queue is filling: 38 of 100 elements
# ERROR:ATPtg.currentTargetStatus:currentTargetStatus DDS read queue is full (100 elements); data may be lost

# %%
location = EarthLocation.from_geodetic(lon=-70.747698*u.deg,
                                                    lat=-30.244728*u.deg,
                                                    height=2663.0*u.m)
# Out:
# currentTargetStatus DDS read queue is full (100 elements); data may be lost
# WARNING:ATMCS.mount_Nasmyth_Encoders:mount_Nasmyth_Encoders DDS read queue is filling: 38 of 100 elements
# mount_Nasmyth_Encoders DDS read queue is filling: 38 of 100 elements
# WARNING:ATMCS.mount_AzEl_Encoders:mount_AzEl_Encoders DDS read queue is filling: 38 of 100 elements
# mount_AzEl_Encoders DDS read queue is filling: 38 of 100 elements

# %%
customSimbad = Simbad()
customSimbad.add_votable_fields('distance_result', "fluxdata(V)")
customSimbad.TIMEOUT = 30
# Out:
# WARNING:ATMCS.measuredTorque:measuredTorque DDS read queue is filling: 38 of 100 elements
# measuredTorque DDS read queue is filling: 38 of 100 elements
# WARNING:ATMCS.measuredMotorVelocity:measuredMotorVelocity DDS read queue is filling: 38 of 100 elements
# measuredMotorVelocity DDS read queue is filling: 38 of 100 elements
# WARNING:ATMCS.mount_AzEl_Encoders:mount_AzEl_Encoders python read queue is filling: 37 of 100 elements
# mount_AzEl_Encoders python read queue is filling: 37 of 100 elements
# WARNING:ATMCS.azEl_mountMotorEncoders:azEl_mountMotorEncoders DDS read queue is filling: 38 of 100 elements
# azEl_mountMotorEncoders DDS read queue is filling: 38 of 100 elements
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 13 of 100 elements
# target DDS read queue is filling: 13 of 100 elements
# WARNING:ATMCS.logevent_target:target python read queue is filling: 12 of 100 elements
# target python read queue is filling: 12 of 100 elements

# %%
def find_target(az, el, mag_limit):
    current_time = Time.now()

    elaz = AltAz(alt=el*u.deg, az=az*u.deg, 
                 obstime=current_time.tai, 
                 location=location)

    radec = elaz.transform_to(ICRS)

    _ra = radec.ra.to_string(u.deg, decimal=True)
    _dec = radec.dec.to_string(u.deg, decimal=True, alwayssign=True)
    r = Angle(2.*u.deg).to_string(u.deg, decimal=True)

    criteria = f"region(circle,ICRS,{_ra} {_dec},{r}d) & Vmag > {mag_limit} & Vmag < {mag_limit+2} & cat = HD"

    try:
        result_table = customSimbad.query_criteria(criteria)
        if result_table is None:
            raise RuntimeError("No result from query.")
    except Exception as e:
        print(f"Error getting target from Simbad. Skipping target {elaz!r}.")
        print(criteria)
        return -1

    result_table.sort('FLUX_V')

    target_radec = SkyCoord(Angle(result_table['RA'][0], unit=u.hour), 
                    Angle(result_table['DEC'][0], unit=u.deg), frame=ICRS)

    t_id = str(result_table['MAIN_ID'][0])
    t_ra = result_table['RA'][0]
    t_dec = result_table['DEC'][0]
    t_mag = result_table['FLUX_V'][0]
    print(f">>>> Point to {t_id:15}: {t_ra} {t_dec} (VMag:{t_mag:5.2f})")

    return 0

# %%
find_target(180, 30, 8.0)
# Out:
# DEBUG:urllib3.connectionpool:Resetting dropped connection: simbad.u-strasbg.fr
# Resetting dropped connection: simbad.u-strasbg.fr
# DEBUG:urllib3.connectionpool:http://simbad.u-strasbg.fr:80 "POST /simbad/sim-script HTTP/1.1" 200 None
# http://simbad.u-strasbg.fr:80 "POST /simbad/sim-script HTTP/1.1" 200 None
# >>>> Point to HD  83745      : 08 57 15.9859 -88 16 14.390 (VMag: 8.01)
# 0
# WARNING:ATMCS.logevent_target:target python read queue is filling: 48 of 100 elements
# target python read queue is filling: 48 of 100 elements

# %%
# Slew to an object if not already there.
await script.atcs.slew_object('HD  83745 ', rot_type=RotType.PhysicalSky)
# Out:
# DEBUG:urllib3.connectionpool:Resetting dropped connection: simbad.u-strasbg.fr
# Resetting dropped connection: simbad.u-strasbg.fr
# DEBUG:urllib3.connectionpool:http://simbad.u-strasbg.fr:80 "POST /simbad/sim-script HTTP/1.1" 200 None
# http://simbad.u-strasbg.fr:80 "POST /simbad/sim-script HTTP/1.1" 200 None
# INFO:Script.ATCS:Slewing to HD  83745 : 08 57 15.9859 -88 16 14.390
# Slewing to HD  83745 : 08 57 15.9859 -88 16 14.390
# DEBUG:Script.ATCS:Setting rotator physical position to 0.0 deg. Rotator will track sky.
# Setting rotator physical position to 0.0 deg. Rotator will track sky.
# DEBUG:Script.ATCS:Sending command
# Sending command
# DEBUG:Script.ATCS:Stop tracking.
# Stop tracking.
# WARNING:ATMCS.logevent_target:target python read queue is filling: 22 of 100 elements
# target python read queue is filling: 22 of 100 elements
# DEBUG:Script.ATCS:Tracking state: <AtMountState.TRACKINGENABLED: 9>
# Tracking state: <AtMountState.TRACKINGENABLED: 9>
# DEBUG:Script.ATCS:Tracking state: <AtMountState.STOPPING: 10>
# Tracking state: <AtMountState.STOPPING: 10>
# DEBUG:Script.ATCS:In Position: True.
# In Position: True.
# DEBUG:Script.ATCS:Scheduling check coroutines
# Scheduling check coroutines
# DEBUG:Script.ATCS:process as completed...
# process as completed...
# DEBUG:Script.ATCS:atmcs: <State.ENABLED: 2>
# atmcs: <State.ENABLED: 2>
# DEBUG:Script.ATCS:atptg: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# DEBUG:Script.ATCS:ataos: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# DEBUG:Script.ATCS:atpneumatics: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# DEBUG:Script.ATCS:athexapod: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# DEBUG:Script.ATCS:atdome: <State.ENABLED: 2>
# atdome: <State.ENABLED: 2>
# DEBUG:Script.ATCS:atdometrajectory: <State.ENABLED: 2>
# atdometrajectory: <State.ENABLED: 2>
# INFO:Script.ATCS:[Telescope] delta Alt = -051.600 deg; delta Az = -046.586 deg; delta N1 = -000.000 deg; delta N2 = +012.904 deg [Dome] delta Az = -039.691 deg
# [Telescope] delta Alt = -051.600 deg; delta Az = -046.586 deg; delta N1 = -000.000 deg; delta N2 = +012.904 deg [Dome] delta Az = -039.691 deg
# INFO:Script.ATCS:[Telescope] delta Alt = -049.547 deg; delta Az = -044.729 deg; delta N1 = +000.000 deg; delta N2 = +011.514 deg [Dome] delta Az = -037.581 deg
# [Telescope] delta Alt = -049.547 deg; delta Az = -044.729 deg; delta N1 = +000.000 deg; delta N2 = +011.514 deg [Dome] delta Az = -037.581 deg
# INFO:Script.ATCS:[Telescope] delta Alt = -043.552 deg; delta Az = -038.741 deg; delta N1 = +000.000 deg; delta N2 = +006.407 deg [Dome] delta Az = -033.311 deg
# [Telescope] delta Alt = -043.552 deg; delta Az = -038.741 deg; delta N1 = +000.000 deg; delta N2 = +006.407 deg [Dome] delta Az = -033.311 deg
# INFO:Script.ATCS:[Telescope] delta Alt = -037.552 deg; delta Az = -032.744 deg; delta N1 = -000.000 deg; delta N2 = +001.340 deg [Dome] delta Az = -027.421 deg
# [Telescope] delta Alt = -037.552 deg; delta Az = -032.744 deg; delta N1 = -000.000 deg; delta N2 = +001.340 deg [Dome] delta Az = -027.421 deg
# INFO:Script.ATCS:[Telescope] delta Alt = -031.551 deg; delta Az = -026.739 deg; delta N1 = -000.000 deg; delta N2 = +000.068 deg [Dome] delta Az = -021.531 deg
# [Telescope] delta Alt = -031.551 deg; delta Az = -026.739 deg; delta N1 = -000.000 deg; delta N2 = +000.068 deg [Dome] delta Az = -021.531 deg
# INFO:Script.ATCS:[Telescope] delta Alt = -027.548 deg; delta Az = -022.762 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg [Dome] delta Az = -012.461 deg
# [Telescope] delta Alt = -027.548 deg; delta Az = -022.762 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg [Dome] delta Az = -012.461 deg
# INFO:Script.ATCS:[Telescope] delta Alt = -021.591 deg; delta Az = -016.978 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -002.791 deg
# [Telescope] delta Alt = -021.591 deg; delta Az = -016.978 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = -002.791 deg
# INFO:Script.ATCS:ATDome in position.
# ATDome in position.
# INFO:Script.ATCS:[Telescope] delta Alt = -015.871 deg; delta Az = -011.663 deg; delta N1 = -000.000 deg; delta N2 = -000.002 deg [Dome] delta Az = +001.689 deg
# [Telescope] delta Alt = -015.871 deg; delta Az = -011.663 deg; delta N1 = -000.000 deg; delta N2 = -000.002 deg [Dome] delta Az = +001.689 deg
# INFO:Script.ATCS:[Telescope] delta Alt = -012.336 deg; delta Az = -008.536 deg; delta N1 = +000.000 deg; delta N2 = +000.002 deg [Dome] delta Az = +002.959 deg
# [Telescope] delta Alt = -012.336 deg; delta Az = -008.536 deg; delta N1 = +000.000 deg; delta N2 = +000.002 deg [Dome] delta Az = +002.959 deg
# INFO:Script.ATCS:[Telescope] delta Alt = -007.680 deg; delta Az = -004.680 deg; delta N1 = -000.000 deg; delta N2 = -000.003 deg [Dome] delta Az = +002.959 deg
# [Telescope] delta Alt = -007.680 deg; delta Az = -004.680 deg; delta N1 = -000.000 deg; delta N2 = -000.003 deg [Dome] delta Az = +002.959 deg
# INFO:Script.ATCS:[Telescope] delta Alt = -005.129 deg; delta Az = -002.756 deg; delta N1 = -000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = +002.959 deg
# [Telescope] delta Alt = -005.129 deg; delta Az = -002.756 deg; delta N1 = -000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = +002.959 deg
# INFO:Script.ATCS:[Telescope] delta Alt = -002.284 deg; delta Az = -000.887 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = +002.959 deg
# [Telescope] delta Alt = -002.284 deg; delta Az = -000.887 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = +002.959 deg
# INFO:Script.ATCS:[Telescope] delta Alt = -000.648 deg; delta Az = -000.109 deg; delta N1 = -000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = +002.959 deg
# [Telescope] delta Alt = -000.648 deg; delta Az = -000.109 deg; delta N1 = -000.000 deg; delta N2 = +000.001 deg [Dome] delta Az = +002.959 deg
# INFO:Script.ATCS:[Telescope] delta Alt = -000.053 deg; delta Az = -000.000 deg; delta N1 = +000.000 deg; delta N2 = -000.003 deg [Dome] delta Az = +002.959 deg
# [Telescope] delta Alt = -000.053 deg; delta Az = -000.000 deg; delta N1 = +000.000 deg; delta N2 = -000.003 deg [Dome] delta Az = +002.959 deg
# INFO:Script.ATCS:Got True
# Got True
# INFO:Script.ATCS:Waiting for telescope to settle.
# Waiting for telescope to settle.
# INFO:Script.ATCS:[Telescope] delta Alt = +000.000 deg; delta Az = -000.000 deg; delta N1 = +000.000 deg; delta N2 = +000.002 deg [Dome] delta Az = +002.959 deg
# [Telescope] delta Alt = +000.000 deg; delta Az = -000.000 deg; delta N1 = +000.000 deg; delta N2 = +000.002 deg [Dome] delta Az = +002.959 deg
# DEBUG:Script.ATCS:Axes in position.
# Axes in position.

# %%
await script.latiss.take_object(5.0, 1)
# Out:
# DEBUG:Script.LATISS:Generating group_id
# Generating group_id
# DEBUG:Script.LATISS:imagetype: OBJECT, wait for TCS to be ready.
# imagetype: OBJECT, wait for TCS to be ready.
# DEBUG:Script.ATCS:atspectrograph correction running. Trying to determine state of the corrections.
# atspectrograph correction running. Trying to determine state of the corrections.
# DEBUG:Script.ATCS:No correction seen in the last 5.0 seconds. Determining order of last corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# DEBUG:Script.ATCS:Last correction completed.
# Last correction completed.
# DEBUG:Script.ATCS:Ready to take data:: atmcs=True, ataos=True, atdome=True.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# DEBUG:Script.LATISS:OBJECT 0001 - 0001
# OBJECT 0001 - 0001
# array([2021070700462])

# %% [markdown]
# ## Emulate how the scriptQueue launches scripts
# ##### Start here if re-running the script after a correction

# %%
configuration = yaml.safe_dump({"filter": 'RG610', 
                                "grating": 'empty_1',
                                "exposure_time": 20,
                                "dataPath": '/project/shared/auxTel/rerun/quickLook'})
print(configuration)
# Out:
# dataPath: /project/shared/auxTel/rerun/quickLook
# exposure_time: 20
# filter: RG610
# grating: empty_1

# %%
# Set script state to UNCONFIGURED
# this is required to run the script a 2nd time but otherwise is a no-op
script.set_state(ScriptState.UNCONFIGURED)
# Configure the script, which puts the ScriptState to CONFIGURED
config_data = script.cmd_configure.DataType()
config_data.config = configuration
await script.do_configure(config_data)
# Out:
# INFO:Script:Using binning factor of 1
# Using binning factor of 1

# %%
# This will run the cwfs multiple times until it converges,
# then apply the calculated offsets
script.intra_visit_id = None
script.extra_visit_id = None
script.short_timeout = 10
results = await script.arun()
# Out:
# DEBUG:Script:CWFS iteration 1 starting...
# CWFS iteration 1 starting...
# WARNING:Script:Intra/Extra images not taken. Running take image sequence.
# Intra/Extra images not taken. Running take image sequence.
# DEBUG:Script:Moving to intra-focal position
# Moving to intra-focal position
# DEBUG:Script.LATISS:imagetype: ENGTEST, skip TCS synchronization.
# imagetype: ENGTEST, skip TCS synchronization.
# DEBUG:Script.LATISS:ENGTEST 0001 - 0001
# ENGTEST 0001 - 0001
# DEBUG:Script:Moving to extra-focal position
# Moving to extra-focal position
# DEBUG:Script:Taking extra-focal image
# Taking extra-focal image
# DEBUG:Script.LATISS:imagetype: ENGTEST, skip TCS synchronization.
# imagetype: ENGTEST, skip TCS synchronization.
# DEBUG:Script.LATISS:ENGTEST 0001 - 0001
# ENGTEST 0001 - 0001
# INFO:Script:intraImage expId for target: 2021070700502
# intraImage expId for target: 2021070700502
# INFO:Script:extraImage expId for target: 2021070700503
# extraImage expId for target: 2021070700503
# INFO:Script:angle used in cwfs algorithm is -38.70
# angle used in cwfs algorithm is -38.70
# DEBUG:Script:Moving hexapod back to zero offset (in-focus) position
# Moving hexapod back to zero offset (in-focus) position
# LsstCamMapper WARN: Unable to find valid calib root directory
# CameraMapper INFO: Loading exposure registry from /readonly/lsstdata/auxtel/base/auxtel/oods/butler/repo/registry.sqlite3
# CameraMapper INFO: Loading calib registry from /project/shared/auxTel/CALIB/calibRegistry.sqlite3
# DEBUG:lsst.ts.observing.utilities.auxtel.latiss.getters:Pulling data with dataset = quickLookExp and dataId = {'dayObs': '2021-07-07', 'seqNum': 502}
# Pulling data with dataset = quickLookExp and dataId = {'dayObs': '2021-07-07', 'seqNum': 502}
# DEBUG:lsst.ts.observing.utilities.auxtel.latiss.getters:Running bestEffort ISR on {'dayObs': '2021-07-07', 'seqNum': 502} and returning exposure
# Running bestEffort ISR on {'dayObs': '2021-07-07', 'seqNum': 502} and returning exposure
# LsstCamMapper WARN: Unable to find valid calib root directory
# CameraMapper INFO: Loading exposure registry from /readonly/lsstdata/auxtel/base/auxtel/oods/butler/repo/registry.sqlite3
# CameraMapper INFO: Loading calib registry from /project/shared/auxTel/CALIB/calibRegistry.sqlite3
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing SHUTTIME header to be None
# AT_O_20210707_000502: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing SHUTTIME header to be None
# AT_O_20210707_000502: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing SHUTTIME header to be None
# AT_O_20210707_000502: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing SHUTTIME header to be None
# AT_O_20210707_000502: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing SHUTTIME header to be None
# AT_O_20210707_000502: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing SHUTTIME header to be None
# AT_O_20210707_000502: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing SHUTTIME header to be None
# AT_O_20210707_000502: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing SHUTTIME header to be None
# AT_O_20210707_000502: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing SHUTTIME header to be None
# AT_O_20210707_000502: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing SHUTTIME header to be None
# AT_O_20210707_000502: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing SHUTTIME header to be None
# AT_O_20210707_000502: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing SHUTTIME header to be None
# AT_O_20210707_000502: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing SHUTTIME header to be None
# AT_O_20210707_000502: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing SHUTTIME header to be None
# AT_O_20210707_000502: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing SHUTTIME header to be None
# AT_O_20210707_000502: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing SHUTTIME header to be None
# AT_O_20210707_000502: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Received 2 headers for merging
# Received 2 headers for merging
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000502.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000502: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000502: Forcing SHUTTIME header to be None
# AT_O_20210707_000502: Forcing SHUTTIME header to be None
# obs.lsst.assembly WARN: DataId(initialdata={'dayObs': '2021-07-07', 'seqNum': 502}, tag=set()): outAmp.getRawBBox() != data.getBBox(); patching. ((minimum=(0, 0), maximum=(543, 2047)) v. (minimum=(0, 0), maximum=(575, 2047)))
# DEBUG:astro_metadata_translator.translator:Using translation class LSST_LATISS
# Using translation class LSST_LATISS
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-None.yaml
# Checking for header correction file named LATISS-None.yaml
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 29 of 100 elements
# target DDS read queue is filling: 29 of 100 elements
# DEBUG:lsst.obs.lsst.translators.latiss:Assigning OBSID to a value of 'None'
# Assigning OBSID to a value of 'None'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-None.yaml
# Checking for header correction file named LATISS-None.yaml
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 27 of 100 elements
# target DDS read queue is filling: 27 of 100 elements
# DEBUG:lsst.obs.lsst.translators.latiss:Assigning OBSID to a value of 'None'
# Assigning OBSID to a value of 'None'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# CameraMapper WARN: Cannot create SkyWcs using VisitInfo and Detector, using metadata-based SkyWcs: Cannot create SkyWcs from camera geometry: rotator angle defined using RotType=RotType.UNKNOWN instead of SKY.
# Running best effort isr...
# Running with bias subtraction
# Running with dark correction subtraction
# Running with defect correction
# isr INFO: Converting exposure to floating point values.
# isr INFO: Assembling CCD from amplifiers.
# isr INFO: Applying bias correction.
# isr INFO: Masking defects.
# isr INFO: Masking non-finite (NAN, inf) value pixels.
# isr INFO: Widening saturation trails.
# isr INFO: Applying dark correction.
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 14 of 100 elements
# target DDS read queue is filling: 14 of 100 elements
# isr INFO: Set 90783 BAD pixels to 84.955017.
# isr INFO: Interpolating masked pixels.
# Running cosmic ray repairisr WARN: No rough magnitude zero point defined for filter RG610~empty.
#
# isr INFO: Setting rough magnitude zero point for filter RG610~empty: 31.252574989159957
# characterizeImage.repair INFO: Identified 101 cosmic rays.
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 36 of 100 elements
# target DDS read queue is filling: 36 of 100 elements
# LsstCamMapper WARN: Unable to find valid calib root directory
# CameraMapper INFO: Loading exposure registry from /readonly/lsstdata/auxtel/base/auxtel/oods/butler/repo/registry.sqlite3
# CameraMapper INFO: Loading calib registry from /project/shared/auxTel/CALIB/calibRegistry.sqlite3
# DEBUG:lsst.ts.observing.utilities.auxtel.latiss.getters:Pulling data with dataset = quickLookExp and dataId = {'dayObs': '2021-07-07', 'seqNum': 503}
# Pulling data with dataset = quickLookExp and dataId = {'dayObs': '2021-07-07', 'seqNum': 503}
# DEBUG:lsst.ts.observing.utilities.auxtel.latiss.getters:Running bestEffort ISR on {'dayObs': '2021-07-07', 'seqNum': 503} and returning exposure
# Running bestEffort ISR on {'dayObs': '2021-07-07', 'seqNum': 503} and returning exposure
# LsstCamMapper WARN: Unable to find valid calib root directory
# CameraMapper INFO: Loading exposure registry from /readonly/lsstdata/auxtel/base/auxtel/oods/butler/repo/registry.sqlite3
# CameraMapper INFO: Loading calib registry from /project/shared/auxTel/CALIB/calibRegistry.sqlite3
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing SHUTTIME header to be None
# AT_O_20210707_000503: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing SHUTTIME header to be None
# AT_O_20210707_000503: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing SHUTTIME header to be None
# AT_O_20210707_000503: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing SHUTTIME header to be None
# AT_O_20210707_000503: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing SHUTTIME header to be None
# AT_O_20210707_000503: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing SHUTTIME header to be None
# AT_O_20210707_000503: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing SHUTTIME header to be None
# AT_O_20210707_000503: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing SHUTTIME header to be None
# AT_O_20210707_000503: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing SHUTTIME header to be None
# AT_O_20210707_000503: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing SHUTTIME header to be None
# AT_O_20210707_000503: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing SHUTTIME header to be None
# AT_O_20210707_000503: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing SHUTTIME header to be None
# AT_O_20210707_000503: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing SHUTTIME header to be None
# AT_O_20210707_000503: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing SHUTTIME header to be None
# AT_O_20210707_000503: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing SHUTTIME header to be None
# AT_O_20210707_000503: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing SHUTTIME header to be None
# AT_O_20210707_000503: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Received 2 headers for merging
# Received 2 headers for merging
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000503.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000503: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000503: Forcing SHUTTIME header to be None
# AT_O_20210707_000503: Forcing SHUTTIME header to be None
# obs.lsst.assembly WARN: DataId(initialdata={'dayObs': '2021-07-07', 'seqNum': 503}, tag=set()): outAmp.getRawBBox() != data.getBBox(); patching. ((minimum=(0, 0), maximum=(543, 2047)) v. (minimum=(0, 0), maximum=(575, 2047)))
# DEBUG:astro_metadata_translator.translator:Using translation class LSST_LATISS
# Using translation class LSST_LATISS
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-None.yaml
# Checking for header correction file named LATISS-None.yaml
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 29 of 100 elements
# target DDS read queue is filling: 29 of 100 elements
# DEBUG:lsst.obs.lsst.translators.latiss:Assigning OBSID to a value of 'None'
# Assigning OBSID to a value of 'None'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 27 of 100 elements
# target DDS read queue is filling: 27 of 100 elements
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-None.yaml
# Checking for header correction file named LATISS-None.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:Assigning OBSID to a value of 'None'
# Assigning OBSID to a value of 'None'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# CameraMapper WARN: Cannot create SkyWcs using VisitInfo and Detector, using metadata-based SkyWcs: Cannot create SkyWcs from camera geometry: rotator angle defined using RotType=RotType.UNKNOWN instead of SKY.
# Running best effort isr...
# Running with bias subtraction
# Running with dark correction subtraction
# Running with defect correction
# isr INFO: Converting exposure to floating point values.
# isr INFO: Assembling CCD from amplifiers.
# isr INFO: Applying bias correction.
# isr INFO: Masking defects.
# isr INFO: Masking non-finite (NAN, inf) value pixels.
# isr INFO: Widening saturation trails.
# isr INFO: Applying dark correction.
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 24 of 100 elements
# target DDS read queue is filling: 24 of 100 elements
# isr INFO: Set 90783 BAD pixels to 83.681396.
# isr INFO: Interpolating masked pixels.
# Running cosmic ray repairisr WARN: No rough magnitude zero point defined for filter RG610~empty.
#
# isr INFO: Setting rough magnitude zero point for filter RG610~empty: 31.252574989159957
# characterizeImage.repair INFO: Identified 105 cosmic rays.
# WARNING:ATMCS.logevent_target:target python read queue is filling: 99 of 100 elements
# target python read queue is filling: 99 of 100 elements
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 33 of 100 elements
# WARNING:ATMCS.mount_AzEl_Encoders:mount_AzEl_Encoders python read queue is filling: 25 of 100 elements
# target DDS read queue is filling: 33 of 100 elements
# mount_AzEl_Encoders python read queue is filling: 25 of 100 elements
# DEBUG:Script:Running source detection
# Running source detection
# WARNING:ATMCS.logevent_target:target python read queue is filling: 34 of 100 elements
# target python read queue is filling: 34 of 100 elements
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 17 of 100 elements
# quickFrameMeasurementTask INFO: Found 3 sources in exposure
# target DDS read queue is filling: 17 of 100 elements
# quickFrameMeasurementTask INFO: Measured 3 of 3 sources in exposure
# WARNING:ATMCS.logevent_target:target python read queue is filling: 16 of 100 elements
# target python read queue is filling: 16 of 100 elements
# quickFrameMeasurementTask INFO: Found 22 sources in exposure
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 16 of 100 elements
# target DDS read queue is filling: 16 of 100 elements
# quickFrameMeasurementTask INFO: Measured 22 of 22 sources in exposure
# WARNING:ATMCS.logevent_target:target python read queue is filling: 15 of 100 elements
# target python read queue is filling: 15 of 100 elements
# DEBUG:Script:Source detection completed
# Source detection completed
# DEBUG:Script:Creating stamp for intra_image donut on centroid [y,x] = [2549,1417] with a side length of 228 pixels
# Creating stamp for intra_image donut on centroid [y,x] = [2549,1417] with a side length of 228 pixels
# DEBUG:Script:Creating stamp for intra_image donut on centroid [y,x] = [2549,1417] with a side length of 228 pixels
# Creating stamp for intra_image donut on centroid [y,x] = [2549,1417] with a side length of 228 pixels
# DEBUG:Script:create_donut_stamps_for_cwfs completed
# create_donut_stamps_for_cwfs completed
# INFO:Script:Starting CWFS algorithm calculation.
# Starting CWFS algorithm calculation.
# INFO:Script:==============================
# Measured [coma-X, coma-Y, focus] zernike coefficients [nm]: [-18.9, 10.6, 127.0, ]
# De-rotated [coma-X, coma-Y, focus]  zernike coefficients [nm]: [-21.3, -3.5, 127.0, ]
# Hexapod [x, y, z] offsets [mm] : -0.1, 0.0, -0.0,
# Telescope offsets [arcsec]: -5.4, 0.9, 0.0,
# ==============================
#
# ==============================
# Measured [coma-X, coma-Y, focus] zernike coefficients [nm]: [-18.9, 10.6, 127.0, ]
# De-rotated [coma-X, coma-Y, focus]  zernike coefficients [nm]: [-21.3, -3.5, 127.0, ]
# Hexapod [x, y, z] offsets [mm] : -0.1, 0.0, -0.0,
# Telescope offsets [arcsec]: -5.4, 0.9, 0.0,
# ==============================
#
# INFO:Script:Applying offset: x=-0.1036403483194663, y=0.01718833416386675, z=-0.030689036560359838.
# Applying offset: x=-0.1036403483194663, y=0.01718833416386675, z=-0.030689036560359838.
# INFO:Script:Applying telescope offset az/el: -0.8674608485820272/-5.436869032490883.
# Applying telescope offset az/el: -0.8674608485820272/-5.436869032490883.
# DEBUG:Script.ATCS:Calculating Az/El offset: -0.8674608485820272/-5.436869032490883
# Calculating Az/El offset: -0.8674608485820272/-5.436869032490883
# DEBUG:Script.ATCS:Persistent x/y offset: -4.093215495057571/-3.6820673691964956
# Persistent x/y offset: -4.093215495057571/-3.6820673691964956
# DEBUG:Script.ATCS:Telescope not in position.
# Telescope not in position.
# DEBUG:Script.ATCS:All axes in position.
# All axes in position.
# DEBUG:Script.ATCS:Waiting for telescope to settle.
# Waiting for telescope to settle.
# DEBUG:Script.ATCS:Done
# Done
# DEBUG:Script:CWFS iteration 2 starting...
# CWFS iteration 2 starting...
# WARNING:Script:Intra/Extra images not taken. Running take image sequence.
# Intra/Extra images not taken. Running take image sequence.
# DEBUG:Script:Moving to intra-focal position
# Moving to intra-focal position
# DEBUG:Script.LATISS:imagetype: ENGTEST, skip TCS synchronization.
# imagetype: ENGTEST, skip TCS synchronization.
# DEBUG:Script.LATISS:ENGTEST 0001 - 0001
# ENGTEST 0001 - 0001
# DEBUG:Script:Moving to extra-focal position
# Moving to extra-focal position
# DEBUG:Script:Taking extra-focal image
# Taking extra-focal image
# DEBUG:Script.LATISS:imagetype: ENGTEST, skip TCS synchronization.
# imagetype: ENGTEST, skip TCS synchronization.
# DEBUG:Script.LATISS:ENGTEST 0001 - 0001
# ENGTEST 0001 - 0001
# INFO:Script:intraImage expId for target: 2021070700504
# intraImage expId for target: 2021070700504
# INFO:Script:extraImage expId for target: 2021070700505
# extraImage expId for target: 2021070700505
# INFO:Script:angle used in cwfs algorithm is -39.21
# angle used in cwfs algorithm is -39.21
# DEBUG:Script:Moving hexapod back to zero offset (in-focus) position
# Moving hexapod back to zero offset (in-focus) position
# LsstCamMapper WARN: Unable to find valid calib root directory
# CameraMapper INFO: Loading exposure registry from /readonly/lsstdata/auxtel/base/auxtel/oods/butler/repo/registry.sqlite3
# CameraMapper INFO: Loading calib registry from /project/shared/auxTel/CALIB/calibRegistry.sqlite3
# DEBUG:lsst.ts.observing.utilities.auxtel.latiss.getters:Pulling data with dataset = quickLookExp and dataId = {'dayObs': '2021-07-07', 'seqNum': 504}
# Pulling data with dataset = quickLookExp and dataId = {'dayObs': '2021-07-07', 'seqNum': 504}
# DEBUG:lsst.ts.observing.utilities.auxtel.latiss.getters:Running bestEffort ISR on {'dayObs': '2021-07-07', 'seqNum': 504} and returning exposure
# Running bestEffort ISR on {'dayObs': '2021-07-07', 'seqNum': 504} and returning exposure
# LsstCamMapper WARN: Unable to find valid calib root directory
# CameraMapper INFO: Loading exposure registry from /readonly/lsstdata/auxtel/base/auxtel/oods/butler/repo/registry.sqlite3
# CameraMapper INFO: Loading calib registry from /project/shared/auxTel/CALIB/calibRegistry.sqlite3
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing SHUTTIME header to be None
# AT_O_20210707_000504: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing SHUTTIME header to be None
# AT_O_20210707_000504: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing SHUTTIME header to be None
# AT_O_20210707_000504: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing SHUTTIME header to be None
# AT_O_20210707_000504: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing SHUTTIME header to be None
# AT_O_20210707_000504: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing SHUTTIME header to be None
# AT_O_20210707_000504: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing SHUTTIME header to be None
# AT_O_20210707_000504: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing SHUTTIME header to be None
# AT_O_20210707_000504: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing SHUTTIME header to be None
# AT_O_20210707_000504: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing SHUTTIME header to be None
# AT_O_20210707_000504: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing SHUTTIME header to be None
# AT_O_20210707_000504: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing SHUTTIME header to be None
# AT_O_20210707_000504: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing SHUTTIME header to be None
# AT_O_20210707_000504: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing SHUTTIME header to be None
# AT_O_20210707_000504: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing SHUTTIME header to be None
# AT_O_20210707_000504: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing SHUTTIME header to be None
# AT_O_20210707_000504: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Received 2 headers for merging
# Received 2 headers for merging
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000504.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000504: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000504: Forcing SHUTTIME header to be None
# AT_O_20210707_000504: Forcing SHUTTIME header to be None
# obs.lsst.assembly WARN: DataId(initialdata={'dayObs': '2021-07-07', 'seqNum': 504}, tag=set()): outAmp.getRawBBox() != data.getBBox(); patching. ((minimum=(0, 0), maximum=(543, 2047)) v. (minimum=(0, 0), maximum=(575, 2047)))
# DEBUG:astro_metadata_translator.translator:Using translation class LSST_LATISS
# Using translation class LSST_LATISS
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-None.yaml
# Checking for header correction file named LATISS-None.yaml
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 28 of 100 elements
# target DDS read queue is filling: 28 of 100 elements
# DEBUG:lsst.obs.lsst.translators.latiss:Assigning OBSID to a value of 'None'
# Assigning OBSID to a value of 'None'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 28 of 100 elements
# target DDS read queue is filling: 28 of 100 elements
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-None.yaml
# Checking for header correction file named LATISS-None.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:Assigning OBSID to a value of 'None'
# Assigning OBSID to a value of 'None'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# CameraMapper WARN: Cannot create SkyWcs using VisitInfo and Detector, using metadata-based SkyWcs: Cannot create SkyWcs from camera geometry: rotator angle defined using RotType=RotType.UNKNOWN instead of SKY.
# Running best effort isr...
# Running with bias subtraction
# Running with dark correction subtraction
# Running with defect correction
# isr INFO: Converting exposure to floating point values.
# isr INFO: Assembling CCD from amplifiers.
# isr INFO: Applying bias correction.
# isr INFO: Masking defects.
# isr INFO: Masking non-finite (NAN, inf) value pixels.
# isr INFO: Widening saturation trails.
# isr INFO: Applying dark correction.
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 10 of 100 elements
# target DDS read queue is filling: 10 of 100 elements
# isr INFO: Set 90783 BAD pixels to 83.628670.
# Running cosmic ray repair
# isr INFO: Interpolating masked pixels.
# isr WARN: No rough magnitude zero point defined for filter RG610~empty.
# isr INFO: Setting rough magnitude zero point for filter RG610~empty: 31.252574989159957
# characterizeImage.repair INFO: Identified 111 cosmic rays.
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 36 of 100 elements
# target DDS read queue is filling: 36 of 100 elements
# LsstCamMapper WARN: Unable to find valid calib root directory
# CameraMapper INFO: Loading exposure registry from /readonly/lsstdata/auxtel/base/auxtel/oods/butler/repo/registry.sqlite3
# CameraMapper INFO: Loading calib registry from /project/shared/auxTel/CALIB/calibRegistry.sqlite3
# DEBUG:lsst.ts.observing.utilities.auxtel.latiss.getters:Pulling data with dataset = quickLookExp and dataId = {'dayObs': '2021-07-07', 'seqNum': 505}
# Pulling data with dataset = quickLookExp and dataId = {'dayObs': '2021-07-07', 'seqNum': 505}
# DEBUG:lsst.ts.observing.utilities.auxtel.latiss.getters:Running bestEffort ISR on {'dayObs': '2021-07-07', 'seqNum': 505} and returning exposure
# Running bestEffort ISR on {'dayObs': '2021-07-07', 'seqNum': 505} and returning exposure
# LsstCamMapper WARN: Unable to find valid calib root directory
# CameraMapper INFO: Loading exposure registry from /readonly/lsstdata/auxtel/base/auxtel/oods/butler/repo/registry.sqlite3
# CameraMapper INFO: Loading calib registry from /project/shared/auxTel/CALIB/calibRegistry.sqlite3
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing SHUTTIME header to be None
# AT_O_20210707_000505: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing SHUTTIME header to be None
# AT_O_20210707_000505: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing SHUTTIME header to be None
# AT_O_20210707_000505: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing SHUTTIME header to be None
# AT_O_20210707_000505: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing SHUTTIME header to be None
# AT_O_20210707_000505: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing SHUTTIME header to be None
# AT_O_20210707_000505: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing SHUTTIME header to be None
# AT_O_20210707_000505: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing SHUTTIME header to be None
# AT_O_20210707_000505: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing SHUTTIME header to be None
# AT_O_20210707_000505: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing SHUTTIME header to be None
# AT_O_20210707_000505: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing SHUTTIME header to be None
# AT_O_20210707_000505: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing SHUTTIME header to be None
# AT_O_20210707_000505: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing SHUTTIME header to be None
# AT_O_20210707_000505: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing SHUTTIME header to be None
# AT_O_20210707_000505: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing SHUTTIME header to be None
# AT_O_20210707_000505: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing SHUTTIME header to be None
# AT_O_20210707_000505: Forcing SHUTTIME header to be None
# DEBUG:astro_metadata_translator.headers:Received 2 headers for merging
# Received 2 headers for merging
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# Checking for header correction file named LATISS-AT_O_20210707_000505.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# AT_O_20210707_000505: Forcing detector serial to ITL-3800C-068
# DEBUG:lsst.obs.lsst.translators.latiss:AT_O_20210707_000505: Forcing SHUTTIME header to be None
# AT_O_20210707_000505: Forcing SHUTTIME header to be None
# obs.lsst.assembly WARN: DataId(initialdata={'dayObs': '2021-07-07', 'seqNum': 505}, tag=set()): outAmp.getRawBBox() != data.getBBox(); patching. ((minimum=(0, 0), maximum=(543, 2047)) v. (minimum=(0, 0), maximum=(575, 2047)))
# DEBUG:astro_metadata_translator.translator:Using translation class LSST_LATISS
# Using translation class LSST_LATISS
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 29 of 100 elements
# target DDS read queue is filling: 29 of 100 elements
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-None.yaml
# Checking for header correction file named LATISS-None.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:Assigning OBSID to a value of 'None'
# Assigning OBSID to a value of 'None'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 28 of 100 elements
# target DDS read queue is filling: 28 of 100 elements
# DEBUG:astro_metadata_translator.headers:Checking for header correction file named LATISS-None.yaml
# Checking for header correction file named LATISS-None.yaml
# DEBUG:lsst.obs.lsst.translators.latiss:Assigning OBSID to a value of 'None'
# Assigning OBSID to a value of 'None'
# CRITICAL:astro_metadata_translator.headers:Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# Ignoring translator header fixup of LATISS None: 'MJD-OBS not found'
# CameraMapper WARN: Cannot create SkyWcs using VisitInfo and Detector, using metadata-based SkyWcs: Cannot create SkyWcs from camera geometry: rotator angle defined using RotType=RotType.UNKNOWN instead of SKY.
# Running best effort isr...
# Running with bias subtraction
# Running with dark correction subtraction
# Running with defect correction
# isr INFO: Converting exposure to floating point values.
# isr INFO: Assembling CCD from amplifiers.
# isr INFO: Applying bias correction.
# isr INFO: Masking defects.
# isr INFO: Masking non-finite (NAN, inf) value pixels.
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 12 of 100 elements
# target DDS read queue is filling: 12 of 100 elements
# isr INFO: Widening saturation trails.
# isr INFO: Applying dark correction.
# isr INFO: Set 90783 BAD pixels to 83.444038.
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 22 of 100 elements
# Running cosmic ray repairisr INFO: Interpolating masked pixels.
# isr WARN: No rough magnitude zero point defined for filter RG610~empty.
# isr INFO: Setting rough magnitude zero point for filter RG610~empty: 31.252574989159957
#
# target DDS read queue is filling: 22 of 100 elements
# characterizeImage.repair INFO: Identified 117 cosmic rays.
# WARNING:ATMCS.logevent_target:target python read queue is filling: 99 of 100 elements
# target python read queue is filling: 99 of 100 elements
# WARNING:ATMCS.mount_AzEl_Encoders:mount_AzEl_Encoders python read queue is filling: 23 of 100 elements
# mount_AzEl_Encoders python read queue is filling: 23 of 100 elements
# DEBUG:Script:Running source detection
# Running source detection
# WARNING:ATMCS.logevent_target:target python read queue is filling: 19 of 100 elements
# target python read queue is filling: 19 of 100 elements
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 19 of 100 elements
# quickFrameMeasurementTask INFO: Found 3 sources in exposure
# quickFrameMeasurementTask INFO: Measured 3 of 3 sources in exposure
# target DDS read queue is filling: 19 of 100 elements
# WARNING:ATMCS.logevent_target:target python read queue is filling: 18 of 100 elements
# target python read queue is filling: 18 of 100 elements
# quickFrameMeasurementTask INFO: Found 6 sources in exposure
# quickFrameMeasurementTask INFO: Measured 6 of 6 sources in exposure
# WARNING:ATMCS.logevent_target:target DDS read queue is filling: 21 of 100 elements
# target DDS read queue is filling: 21 of 100 elements
# WARNING:ATMCS.logevent_target:target python read queue is filling: 20 of 100 elements
# target python read queue is filling: 20 of 100 elements
# DEBUG:Script:Source detection completed
# Source detection completed
# DEBUG:Script:Creating stamp for intra_image donut on centroid [y,x] = [2561,1418] with a side length of 228 pixels
# Creating stamp for intra_image donut on centroid [y,x] = [2561,1418] with a side length of 228 pixels
# DEBUG:Script:Creating stamp for intra_image donut on centroid [y,x] = [2564,1424] with a side length of 228 pixels
# Creating stamp for intra_image donut on centroid [y,x] = [2564,1424] with a side length of 228 pixels
# DEBUG:Script:create_donut_stamps_for_cwfs completed
# create_donut_stamps_for_cwfs completed
# INFO:Script:Starting CWFS algorithm calculation.
# Starting CWFS algorithm calculation.
# INFO:Script:==============================
# Measured [coma-X, coma-Y, focus] zernike coefficients [nm]: [17.5, -5.7, 19.0, ]
# De-rotated [coma-X, coma-Y, focus]  zernike coefficients [nm]: [17.1, 6.7, 19.0, ]
# Hexapod [x, y, z] offsets [mm] : 0.1, -0.0, -0.0,
# Telescope offsets [arcsec]: 4.4, -1.6, 0.0,
# ==============================
#
# ==============================
# Measured [coma-X, coma-Y, focus] zernike coefficients [nm]: [17.5, -5.7, 19.0, ]
# De-rotated [coma-X, coma-Y, focus]  zernike coefficients [nm]: [17.1, 6.7, 19.0, ]
# Hexapod [x, y, z] offsets [mm] : 0.1, -0.0, -0.0,
# Telescope offsets [arcsec]: 4.4, -1.6, 0.0,
# ==============================
#
# INFO:Script:Focus (-0.004) and coma (0.089) offsets inside tolerance level (0.010). Total focus correction: -0.034 mm. Total coma-x correction: -0.104 mm. Total coma-y correction: 0.017 mm.
# Focus (-0.004) and coma (0.089) offsets inside tolerance level (0.010). Total focus correction: -0.034 mm. Total coma-x correction: -0.104 mm. Total coma-y correction: 0.017 mm.
# INFO:Script:Applying telescope offset [az,el]: [1.629, 4.367].
# Applying telescope offset [az,el]: [1.629, 4.367].
# DEBUG:Script.ATCS:Calculating Az/El offset: 1.6291946983223191/4.3673031639341495
# Calculating Az/El offset: 1.6291946983223191/4.3673031639341495
# DEBUG:Script.ATCS:Persistent x/y offset: 4.03392598956455/2.3356055748919693
# Persistent x/y offset: 4.03392598956455/2.3356055748919693
# DEBUG:Script.ATCS:Telescope not in position.
# Telescope not in position.
# DEBUG:Script.ATCS:All axes in position.
# All axes in position.
# DEBUG:Script.ATCS:Waiting for telescope to settle.
# Waiting for telescope to settle.
# DEBUG:Script.ATCS:Done
# Done
# INFO:Script:Hexapod LUT Datapoint - HD  83745  - reported hexapod position is, [-2.53421748855, 2.38634556232, -1.43497604149, 0.349999544205, 0.220000599832, 4.43114440878e-07].
# Hexapod LUT Datapoint - HD  83745  - reported hexapod position is, [-2.53421748855, 2.38634556232, -1.43497604149, 0.349999544205, 0.220000599832, 4.43114440878e-07].
# DEBUG:Script:Taking in focus image after applying final results.
# Taking in focus image after applying final results.
# DEBUG:Script.LATISS:Generating group_id
# Generating group_id
# DEBUG:Script.LATISS:imagetype: OBJECT, wait for TCS to be ready.
# imagetype: OBJECT, wait for TCS to be ready.
# DEBUG:Script.ATCS:atspectrograph correction running. Trying to determine state of the corrections.
# atspectrograph correction running. Trying to determine state of the corrections.
# DEBUG:Script.ATCS:No correction seen in the last 5.0 seconds. Determining order of last corrections.
# No correction seen in the last 5.0 seconds. Determining order of last corrections.
# DEBUG:Script.ATCS:Last correction completed.
# Last correction completed.
# DEBUG:Script.ATCS:Ready to take data:: atmcs=True, ataos=True, atdome=True.
# Ready to take data:: atmcs=True, ataos=True, atdome=True.
# DEBUG:Script.LATISS:OBJECT 0001 - 0001
# OBJECT 0001 - 0001
# WARNING:ATHeaderService.logevent_logMessage:logMessage DDS read queue is filling: 10 of 100 elements
# logMessage DDS read queue is filling: 10 of 100 elements
# WARNING:ATHeaderService.logevent_logMessage:logMessage DDS read queue is filling: 19 of 100 elements
# logMessage DDS read queue is filling: 19 of 100 elements

# %%
focus_offset_summary = await script.atcs.rem.ataos.evt_focusOffsetSummary.aget()

# %%
print(focus_offset_summary)

# %%
# This will just run the CWFS one time
script.intra_visit_id = None
script.extra_visit_id = None
script.short_timeout = 10
results = await script.run_cwfs()

# %%
# show donuts and centroids
fig1 = plt.figure(1, figsize=(12,8))
ax11 = fig1.add_subplot(121)
ax11.set_title(f"intra visitID - {script.intra_visit_id}")
ax11.imshow(script.I1[0].image0)
ax11.contour(script.algo.pMask) 
ax12 = fig1.add_subplot(122)
ax12.set_title(f"extra visitID - {script.extra_visit_id}")
ax12.imshow(script.I2[0].image0)
ax12.contour(script.algo.pMask)

# %%
# Apply calculated focus offset
calculated_hexapod_focus_offset = results['hex_offset'][2]
print(f'Applying focus offset of {calculated_hexapod_focus_offset}')
await script.atcs.rem.ataos.cmd_offset.set_start(z=calculated_hexapod_focus_offset)

# %%
await script.atcs.slew_object('HD185975', rot_type=2)

# %%
await script.latiss.take_object(5.0)

# %% [markdown]
# # Stop here unless a re-reduction of the doughnuts is required.

# %% [markdown]
# #### If you want to re-reduce data then use the below cells

# %%
# Show which files/parameters were taken in the sequence above
print(f'intra_visit_id is {script.intra_visit_id}')
print(f'extra_visit_id is {script.extra_visit_id}')
print(f'angle is {script.angle}')

# %%
# If desired then different filenames can be manually input here
#script.intra_visit_id=2021011900169 
#script.extra_visit_id=2021011900170 
#script.angle=-91.56748047249727

# %%
# reruns reduction part only. ALL 3 fields above must be set! 
rerun_results = await script.run_cwfs()
