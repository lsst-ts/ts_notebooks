# %% [markdown]
# ## AuxTel test LTS-337-003 (Nasmyth rotator)
#
# In this notebook, I slew the Nasmyth2 rotator through it's range of travel, and evaluate range, max slew speed, and accuracy of position.  Desired specs:
#
# | Description | Value       | Unit          |   Name     |
# | :---        |    :----:   |       :----:  |       ---: |
# |The rotator shall have a minimum range of rotation of:    | ±120       | Degrees   |Aux_Tel_Field_Rotation_Range|
# |The rotator shall be able to achieve or surpass this velocity during slews of the telescope.  |3.5       | Degrees/Second      |Aux_Tel_Inst_Rot_Max_Vel|
# |The rotator shall have at maximum this absolute angle error.      | 0.01|Degrees|Aux_Tel_Inst_Rot_Abs_Error|

# %%
import sys, time, os, asyncio

from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from lsst.ts import salobj
from lsst.ts.observatory.control.auxtel.atcs import ATCS
from lsst.ts.observatory.control.auxtel.latiss import LATISS
from astropy.time import Time, TimeDelta
from lsst_efd_client import EfdClient
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /opt/lsst/software/stack/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
# for tab completion to work in current notebook instance
# %config IPCompleter.use_jedi = False

# %%
import logging
stream_handler = logging.StreamHandler(sys.stdout)
logger = logging.getLogger()
logger.addHandler(stream_handler)
logger.level = logging.DEBUG

# %%
# Get EFD client and bring in Lupton's unpacking code
client = EfdClient('summit_efd')

def merge_packed_time_series(packed_dataframe, base_field, stride=1, 
                             ref_timestamp_col="cRIO_timestamp", internal_time_scale="tai"):
    """Select fields that are time samples and unpack them into a dataframe.
            Parameters
            ----------
            packedDF : `pandas.DataFrame`
                packed data frame containing the desired data
            base_field :  `str`
                Base field name that will be expanded to query all
                vector entries.
            stride : `int`, optional
                Only use every stride value when unpacking.  Must be a factor
                of the number of packed values.
                (1 by default)
            ref_timestamp_col : `str`, optional
                Name of the field name to use to assign timestamps to unpacked
                vector fields (default is 'cRIO_timestamp').
            internal_time_scale : `str`, optional
                Time scale to use when converting times to internal formats
                ('tai' by default). Equivalent to EfdClient.internal_scale
        Returns
            -------
            result : `pandas.DataFrame`
                A `pandas.DataFrame` containing the results of the query.
            """
    
    packed_fields = [k for k in packed_dataframe.keys() if k.startswith(base_field)]
    packed_fields = sorted(packed_fields, key=lambda k: int(k[len(base_field):]))  # sort by pack ID
    npack = len(packed_fields)
    if npack%stride != 0:
        raise RuntimeError(f"Stride must be a factor of the number of packed fields: {stride} v. {npack}")
    packed_len = len(packed_dataframe)
    n_used = npack//stride   # number of raw fields being used
    output = np.empty(n_used*packed_len)
    times = np.empty_like(output, dtype=packed_dataframe[ref_timestamp_col][0])
    
    if packed_len == 1:
        dt = 0
    else:
        dt = (packed_dataframe[ref_timestamp_col][1] - packed_dataframe[ref_timestamp_col][0])/npack
    for i in range(0, npack, stride):
        i0 = i//stride
        output[i0::n_used] = packed_dataframe[f"{base_field}{i}"]
        times[i0::n_used] = packed_dataframe[ref_timestamp_col] + i*dt
     
    timestamps = Time(times, format='unix', scale=internal_time_scale).datetime64
    return pd.DataFrame({base_field:output, "times":times}, index=timestamps)
# Out:
# Starting new HTTPS connection (1): roundtable.lsst.codes:443
# https://roundtable.lsst.codes:443 "GET /segwarides/ HTTP/1.1" 200 253
# Starting new HTTPS connection (1): roundtable.lsst.codes:443
# https://roundtable.lsst.codes:443 "GET /segwarides/creds/summit_efd HTTP/1.1" 200 92

# %%
#get classes and start them
domain = salobj.Domain()
await asyncio.sleep(10) # This can be removed in the future...
atcs = ATCS(domain)
latiss = LATISS(domain)
await asyncio.gather(atcs.start_task, latiss.start_task)
# Out:
# atmcs: Adding all resources.
# atptg: Adding all resources.
# ataos: Adding all resources.
# atpneumatics: Adding all resources.
# athexapod: Adding all resources.
# atdome: Adding all resources.
# atdometrajectory: Adding all resources.
# atcamera: Adding all resources.
# atspectrograph: Adding all resources.
# atheaderservice: Adding all resources.
# atarchiver: Adding all resources.
# Read historical data in 0.17 sec
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, algorithm)
# Read 8 history items for RemoteEvent(ATDomeTrajectory, 0, appliedSettingsMatchStart)
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, authList)
# Read 100 history items for RemoteEvent(ATDomeTrajectory, 0, heartbeat)
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, logLevel)
# Read 12 history items for RemoteEvent(ATDomeTrajectory, 0, logMessage)
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, settingVersions)
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, settingsApplied)
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATDomeTrajectory, 0, softwareVersions)
# Read 33 history items for RemoteEvent(ATDomeTrajectory, 0, summaryState)
# Read historical data in 0.22 sec
# Read 1 history items for RemoteEvent(ATHeaderService, 0, authList)
# Read 100 history items for RemoteEvent(ATHeaderService, 0, heartbeat)
# Read 21 history items for RemoteEvent(ATHeaderService, 0, largeFileObjectAvailable)
# Read 1 history items for RemoteEvent(ATHeaderService, 0, logLevel)
# Read 100 history items for RemoteEvent(ATHeaderService, 0, logMessage)
# Read 1 history items for RemoteEvent(ATHeaderService, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATHeaderService, 0, softwareVersions)
# Read 13 history items for RemoteEvent(ATHeaderService, 0, summaryState)
# Read historical data in 0.24 sec
# Read 1 history items for RemoteEvent(ATArchiver, 0, authList)
# Read 1 history items for RemoteEvent(ATArchiver, 0, errorCode)
# Read 100 history items for RemoteEvent(ATArchiver, 0, heartbeat)
# Read 21 history items for RemoteEvent(ATArchiver, 0, imageInOODS)
# Read 21 history items for RemoteEvent(ATArchiver, 0, imageRetrievalForArchiving)
# Read 1 history items for RemoteEvent(ATArchiver, 0, logLevel)
# Read 1 history items for RemoteEvent(ATArchiver, 0, logMessage)
# Read 1 history items for RemoteEvent(ATArchiver, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATArchiver, 0, softwareVersions)
# Read 17 history items for RemoteEvent(ATArchiver, 0, summaryState)
# Read historical data in 0.26 sec
# Read 5 history items for RemoteEvent(ATAOS, 0, appliedSettingsMatchStart)
# Read 19 history items for RemoteEvent(ATAOS, 0, atspectrographCorrectionCompleted)
# Read 19 history items for RemoteEvent(ATAOS, 0, atspectrographCorrectionStarted)
# Read 1 history items for RemoteEvent(ATAOS, 0, authList)
# Read 6 history items for RemoteEvent(ATAOS, 0, correctionEnabled)
# Read 15 history items for RemoteEvent(ATAOS, 0, correctionOffsets)
# Read 100 history items for RemoteEvent(ATAOS, 0, detailedState)
# Read 15 history items for RemoteEvent(ATAOS, 0, focusOffsetSummary)
# Read 100 history items for RemoteEvent(ATAOS, 0, heartbeat)
# Read 43 history items for RemoteEvent(ATAOS, 0, hexapodCorrectionCompleted)
# Read 43 history items for RemoteEvent(ATAOS, 0, hexapodCorrectionStarted)
# Read 1 history items for RemoteEvent(ATAOS, 0, logLevel)
# Read 55 history items for RemoteEvent(ATAOS, 0, logMessage)
# Read 100 history items for RemoteEvent(ATAOS, 0, m1CorrectionCompleted)
# Read 100 history items for RemoteEvent(ATAOS, 0, m1CorrectionStarted)
# Read 6 history items for RemoteEvent(ATAOS, 0, pointingOffsetSummary)
# Read 1 history items for RemoteEvent(ATAOS, 0, settingVersions)
# Read 1 history items for RemoteEvent(ATAOS, 0, settingsApplied)
# Read 1 history items for RemoteEvent(ATAOS, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATAOS, 0, softwareVersions)
# Read 21 history items for RemoteEvent(ATAOS, 0, summaryState)
# Read historical data in 0.29 sec
# Read 5 history items for RemoteEvent(ATHexapod, 0, appliedSettingsMatchStart)
# Read 1 history items for RemoteEvent(ATHexapod, 0, authList)
# Read 87 history items for RemoteEvent(ATHexapod, 0, detailedState)
# Read 1 history items for RemoteEvent(ATHexapod, 0, errorCode)
# Read 100 history items for RemoteEvent(ATHexapod, 0, heartbeat)
# Read 86 history items for RemoteEvent(ATHexapod, 0, inPosition)
# Read 1 history items for RemoteEvent(ATHexapod, 0, logLevel)
# Read 3 history items for RemoteEvent(ATHexapod, 0, logMessage)
# Read 46 history items for RemoteEvent(ATHexapod, 0, positionUpdate)
# Read 1 history items for RemoteEvent(ATHexapod, 0, readyForCommand)
# Read 1 history items for RemoteEvent(ATHexapod, 0, settingVersions)
# Read 1 history items for RemoteEvent(ATHexapod, 0, settingsApplied)
# Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedPivot)
# Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedPositionLimits)
# Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedTcp)
# Read 1 history items for RemoteEvent(ATHexapod, 0, settingsAppliedVelocities)
# Read 1 history items for RemoteEvent(ATHexapod, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATHexapod, 0, softwareVersions)
# Read 20 history items for RemoteEvent(ATHexapod, 0, summaryState)
# Read historical data in 0.31 sec
# Read 5 history items for RemoteEvent(ATPneumatics, 0, appliedSettingsMatchStart)
# Read 7 history items for RemoteEvent(ATPneumatics, 0, cellVentsState)
# Read 1 history items for RemoteEvent(ATPneumatics, 0, eStop)
# Read 100 history items for RemoteEvent(ATPneumatics, 0, heartbeat)
# Read 9 history items for RemoteEvent(ATPneumatics, 0, instrumentState)
# Read 12 history items for RemoteEvent(ATPneumatics, 0, m1CoverLimitSwitches)
# Read 12 history items for RemoteEvent(ATPneumatics, 0, m1CoverState)
# Read 100 history items for RemoteEvent(ATPneumatics, 0, m1SetPressure)
# Read 12 history items for RemoteEvent(ATPneumatics, 0, m1State)
# Read 1 history items for RemoteEvent(ATPneumatics, 0, m1VentsPosition)
# Read 11 history items for RemoteEvent(ATPneumatics, 0, m2State)
# Read 9 history items for RemoteEvent(ATPneumatics, 0, mainValveState)
# Read 1 history items for RemoteEvent(ATPneumatics, 0, powerStatus)
# Read 5 history items for RemoteEvent(ATPneumatics, 0, settingVersions)
# Read 22 history items for RemoteEvent(ATPneumatics, 0, summaryState)
# Read historical data in 0.32 sec
# Read 3 history items for RemoteEvent(ATSpectrograph, 0, appliedSettingsMatchStart)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, authList)
# Read 12 history items for RemoteEvent(ATSpectrograph, 0, disperserInPosition)
# Read 12 history items for RemoteEvent(ATSpectrograph, 0, filterInPosition)
# Read 9 history items for RemoteEvent(ATSpectrograph, 0, fwState)
# Read 12 history items for RemoteEvent(ATSpectrograph, 0, gwState)
# Read 100 history items for RemoteEvent(ATSpectrograph, 0, heartbeat)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, logLevel)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, logMessage)
# Read 7 history items for RemoteEvent(ATSpectrograph, 0, reportedDisperserPosition)
# Read 7 history items for RemoteEvent(ATSpectrograph, 0, reportedFilterPosition)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, reportedLinearStagePosition)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, settingVersions)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, settingsApplied)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, settingsAppliedValues)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, softwareVersions)
# Read 13 history items for RemoteEvent(ATSpectrograph, 0, summaryState)
# Read historical data in 0.35 sec
# Read 1 history items for RemoteEvent(ATDome, 0, allAxesInPosition)
# Read 1 history items for RemoteEvent(ATDome, 0, appliedSettingsMatchStart)
# Read 1 history items for RemoteEvent(ATDome, 0, authList)
# Read 3 history items for RemoteEvent(ATDome, 0, azimuthCommandedState)
# Read 3 history items for RemoteEvent(ATDome, 0, azimuthInPosition)
# Read 3 history items for RemoteEvent(ATDome, 0, azimuthState)
# Read 100 history items for RemoteEvent(ATDome, 0, doorEncoderExtremes)
# Read 2 history items for RemoteEvent(ATDome, 0, dropoutDoorCommandedState)
# Read 1 history items for RemoteEvent(ATDome, 0, dropoutDoorState)
# Read 1 history items for RemoteEvent(ATDome, 0, emergencyStop)
# Read 100 history items for RemoteEvent(ATDome, 0, heartbeat)
# Read 2 history items for RemoteEvent(ATDome, 0, lastAzimuthGoTo)
# Read 1 history items for RemoteEvent(ATDome, 0, logLevel)
# Read 6 history items for RemoteEvent(ATDome, 0, logMessage)
# Read 2 history items for RemoteEvent(ATDome, 0, mainDoorCommandedState)
# Read 1 history items for RemoteEvent(ATDome, 0, mainDoorState)
# Read 2 history items for RemoteEvent(ATDome, 0, scbLink)
# Read 1 history items for RemoteEvent(ATDome, 0, settingVersions)
# Read 1 history items for RemoteEvent(ATDome, 0, settingsApplied)
# Read 2 history items for RemoteEvent(ATDome, 0, settingsAppliedDomeController)
# Read 1 history items for RemoteEvent(ATDome, 0, settingsAppliedDomeTcp)
# Read 1 history items for RemoteEvent(ATDome, 0, shutterInPosition)
# Read 1 history items for RemoteEvent(ATDome, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATDome, 0, softwareVersions)
# Read 4 history items for RemoteEvent(ATDome, 0, summaryState)
# Read historical data in 0.38 sec
# Read 1 history items for RemoteEvent(ATPtg, 0, airmassWarning)
# Read 1 history items for RemoteEvent(ATPtg, 0, azWrapWarning)
# Read 6 history items for RemoteEvent(ATPtg, 0, currentDebugLevel)
# Read 43 history items for RemoteEvent(ATPtg, 0, currentTarget)
# Read 87 history items for RemoteEvent(ATPtg, 0, detailedState)
# Read 1 history items for RemoteEvent(ATPtg, 0, elLimitWarning)
# Read 6 history items for RemoteEvent(ATPtg, 0, errorCode)
# Read 1 history items for RemoteEvent(ATPtg, 0, focusNameInconsistentWarning)
# Read 9 history items for RemoteEvent(ATPtg, 0, focusNameSelected)
# Read 100 history items for RemoteEvent(ATPtg, 0, heartbeat)
# Read 10 history items for RemoteEvent(ATPtg, 0, iers)
# Read 3 history items for RemoteEvent(ATPtg, 0, iersOutOfDate)
# Read 1 history items for RemoteEvent(ATPtg, 0, moonProximityWarning)
# Read 2 history items for RemoteEvent(ATPtg, 0, mountDataWarning)
# Read 1 history items for RemoteEvent(ATPtg, 0, objectSetWarning)
# Read 5 history items for RemoteEvent(ATPtg, 0, pointingModel)
# Read 1 history items for RemoteEvent(ATPtg, 0, pointing_file)
# Read 1 history items for RemoteEvent(ATPtg, 0, ptgAzCurrentWrap)
# Read 1 history items for RemoteEvent(ATPtg, 0, ptgRotCurrentWrap)
# Read 1 history items for RemoteEvent(ATPtg, 0, rotWrapWarning)
# Read 21 history items for RemoteEvent(ATPtg, 0, summaryState)
# Read 1 history items for RemoteEvent(ATPtg, 0, sunProximityWarning)
# Read 48 history items for RemoteEvent(ATPtg, 0, timesOfLimits)
# Read 87 history items for RemoteEvent(ATPtg, 0, trackPosting)
# Read 5 history items for RemoteEvent(ATPtg, 0, wavelength)
# Read 100 history items for RemoteEvent(ATPtg, 0, weatherDataApplied)
# Read 100 history items for RemoteEvent(ATPtg, 0, weatherDataInvalid)
# Read historical data in 0.41 sec
# Read 100 history items for RemoteEvent(ATMCS, 0, allAxesInPosition)
# Read 14 history items for RemoteEvent(ATMCS, 0, appliedSettingsMatchStart)
# Read 100 history items for RemoteEvent(ATMCS, 0, atMountState)
# Read 28 history items for RemoteEvent(ATMCS, 0, azimuthBrake1)
# Read 28 history items for RemoteEvent(ATMCS, 0, azimuthBrake2)
# Read 28 history items for RemoteEvent(ATMCS, 0, azimuthDrive1Status)
# Read 28 history items for RemoteEvent(ATMCS, 0, azimuthDrive2Status)
# Read 41 history items for RemoteEvent(ATMCS, 0, azimuthInPosition)
# Read 28 history items for RemoteEvent(ATMCS, 0, elevationBrake)
# Read 28 history items for RemoteEvent(ATMCS, 0, elevationDriveStatus)
# Read 27 history items for RemoteEvent(ATMCS, 0, elevationInPosition)
# Read 2 history items for RemoteEvent(ATMCS, 0, elevationLimitSwitchLower)
# Read 100 history items for RemoteEvent(ATMCS, 0, heartbeat)
# Read 28 history items for RemoteEvent(ATMCS, 0, m3State)
# Read 28 history items for RemoteEvent(ATMCS, 0, nasmyth1Brake)
# Read 28 history items for RemoteEvent(ATMCS, 0, nasmyth1DriveStatus)
# Read 14 history items for RemoteEvent(ATMCS, 0, nasmyth1RotatorInPosition)
# Read 28 history items for RemoteEvent(ATMCS, 0, nasmyth2Brake)
# Read 28 history items for RemoteEvent(ATMCS, 0, nasmyth2DriveStatus)
# Read 82 history items for RemoteEvent(ATMCS, 0, nasmyth2RotatorInPosition)
# Read 14 history items for RemoteEvent(ATMCS, 0, positionLimits)
# Read 14 history items for RemoteEvent(ATMCS, 0, settingVersions)
# Read 56 history items for RemoteEvent(ATMCS, 0, summaryState)
# Read 100 history items for RemoteEvent(ATMCS, 0, target)
# Read historical data in 0.46 sec
# timeAndDate DDS read queue is full (100 elements); data may be lost
# Read 3 history items for RemoteEvent(ATCamera, 0, appliedSettingsMatchStart)
# Read 73 history items for RemoteEvent(ATCamera, 0, ccsCommandState)
# Read 21 history items for RemoteEvent(ATCamera, 0, endOfImageTelemetry)
# Read 21 history items for RemoteEvent(ATCamera, 0, endReadout)
# Read 4 history items for RemoteEvent(ATCamera, 0, focalPlaneHardwareIdSettingsApplied)
# Read 4 history items for RemoteEvent(ATCamera, 0, focalPlaneSummaryInfo)
# Read 100 history items for RemoteEvent(ATCamera, 0, heartbeat)
# Read 44 history items for RemoteEvent(ATCamera, 0, imageReadinessDetailedState)
# Read 21 history items for RemoteEvent(ATCamera, 0, imageReadoutParameters)
# Read 4 history items for RemoteEvent(ATCamera, 0, offlineDetailedState)
# Read 85 history items for RemoteEvent(ATCamera, 0, raftsDetailedState)
# Read 5 history items for RemoteEvent(ATCamera, 0, settingVersions)
# Read 5 history items for RemoteEvent(ATCamera, 0, softwareVersions)
# Read 21 history items for RemoteEvent(ATCamera, 0, startIntegration)
# Read 21 history items for RemoteEvent(ATCamera, 0, startReadout)
# Read 16 history items for RemoteEvent(ATCamera, 0, summaryState)
# [[None, None, None, None, None, None, None], [None, None, None, None]]

# %%
# enable components if required
await atcs.enable()
#await latiss.enable()
# Out:
# Enabling all components
# Gathering settings.
# Couldn't get settingVersions event. Using empty settings.
# Complete settings for atmcs.
# Complete settings for atptg.
# Complete settings for ataos.
# Complete settings for atpneumatics.
# Complete settings for athexapod.
# Complete settings for atdome.
# Complete settings for atdometrajectory.
# Settings versions: {'atmcs': '                                                                                                                               ', 'atptg': '', 'ataos': 'current', 'atpneumatics': '                                                                                                                               ', 'athexapod': 'summit', 'atdome': 'test', 'atdometrajectory': ''}
# [atmcs]::[<State.STANDBY: 5>, <State.DISABLED: 1>, <State.ENABLED: 2>]
# [atptg]::[<State.STANDBY: 5>, <State.DISABLED: 1>, <State.ENABLED: 2>]
# [ataos]::[<State.STANDBY: 5>, <State.DISABLED: 1>, <State.ENABLED: 2>]
# [atpneumatics]::[<State.STANDBY: 5>, <State.DISABLED: 1>, <State.ENABLED: 2>]
# [athexapod]::[<State.STANDBY: 5>, <State.DISABLED: 1>, <State.ENABLED: 2>]
# Unable to transition atdome to <State.ENABLED: 2> NoneType: None
# .
# Traceback (most recent call last):
#   File "/opt/lsst/src/ts_salobj/python/lsst/ts/salobj/csc_utils.py", line 148, in set_summary_state
#     await cmd.start(timeout=timeout)
#   File "/opt/lsst/src/ts_salobj/python/lsst/ts/salobj/topics/remote_command.py", line 446, in start
#     return await cmd_info.next_ackcmd(timeout=timeout)
#   File "/opt/lsst/src/ts_salobj/python/lsst/ts/salobj/topics/remote_command.py", line 183, in next_ackcmd
#     raise base.AckError(msg="Command failed", ackcmd=ackcmd)
# lsst.ts.salobj.base.AckError: msg='Command failed', ackcmd=(ackcmd private_seqNum=502243990, ack=<SalRetCode.CMD_FAILED: -302>, error=1, result='Failed: enable not allowed in state <State.STANDBY: 5>')
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/opt/lsst/src/ts_salobj/python/lsst/ts/salobj/csc_utils.py", line 152, in set_summary_state
#     ) from e
# RuntimeError: Error on cmd=cmd_enable, initial_state=1: msg='Command failed', ackcmd=(ackcmd private_seqNum=502243990, ack=<SalRetCode.CMD_FAILED: -302>, error=1, result='Failed: enable not allowed in state <State.STANDBY: 5>')
#
# [atdometrajectory]::[<State.STANDBY: 5>, <State.DISABLED: 1>, <State.ENABLED: 2>]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-acb8b0a457fa> in async-def-wrapper()
#       3 #await latiss.enable()
#
# ~/WORK/ts_observatory_control/python/lsst/ts/observatory/control/remote_group.py in enable(self, settings)
#     712         settings_all = await self.expand_settings(settings)
#     713
# --> 714         await self.set_state(salobj.State.ENABLED, settings=settings_all)
#     715
#     716     async def standby(self):
#
# ~/WORK/ts_observatory_control/python/lsst/ts/observatory/control/remote_group.py in set_state(self, state, settings, components)
#     687         if error_flag:
#     688             raise RuntimeError(
# --> 689                 f"Failed to transition {failed_components} to "
#     690                 f"{salobj.State(state)!r}."
#     691             )
#
# RuntimeError: Failed to transition ['atdome'] to <State.ENABLED: 2>.

# %%
# take event checking out the slew commands to test telescope only
# otherwise it'll wait for the dome before completing slew command
atcs.check.atdome = False
atcs.check.atdometrajectory = False

# %%
# turn on ATAOS corrections just to make sure the mirror is under air
tmp = await atcs.rem.ataos.cmd_enableCorrection.set_start(m1=True, hexapod=True, atspectrograph=False)

# %%
# Ensure we're using Nasmyth 2
await atcs.rem.atptg.cmd_focusName.set_start(focus=3)

# %%
# slew telescope to desired starting position
# rotator does not move for this test as it's part of a different
# requirement/verification
start_az=0
start_el=80
start_rot_pa=0.0
await atcs.point_azel(start_az, start_el, rot_tel=start_rot_pa, wait_dome=False)
# Out:
# Sending command
# Stop tracking.
# Unknown tracking state: 10.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got True
# Waiting for telescope to settle.
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -000.908 deg
# Telescope in position.

# %%
# Here is where the tests are carried out.
max_rot = 130.0 # Maximum +/- 130 degrees
rot_step = 10.0 # 10 degree steps
n_steps = int(max_rot / rot_step)
maxes = []
errors = []
speeds = []
signs = [-1.0, 1.0] # Repeat tests in both directions

for sign in signs:
    await atcs.point_azel(start_az, start_el, rot_tel=start_rot_pa, wait_dome=False)
    # Move to max_rot
    current_rot = start_rot_pa + sign * max_rot
    await atcs.point_azel(start_az, start_el, rot_tel=current_rot, wait_dome=False)
    current_time = Time(Time.now(), format='fits', scale='tai')
    # Get velocity data for 60 seconds before current time
    # and find median of 100 largest values
    t_end = current_time
    nsec = 60
    nasmyth_velocity = await client.select_time_series("lsst.sal.ATMCS.measuredMotorVelocity", ['*'],
                                              t_end - TimeDelta(nsec, format='sec'), t_end)
    velocity = merge_packed_time_series(nasmyth_velocity, 'nasmyth2MotorVelocity', stride=1)
    velArray = np.array(velocity.values.tolist())[:,0]
    sortedVelArray = velArray[np.argsort(velArray)]
    measuredPeakVelocity = max(abs(np.median(sortedVelArray[0:100])), abs(np.median(sortedVelArray[-100:])))
    print(f"Measured peak velocity = {measuredPeakVelocity}")
    speeds.append(measuredPeakVelocity)
    # Get current position to verify it is beyond the max
    await asyncio.sleep(3)
    current_time = current_time = Time(Time.now(), format='fits', scale='tai')
    t_end = current_time - TimeDelta(1, format='sec')
    nsec = 2
    nasmyth_angle = await client.select_time_series("lsst.sal.ATMCS.mount_Nasmyth_Encoders", ['*'],
                                              t_end - TimeDelta(nsec, format='sec'), t_end)
    angle = merge_packed_time_series(nasmyth_angle, 'nasmyth2CalculatedAngle', stride=1)
    current_angle = angle.values.tolist()[-1][0]
    print(f"Current rotator angle = {current_angle}")
    maxes.append(abs(current_angle))
    # Now slew through a range of angles and evaluate the error
    for n in range(n_steps):
        current_rot = current_rot - sign * rot_step
        await atcs.point_azel(start_az, start_el, rot_tel=current_rot, wait_dome=False)
        # Get current position and compare to set point
        await asyncio.sleep(3)
        current_time = current_time = Time(Time.now(), format='fits', scale='tai')
        t_end = current_time - TimeDelta(1, format='sec')
        nsec = 2
        nasmyth_angle = await client.select_time_series("lsst.sal.ATMCS.mount_Nasmyth_Encoders", ['*'],
                                                  t_end - TimeDelta(nsec, format='sec'), t_end)
        angle = merge_packed_time_series(nasmyth_angle, 'nasmyth2CalculatedAngle', stride=1)
        current_angle = angle.values.tolist()[-1][0]
        error = current_angle - current_rot
        print(f"Current rotator angle = {current_angle}. Set point = {current_rot}.  Error = {error}")
        errors.append(abs(error))
# Out:
# Sending command
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got False
# Telescope not in position
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +129.921 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +125.123 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +119.129 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +113.127 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +107.121 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +103.122 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +099.130 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +093.120 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +089.126 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +083.124 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +079.120 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +075.121 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +069.124 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +063.116 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +057.132 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +053.117 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +049.122 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +043.126 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +037.122 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +000.000 deg; delta N1 = -000.000 deg; delta N2 = +031.125 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +000.000 deg; delta N1 = -000.000 deg; delta N2 = +025.128 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +000.000 deg; delta N1 = +000.000 deg; delta N2 = +019.238 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +000.000 deg; delta N1 = -000.000 deg; delta N2 = +015.486 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +011.985 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +008.822 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +000.000 deg; delta N1 = -000.000 deg; delta N2 = +004.900 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +002.140 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +000.000 deg; delta N1 = +000.000 deg; delta N2 = +000.975 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +000.000 deg; delta N1 = -000.000 deg; delta N2 = +000.133 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= +000.000 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# Got True
# Waiting for telescope to settle.
# Axes in position.
# Sending command
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got False
# Telescope not in position
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -130.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -128.755 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -124.822 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -118.824 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -116.825 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -110.822 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -104.823 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -100.829 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -094.819 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -088.827 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -082.820 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -078.819 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -072.827 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -066.825 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -060.824 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -054.819 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -048.824 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -044.826 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= +000.000 deg; delta N1 = +000.000 deg; delta N2 = -042.821 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +000.000 deg; delta N1 = +000.000 deg; delta N2 = -036.818 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= +000.000 deg; delta N1 = -000.000 deg; delta N2 = -032.827 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +000.000 deg; delta N1 = -000.000 deg; delta N2 = -028.825 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= +000.000 deg; delta N1 = +000.000 deg; delta N2 = -022.842 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +000.000 deg; delta N1 = +000.000 deg; delta N2 = -017.055 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +000.000 deg; delta N1 = +000.000 deg; delta N2 = -013.435 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -010.120 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +000.000 deg; delta N1 = -000.000 deg; delta N2 = -005.897 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +000.000 deg; delta N1 = -000.000 deg; delta N2 = -002.798 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +000.000 deg; delta N1 = +000.000 deg; delta N2 = -000.908 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= +000.000 deg; delta N1 = -000.000 deg; delta N2 = -000.115 deg
# Got True
# Waiting for telescope to settle.
# [Telescope] delta Alt = -000.000 deg; delta Az= +000.000 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# Axes in position.
# 200: SELECT * FROM "efd"."autogen"."lsst.sal.ATMCS.measuredMotorVelocity" WHERE time >= '2021-02-09T13:57:18.016Z' AND time <= '2021-02-09T13:58:18.016Z'
# Measured peak velocity = 2.2185812444
# 200: SELECT * FROM "efd"."autogen"."lsst.sal.ATMCS.mount_Nasmyth_Encoders" WHERE time >= '2021-02-09T13:58:18.601Z' AND time <= '2021-02-09T13:58:20.601Z'
# Current rotator angle = -130.00000542920316
# Sending command
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got False
# Telescope not in position
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +009.825 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +005.968 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +002.188 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -000.000 deg
# Got True
# Waiting for telescope to settle.
# Axes in position.
# 200: SELECT * FROM "efd"."autogen"."lsst.sal.ATMCS.mount_Nasmyth_Encoders" WHERE time >= '2021-02-09T13:59:08.028Z' AND time <= '2021-02-09T13:59:10.028Z'
# Current rotator angle = -120.00001429540862. Set point = -120.0.  Error = -1.429540861863643e-05
# Sending command
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got False
# Telescope not in position
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +009.862 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +006.155 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +002.342 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +000.002 deg
# Got True
# Waiting for telescope to settle.
# Axes in position.
# 200: SELECT * FROM "efd"."autogen"."lsst.sal.ATMCS.mount_Nasmyth_Encoders" WHERE time >= '2021-02-09T13:59:57.978Z' AND time <= '2021-02-09T13:59:59.978Z'
# Current rotator angle = -109.99993219001044. Set point = -110.0.  Error = 6.780998955946416e-05
# Sending command
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got False
# Telescope not in position
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +009.706 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +005.470 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +000.625 deg
# Got True
# Waiting for telescope to settle.
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# Axes in position.
# 200: SELECT * FROM "efd"."autogen"."lsst.sal.ATMCS.mount_Nasmyth_Encoders" WHERE time >= '2021-02-09T14:00:49.008Z' AND time <= '2021-02-09T14:00:51.008Z'
# Current rotator angle = -100.00000878199353. Set point = -100.0.  Error = -8.781993528828025e-06
# Sending command
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got False
# Telescope not in position
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +009.809 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +007.693 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +002.110 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +000.146 deg
# Got True
# Waiting for telescope to settle.
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# Axes in position.
# 200: SELECT * FROM "efd"."autogen"."lsst.sal.ATMCS.mount_Nasmyth_Encoders" WHERE time >= '2021-02-09T14:01:41.081Z' AND time <= '2021-02-09T14:01:43.081Z'
# Current rotator angle = -90.00000691934838. Set point = -90.0.  Error = -6.919348379597068e-06
# Sending command
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got False
# Telescope not in position
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +009.801 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +005.867 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +000.808 deg
# Got True
# Waiting for telescope to settle.
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# Axes in position.
# 200: SELECT * FROM "efd"."autogen"."lsst.sal.ATMCS.mount_Nasmyth_Encoders" WHERE time >= '2021-02-09T14:02:32.038Z' AND time <= '2021-02-09T14:02:34.038Z'
# Current rotator angle = -80.00000975058356. Set point = -80.0.  Error = -9.750583558343351e-06
# Sending command
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got False
# Telescope not in position
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +009.989 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +007.279 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +001.732 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +000.072 deg
# Got True
# Waiting for telescope to settle.
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# Axes in position.
# 200: SELECT * FROM "efd"."autogen"."lsst.sal.ATMCS.mount_Nasmyth_Encoders" WHERE time >= '2021-02-09T14:03:24.051Z' AND time <= '2021-02-09T14:03:26.051Z'
# Current rotator angle = -70.00000252352038. Set point = -70.0.  Error = -2.5235203793272376e-06
# Sending command
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got False
# Telescope not in position
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +009.994 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +008.846 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +005.484 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +001.802 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -000.001 deg
# Got True
# Waiting for telescope to settle.
# Axes in position.
# 200: SELECT * FROM "efd"."autogen"."lsst.sal.ATMCS.mount_Nasmyth_Encoders" WHERE time >= '2021-02-09T14:04:13.978Z' AND time <= '2021-02-09T14:04:15.978Z'
# Current rotator angle = -60.00000803695002. Set point = -60.0.  Error = -8.03695002105087e-06
# Sending command
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got False
# Telescope not in position
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +009.803 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +005.866 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +002.100 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# Got True
# Waiting for telescope to settle.
# Axes in position.
# 200: SELECT * FROM "efd"."autogen"."lsst.sal.ATMCS.mount_Nasmyth_Encoders" WHERE time >= '2021-02-09T14:05:04.051Z' AND time <= '2021-02-09T14:05:06.051Z'
# Current rotator angle = -50.00000818596163. Set point = -50.0.  Error = -8.185961632989347e-06
# Sending command
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got False
# Telescope not in position
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +009.725 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +005.556 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +000.661 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -000.001 deg
# Got True
# Waiting for telescope to settle.
# Axes in position.
# 200: SELECT * FROM "efd"."autogen"."lsst.sal.ATMCS.mount_Nasmyth_Encoders" WHERE time >= '2021-02-09T14:05:53.985Z' AND time <= '2021-02-09T14:05:55.985Z'
# Current rotator angle = -40.00000364109292. Set point = -40.0.  Error = -3.6410929169505835e-06
# Sending command
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got False
# Telescope not in position
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +009.780 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +005.756 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +000.757 deg
# Got True
# Waiting for telescope to settle.
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# Axes in position.
# 200: SELECT * FROM "efd"."autogen"."lsst.sal.ATMCS.mount_Nasmyth_Encoders" WHERE time >= '2021-02-09T14:06:44.975Z' AND time <= '2021-02-09T14:06:46.975Z'
# Current rotator angle = -30.000021000945708. Set point = -30.0.  Error = -2.1000945707783103e-05
# Sending command
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got False
# Telescope not in position
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +009.823 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +007.769 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +003.980 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +000.163 deg
# Got True
# Waiting for telescope to settle.
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# Axes in position.
# 200: SELECT * FROM "efd"."autogen"."lsst.sal.ATMCS.mount_Nasmyth_Encoders" WHERE time >= '2021-02-09T14:07:37.033Z' AND time <= '2021-02-09T14:07:39.033Z'
# Current rotator angle = -20.000025620305678. Set point = -20.0.  Error = -2.5620305677875876e-05
# Sending command
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got False
# Telescope not in position
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +009.730 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +005.565 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +003.593 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +000.670 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -000.001 deg
# Got True
# Waiting for telescope to settle.
# Axes in position.
# 200: SELECT * FROM "efd"."autogen"."lsst.sal.ATMCS.mount_Nasmyth_Encoders" WHERE time >= '2021-02-09T14:08:26.997Z' AND time <= '2021-02-09T14:08:28.997Z'
# Current rotator angle = -9.999964525544783. Set point = -10.0.  Error = 3.5474455216899514e-05
# Sending command
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got False
# Telescope not in position
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +009.731 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +005.564 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +000.669 deg
# Got True
# Waiting for telescope to settle.
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -000.000 deg
# Axes in position.
# 200: SELECT * FROM "efd"."autogen"."lsst.sal.ATMCS.mount_Nasmyth_Encoders" WHERE time >= '2021-02-09T14:09:17.984Z' AND time <= '2021-02-09T14:09:19.984Z'
# Current rotator angle = -3.552957787178457e-05. Set point = 0.0.  Error = -3.552957787178457e-05
# Sending command
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# Axes in position.
# Sending command
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got False
# Telescope not in position
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +129.868 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +124.880 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +118.871 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +112.874 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +106.875 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +100.873 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +096.879 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +090.872 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +084.881 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +078.869 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +072.876 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +066.874 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +062.871 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +056.875 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +050.874 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +044.873 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +000.000 deg; delta N1 = -000.000 deg; delta N2 = +038.872 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +032.874 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +000.000 deg; delta N1 = -000.000 deg; delta N2 = +026.878 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +000.000 deg; delta N1 = +000.000 deg; delta N2 = +020.929 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +015.261 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +010.162 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +005.932 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +000.000 deg; delta N1 = -000.000 deg; delta N2 = +002.819 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= +000.000 deg; delta N1 = +000.000 deg; delta N2 = +000.920 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +000.282 deg
# [Telescope] delta Alt = -000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +000.003 deg
# Got True
# Waiting for telescope to settle.
# Axes in position.
# 200: SELECT * FROM "efd"."autogen"."lsst.sal.ATMCS.measuredMotorVelocity" WHERE time >= '2021-02-09T14:10:52.165Z' AND time <= '2021-02-09T14:11:52.165Z'
# Measured peak velocity = 2.1721461324
# 200: SELECT * FROM "efd"."autogen"."lsst.sal.ATMCS.mount_Nasmyth_Encoders" WHERE time >= '2021-02-09T14:11:52.594Z' AND time <= '2021-02-09T14:11:54.594Z'
# Current rotator angle = 130.00022583751706
# Sending command
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got False
# Telescope not in position
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -009.875 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -006.205 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -000.992 deg
# Got True
# Waiting for telescope to settle.
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg
# Axes in position.
# 200: SELECT * FROM "efd"."autogen"."lsst.sal.ATMCS.mount_Nasmyth_Encoders" WHERE time >= '2021-02-09T14:12:43.199Z' AND time <= '2021-02-09T14:12:45.199Z'
# Current rotator angle = 120.00002750307613. Set point = 120.0.  Error = 2.7503076125867665e-05
# Sending command
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got False
# Telescope not in position
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -009.813 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -005.908 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -002.143 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -000.156 deg
# Got True
# Waiting for telescope to settle.
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# Axes in position.
# 200: SELECT * FROM "efd"."autogen"."lsst.sal.ATMCS.mount_Nasmyth_Encoders" WHERE time >= '2021-02-09T14:13:35.167Z' AND time <= '2021-02-09T14:13:37.167Z'
# Current rotator angle = 110.00001066389086. Set point = 110.0.  Error = 1.0663890861906111e-05
# Sending command
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got False
# Telescope not in position
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -009.744 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -005.615 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -000.692 deg
# Got True
# Waiting for telescope to settle.
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# Axes in position.
# 200: SELECT * FROM "efd"."autogen"."lsst.sal.ATMCS.mount_Nasmyth_Encoders" WHERE time >= '2021-02-09T14:14:26.205Z' AND time <= '2021-02-09T14:14:28.205Z'
# Current rotator angle = 100.00002288284304. Set point = 100.0.  Error = 2.288284304086119e-05
# Sending command
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got False
# Telescope not in position
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -009.854 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -006.112 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -000.938 deg
# Got True
# Waiting for telescope to settle.
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# Axes in position.
# 200: SELECT * FROM "efd"."autogen"."lsst.sal.ATMCS.mount_Nasmyth_Encoders" WHERE time >= '2021-02-09T14:15:17.196Z' AND time <= '2021-02-09T14:15:19.196Z'
# Current rotator angle = 90.00000716213253. Set point = 90.0.  Error = 7.16213253326714e-06
# Sending command
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got False
# Telescope not in position
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -009.750 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -005.634 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -000.692 deg
# Got True
# Waiting for telescope to settle.
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# Axes in position.
# 200: SELECT * FROM "efd"."autogen"."lsst.sal.ATMCS.mount_Nasmyth_Encoders" WHERE time >= '2021-02-09T14:16:08.188Z' AND time <= '2021-02-09T14:16:10.188Z'
# Current rotator angle = 80.00000909928349. Set point = 80.0.  Error = 9.099283488467336e-06
# Sending command
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got False
# Telescope not in position
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -009.724 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -005.538 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -000.652 deg
# Got True
# Waiting for telescope to settle.
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +000.000 deg
# Axes in position.
# 200: SELECT * FROM "efd"."autogen"."lsst.sal.ATMCS.mount_Nasmyth_Encoders" WHERE time >= '2021-02-09T14:16:59.193Z' AND time <= '2021-02-09T14:17:01.193Z'
# Current rotator angle = 69.99999784890679. Set point = 70.0.  Error = -2.1510932128876448e-06
# Sending command
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got False
# Telescope not in position
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -009.976 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -007.075 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -001.561 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +000.001 deg
# Got True
# Waiting for telescope to settle.
# Axes in position.
# 200: SELECT * FROM "efd"."autogen"."lsst.sal.ATMCS.mount_Nasmyth_Encoders" WHERE time >= '2021-02-09T14:17:49.232Z' AND time <= '2021-02-09T14:17:51.232Z'
# Current rotator angle = 60.000002915316145. Set point = 60.0.  Error = 2.9153161449357867e-06
# Sending command
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got False
# Telescope not in position
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -010.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -009.802 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -005.839 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -000.787 deg
# Got True
# Waiting for telescope to settle.
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# Axes in position.
# 200: SELECT * FROM "efd"."autogen"."lsst.sal.ATMCS.mount_Nasmyth_Encoders" WHERE time >= '2021-02-09T14:18:40.169Z' AND time <= '2021-02-09T14:18:42.169Z'
# Current rotator angle = 50.000012899094145. Set point = 50.0.  Error = 1.2899094144813716e-05
# Sending command
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got False
# Telescope not in position
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -009.790 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -005.813 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -000.786 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# Got True
# Waiting for telescope to settle.
# Axes in position.
# 200: SELECT * FROM "efd"."autogen"."lsst.sal.ATMCS.mount_Nasmyth_Encoders" WHERE time >= '2021-02-09T14:19:30.176Z' AND time <= '2021-02-09T14:19:32.176Z'
# Current rotator angle = 40.00002869432501. Set point = 40.0.  Error = 2.8694325010292232e-05
# Sending command
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got False
# Telescope not in position
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -009.717 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -005.512 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -000.651 deg
# Got True
# Waiting for telescope to settle.
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = +000.000 deg
# Axes in position.
# 200: SELECT * FROM "efd"."autogen"."lsst.sal.ATMCS.mount_Nasmyth_Encoders" WHERE time >= '2021-02-09T14:20:21.167Z' AND time <= '2021-02-09T14:20:23.167Z'
# Current rotator angle = 30.00002169077925. Set point = 30.0.  Error = 2.1690779249183834e-05
# Sending command
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got False
# Telescope not in position
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -009.853 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -007.892 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -002.301 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -000.001 deg
# Got True
# Waiting for telescope to settle.
# Axes in position.
# 200: SELECT * FROM "efd"."autogen"."lsst.sal.ATMCS.mount_Nasmyth_Encoders" WHERE time >= '2021-02-09T14:21:11.178Z' AND time <= '2021-02-09T14:21:13.178Z'
# Current rotator angle = 20.000001052670996. Set point = 20.0.  Error = 1.0526709957048297e-06
# Sending command
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got False
# Telescope not in position
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -009.867 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -006.185 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -000.992 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -000.003 deg
# Got True
# Waiting for telescope to settle.
# Axes in position.
# 200: SELECT * FROM "efd"."autogen"."lsst.sal.ATMCS.mount_Nasmyth_Encoders" WHERE time >= '2021-02-09T14:22:01.179Z' AND time <= '2021-02-09T14:22:03.179Z'
# Current rotator angle = 10.000016847989173. Set point = 10.0.  Error = 1.6847989172674716e-05
# Sending command
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# Scheduling check coroutines
# process as completed...
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# Got False
# Telescope not in position
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -010.000 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = +000.000 deg; delta N2 = -007.645 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = -002.056 deg
# [Telescope] delta Alt = +000.000 deg; delta Az= -000.000 deg; delta N1 = -000.000 deg; delta N2 = +000.001 deg
# Got True
# Waiting for telescope to settle.
# Axes in position.
# 200: SELECT * FROM "efd"."autogen"."lsst.sal.ATMCS.mount_Nasmyth_Encoders" WHERE time >= '2021-02-09T14:22:51.178Z' AND time <= '2021-02-09T14:22:53.178Z'
# Current rotator angle = 1.7220518202520907e-05. Set point = 0.0.  Error = 1.7220518202520907e-05

# %%
# Now check to see if the specs are met:
Aux_Tel_Field_Rotation_Range = 120.0
if min(maxes) > Aux_Tel_Field_Rotation_Range:
    print(f"Aux_Tel_Field_Rotation_Range passed.  Spec = {Aux_Tel_Field_Rotation_Range}.\
    Measured = {min(maxes)} ")
else:
    print(f"Aux_Tel_Field_Rotation_Range failed!  Spec = {Aux_Tel_Field_Rotation_Range}. \
    Measured = {min(maxes)} ")

Aux_Tel_Inst_Rot_Max_Vel = 3.5
if min(speeds) > Aux_Tel_Inst_Rot_Max_Vel:
    print(f"Aux_Tel_Inst_Rot_Max_Vel passed.  Spec = {Aux_Tel_Inst_Rot_Max_Vel}. \
    Measured = {min(speeds)} ")
else:
    print(f"Aux_Tel_Inst_Rot_Max_Vel failed!  Spec = {Aux_Tel_Inst_Rot_Max_Vel}. \
    Measured = {min(speeds)} ")

Aux_Tel_Inst_Rot_Abs_Error = 0.01
if max(errors) < Aux_Tel_Inst_Rot_Abs_Error:
    print(f"Aux_Tel_Inst_Rot_Abs_Error passed.  Spec = {Aux_Tel_Inst_Rot_Abs_Error}. \
    Worst case error = {max(errors)} ")
else:
    print(f"Aux_Tel_Inst_Rot_Abs_Error failed!  Spec = {Aux_Tel_Inst_Rot_Abs_Error}. \
    Worst case error = {max(errors)} ")
# Out:
# Aux_Tel_Field_Rotation_Range passed.  Spec = 120.0.    Measured = 130.00000542920316
# Aux_Tel_Inst_Rot_Max_Vel failed!  Spec = 3.5.     Measured = 2.1721461324
# Aux_Tel_Inst_Rot_Abs_Error passed.  Spec = 0.01.     Worst case error = 6.780998955946416e-05

# %%
# Putting everything back in standby.
# Need to do it one at a time, since ATDome fails with check=False.
# Need to do this first, but it will fail with atimeout
await atcs.stop_tracking()
# Out:
# Stop tracking.
# Unknown tracking state: 9.
# Unknown tracking state: 10.
# In Position: True.
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# <ipython-input-16-708e682974e6> in async-def-wrapper()
#
# ~/WORK/ts_observatory_control/python/lsst/ts/observatory/control/auxtel/atcs.py in stop_tracking(self)
#     382                 self.log.debug(f"In Position: {in_position.inPosition}.")
#     383                 in_position = await self.rem.atmcs.evt_allAxesInPosition.next(
# --> 384                     flush=False, timeout=self.long_timeout
#     385                 )
#     386
#
# /opt/lsst/src/ts_salobj/python/lsst/ts/salobj/topics/read_topic.py in next(self, flush, timeout)
#     631         if flush:
#     632             self.flush()
# --> 633         return await self._next(timeout=timeout)
#     634
#     635     async def _next(self, *, timeout=None):
#
# /opt/lsst/src/ts_salobj/python/lsst/ts/salobj/topics/read_topic.py in _next(self, timeout)
#     643         if self._next_task.done():
#     644             self._next_task = asyncio.Future()
# --> 645         return await asyncio.wait_for(self._next_task, timeout=timeout)
#     646
#     647     async def _callback_loop(self):
#
# /opt/lsst/software/stack/conda/miniconda3-py37_4.8.2/envs/lsst-scipipe-cb4e2dc/lib/python3.7/asyncio/tasks.py in wait_for(fut, timeout, loop)
#     447             # See https://bugs.python.org/issue32751
#     448             await _cancel_and_wait(fut, loop=loop)
# --> 449             raise futures.TimeoutError()
#     450     finally:
#     451         timeout_handle.cancel()
#
# TimeoutError:

# %%
# Putting everything back in standby.
# Need to do it one at a time, since ATDome fails with check=False.
await salobj.set_summary_state(atcs.rem.atmcs, salobj.State.STANDBY)
await salobj.set_summary_state(atcs.rem.ataos, salobj.State.STANDBY)
await salobj.set_summary_state(atcs.rem.atdometrajectory, salobj.State.STANDBY)
await salobj.set_summary_state(atcs.rem.atpneumatics, salobj.State.STANDBY)
await salobj.set_summary_state(atcs.rem.atptg, salobj.State.STANDBY)
await salobj.set_summary_state(atcs.rem.athexapod, salobj.State.STANDBY)
# Out:
# [<State.ENABLED: 2>, <State.DISABLED: 1>, <State.STANDBY: 5>]
