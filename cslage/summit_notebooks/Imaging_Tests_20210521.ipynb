# %%
import sys
import asyncio
import time
import os

import numpy as np

from lsst.ts import salobj

from lsst.ts.observatory.control.auxtel.atcs import ATCS
from lsst.ts.observatory.control.auxtel.latiss import LATISS

# %%
import logging
stream_handler = logging.StreamHandler(sys.stdout)
logger = logging.getLogger()
logger.addHandler(stream_handler)
logger.level = logging.DEBUG

# %%
#Start classes
domain = salobj.Domain()
await asyncio.sleep(10) # This can be removed in the future...
#atcs = ATCS(domain)
latiss = LATISS(domain)
await asyncio.gather(latiss.start_task)
#await asyncio.gather(atcs.start_task, latiss.start_task)
# Out:
# atcamera: Adding all resources.
# atspectrograph: Adding all resources.
# atheaderservice: Adding all resources.
# atarchiver: Adding all resources.
# Read historical data in 0.07 sec
# Read 1 history items for RemoteEvent(ATHeaderService, 0, authList)
# Read 100 history items for RemoteEvent(ATHeaderService, 0, heartbeat)
# Read 1 history items for RemoteEvent(ATHeaderService, 0, logLevel)
# Read 59 history items for RemoteEvent(ATHeaderService, 0, logMessage)
# Read 1 history items for RemoteEvent(ATHeaderService, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATHeaderService, 0, softwareVersions)
# Read 1 history items for RemoteEvent(ATHeaderService, 0, summaryState)
# Read historical data in 0.11 sec
# Read 2 history items for RemoteEvent(ATSpectrograph, 0, appliedSettingsMatchStart)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, authList)
# Read 4 history items for RemoteEvent(ATSpectrograph, 0, disperserInPosition)
# Read 2 history items for RemoteEvent(ATSpectrograph, 0, errorCode)
# Read 6 history items for RemoteEvent(ATSpectrograph, 0, filterInPosition)
# Read 6 history items for RemoteEvent(ATSpectrograph, 0, fwState)
# Read 4 history items for RemoteEvent(ATSpectrograph, 0, gwState)
# Read 100 history items for RemoteEvent(ATSpectrograph, 0, heartbeat)
# Read 2 history items for RemoteEvent(ATSpectrograph, 0, linearStageInPosition)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, logLevel)
# Read 4 history items for RemoteEvent(ATSpectrograph, 0, logMessage)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, lsState)
# Read 3 history items for RemoteEvent(ATSpectrograph, 0, reportedDisperserPosition)
# Read 4 history items for RemoteEvent(ATSpectrograph, 0, reportedFilterPosition)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, reportedLinearStagePosition)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, settingVersions)
# Read 2 history items for RemoteEvent(ATSpectrograph, 0, settingsApplied)
# Read 2 history items for RemoteEvent(ATSpectrograph, 0, settingsAppliedValues)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATSpectrograph, 0, softwareVersions)
# Read 8 history items for RemoteEvent(ATSpectrograph, 0, summaryState)
# Read historical data in 0.13 sec
# Read 1 history items for RemoteEvent(ATCamera, 0, appliedSettingsMatchStart)
# Read 9 history items for RemoteEvent(ATCamera, 0, ccsCommandState)
# Read 1 history items for RemoteEvent(ATCamera, 0, endOfImageTelemetry)
# Read 1 history items for RemoteEvent(ATCamera, 0, endReadout)
# Read 1 history items for RemoteEvent(ATCamera, 0, endShutterClose)
# Read 4 history items for RemoteEvent(ATCamera, 0, focalPlaneHardwareIdSettingsApplied)
# Read 4 history items for RemoteEvent(ATCamera, 0, focalPlaneSummaryInfo)
# Read 100 history items for RemoteEvent(ATCamera, 0, heartbeat)
# Read 4 history items for RemoteEvent(ATCamera, 0, imageReadinessDetailedState)
# Read 1 history items for RemoteEvent(ATCamera, 0, imageReadoutParameters)
# Read 2 history items for RemoteEvent(ATCamera, 0, offlineDetailedState)
# Read 6 history items for RemoteEvent(ATCamera, 0, raftsDetailedState)
# Read 1 history items for RemoteEvent(ATCamera, 0, settingVersions)
# Read 2 history items for RemoteEvent(ATCamera, 0, shutterDetailedState)
# Read 1 history items for RemoteEvent(ATCamera, 0, shutterMotionProfile)
# Read 1 history items for RemoteEvent(ATCamera, 0, softwareVersions)
# Read 1 history items for RemoteEvent(ATCamera, 0, startIntegration)
# Read 1 history items for RemoteEvent(ATCamera, 0, startReadout)
# Read 4 history items for RemoteEvent(ATCamera, 0, summaryState)
# Read historical data in 0.27 sec
# Read 1 history items for RemoteEvent(ATArchiver, 0, authList)
# Read 100 history items for RemoteEvent(ATArchiver, 0, heartbeat)
# Read 1 history items for RemoteEvent(ATArchiver, 0, logLevel)
# Read 1 history items for RemoteEvent(ATArchiver, 0, logMessage)
# Read 1 history items for RemoteEvent(ATArchiver, 0, simulationMode)
# Read 1 history items for RemoteEvent(ATArchiver, 0, softwareVersions)
# Read 1 history items for RemoteEvent(ATArchiver, 0, summaryState)
# [[None, None, None, None]]

# %%
# enable components
#await atcs.enable({"atdome": "current", "ataos": "current", "athexapod": "current"})
await latiss.enable()
# Out:
# Enabling all components
# Gathering settings.
# Couldn't get settingVersions event. Using empty settings.
# Couldn't get settingVersions event. Using empty settings.
# Complete settings for atcamera.
# Complete settings for atspectrograph.
# Complete settings for atheaderservice.
# Complete settings for atarchiver.
# Settings versions: {'atcamera': 'Normal', 'atspectrograph': 'current', 'atheaderservice': '', 'atarchiver': ''}
# [atcamera]::[<State.ENABLED: 2>]
# [atspectrograph]::[<State.STANDBY: 5>, <State.DISABLED: 1>, <State.ENABLED: 2>]
# [atheaderservice]::[<State.STANDBY: 5>, <State.DISABLED: 1>, <State.ENABLED: 2>]
# [atarchiver]::[<State.STANDBY: 5>, <State.DISABLED: 1>, <State.ENABLED: 2>]
# All components in <State.ENABLED: 2>.

# %%
await latiss.take_bias(1)
# Out:
# Generating group_id
# BIAS 0001 - 0001
# array([2021052100001])

# %%
# Take 10 biases seq # 2-11
# Added wait to stop killing the recent images
for i in range(10):
    await asyncio.sleep(2.0)
    await latiss.take_bias(1)
# Out:
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# logMessage DDS read queue is filling: 14 of 100 elements
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001
# Generating group_id
# BIAS 0001 - 0001

# %%
# Take 10 10 second darks 12-21
await latiss.take_darks(10.0, 10)
# Out:
# Generating group_id
# DARK 0001 - 0010
# DARK 0002 - 0010
# DARK 0003 - 0010
# DARK 0004 - 0010
# DARK 0005 - 0010
# DARK 0006 - 0010
# DARK 0007 - 0010
# DARK 0008 - 0010
# DARK 0009 - 0010
# DARK 0010 - 0010
# array([2021052100012, 2021052100013, 2021052100014, 2021052100015,
#        2021052100016, 2021052100017, 2021052100018, 2021052100019,
#        2021052100020, 2021052100021])

# %%
await latiss.take_darks(120.0, 1)
# Out:
# Generating group_id
# DARK 0001 - 0001
# array([2021052100022])

# %%
tmp=await atcs.rem.atmcs.cmd_start.set_start()
print(tmp)

# %%
await salobj.set_summary_state(latiss.rem.atheaderservice, salobj.State.ENABLED)

# %%
tmp=await atcs.rem.atmcs.cmd_start.set_start()
print(tmp)

# %%
await atcs.stop_tracking()

# %%
await salobj.set_summary_state(atcs.rem.atptg, salobj.State.STANDBY)

# %%
await salobj.set_summary_state(atcs.rem.atptg, salobj.State.ENABLED)

# %%
await salobj.set_summary_state(atcs.rem.atmcs, salobj.State.STANDBY)

# %%
await salobj.set_summary_state(atcs.rem.atmcs, salobj.State.ENABLED)

# %%
await latiss.standby()
# Out:
# [atcamera]::[<State.ENABLED: 2>, <State.DISABLED: 1>, <State.STANDBY: 5>]
# [atspectrograph]::[<State.ENABLED: 2>, <State.DISABLED: 1>, <State.STANDBY: 5>]
# [atheaderservice]::[<State.ENABLED: 2>, <State.DISABLED: 1>, <State.STANDBY: 5>]
# [atarchiver]::[<State.ENABLED: 2>, <State.DISABLED: 1>, <State.STANDBY: 5>]
# All components in <State.STANDBY: 5>.

# %%
await atcs.standby()

# %%
await salobj.set_summary_state(atcs.rem.atdome, salobj.State.STANDBY)

# %%
await salobj.set_summary_state(latiss.rem.atarchiver, salobj.State.STANDBY)
