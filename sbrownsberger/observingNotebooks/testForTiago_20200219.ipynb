# %%
import sys
import asyncio
import logging
import time

import numpy as np

from lsst.ts import salobj


from lsst.ts.standardscripts.auxtel.attcs import ATTCS
from lsst.ts.standardscripts.auxtel.latiss import LATISS

# %%
stream_handler = logging.StreamHandler(sys.stdout)
logger = logging.getLogger()
logger.addHandler(stream_handler)
logger.level = logging.DEBUG

# %%
attcs = ATTCS()
latiss = LATISS(attcs.domain)
# Out:
# Read historical data in 0.00 sec
# Read historical data in 0.33 sec

# %%
await attcs.enable()
# Out:
# Gathering settings.
# No settings for atmcs.
# Using                                                                                                                                 from settingVersions event.
# No settings for atptg.
# Couldn't get settingVersions event. Using empty settings.
# No settings for ataos.
# Using current from settingVersions event.
# No settings for atpneumatics.
# Using                                                                                                                                 from settingVersions event.
# No settings for athexapod.
# Couldn't get settingVersions event. Using empty settings.
# No settings for atdome.
# Couldn't get settingVersions event. Using empty settings.
# No settings for atdometrajectory.
# Using  from settingVersions event.
# Settings versions: {'atmcs': '                                                                                                                               ', 'atptg': '', 'ataos': 'current', 'atpneumatics': '                                                                                                                               ', 'athexapod': '', 'atdome': '', 'atdometrajectory': ''}
# Enabling all components
# Enabling  atmcs
# Enabling  atptg
# Enabling  ataos
# Enabling  atpneumatics
# Enabling  athexapod
# Enabling  atdome
# Enabling  atdometrajectory
# [atmcs]::[<State.DISABLED: 1>, <State.ENABLED: 2>]
# [atptg]::[<State.DISABLED: 1>, <State.ENABLED: 2>]
# [ataos]::[<State.DISABLED: 1>, <State.ENABLED: 2>]
# [atpneumatics]::[<State.DISABLED: 1>, <State.ENABLED: 2>]
# [athexapod]::[<State.DISABLED: 1>, <State.ENABLED: 2>]
# [atdome]::[<State.DISABLED: 1>, <State.ENABLED: 2>]
# [atdometrajectory]::[<State.DISABLED: 1>, <State.ENABLED: 2>]
# All components enabled.

# %%
await attcs.shutdown()
# Out:
# Disabling ATAOS corrections
# Disable ATDomeTrajectory
# Slew telescope to Park position.
# Sending command
# Stop tracking.
# Mount tracking state is 10
# Tracking state: 8.
# In Position: False.
# Scheduling check coroutines
# process as completed...
# Got False
# Telescope not in position
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# [Telescope] delta Alt = +040.980 | delta Az= +154.310
# [Telescope] delta Alt = +038.656 | delta Az= +156.656
# [Telescope] delta Alt = +034.654 | delta Az= +160.653
# [Telescope] delta Alt = +030.656 | delta Az= +164.653
# [Telescope] delta Alt = +026.664 | delta Az= +168.653
# [Telescope] delta Alt = +022.708 | delta Az= +172.654
# [Telescope] delta Alt = +020.763 | delta Az= +174.654
# [Telescope] delta Alt = +016.984 | delta Az= +178.653
# [Telescope] delta Alt = +013.414 | delta Az= -177.347
# [Telescope] delta Alt = +010.153 | delta Az= -173.347
# [Telescope] delta Alt = +007.274 | delta Az= -169.347
# [Telescope] delta Alt = +004.846 | delta Az= -165.347
# [Telescope] delta Alt = +002.919 | delta Az= -161.347
# [Telescope] delta Alt = +001.514 | delta Az= -157.346
# [Telescope] delta Alt = +000.618 | delta Az= -153.347
# [Telescope] delta Alt = +000.155 | delta Az= -149.346
# [Telescope] delta Alt = +000.008 | delta Az= -145.346
# [Telescope] delta Alt = -000.000 | delta Az= -141.347
# [Telescope] delta Alt = -000.000 | delta Az= -137.348
# [Telescope] delta Alt = -000.000 | delta Az= -133.346
# [Telescope] delta Alt = -000.000 | delta Az= -129.346
# [Telescope] delta Alt = +000.000 | delta Az= -125.346
# [Telescope] delta Alt = +000.000 | delta Az= -121.347
# [Telescope] delta Alt = +000.000 | delta Az= -117.347
# [Telescope] delta Alt = +000.000 | delta Az= -115.347
# [Telescope] delta Alt = +000.000 | delta Az= -111.346
# [Telescope] delta Alt = +000.000 | delta Az= -107.348
# [Telescope] delta Alt = +000.000 | delta Az= -103.348
# [Telescope] delta Alt = -000.000 | delta Az= -099.347
# [Telescope] delta Alt = +000.000 | delta Az= -095.347
# [Telescope] delta Alt = -000.000 | delta Az= -093.347
# [Telescope] delta Alt = +000.000 | delta Az= -089.346
# [Telescope] delta Alt = -000.000 | delta Az= -087.347
# [Telescope] delta Alt = +000.000 | delta Az= -083.346
# [Telescope] delta Alt = -000.000 | delta Az= -079.346
# [Telescope] delta Alt = +000.000 | delta Az= -075.347
# [Telescope] delta Alt = +000.000 | delta Az= -071.346
# [Telescope] delta Alt = -000.000 | delta Az= -067.346
# [Telescope] delta Alt = +000.000 | delta Az= -063.348
# [Telescope] delta Alt = -000.000 | delta Az= -061.347
# [Telescope] delta Alt = +000.000 | delta Az= -057.346
# [Telescope] delta Alt = -000.000 | delta Az= -053.346
# [Telescope] delta Alt = +000.000 | delta Az= -049.348
# [Telescope] delta Alt = -000.000 | delta Az= -045.347
# [Telescope] delta Alt = +000.000 | delta Az= -043.346
# [Telescope] delta Alt = -000.000 | delta Az= -039.346
# [Telescope] delta Alt = +000.000 | delta Az= -037.346
# [Telescope] delta Alt = -000.000 | delta Az= -033.347
# [Telescope] delta Alt = +000.000 | delta Az= -029.349
# [Telescope] delta Alt = -000.000 | delta Az= -025.363
# [Telescope] delta Alt = -000.000 | delta Az= -021.432
# [Telescope] delta Alt = -000.000 | delta Az= -017.624
# [Telescope] delta Alt = -000.000 | delta Az= -014.015
# [Telescope] delta Alt = -000.000 | delta Az= -010.691
# [Telescope] delta Alt = +000.000 | delta Az= -007.740
# [Telescope] delta Alt = +000.000 | delta Az= -005.230
# [Telescope] delta Alt = +000.000 | delta Az= -003.215
# [Telescope] delta Alt = +000.000 | delta Az= -002.403
# [Telescope] delta Alt = +000.000 | delta Az= -001.168
# [Telescope] delta Alt = +000.000 | delta Az= -000.419
# [Telescope] delta Alt = +000.000 | delta Az= -000.079
# [Telescope] delta Alt = +000.000 | delta Az= -000.001
# Axes in position.
# None
# Stop tracking.
# Mount tracking state is 9
# Tracking state: 10.
# Tracking state: 8.
# In Position: False.
# Cover state <MirrorCoverState.OPENED: 7>
# Closing M1 cover.
# Cover state <MirrorCoverState.OPENED: 7>
# Cover state <MirrorCoverState.DISABLED: 1>
# Cover state <MirrorCoverState.OPENED: 7>
# Cover state <MirrorCoverState.INMOTION: 8>
# Cover state <MirrorCoverState.CLOSED: 6>
# Close dome.
# ATDome Shutter Door is already closed. Ignoring.
# Slew dome to Park position.
# atdometrajectory: <State.DISABLED: 1>
# [Dome] delta Az = -097.990
# [Dome] delta Az = -097.880
# [Dome] delta Az = -097.520
# [Dome] delta Az = -096.920
# [Dome] delta Az = -096.100
# [Dome] delta Az = -095.050
# [Dome] delta Az = -093.770
# [Dome] delta Az = -092.260
# [Dome] delta Az = -090.520
# [Dome] delta Az = -088.540
# [Dome] delta Az = -086.340
# [Dome] delta Az = -083.910
# [Dome] delta Az = -081.260
# [Dome] delta Az = -078.350
# [Dome] delta Az = -075.230
# [Dome] delta Az = -071.910
# [Dome] delta Az = -068.470
# [Dome] delta Az = -065.030
# [Dome] delta Az = -061.590
# [Dome] delta Az = -058.130
# [Dome] delta Az = -054.700
# [Dome] delta Az = -051.250
# [Dome] delta Az = -047.810
# [Dome] delta Az = -044.370
# [Dome] delta Az = -040.910
# [Dome] delta Az = -037.470
# [Dome] delta Az = -034.010
# [Dome] delta Az = -030.560
# [Dome] delta Az = -027.110
# [Dome] delta Az = -023.670
# [Dome] delta Az = -020.220
# [Dome] delta Az = -016.770
# [Dome] delta Az = -013.340
# [Dome] delta Az = -009.900
# [Dome] delta Az = -006.470
# [Dome] delta Az = -003.050
# ATDome in position.
# Put all CSCs in standby
# RemoteEvent(ATDome, 0, settingVersions) falling behind; read 84 messages
# RemoteEvent(ATHexapod, 0, settingVersions) falling behind; read 64 messages
# [atmcs]::[<State.ENABLED: 2>, <State.DISABLED: 1>, <State.STANDBY: 5>]
# [atptg]::[<State.ENABLED: 2>, <State.DISABLED: 1>, <State.STANDBY: 5>]
# [ataos]::[<State.ENABLED: 2>, <State.DISABLED: 1>, <State.STANDBY: 5>]
# [atpneumatics]::[<State.ENABLED: 2>, <State.DISABLED: 1>, <State.STANDBY: 5>]
# [athexapod]::[<State.ENABLED: 2>, <State.DISABLED: 1>, <State.STANDBY: 5>]
# [atdome]::[<State.ENABLED: 2>, <State.DISABLED: 1>, <State.STANDBY: 5>]
# [atdometrajectory]::[<State.DISABLED: 1>, <State.STANDBY: 5>]
# All components in standby.

# %%
await attcs.enable()
# Out:
# Gathering settings.
# No settings for atmcs.
# Using                                                                                                                                 from settingVersions event.
# No settings for atptg.
# Couldn't get settingVersions event. Using empty settings.
# No settings for ataos.
# Using current from settingVersions event.
# No settings for atpneumatics.
# Using                                                                                                                                 from settingVersions event.
# No settings for athexapod.
# Using current from settingVersions event.
# No settings for atdome.
# Using test from settingVersions event.
# No settings for atdometrajectory.
# Using  from settingVersions event.
# Settings versions: {'atmcs': '                                                                                                                               ', 'atptg': '', 'ataos': 'current', 'atpneumatics': '                                                                                                                               ', 'athexapod': 'current', 'atdome': 'test', 'atdometrajectory': ''}
# Enabling all components
# Enabling  atmcs
# Enabling  atptg
# Enabling  ataos
# Enabling  atpneumatics
# Enabling  athexapod
# Enabling  atdome
# Enabling  atdometrajectory
# [atmcs]::[<State.STANDBY: 5>, <State.DISABLED: 1>, <State.ENABLED: 2>]
# [atptg]::[<State.STANDBY: 5>, <State.DISABLED: 1>, <State.ENABLED: 2>]
# [ataos]::[<State.STANDBY: 5>, <State.DISABLED: 1>, <State.ENABLED: 2>]
# [atpneumatics]::[<State.STANDBY: 5>, <State.DISABLED: 1>, <State.ENABLED: 2>]
# [athexapod]::[<State.STANDBY: 5>, <State.DISABLED: 1>, <State.ENABLED: 2>]
# [atdome]::[<State.STANDBY: 5>, <State.DISABLED: 1>, <State.ENABLED: 2>]
# [atdometrajectory]::[<State.STANDBY: 5>, <State.DISABLED: 1>, <State.ENABLED: 2>]
# All components enabled.

# %%
await attcs.prepare_for_flatfield()
# Out:
# Cover state <MirrorCoverState.CLOSED: 6>
# Opening M1 cover.
# Cover state <MirrorCoverState.DISABLED: 1>
# Cover state <MirrorCoverState.STANDBY: 5>
# Cover state <MirrorCoverState.DISABLED: 1>
# Cover state <MirrorCoverState.CLOSED: 6>
# Cover state <MirrorCoverState.INMOTION: 8>
# Cover state <MirrorCoverState.OPENED: 7>
# Sending command
# Stop tracking.
# Mount tracking state is 10
# Tracking state: 6.
# Tracking state: 5.
# Tracking state: 6.
# Tracking state: 10.
# Scheduling check coroutines
# process as completed...
# Got False
# Telescope not in position
# atmcs: <State.ENABLED: 2>
# atptg: <State.ENABLED: 2>
# ataos: <State.ENABLED: 2>
# atpneumatics: <State.ENABLED: 2>
# athexapod: <State.ENABLED: 2>
# [Telescope] delta Alt = -040.902 | delta Az= -154.371
# [Telescope] delta Alt = -038.061 | delta Az= -157.159
# [Telescope] delta Alt = -034.063 | delta Az= -161.156
# [Telescope] delta Alt = -030.063 | delta Az= -165.155
# [Telescope] delta Alt = -026.072 | delta Az= -169.155
# [Telescope] delta Alt = -022.129 | delta Az= -173.155
# [Telescope] delta Alt = -018.292 | delta Az= -177.156
# [Telescope] delta Alt = -014.639 | delta Az= +178.845
# [Telescope] delta Alt = -012.914 | delta Az= +176.845
# [Telescope] delta Alt = -009.700 | delta Az= +172.844
# [Telescope] delta Alt = -006.880 | delta Az= +168.845
# [Telescope] delta Alt = -004.526 | delta Az= +164.844
# [Telescope] delta Alt = -002.673 | delta Az= +160.843
# [Telescope] delta Alt = -001.351 | delta Az= +156.845
# [Telescope] delta Alt = -000.520 | delta Az= +152.845
# [Telescope] delta Alt = -000.272 | delta Az= +150.844
# [Telescope] delta Alt = -000.033 | delta Az= +146.845
# [Telescope] delta Alt = -000.003 | delta Az= +144.844
# [Telescope] delta Alt = +000.000 | delta Az= +140.845
# [Telescope] delta Alt = +000.000 | delta Az= +136.845
# [Telescope] delta Alt = -000.000 | delta Az= +132.844
# [Telescope] delta Alt = -000.000 | delta Az= +128.844
# [Telescope] delta Alt = +000.000 | delta Az= +124.845
# [Telescope] delta Alt = -000.000 | delta Az= +120.845
# [Telescope] delta Alt = +000.000 | delta Az= +116.845
# [Telescope] delta Alt = -000.000 | delta Az= +112.846
# [Telescope] delta Alt = -000.000 | delta Az= +108.844
# [Telescope] delta Alt = +000.000 | delta Az= +104.845
# [Telescope] delta Alt = +000.000 | delta Az= +102.845
# [Telescope] delta Alt = +000.000 | delta Az= +098.845
# [Telescope] delta Alt = -000.000 | delta Az= +094.845
# [Telescope] delta Alt = +000.000 | delta Az= +090.845
# [Telescope] delta Alt = -000.000 | delta Az= +086.844
# [Telescope] delta Alt = -000.000 | delta Az= +082.845
# [Telescope] delta Alt = -000.000 | delta Az= +080.845
# [Telescope] delta Alt = -000.000 | delta Az= +076.845
# [Telescope] delta Alt = -000.000 | delta Az= +072.844
# [Telescope] delta Alt = -000.000 | delta Az= +068.845
# [Telescope] delta Alt = +000.000 | delta Az= +064.845
# [Telescope] delta Alt = +000.000 | delta Az= +060.845
# [Telescope] delta Alt = -000.000 | delta Az= +056.845
# [Telescope] delta Alt = -000.000 | delta Az= +052.845
# [Telescope] delta Alt = +000.000 | delta Az= +048.844
# [Telescope] delta Alt = -000.000 | delta Az= +044.846
# [Telescope] delta Alt = +000.000 | delta Az= +040.845
# [Telescope] delta Alt = +000.000 | delta Az= +036.844
# [Telescope] delta Alt = +000.000 | delta Az= +032.845
# [Telescope] delta Alt = +000.000 | delta Az= +028.846
# [Telescope] delta Alt = +000.000 | delta Az= +024.865
# [Telescope] delta Alt = +000.000 | delta Az= +022.894
# [Telescope] delta Alt = +000.000 | delta Az= +019.030
# [Telescope] delta Alt = -000.000 | delta Az= +017.157
# [Telescope] delta Alt = +000.000 | delta Az= +013.580
# [Telescope] delta Alt = +000.000 | delta Az= +010.299
# [Telescope] delta Alt = +000.000 | delta Az= +007.399
# [Telescope] delta Alt = +000.000 | delta Az= +004.949
# [Telescope] delta Alt = +000.000 | delta Az= +002.998
# [Telescope] delta Alt = +000.000 | delta Az= +002.219
# [Telescope] delta Alt = +000.000 | delta Az= +001.048
# [Telescope] delta Alt = +000.000 | delta Az= +000.358
# [Telescope] delta Alt = +000.000 | delta Az= +000.058
# [Telescope] delta Alt = +000.000 | delta Az= +000.000
# Axes in position.
# None
# Stop tracking.
# Mount tracking state is 9
# Tracking state: 10.
# Tracking state: 8.
# In Position: False.
# atdometrajectory: <State.DISABLED: 1>
# [Dome] delta Az = +097.930
# [Dome] delta Az = +097.820
# [Dome] delta Az = +097.470
# [Dome] delta Az = +096.890
# [Dome] delta Az = +096.080
# [Dome] delta Az = +095.040
# [Dome] delta Az = +093.760
# [Dome] delta Az = +092.250
# [Dome] delta Az = +090.520
# [Dome] delta Az = +088.540
# [Dome] delta Az = +086.360
# [Dome] delta Az = +083.920
# [Dome] delta Az = +081.290
# [Dome] delta Az = +078.390
# [Dome] delta Az = +075.270
# [Dome] delta Az = +071.970
# [Dome] delta Az = +068.510
# [Dome] delta Az = +065.080
# [Dome] delta Az = +061.620
# [Dome] delta Az = +058.170
# [Dome] delta Az = +054.720
# [Dome] delta Az = +051.270
# [Dome] delta Az = +047.860
# [Dome] delta Az = +044.410
# [Dome] delta Az = +040.950
# [Dome] delta Az = +037.510
# [Dome] delta Az = +034.060
# [Dome] delta Az = +030.620
# [Dome] delta Az = +027.180
# [Dome] delta Az = +023.730
# [Dome] delta Az = +020.310
# [Dome] delta Az = +016.870
# [Dome] delta Az = +013.430
# [Dome] delta Az = +009.980
# [Dome] delta Az = +006.540
# [Dome] delta Az = +003.160
# ATDome in position.
# RemoteEvent(ATHeaderService, 0, logMessage) falling behind; read 10 messages
# RemoteEvent(ATHeaderService, 0, logMessage) falling behind; read 10 messages
# RemoteEvent(ATHeaderService, 0, logMessage) falling behind; read 12 messages
# RemoteEvent(ATHeaderService, 0, logMessage) falling behind; read 18 messages
# RemoteEvent(ATHeaderService, 0, logMessage) falling behind; read 12 messages
# RemoteEvent(ATHeaderService, 0, logMessage) falling behind; read 10 messages
# RemoteEvent(ATHeaderService, 0, logMessage) falling behind; read 13 messages
# RemoteEvent(ATHeaderService, 0, logMessage) falling behind; read 73 messages
# RemoteEvent(ATHeaderService, 0, logMessage) falling behind; read 10 messages
# RemoteEvent(ATHeaderService, 0, logMessage) falling behind; read 10 messages
# RemoteEvent(ATHeaderService, 0, logMessage) falling behind; read 11 messages
# RemoteEvent(ATHeaderService, 0, logMessage) falling behind; read 11 messages
# RemoteEvent(ATHeaderService, 0, logMessage) falling behind; read 15 messages
# RemoteEvent(ATHeaderService, 0, logMessage) falling behind; read 13 messages
