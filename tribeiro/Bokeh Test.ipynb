# %%
from bokeh.plotting import figure 
from bokeh.io import output_notebook, show

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
from numpy import cos, linspace
x = linspace(-6, 6, 100)
y = cos(x)

# %%
p = figure(width=500, height=500)
p.circle(x, y, size=7, color="firebrick", alpha=0.5)
show(p)
# Out:
#   <div class="bk-root" id="abd3aa81-9bd0-4b13-9840-9d2fac451e9a" data-root-id="1002"></div>

# %%
import time
import numpy as np

# %%
from bokeh.models.sources import ColumnDataSource
from bokeh.plotting import figure
from bokeh.io import output_notebook, show, push_notebook

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
x = np.arange(10)
y = np.random.rand(10)

# %%
np.random.rand()
# Out:
# 0.3256389090326496

# %%
my_figure = figure(plot_width=400, plot_height=200)

data = {'x': x,
        'y': y}

test_data = ColumnDataSource(data=data)

line = my_figure.circle("x", "y", source=test_data)

handle = show(my_figure, notebook_handle=True)
# Out:
#   <div class="bk-root" id="6ec27021-0b40-401f-a952-ace1b3a4feb1" data-root-id="1255"></div>

# %%
for i in range(10):
    new_data = {
        'x' : np.array([10+i]),
        'y' : np.array([np.random.rand()]),
    }
    
    print(new_data)
    test_data.stream(new_data, 300)
    push_notebook(handle=handle)
#     handle = show(my_figure, notebook_handle=True)
    time.sleep(.5)
# Out:
# {'x': array([10]), 'y': array([0.72272033])}
# {'x': array([11]), 'y': array([0.91973423])}
# {'x': array([12]), 'y': array([0.63376483])}
# {'x': array([13]), 'y': array([0.11726242])}
# {'x': array([14]), 'y': array([0.60142547])}
# {'x': array([15]), 'y': array([0.17604379])}
# {'x': array([16]), 'y': array([0.54232683])}
# {'x': array([17]), 'y': array([0.06497175])}
# {'x': array([18]), 'y': array([0.96039475])}
# {'x': array([19]), 'y': array([0.14183375])}

# %%
my_figure.title.text = "New Title"
push_notebook(handle=handle)

# %%
plot = figure(plot_width=400, plot_height=200)
plot.circle([1,2,3], [4,6,5])
plot.title.text = "Old Title"
handle = show(plot, notebook_handle=True)

# Update the plot title in the earlier cell
# Out:
#   <div class="bk-root" id="6b500ed8-33e7-4a33-9be9-53257e17235e" data-root-id="6411"></div>

# %%
plot.title.text = "New Title"
push_notebook(handle=handle)
