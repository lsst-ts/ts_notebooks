# %%
import logging
import asyncio
from lsst.ts.salobj import Remote, State

import SALPY_ATMCS
import SALPY_ATPtg

# %%
log_format = "%(asctime)s - %(levelname)s - %(name)s - %(message)s"
log = logging.getLogger("monitor")
logging.basicConfig(level=logging.DEBUG, format=log_format)

# %%
atmcs = Remote(SALPY_ATMCS) 
atptg = Remote(SALPY_ATPtg)

# %%
def get_log_callback_for(component):
    def monitor_log_callback(id_data):
        log.log(id_data.level, f"::{component}::{id_data.message}")
    return monitor_log_callback

def get_error_callback_for(component):
    
    def monitor_error_callback(id_data):
        log.error(f"::{component}::{id_data.errorReport}")
        log.exception(f"::{component}::\n{id_data.traceback}\n::{component}::")

    return monitor_error_callback

def get_summary_state_callback_for(component):

    def monitor_summary_state_callback(id_data):
        log.debug(f"::{component}:: {State(id_data.summaryState)!s}")

    return monitor_summary_state_callback

# %%
atmcs.evt_errorCode.callback = get_error_callback_for("ATMCS")
atmcs.evt_logMessage.callback = get_log_callback_for("ATMCS")
atmcs.evt_summaryState.callback = get_summary_state_callback_for("ATMCS")

atptg.evt_errorCode.callback = get_error_callback_for("ATPtg")
atptg.evt_logMessage.callback = get_log_callback_for("ATPtg")
atptg.evt_summaryState.callback = get_summary_state_callback_for("ATPtg")

# %%
asyncio.get_event_loop().run_forever()
# Out:
# 2019-04-26 14:57:38,857 - DEBUG - monitor - ::ATMCS:: State.DISABLED
# 2019-04-26 14:57:38,961 - DEBUG - monitor - ::ATPtg:: State.DISABLED
# 2019-04-26 14:57:47,346 - DEBUG - monitor - ::ATMCS:: State.ENABLED
# 2019-04-26 14:57:47,449 - DEBUG - monitor - ::ATPtg:: State.ENABLED
# 2019-04-26 21:36:13,202 - ERROR - monitor - ::ATPtg::elevation out of range
# 2019-04-26 21:36:13,205 - ERROR - monitor - ::ATPtg::
#
# ::ATPtg::
# NoneType: None
# 2019-04-26 21:36:13,211 - DEBUG - monitor - ::ATPtg:: State.FAULT
# 2019-04-26 21:36:15,763 - ERROR - monitor - ::ATMCS::trackTarget not seen in 2.5 sec
# 2019-04-26 21:36:15,764 - ERROR - monitor - ::ATMCS::
#
# ::ATMCS::
# NoneType: None
# 2019-04-26 21:36:15,767 - DEBUG - monitor - ::ATMCS:: State.FAULT
# 2019-04-26 21:56:42,791 - DEBUG - monitor - ::ATMCS:: State.STANDBY
# 2019-04-26 21:57:36,160 - ERROR - monitor - ::ATPtg::
# 2019-04-26 21:57:36,161 - ERROR - monitor - ::ATPtg::
#
# ::ATPtg::
# NoneType: None
# 2019-04-26 21:57:36,169 - DEBUG - monitor - ::ATPtg:: State.STANDBY
# 2019-04-26 22:22:10,915 - DEBUG - monitor - ::ATMCS:: State.DISABLED
# 2019-04-26 22:22:11,072 - DEBUG - monitor - ::ATPtg:: State.DISABLED
# 2019-04-26 22:22:11,172 - ERROR - monitor - ::ATPtg::Error ATMCS replied error for stopTracking command (846930886) Ack no: -302 Error no:1 message:Failed: stopTracking not allowed in state <State.DISABLED: 1>
# 2019-04-26 22:22:11,174 - ERROR - monitor - ::ATPtg::
#
# ::ATPtg::
# NoneType: None
# 2019-04-26 22:22:11,180 - DEBUG - monitor - ::ATPtg:: State.FAULT
# 2019-04-26 22:22:13,371 - DEBUG - monitor - ::ATMCS:: State.ENABLED
# 2019-04-26 22:23:28,772 - ERROR - monitor - ::ATPtg::
# 2019-04-26 22:23:28,773 - ERROR - monitor - ::ATPtg::
#
# ::ATPtg::
# NoneType: None
# 2019-04-26 22:23:28,775 - DEBUG - monitor - ::ATPtg:: State.STANDBY
# 2019-04-26 22:24:18,045 - DEBUG - monitor - ::ATPtg:: State.DISABLED
# 2019-04-26 22:24:21,079 - DEBUG - monitor - ::ATPtg:: State.ENABLED
# 2019-04-26 23:00:49,342 - DEBUG - monitor - ::ATMCS:: State.DISABLED
# 2019-04-26 23:01:42,163 - DEBUG - monitor - ::ATPtg:: State.DISABLED
# 2019-04-26 23:01:45,701 - DEBUG - monitor - ::ATMCS:: State.STANDBY
# 2019-04-26 23:01:45,973 - ERROR - monitor - ::ATPtg::
# 2019-04-26 23:01:45,975 - ERROR - monitor - ::ATPtg::
#
# ::ATPtg::
# NoneType: None
# 2019-04-26 23:01:46,011 - DEBUG - monitor - ::ATPtg:: State.STANDBY
# 2019-04-26 23:02:04,986 - DEBUG - monitor - ::ATMCS:: State.DISABLED
# 2019-04-26 23:02:05,145 - DEBUG - monitor - ::ATPtg:: State.DISABLED
# 2019-04-26 23:02:09,692 - DEBUG - monitor - ::ATMCS:: State.ENABLED
# 2019-04-26 23:02:09,744 - DEBUG - monitor - ::ATPtg:: State.ENABLED
# 2019-04-26 23:04:16,375 - DEBUG - monitor - ::ATMCS:: State.DISABLED
# 2019-04-26 23:04:39,731 - DEBUG - monitor - ::ATPtg:: State.DISABLED
# 2019-04-26 23:04:39,966 - DEBUG - monitor - ::ATMCS:: State.STANDBY
# 2019-04-26 23:04:40,156 - DEBUG - monitor - ::ATPtg:: State.STANDBY
# 2019-04-26 23:04:40,178 - ERROR - monitor - ::ATPtg::
# 2019-04-26 23:04:40,183 - ERROR - monitor - ::ATPtg::
#
# ::ATPtg::
# NoneType: None
# 2019-04-26 23:04:57,612 - DEBUG - monitor - ::ATMCS:: State.OFFLINE
# 2019-04-26 23:06:23,608 - DEBUG - monitor - ::ATMCS:: State.STANDBY
# 2019-04-26 23:06:24,792 - ERROR - monitor - ::ATPtg::
# 2019-04-26 23:06:24,794 - ERROR - monitor - ::ATPtg::
#
# ::ATPtg::
# NoneType: None
# 2019-04-26 23:06:24,801 - DEBUG - monitor - ::ATPtg:: State.STANDBY
# 2019-04-26 23:06:47,514 - DEBUG - monitor - ::ATMCS:: State.DISABLED
# 2019-04-26 23:06:47,576 - DEBUG - monitor - ::ATPtg:: State.DISABLED
# 2019-04-26 23:08:51,843 - DEBUG - monitor - ::ATMCS:: State.ENABLED
# 2019-04-26 23:08:55,850 - DEBUG - monitor - ::ATPtg:: State.ENABLED
# 2019-04-26 23:15:07,557 - DEBUG - monitor - ::ATMCS:: State.DISABLED
# 2019-04-26 23:16:00,496 - DEBUG - monitor - ::ATPtg:: State.DISABLED
# 2019-04-26 23:16:00,597 - DEBUG - monitor - ::ATMCS:: State.STANDBY
# 2019-04-26 23:16:00,915 - DEBUG - monitor - ::ATPtg:: State.STANDBY
# 2019-04-26 23:16:00,921 - ERROR - monitor - ::ATPtg::
# 2019-04-26 23:16:00,922 - ERROR - monitor - ::ATPtg::
#
# ::ATPtg::
# NoneType: None
# 2019-04-26 23:16:00,974 - DEBUG - monitor - ::ATMCS:: State.OFFLINE
# 2019-04-26 23:16:51,472 - DEBUG - monitor - ::ATMCS:: State.STANDBY
# 2019-04-26 23:16:57,224 - DEBUG - monitor - ::ATPtg:: State.STANDBY
# 2019-04-26 23:16:57,237 - ERROR - monitor - ::ATPtg::
# 2019-04-26 23:16:57,241 - ERROR - monitor - ::ATPtg::
#
# ::ATPtg::
# NoneType: None
# 2019-04-26 23:18:00,660 - DEBUG - monitor - ::ATMCS:: State.DISABLED
# 2019-04-26 23:18:00,762 - DEBUG - monitor - ::ATPtg:: State.DISABLED
# 2019-04-26 23:18:00,765 - DEBUG - monitor - ::ATPtg:: State.FAULT
# 2019-04-26 23:18:00,766 - ERROR - monitor - ::ATPtg::No such node (azimuth_low_limit)
# 2019-04-26 23:18:00,768 - ERROR - monitor - ::ATPtg::
#
# ::ATPtg::
# NoneType: None
# 2019-04-26 23:18:07,336 - DEBUG - monitor - ::ATMCS:: State.ENABLED
# 2019-04-26 23:18:45,163 - ERROR - monitor - ::ATPtg::
# 2019-04-26 23:18:45,165 - ERROR - monitor - ::ATPtg::
#
# ::ATPtg::
# NoneType: None
# 2019-04-26 23:18:45,183 - DEBUG - monitor - ::ATPtg:: State.STANDBY
# 2019-04-26 23:19:14,584 - DEBUG - monitor - ::ATPtg:: State.STANDBY
# 2019-04-26 23:19:14,597 - ERROR - monitor - ::ATPtg::
# 2019-04-26 23:19:14,599 - ERROR - monitor - ::ATPtg::
#
# ::ATPtg::
# NoneType: None
# 2019-04-26 23:20:44,164 - DEBUG - monitor - ::ATMCS:: State.DISABLED
# 2019-04-26 23:20:47,072 - DEBUG - monitor - ::ATMCS:: State.STANDBY
# 2019-04-26 23:20:52,389 - DEBUG - monitor - ::ATMCS:: State.DISABLED
# 2019-04-26 23:20:52,573 - DEBUG - monitor - ::ATPtg:: State.DISABLED
# 2019-04-26 23:21:16,331 - DEBUG - monitor - ::ATMCS:: State.ENABLED
# 2019-04-26 23:21:48,694 - DEBUG - monitor - ::ATPtg:: State.ENABLED
# 2019-04-26 23:24:54,860 - DEBUG - monitor - ::ATMCS:: State.DISABLED
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-a18ce17cfdf0> in <module>
# ----> 1 asyncio.get_event_loop().run_forever()
#
# /opt/lsst/software/stack/python/miniconda3-4.5.4/envs/lsst-scipipe-fcd27eb/lib/python3.6/asyncio/base_events.py in run_forever(self)
#     420             events._set_running_loop(self)
#     421             while True:
# --> 422                 self._run_once()
#     423                 if self._stopping:
#     424                     break
#
# /opt/lsst/software/stack/python/miniconda3-4.5.4/envs/lsst-scipipe-fcd27eb/lib/python3.6/asyncio/base_events.py in _run_once(self)
#    1432                     self._current_handle = None
#    1433             else:
# -> 1434                 handle._run()
#    1435         handle = None  # Needed to break cycles when an exception occurs.
#    1436
#
# /opt/lsst/software/stack/python/miniconda3-4.5.4/envs/lsst-scipipe-fcd27eb/lib/python3.6/asyncio/events.py in _run(self)
#     143     def _run(self):
#     144         try:
# --> 145             self._callback(*self._args)
#     146         except Exception as exc:
#     147             cb = _format_callback_source(self._callback, self._args)
#
# /opt/lsst/software/stack/python/miniconda3-4.5.4/envs/lsst-scipipe-fcd27eb/lib/python3.6/asyncio/futures.py in _set_result_unless_cancelled(fut, result)
#     341     if fut.cancelled():
#     342         return
# --> 343     fut.set_result(result)
#     344
#     345
#
# /opt/lsst/software/stack/python/miniconda3-4.5.4/envs/lsst-scipipe-fcd27eb/lib/python3.6/asyncio/base_events.py in call_soon(self, callback, *args)
#     577             self._check_thread()
#     578             self._check_callback(callback, 'call_soon')
# --> 579         handle = self._call_soon(callback, args)
#     580         if handle._source_traceback:
#     581             del handle._source_traceback[-1]
#
# /opt/lsst/software/stack/python/miniconda3-4.5.4/envs/lsst-scipipe-fcd27eb/lib/python3.6/asyncio/base_events.py in _call_soon(self, callback, args)
#     597         if handle._source_traceback:
#     598             del handle._source_traceback[-1]
# --> 599         self._ready.append(handle)
#     600         return handle
#     601
#
# KeyboardInterrupt:
