# %% [markdown]
# # Pointing Model Utility

# %% [markdown]
# This notebook is intended to help building initial pointing model for the Auxiliary Telescope.
#
# The user can define a grid of Az/El pointings that will be converted to RA/Dec target commands to the ATPtg. For each pointing the user can center the target and register the pointing throught ATPtg. The data can then be saved and used as input to TPOINT to compute pointing model parameters.
#
# Initially the process is very interactive. Once the process is well stablished we can turn this into a more automated process.

# %% [markdown]
# ## Building Az/El pointing grid.

# %%
import numpy as np

import asyncio 

import matplotlib.pyplot as plt

import astropy.units as u
from astropy.time import Time
from astropy.coordinates import SkyCoord, AltAz, ICRS, EarthLocation, Angle
from astroquery.vo_conesearch import ConeSearch
from astroquery.simbad import Simbad

import ipywidgets as widgets

import SALPY_ATPtg
import SALPY_ATMCS

from lsst.ts import salobj

# %matplotlib inline

# %%
# %%script bash
# make_salpy_libs.py ATPtg ATMCS
# Out:
# argv = ATPtg validate
# SAL generator - 3.9.2
# Processing ATPtg
# Add Generic Commands and Events
# Translating ATPtg_prospectiveTargetStatus
# Translating ATPtg_nextTargetStatus
# Translating ATPtg_currentTimesToLimits
# Translating ATPtg_currentTargetStatus
# Translating ATPtg_guidingAndOffsets
# Translating ATPtg_prospectiveTimesToLimits
# Translating ATPtg_timeAndDate
# Translating ATPtg_mountStatus
# Translating ATPtg_nextTimesToLimits
# itemid for /home/saluser/repos/ts_sal/test/idl-templates/ATPtg_nextTimesToLimits.idl=  7
# Generating telemetry gui input
# Generating html telemetry table ATPtg
# Imported ATPtg Telemetry interface definitions
# Translating ATPtg_command_pointCloseFile
# Translating ATPtg_command_poriginAbsorb
# Translating ATPtg_command_guideClear
# Translating ATPtg_command_collOffset
# Translating ATPtg_command_rotOffset
# Translating ATPtg_command_clearCollOffset
# Translating ATPtg_command_poriginXY
# Translating ATPtg_command_iersUpdate
# Translating ATPtg_command_offsetRADec
# Translating ATPtg_command_pointAddData
# Translating ATPtg_command_guideControl
# Translating ATPtg_command_offsetAbsorb
# Translating ATPtg_command_ephemTarget
# Translating ATPtg_command_wavelength
# Translating ATPtg_command_pointLoadModel
# Translating ATPtg_command_azCurrentWrap
# Translating ATPtg_command_debugLevel
# Translating ATPtg_command_raDecTarget
# Translating ATPtg_command_offsetPA
# Translating ATPtg_command_rotCurrentWrap
# Translating ATPtg_command_poriginOffset
# Translating ATPtg_command_offsetClear
# Translating ATPtg_command_offsetAzEl
# Translating ATPtg_command_setAccessMode
# Translating ATPtg_command_azElTarget
# Translating ATPtg_command_copyTarget
# Translating ATPtg_command_planetTarget
# Translating ATPtg_command_pointNewFile
# Translating ATPtg_command_poriginClear
# Translating ATPtg_command_focusName
# Translating ATPtg_command_amLimitSet
# Translating ATPtg_command_guideAutoclear
# Translating ATPtg_command_stopTracking
# itemid for /home/saluser/repos/ts_sal/test/idl-templates/ATPtg_command_stopTracking.idl=  1
# Generating test command gui input
# Generating html command table ATPtg
# Generating telemetry gui input
# Generating html telemetry table ATPtg
# Imported ATPtg Commands interface definitions
# Translating ATPtg_logevent_focusNameSelected
# Translating ATPtg_logevent_settingsApplied
# Translating ATPtg_logevent_sunProximityWarning
# Translating ATPtg_logevent_detailedState
# Translating ATPtg_logevent_mountGuideMode
# Translating ATPtg_logevent_azWrapWarning
# Translating ATPtg_logevent_wavelength
# Translating ATPtg_logevent_inPositionEl
# Translating ATPtg_logevent_inBlindSpot
# Translating ATPtg_logevent_blindSpotWarning
# Translating ATPtg_logevent_axesTrackMode
# Translating ATPtg_logevent_objectSetWarning
# Translating ATPtg_logevent_pointingModel
# Translating ATPtg_logevent_airmassWarning
# Translating ATPtg_logevent_weatherDataInvalid
# Translating ATPtg_logevent_focusNameInconsistentWarning
# Translating ATPtg_logevent_currentTarget
# Translating ATPtg_logevent_iersOutOfDate
# Translating ATPtg_logevent_weatherDataApplied
# Translating ATPtg_logevent_currentDebugLevel
# Translating ATPtg_logevent_nextTarget
# Translating ATPtg_logevent_mountDataWarning
# Translating ATPtg_logevent_accessMode
# Translating ATPtg_logevent_rotWrapWarning
# Translating ATPtg_logevent_inPosition
# Translating ATPtg_logevent_inPositionRot
# Translating ATPtg_logevent_inPositionAz
# Translating ATPtg_logevent_iers
# Translating ATPtg_logevent_prospectiveTarget
# Translating ATPtg_logevent_moonProximityWarning
# Translating ATPtg_logevent_trackPosting
# Translating ATPtg_logevent_ptgAzCurrentWrap
# Translating ATPtg_logevent_ptgRotCurrentWrap
# itemid for /home/saluser/repos/ts_sal/test/idl-templates/ATPtg_logevent_ptgRotCurrentWrap.idl=  1
# Generating test command gui input
# Generating html command table ATPtg
# Generating test event gui input
# Generating html logevent table ATPtg
# Generating telemetry gui input
# Generating html telemetry table ATPtg
# Imported ATPtg Events interface definitions
# Translating ATPtg_command_abort
# Translating ATPtg_command_enable
# Translating ATPtg_command_disable
# Translating ATPtg_command_standby
# Translating ATPtg_command_exitControl
# Translating ATPtg_command_start
# Translating ATPtg_command_enterControl
# Translating ATPtg_command_setLogLevel
# Translating ATPtg_command_setSimulationMode
# Translating ATPtg_command_setValue
# Translating ATPtg_logevent_settingVersions
# Translating ATPtg_logevent_errorCode
# Translating ATPtg_logevent_summaryState
# Translating ATPtg_logevent_appliedSettingsMatchStart
# Translating ATPtg_logevent_logLevel
# Translating ATPtg_logevent_logMessage
# Translating ATPtg_logevent_simulationMode
# itemid for /home/saluser/repos/ts_sal/test/idl-templates/ATPtg_logevent_simulationMode.idl=  1
# Generating test command gui input
# Generating html command table ATPtg
# Generating test event gui input
# Generating html logevent table ATPtg
# Generating telemetry gui input
# Generating html telemetry table ATPtg
# Imported ATPtg Generics interface definitions
# Validating ATPtg interface IDL format definitions
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_abort.idl
# --->  struct ATPtg_command_abort {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  boolean value
# doitem 6 file4 value boolean 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_abort
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_amLimitSet.idl
# --->  struct ATPtg_command_amLimitSet {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  double amlimit
# doitem 6 file4 amlimit double 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_amLimitSet
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_azCurrentWrap.idl
# --->  struct ATPtg_command_azCurrentWrap {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  long wrap
# doitem 6 file4 wrap long 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_azCurrentWrap
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_azElTarget.idl
# --->  struct ATPtg_command_azElTarget {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  string targetName
# doitem 6 file4 targetName string 4096 | |  |
# --->  long targetInstance
# doitem 7 file4 targetInstance long 1 | |  |
# --->  double azDegs
# doitem 8 file4 azDegs double 1 | |  |
# --->  double elDegs
# doitem 9 file4 elDegs double 1 | |  |
# --->  long trackId
# doitem 10 file4 trackId long 1 | |  |
# --->  double rotPA
# doitem 11 file4 rotPA double 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_azElTarget
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_clearCollOffset.idl
# --->  struct ATPtg_command_clearCollOffset {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  int num
# doitem 6 file4 num long 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_clearCollOffset
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_collOffset.idl
# --->  struct ATPtg_command_collOffset {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  double ca
# doitem 6 file4 ca double 1 | |  |
# --->  double ce
# doitem 7 file4 ce double 1 | |  |
# --->  int num
# doitem 8 file4 num long 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_collOffset
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_copyTarget.idl
# --->  struct ATPtg_command_copyTarget {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  long copyFrom
# doitem 6 file4 copyFrom long 1 | |  |
# --->  long copyTo
# doitem 7 file4 copyTo long 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_copyTarget
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_debugLevel.idl
# --->  struct ATPtg_command_debugLevel {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  long level
# doitem 6 file4 level long 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_debugLevel
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_disable.idl
# --->  struct ATPtg_command_disable {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  boolean value
# doitem 6 file4 value boolean 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_disable
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_enable.idl
# --->  struct ATPtg_command_enable {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  boolean value
# doitem 6 file4 value boolean 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_enable
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_enterControl.idl
# --->  struct ATPtg_command_enterControl {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  boolean value
# doitem 6 file4 value boolean 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_enterControl
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_ephemTarget.idl
# --->  struct ATPtg_command_ephemTarget {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  string ephemFile
# doitem 6 file4 ephemFile string 4096 | |  |
# --->  string targetName
# doitem 7 file4 targetName string 4096 | |  |
# --->  long targetInstance
# doitem 8 file4 targetInstance long 1 | |  |
# --->  double dRA
# doitem 9 file4 dRA double 1 | |  |
# --->  double dDec
# doitem 10 file4 dDec double 1 | |  |
# --->  long trackId
# doitem 11 file4 trackId long 1 | |  |
# --->  double rotPA
# doitem 12 file4 rotPA double 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_ephemTarget
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_exitControl.idl
# --->  struct ATPtg_command_exitControl {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  boolean value
# doitem 6 file4 value boolean 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_exitControl
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_focusName.idl
# --->  struct ATPtg_command_focusName {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  long focus
# doitem 6 file4 focus long 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_focusName
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_guideAutoclear.idl
# --->  struct ATPtg_command_guideAutoclear {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  long state
# doitem 6 file4 state long 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_guideAutoclear
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_guideClear.idl
# --->  struct ATPtg_command_guideClear {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  boolean ignored
# doitem 6 file4 ignored boolean 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_guideClear
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_guideControl.idl
# --->  struct ATPtg_command_guideControl {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  long state
# doitem 6 file4 state long 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_guideControl
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_iersUpdate.idl
# --->  struct ATPtg_command_iersUpdate {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  boolean ignored
# doitem 6 file4 ignored boolean 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_iersUpdate
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_offsetAbsorb.idl
# --->  struct ATPtg_command_offsetAbsorb {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  int num
# doitem 6 file4 num long 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_offsetAbsorb
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_offsetAzEl.idl
# --->  struct ATPtg_command_offsetAzEl {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  double az
# doitem 6 file4 az double 1 | |  |
# --->  double el
# doitem 7 file4 el double 1 | |  |
# --->  int num
# doitem 8 file4 num long 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_offsetAzEl
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_offsetClear.idl
# --->  struct ATPtg_command_offsetClear {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  int num
# doitem 6 file4 num long 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_offsetClear
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_offsetPA.idl
# --->  struct ATPtg_command_offsetPA {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  double angle
# doitem 6 file4 angle double 1 | |  |
# --->  double radius
# doitem 7 file4 radius double 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_offsetPA
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_offsetRADec.idl
# --->  struct ATPtg_command_offsetRADec {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  long type
# doitem 6 file4 type long 1 | |  |
# --->  double off1
# doitem 7 file4 off1 double 1 | |  |
# --->  double off2
# doitem 8 file4 off2 double 1 | |  |
# --->  int num
# doitem 9 file4 num long 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_offsetRADec
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_planetTarget.idl
# --->  struct ATPtg_command_planetTarget {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  long planetName
# doitem 6 file4 planetName long 1 | |  |
# --->  long targetInstance
# doitem 7 file4 targetInstance long 1 | |  |
# --->  double dRA
# doitem 8 file4 dRA double 1 | |  |
# --->  double dDec
# doitem 9 file4 dDec double 1 | |  |
# --->  long trackId
# doitem 10 file4 trackId long 1 | |  |
# --->  double rotPA
# doitem 11 file4 rotPA double 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_planetTarget
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_pointAddData.idl
# --->  struct ATPtg_command_pointAddData {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  boolean ignored
# doitem 6 file4 ignored boolean 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_pointAddData
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_pointCloseFile.idl
# --->  struct ATPtg_command_pointCloseFile {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  boolean ignored
# doitem 6 file4 ignored boolean 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_pointCloseFile
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_pointLoadModel.idl
# --->  struct ATPtg_command_pointLoadModel {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  string pointingFile
# doitem 6 file4 pointingFile string 4096 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_pointLoadModel
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_pointNewFile.idl
# --->  struct ATPtg_command_pointNewFile {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  boolean ignored
# doitem 6 file4 ignored boolean 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_pointNewFile
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_poriginAbsorb.idl
# --->  struct ATPtg_command_poriginAbsorb {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  int num
# doitem 6 file4 num long 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_poriginAbsorb
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_poriginClear.idl
# --->  struct ATPtg_command_poriginClear {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  int num
# doitem 6 file4 num long 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_poriginClear
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_poriginOffset.idl
# --->  struct ATPtg_command_poriginOffset {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  double dx
# doitem 6 file4 dx double 1 | |  |
# --->  double dy
# doitem 7 file4 dy double 1 | |  |
# --->  int num
# doitem 8 file4 num long 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_poriginOffset
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_poriginXY.idl
# --->  struct ATPtg_command_poriginXY {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  double x
# doitem 6 file4 x double 1 | |  |
# --->  double y
# doitem 7 file4 y double 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_poriginXY
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_raDecTarget.idl
# --->  struct ATPtg_command_raDecTarget {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  string targetName
# doitem 6 file4 targetName string 4096 | |  |
# --->  long targetInstance
# doitem 7 file4 targetInstance long 1 | |  |
# --->  long frame
# doitem 8 file4 frame long 1 | |  |
# --->  double epoch
# doitem 9 file4 epoch double 1 | |  |
# --->  double equinox
# doitem 10 file4 equinox double 1 | |  |
# --->  double ra
# doitem 11 file4 ra double 1 | |  |
# --->  double declination
# doitem 12 file4 declination double 1 | |  |
# --->  double parallax
# doitem 13 file4 parallax double 1 | |  |
# --->  double pmRA
# doitem 14 file4 pmRA double 1 | |  |
# --->  double pmDec
# doitem 15 file4 pmDec double 1 | |  |
# --->  double rv
# doitem 16 file4 rv double 1 | |  |
# --->  double dRA
# doitem 17 file4 dRA double 1 | |  |
# --->  long trackId
# doitem 18 file4 trackId long 1 | |  |
# --->  double dDec
# doitem 19 file4 dDec double 1 | |  |
# --->  double rotPA
# doitem 20 file4 rotPA double 1 | |  |
# --->  long rotFrame
# doitem 21 file4 rotFrame long 1 | |  |
# --->  long rotMode
# doitem 22 file4 rotMode long 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_raDecTarget
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_rotCurrentWrap.idl
# --->  struct ATPtg_command_rotCurrentWrap {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  long wrap
# doitem 6 file4 wrap long 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_rotCurrentWrap
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_rotOffset.idl
# --->  struct ATPtg_command_rotOffset {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  double iaa
# doitem 6 file4 iaa double 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_rotOffset
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_setAccessMode.idl
# --->  struct ATPtg_command_setAccessMode {
# --->     string<8> private_revCode; //private
# Skipping private item private_revCode or const
# --->     double private_sndStamp;    //private
# Skipping private item private_sndStamp or const
# --->     double private_rcvStamp;    //private
# Skipping private item private_rcvStamp or const
# --->     long private_seqNum;        //private
# Skipping private item private_seqNum or const
# --->     long private_origin;        //private
# Skipping private item private_origin or const
# --->     long private_host;          //private
# Skipping private item private_host or const
# --->     string<32>	device;
# doitem 2 file4 device string<32> 32 | |  |
# --->     string<32>	property;
# doitem 3 file4 property string<32> 32 | |  |
# --->     string<32>	action;
# doitem 4 file4 action string<32> 32 | |  |
# --->     string<32>	itemValue;
# doitem 5 file4 itemValue string<32> 32 | |  |
# --->  long mode
# doitem 6 file4 mode long 1 | |  |
# --->  };
# end of topic
# --->  #pragma keylist ATPtg_command_setAccessMode
# Creating /home/saluser/repos/ts_sal/test/idl-templates/validated/ATPtg_command_setLogLevel.idl
# --->  struct ATPtg_command_setLogLevel {
# ...
# 	: command test receive for = enable
# 	: command test send for = disable
# 	: command test receive for = disable
# 	: command test send for = standby
# 	: command test receive for = standby
# 	: command test send for = exitControl
# 	: command test receive for = exitControl
# 	: command test send for = start
# 	: command test receive for = start
# 	: command test send for = enterControl
# 	: command test receive for = enterControl
# 	: command test send for = setLogLevel
# 	: command test receive for = setLogLevel
# 	: command test send for = setSimulationMode
# 	: command test receive for = setSimulationMode
# 	: command test send for = setValue
# 	: command test receive for = setValue
#
# Generate event alias support for python
# 	: alias = detailedState
# 	: alias = heartbeat
# 	: alias = atMountState
# 	: alias = m3State
# 	: alias = m3PortSelected
# 	: alias = target
# 	: alias = elevationInPosition
# 	: alias = azimuthInPosition
# 	: alias = nasmyth1RotatorInPosition
# 	: alias = nasmyth2RotatorInPosition
# 	: alias = m3InPosition
# 	: alias = allAxesInPosition
# 	: alias = azimuthToppleBlockCCW
# 	: alias = azimuthToppleBlockCW
# 	: alias = m3RotatorDetentSwitches
# 	: alias = elevationLimitSwitchLower
# 	: alias = elevationLimitSwitchUpper
# 	: alias = azimuthLimitSwitchCCW
# 	: alias = azimuthLimitSwitchCW
# 	: alias = nasmyth1LimitSwitchCCW
# 	: alias = nasmyth1LimitSwitchCW
# 	: alias = nasmyth2LimitSwitchCCW
# 	: alias = nasmyth2LimitSwitchCW
# 	: alias = m3RotatorLimitSwitchCCW
# 	: alias = m3RotatorLimitSwitchCW
# 	: alias = elevationDriveStatus
# 	: alias = azimuthDrive1Status
# 	: alias = azimuthDrive2Status
# 	: alias = nasmyth1DriveStatus
# 	: alias = nasmyth2DriveStatus
# 	: alias = m3DriveStatus
# 	: alias = elevationBrake
# 	: alias = azimuthBrake1
# 	: alias = azimuthBrake2
# 	: alias = nasmyth1Brake
# 	: alias = nasmyth2Brake
# 	: alias = settingVersions
# 	: alias = errorCode
# 	: alias = summaryState
# 	: alias = appliedSettingsMatchStart
# 	: alias = logLevel
# 	: alias = logMessage
# 	: alias = simulationMode
#
# 	: event test send for = detailedState
# 	: event test receive for = detailedState
# 	: event test send for = heartbeat
# 	: event test receive for = heartbeat
# 	: event test send for = atMountState
# 	: event test receive for = atMountState
# 	: event test send for = m3State
# 	: event test receive for = m3State
# 	: event test send for = m3PortSelected
# 	: event test receive for = m3PortSelected
# 	: event test send for = target
# 	: event test receive for = target
# 	: event test send for = elevationInPosition
# 	: event test receive for = elevationInPosition
# 	: event test send for = azimuthInPosition
# 	: event test receive for = azimuthInPosition
# 	: event test send for = nasmyth1RotatorInPosition
# 	: event test receive for = nasmyth1RotatorInPosition
# 	: event test send for = nasmyth2RotatorInPosition
# 	: event test receive for = nasmyth2RotatorInPosition
# 	: event test send for = m3InPosition
# 	: event test receive for = m3InPosition
# 	: event test send for = allAxesInPosition
# 	: event test receive for = allAxesInPosition
# 	: event test send for = azimuthToppleBlockCCW
# 	: event test receive for = azimuthToppleBlockCCW
# 	: event test send for = azimuthToppleBlockCW
# 	: event test receive for = azimuthToppleBlockCW
# 	: event test send for = m3RotatorDetentSwitches
# 	: event test receive for = m3RotatorDetentSwitches
# 	: event test send for = elevationLimitSwitchLower
# 	: event test receive for = elevationLimitSwitchLower
# 	: event test send for = elevationLimitSwitchUpper
# 	: event test receive for = elevationLimitSwitchUpper
# 	: event test send for = azimuthLimitSwitchCCW
# 	: event test receive for = azimuthLimitSwitchCCW
# 	: event test send for = azimuthLimitSwitchCW
# 	: event test receive for = azimuthLimitSwitchCW
# 	: event test send for = nasmyth1LimitSwitchCCW
# 	: event test receive for = nasmyth1LimitSwitchCCW
# 	: event test send for = nasmyth1LimitSwitchCW
# 	: event test receive for = nasmyth1LimitSwitchCW
# 	: event test send for = nasmyth2LimitSwitchCCW
# 	: event test receive for = nasmyth2LimitSwitchCCW
# 	: event test send for = nasmyth2LimitSwitchCW
# 	: event test receive for = nasmyth2LimitSwitchCW
# 	: event test send for = m3RotatorLimitSwitchCCW
# 	: event test receive for = m3RotatorLimitSwitchCCW
# 	: event test send for = m3RotatorLimitSwitchCW
# 	: event test receive for = m3RotatorLimitSwitchCW
# 	: event test send for = elevationDriveStatus
# 	: event test receive for = elevationDriveStatus
# 	: event test send for = azimuthDrive1Status
# 	: event test receive for = azimuthDrive1Status
# 	: event test send for = azimuthDrive2Status
# 	: event test receive for = azimuthDrive2Status
# 	: event test send for = nasmyth1DriveStatus
# 	: event test receive for = nasmyth1DriveStatus
# 	: event test send for = nasmyth2DriveStatus
# 	: event test receive for = nasmyth2DriveStatus
# 	: event test send for = m3DriveStatus
# 	: event test receive for = m3DriveStatus
# 	: event test send for = elevationBrake
# 	: event test receive for = elevationBrake
# 	: event test send for = azimuthBrake1
# 	: event test receive for = azimuthBrake1
# 	: event test send for = azimuthBrake2
# 	: event test receive for = azimuthBrake2
# 	: event test send for = nasmyth1Brake
# 	: event test receive for = nasmyth1Brake
# 	: event test send for = nasmyth2Brake
# 	: event test receive for = nasmyth2Brake
# 	: event test send for = settingVersions
# 	: event test receive for = settingVersions
# 	: event test send for = errorCode
# 	: event test receive for = errorCode
# 	: event test send for = summaryState
# 	: event test receive for = summaryState
# 	: event test send for = appliedSettingsMatchStart
# 	: event test receive for = appliedSettingsMatchStart
# 	: event test send for = logLevel
# 	: event test receive for = logLevel
# 	: event test send for = logMessage
# 	: event test receive for = logMessage
# 	: event test send for = simulationMode
# 	: event test receive for = simulationMode
#
# Generating python shared library
# Generating Python SAL support for ATMCS
# g++  -fPIC -g -m64 -Wno-write-strings -std=c++11 -D_REENTRANT -Wall -I"." -I"/opt/OpenSpliceDDS/V6.9.0/HDE/x86_64.linux/examples/include" -I"/opt/OpenSpliceDDS/V6.9.0/HDE/x86_64.linux/examples" -I"/opt/OpenSpliceDDS/V6.9.0/HDE/x86_64.linux/include" -I"/opt/OpenSpliceDDS/V6.9.0/HDE/x86_64.linux/include/sys" -I"/opt/OpenSpliceDDS/V6.9.0/HDE/x86_64.linux/include/dcps/C++/SACPP" -I"/opt/lsst/software/stack/python/miniconda3-4.5.4//include/python3.6m" -I"/home/saluser/repos/ts_sal/lsstsal/include" -I"/opt/lsst/software/stack/python/miniconda3-4.5.4//include/python3.6m" -I../../../ATMCS/cpp/src -I../../../ATMCS/cpp -DSAL_BUILD_FOR_PYTHON  -c  -o ".obj/SAL_ATMCS_python.o" ../src/SAL_ATMCS.cpp
# g++  -fPIC -g -m64 -Wno-write-strings -std=c++11 -D_REENTRANT -Wall -I"." -I"/opt/OpenSpliceDDS/V6.9.0/HDE/x86_64.linux/examples/include" -I"/opt/OpenSpliceDDS/V6.9.0/HDE/x86_64.linux/examples" -I"/opt/OpenSpliceDDS/V6.9.0/HDE/x86_64.linux/include" -I"/opt/OpenSpliceDDS/V6.9.0/HDE/x86_64.linux/include/sys" -I"/opt/OpenSpliceDDS/V6.9.0/HDE/x86_64.linux/include/dcps/C++/SACPP" -I"/opt/lsst/software/stack/python/miniconda3-4.5.4//include/python3.6m" -I"/home/saluser/repos/ts_sal/lsstsal/include" -I"/opt/lsst/software/stack/python/miniconda3-4.5.4//include/python3.6m" -I../../../ATMCS/cpp/src -I../../../ATMCS/cpp -DSAL_BUILD_FOR_PYTHON  -c  -o ".obj/SALPY_ATMCS.o" ../src/SALPY_ATMCS.cpp
# g++  -fPIC -g -m64 -Wno-write-strings -std=c++11 -D_REENTRANT -Wall -I"." -I"/opt/OpenSpliceDDS/V6.9.0/HDE/x86_64.linux/examples/include" -I"/opt/OpenSpliceDDS/V6.9.0/HDE/x86_64.linux/examples" -I"/opt/OpenSpliceDDS/V6.9.0/HDE/x86_64.linux/include" -I"/opt/OpenSpliceDDS/V6.9.0/HDE/x86_64.linux/include/sys" -I"/opt/OpenSpliceDDS/V6.9.0/HDE/x86_64.linux/include/dcps/C++/SACPP" -I"/opt/lsst/software/stack/python/miniconda3-4.5.4//include/python3.6m" -I"/home/saluser/repos/ts_sal/lsstsal/include" -I"/opt/lsst/software/stack/python/miniconda3-4.5.4//include/python3.6m" -I../../../ATMCS/cpp/src -I../../../ATMCS/cpp -DSAL_BUILD_FOR_PYTHON  -shared -fPIC -L"." -L"/opt/OpenSpliceDDS/V6.9.0/HDE/x86_64.linux/lib" -Wl,-rpath,\$ORIGIN -Wl,-rpath,\$ORIGIN//opt/OpenSpliceDDS/V6.9.0/HDE/x86_64.linux/lib -L"/home/saluser/repos/ts_sal/test/lib" -L"/opt/lsst/software/stack/python/miniconda3-4.5.4//lib" -l"python3.6m" .obj/SAL_ATMCS_python.o .obj/SALPY_ATMCS.o -l"sacpp_ATMCS_types" -l"dcpssacpp" -l"dcpsgapi" -l"ddsuser" -l"ddskernel" -l"ddsserialization" -l"ddsconfparser" -l"ddsconf" -l"ddsdatabase" -l"ddsutil" -l"ddsos" -ldl  -lpthread -o "SALPY_ATMCS.so"
# python : Done SALPY_ATMCS.so
# Generating python command tests
# 	: command test send for = startTracking
# 	: command test receive for = startTracking
# 	: command test send for = trackTarget
# 	: command test receive for = trackTarget
# 	: command test send for = setInstrumentPort
# 	: command test receive for = setInstrumentPort
# 	: command test send for = stopTracking
# 	: command test receive for = stopTracking
# 	: command test send for = abort
# 	: command test receive for = abort
# 	: command test send for = enable
# 	: command test receive for = enable
# 	: command test send for = disable
# 	: command test receive for = disable
# 	: command test send for = standby
# 	: command test receive for = standby
# 	: command test send for = exitControl
# 	: command test receive for = exitControl
# 	: command test send for = start
# 	: command test receive for = start
# 	: command test send for = enterControl
# 	: command test receive for = enterControl
# 	: command test send for = setLogLevel
# 	: command test receive for = setLogLevel
# 	: command test send for = setSimulationMode
# 	: command test receive for = setSimulationMode
# 	: command test send for = setValue
# 	: command test receive for = setValue
# Generating python event tests
# 	: event test send for = detailedState
# 	: event test receive for = detailedState
# 	: event test send for = heartbeat
# 	: event test receive for = heartbeat
# 	: event test send for = atMountState
# 	: event test receive for = atMountState
# 	: event test send for = m3State
# 	: event test receive for = m3State
# 	: event test send for = m3PortSelected
# 	: event test receive for = m3PortSelected
# 	: event test send for = target
# 	: event test receive for = target
# 	: event test send for = elevationInPosition
# 	: event test receive for = elevationInPosition
# 	: event test send for = azimuthInPosition
# 	: event test receive for = azimuthInPosition
# 	: event test send for = nasmyth1RotatorInPosition
# 	: event test receive for = nasmyth1RotatorInPosition
# 	: event test send for = nasmyth2RotatorInPosition
# 	: event test receive for = nasmyth2RotatorInPosition
# 	: event test send for = m3InPosition
# 	: event test receive for = m3InPosition
# 	: event test send for = allAxesInPosition
# 	: event test receive for = allAxesInPosition
# 	: event test send for = azimuthToppleBlockCCW
# 	: event test receive for = azimuthToppleBlockCCW
# 	: event test send for = azimuthToppleBlockCW
# 	: event test receive for = azimuthToppleBlockCW
# 	: event test send for = m3RotatorDetentSwitches
# 	: event test receive for = m3RotatorDetentSwitches
# 	: event test send for = elevationLimitSwitchLower
# 	: event test receive for = elevationLimitSwitchLower
# 	: event test send for = elevationLimitSwitchUpper
# 	: event test receive for = elevationLimitSwitchUpper
# 	: event test send for = azimuthLimitSwitchCCW
# 	: event test receive for = azimuthLimitSwitchCCW
# 	: event test send for = azimuthLimitSwitchCW
# 	: event test receive for = azimuthLimitSwitchCW
# 	: event test send for = nasmyth1LimitSwitchCCW
# 	: event test receive for = nasmyth1LimitSwitchCCW
# 	: event test send for = nasmyth1LimitSwitchCW
# 	: event test receive for = nasmyth1LimitSwitchCW
# 	: event test send for = nasmyth2LimitSwitchCCW
# 	: event test receive for = nasmyth2LimitSwitchCCW
# 	: event test send for = nasmyth2LimitSwitchCW
# 	: event test receive for = nasmyth2LimitSwitchCW
# 	: event test send for = m3RotatorLimitSwitchCCW
# 	: event test receive for = m3RotatorLimitSwitchCCW
# 	: event test send for = m3RotatorLimitSwitchCW
# 	: event test receive for = m3RotatorLimitSwitchCW
# 	: event test send for = elevationDriveStatus
# 	: event test receive for = elevationDriveStatus
# 	: event test send for = azimuthDrive1Status
# 	: event test receive for = azimuthDrive1Status
# 	: event test send for = azimuthDrive2Status
# 	: event test receive for = azimuthDrive2Status
# 	: event test send for = nasmyth1DriveStatus
# 	: event test receive for = nasmyth1DriveStatus
# 	: event test send for = nasmyth2DriveStatus
# 	: event test receive for = nasmyth2DriveStatus
# 	: event test send for = m3DriveStatus
# 	: event test receive for = m3DriveStatus
# 	: event test send for = elevationBrake
# 	: event test receive for = elevationBrake
# 	: event test send for = azimuthBrake1
# 	: event test receive for = azimuthBrake1
# 	: event test send for = azimuthBrake2
# 	: event test receive for = azimuthBrake2
# 	: event test send for = nasmyth1Brake
# 	: event test receive for = nasmyth1Brake
# 	: event test send for = nasmyth2Brake
# 	: event test receive for = nasmyth2Brake
# 	: event test send for = settingVersions
# 	: event test receive for = settingVersions
# 	: event test send for = errorCode
# 	: event test receive for = errorCode
# 	: event test send for = summaryState
# 	: event test receive for = summaryState
# 	: event test send for = appliedSettingsMatchStart
# 	: event test receive for = appliedSettingsMatchStart
# 	: event test send for = logLevel
# 	: event test receive for = logLevel
# 	: event test send for = logMessage
# 	: event test receive for = logMessage
# 	: event test send for = simulationMode
# 	: event test receive for = simulationMode
# Generating python telemetry tests
# 	: publisher for = measuredMotorVelocity
# 	: subscriber for = measuredMotorVelocity
# 	: publisher for = measuredTorque
# 	: subscriber for = measuredTorque
# 	: publisher for = mountEncoders
# 	: subscriber for = mountEncoders
# 	: publisher for = mountMotorEncoders
# 	: subscriber for = mountMotorEncoders
# 	: publisher for = torqueDemand
# 	: subscriber for = torqueDemand
# $TS_SAL_DIR = /home/saluser/repos/ts_sal
# $TS_XML_DIR = /home/saluser/repos/ts_xml
# $SAL_WORK_DIR = /home/saluser/repos/ts_sal/test
# * Make SALPY_ATPtg libraries ***
# *** Cleanup old ATPtg files ***
# Remove subdir include
# Remove subdir lib
# Removing demos
# *** Copy ATPtg XML files ***
# *** Validate and generate ATPtg libraries ***
# ***** salgenerator ATPtg validate
# ***** salgenerator ATPtg sal cpp fastest
# ***** salgenerator ATPtg sal python fastest
# *** Move ATPtg libraries into place ***
# *** Final cleanup ***
# Remove subdir include
# Remove subdir lib
# Removing demos
# Remove /home/saluser/repos/ts_sal/test/ATPtg_guidingAndOffsets
# Remove /home/saluser/repos/ts_sal/test/ATPtg_currentTargetStatus
# Remove /home/saluser/repos/ts_sal/test/ATPtg_prospectiveTimesToLimits
# Remove /home/saluser/repos/ts_sal/test/ATPtg_nextTimesToLimits
# Remove /home/saluser/repos/ts_sal/test/ATPtg
# Remove /home/saluser/repos/ts_sal/test/ATPtg_mountStatus
# Remove /home/saluser/repos/ts_sal/test/ATPtg_prospectiveTargetStatus
# Remove /home/saluser/repos/ts_sal/test/ATPtg_currentTimesToLimits
# Remove /home/saluser/repos/ts_sal/test/ATPtg_nextTargetStatus
# Remove /home/saluser/repos/ts_sal/test/ATPtg_timeAndDate
# *** Done generating SALPY_ATPtg ***
# $TS_SAL_DIR = /home/saluser/repos/ts_sal
# $TS_XML_DIR = /home/saluser/repos/ts_xml
# $SAL_WORK_DIR = /home/saluser/repos/ts_sal/test
# * Make SALPY_ATMCS libraries ***
# *** Cleanup old ATMCS files ***
# Remove subdir include
# Remove subdir lib
# Removing demos
# *** Copy ATMCS XML files ***
# *** Validate and generate ATMCS libraries ***
# ***** salgenerator ATMCS validate
# ***** salgenerator ATMCS sal cpp fastest
# ***** salgenerator ATMCS sal python fastest
# *** Move ATMCS libraries into place ***
# *** Final cleanup ***
# Remove subdir include
# Remove subdir lib
# Removing demos
# Remove /home/saluser/repos/ts_sal/test/ATMCS_mountMotorEncoders
# Remove /home/saluser/repos/ts_sal/test/ATMCS
# Remove /home/saluser/repos/ts_sal/test/ATMCS_measuredTorque
# Remove /home/saluser/repos/ts_sal/test/ATMCS_mountEncoders
# Remove /home/saluser/repos/ts_sal/test/ATMCS_measuredMotorVelocity
# Remove /home/saluser/repos/ts_sal/test/ATMCS_torqueDemand
# *** Done generating SALPY_ATMCS ***

# %% [markdown]
# The first step is to create Remotes to talk to the ATPtg and ATMCS componentes. The `include` is not required but it reduces the initialization time by only subscribing to the events, telemetry and commands that are actually used.

# %%
domain = salobj.Domain()

# %%
salobj.Remote?

# %%
atptg = salobj.Remote(domain=domain, 
                      name="ATPtg", 
                      include=["timeAndDate",
                               "summaryState",
                               "heartbeat",
                               "start", 
                               "enable", 
                               "standby", 
                               "raDecTarget", 
                               "pointAddData"])  # Remote to talk to the pointing component
# atmcs = salobj.Remote(domain=domain, 
#                       name="ATMCS", 
#                       include=["summaryState",
#                                "heartbeat",
#                                "allAxesInPosition",
#                                "start", 
#                                "enable", 
#                                "standby"])  # Remote to listen to the mount
# Out:
# ---------------------------------------------------------------------------
# DDSException                              Traceback (most recent call last)
# <ipython-input-3-50a61e921cd3> in <module>
#       8                                "standby",
#       9                                "raDecTarget",
# ---> 10                                "pointAddData"])  # Remote to talk to the pointing component
#      11 # atmcs = salobj.Remote(domain=domain,
#      12 #                       name="ATMCS",
#
# ~/repos/ts_salobj/python/lsst/ts/salobj/remote.py in __init__(self, domain, name, index, readonly, include, exclude)
#     129             if not readonly:
#     130                 for cmd_name in salinfo.command_names:
# --> 131                     cmd = RemoteCommand(salinfo, cmd_name)
#     132                     setattr(self, "cmd_" + cmd_name, cmd)
#     133
#
# ~/repos/ts_salobj/python/lsst/ts/salobj/topics/remote_command.py in __init__(self, salinfo, name)
#     248         # dict of seq_num: CommandInfo
#     249         if salinfo._ackcmd_reader is None:
# --> 250             salinfo._ackcmd_reader = AckCmdReader(salinfo)
#     251             salinfo._ackcmd_reader.callback = salinfo._ackcmd_callback
#     252
#
# ~/repos/ts_salobj/python/lsst/ts/salobj/topics/remote_command.py in __init__(self, salinfo, max_history, queue_len)
#      57     def __init__(self, salinfo, max_history=0, queue_len=100):
#      58         super().__init__(salinfo=salinfo, name="ackcmd", sal_prefix="",
# ---> 59                          max_history=max_history, queue_len=queue_len)
#      60
#      61
#
# ~/repos/ts_salobj/python/lsst/ts/salobj/topics/read_topic.py in __init__(self, salinfo, name, sal_prefix, max_history, queue_len)
#     111     """
#     112     def __init__(self, *, salinfo, name, sal_prefix, max_history, queue_len=100):
# --> 113         super().__init__(salinfo=salinfo, name=name, sal_prefix=sal_prefix)
#     114         self.isopen = True
#     115         self._allow_multiple_callbacks = False
#
# ~/repos/ts_salobj/python/lsst/ts/salobj/topics/base_topic.py in __init__(self, salinfo, name, sal_prefix)
#      59             self._revCode = ddsname[-8:]
#      60         self._type = ddsutil.get_dds_classes_from_idl(salinfo.idl_loc, revname)
# ---> 61         self._topic = self._type.register_topic(salinfo.domain.participant, ddsname, salinfo.domain.topic_qos)
#      62
#      63     @property
#
# ~/repos/ts_salobj/python/lsst/ts/salobj/ddsutil.py in register_topic(self, dp, name, qos, listener)
#     122         '''
#     123
# --> 124         return dds.Topic(dp, name, self.type_support_class(), qos, listener)
#     125
#     126
#
# dds.pyx in dds.Topic.__init__()
#
# DDSException: Failed to create topic.  Return code: Error

# %% [markdown]
# Next, check the current summary state of both components. Note the use of `get` instead of `next` that is because we just need to check the last published value and don't need to wait for something. If no summary state was published, this will probably raise an exception. This can be due to multiple things, like the component not being up or even a network communication issue.

# %%
print(f"ATPtg: {salobj.State(atptg.evt_summaryState.get().summaryState)!r}")
print(f"ATMCS: {salobj.State(atmcs.evt_summaryState.get().summaryState)!r}")

# %% [markdown]
# We now use the `set_summary_state` utility function provided by `salobj` to enable both components. This will work (or should work) no matter what the current state of the CSC is, as long as the communication is working.

# %%
await salobj.set_summary_state(atptg, salobj.State.ENABLED)

# %%
await set_summary_state(atmcs, State.ENABLED)

# %%
print(f"ATPtg: {State(atptg.evt_summaryState.get().summaryState)!r}")
print(f"ATMCS: {State(atmcs.evt_summaryState.get().summaryState)!r}")

# %% [markdown]
# Next step is setting up the parameters for the run. Currently we use a simple `NxN` pointing scheme in both azimuth and altitude. This will likely need to be improved as regions with lower elevation may need a better cover.
#
# TODO: Check with pointing component vendors a better grid.

# %%
n_az = 5  # Maximum number of pointings in azimuth
n_alt = 5  # Number of pointings in altitude
mag_limit = 7  # Magnitude limit

# %%
alt_min = Angle(35.*u.deg)
alt_max = Angle(70.*u.deg)
d_alt = (alt_max-alt_min) / n_alt

# %%
az_min = Angle(0.*u.deg)
az_max = Angle(360.*u.deg)

# %%
alt_grid = np.linspace(alt_min, alt_max, n_alt)

# %% [markdown]
# Building the Azimuth grid.
#
# For each altitude it will select a quasi-uniform number of values in azimuth.

# %%
az_grid = np.zeros((n_alt, n_az))

for i in range(n_alt):
#     n_az_add = int(np.floor(np.cos(alt_grid[i].radian)*max_n_az))
#     d_az = (az_max-az_min) / n_az
    d_az = (az_max-az_min) / n_az
    zero = (np.random.rand()+0.5)*d_az.deg
    zero = i*d_az.deg/4
#     az_grid.append(np.arange(az_min.deg+zero, az_max.deg+zero, d_az.deg))
    az_grid[i] += np.arange(az_min.deg+zero, az_max.deg+zero, d_az.deg)

# %% [markdown]
# At this point altitude is stored in a 1-d array and azimuth is stored in a matrix. I'll flatten these arrays so they are both 1-d with a one to one mapping.
#
# I'm also preparing the order of the pointings here so we will go over from lower to higher altitutes instead of doing a constant altitude sweap.

# %%
az_pt_grid = np.zeros(n_alt*n_az)
el_pt_grid = np.zeros(n_alt*n_az)

for i in range(n_az):
    for j in range(n_alt):
        az_pt_grid[i*n_az + j] = az_grid[j][i]
        el_pt_grid[i*n_az + j] = alt_grid[j].deg

# %% [markdown]
# Make a polar plot of the pointings

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='polar')
ax.set_theta_zero_location('W', offset=0)

c = ax.scatter(np.radians(az_pt_grid), 90.-el_pt_grid)
l = ax.plot(np.radians(az_pt_grid), 90.-el_pt_grid)

# for i in range(n_alt):
#     az = np.radians(az_grid[i])
#     el = np.zeros(len(az))+alt_grid[i].deg
#     c = ax.scatter(az, 90.-el)

# %% [markdown]
# Now for each Az/El pointing try to find a bright star to point.

# %%
location = EarthLocation.from_geodetic(lon=-70.747698*u.deg,
                                                    lat=-30.244728*u.deg,
                                                    height=2663.0*u.m)

# %%
customSimbad = Simbad()
customSimbad.add_votable_fields('distance_result', "fluxdata(V)")
customSimbad.TIMEOUT = 10

# %%
async def point(az, el):
    """A method to point.
    """
    
    current_time = Time.now()

    elaz = AltAz(alt=el, az=az, 
                 obstime=current_time.tai, 
                 location=location)

    radec = elaz.transform_to(ICRS)

    _ra = radec.ra.to_string(u.deg, decimal=True)
    _dec = radec.dec.to_string(u.deg, decimal=True, alwayssign=True)
    r = Angle(4.*u.deg).to_string(u.deg, decimal=True)

    criteria = f"region(circle,ICRS,{_ra} {_dec},{r}d) & Vmag < {mag_limit}"
    try:
        result_table = customSimbad.query_criteria(criteria)
    except Exception as e:
        print(f"Error getting target from Simbad. Skipping target {elaz!r}.")
        return -1

    if len(result_table) == 0:
        print(f"Could not find a suitable target around {elaz}.")
        return -1

    # sort by magnitude so first is the brightest 
    result_table.sort('FLUX_V')

    target_radec = SkyCoord(Angle(result_table['RA'][0], unit=u.hour), 
                    Angle(result_table['DEC'][0], unit=u.deg), frame=ICRS)

    t_id = str(result_table['MAIN_ID'][0])
    t_ra = result_table['RA'][0]
    t_dec = result_table['DEC'][0]
    t_mag = result_table['FLUX_V'][0]
    print(f"Pointing to {t_id:15}: {t_ra} {t_dec} (VMag:{t_mag:5.2f})")

    atptg.cmd_raDecTarget.set(
        targetName=f"{result_table['MAIN_ID'][0]}",
        targetInstance=SALPY_ATPtg.ATPtg_shared_TargetInstances_current,
        frame=SALPY_ATPtg.ATPtg_shared_CoordFrame_icrs,
        epoch=2000,  # should be ignored: no parallax or proper motion
        equinox=2000,  # should be ignored for ICRS
        ra=target_radec.ra.hour,
        declination=target_radec.dec.deg,
        parallax=0,
        pmRA=0,
        pmDec=0,
        rv=0,
        dRA=0,
        dDec=0,
        rotPA=0,
        rotFrame=SALPY_ATPtg.ATPtg_shared_RotFrame_target,
        rotMode=SALPY_ATPtg.ATPtg_shared_RotMode_field,
    )
    atmcs.evt_allAxesInPosition.flush()
    try:
        await atptg.cmd_raDecTarget.start()
    except Exception as e:
        print("Could not point to target.")
        return -1
        
    in_position = await atmcs.evt_allAxesInPosition.next(flush=False)
    while not in_position.inPosition:
        in_position = await atmcs.evt_allAxesInPosition.next(flush=False)
    print(f"Mount in position.")
    return 0
#     await asyncio.sleep(wait_time)
#     print("Done... Stop tracking...")
#     await atptg.cmd_stopTracking.start()
#     print("Next...")

# %%
async def wait_center():
    while True:
        opt = input("Center telescope and choose action (press ?<enter>, for list of actions): ")
        
        if opt == 'x':
            print("Telescope centered. Adding data and continuing...")
            await atptg.cmd_pointAddData.start()
            return 0
        elif opt == 's':
            print("Skipping...")
            return 1
        elif opt == 't':
            print("Stopping test...")
            return -1
        elif opt == '?':
            print("""Options are:
            x - Telescope centered, add data and continue.
            s - Skipp point and continue.
            t - Terminate test.
            """)

# %% [markdown]
# Store pass/fail pointings.

# %%
pt_grid_done = np.zeros(n_alt*n_az, dtype=np.bool)

# %%
for i in range(len(az_pt_grid)):
    
    if not pt_grid_done[i]:
        print(f"Pointing to: az={Angle(az_pt_grid[i]*u.deg)} / el {Angle(el_pt_grid[i]*u.deg)}")
        ret_val = await point(az=Angle(az_pt_grid[i]*u.deg),
                              el=Angle(el_pt_grid[i]*u.deg))
    else:
        print(f"Pointing {i} already completed. Skipping...")
        continue
        
    if ret_val == 0.:
        wait_ret_val = await wait_center()
        await atptg.cmd_stopTracking.start()
        if wait_ret_val < 0:
            break
        pt_grid_done[i] = wait_ret_val == 0
    else:
        print(f"Failed to point to position {i} in the grid. continuing...")
            

print("Done...")

# %%
pt_grid_done

# %%
for i in range(len(az_pt_grid)):
    
    if not pt_grid_done[i]:
        print(f"Pointing to: az={Angle(az_pt_grid[i]*u.deg)} / el {Angle(el_pt_grid[i]*u.deg)}")
        ret_val = await point(az=Angle(az_pt_grid[i]*u.deg),
                              el=Angle(el_pt_grid[i]*u.deg))
    else:
        print(f"Pointing {i} already completed. Skipping...")
        continue
        
    if ret_val == 0.:
        wait_ret_val = await wait_center()
        await atptg.cmd_stopTracking.start()
        if wait_ret_val < 0:
            break
        pt_grid_done[i] = wait_ret_val == 0
    else:
        print(f"Failed to point to position {i} in the grid. continuing...")
            

print("Done...")

# %%
pt_grid_done

# %%
for i in range(len(az_pt_grid)):
    
    if not pt_grid_done[i]:
        print(f"Pointing to: az={Angle(az_pt_grid[i]*u.deg)} / el {Angle(el_pt_grid[i]*u.deg)}")
        ret_val = await point(az=Angle(az_pt_grid[i]*u.deg),
                              el=Angle(el_pt_grid[i]*u.deg))
    else:
        print(f"Pointing {i} already completed. Skipping...")
        continue
        
    if ret_val == 0.:
        wait_ret_val = await wait_center()
        await atptg.cmd_stopTracking.start()
        if wait_ret_val < 0:
            break
        pt_grid_done[i] = wait_ret_val == 0
    else:
        print(f"Failed to point to position {i} in the grid. continuing...")
            

print("Done...")

# %%
await set_summary_state(atptg, State.STANDBY)

# %%
await set_summary_state(atmcs, State.STANDBY)

# %%
print(f"ATPtg: {State(atptg.evt_summaryState.get().summaryState)!r}")
print(f"ATMCS: {State(atmcs.evt_summaryState.get().summaryState)!r}")

# %% [markdown]
# # IGNORE FROM HERE ON

# %%
current_time = Time.now()

elaz = AltAz(alt=alt_grid[i], az=Angle(az_grid[i][0]*u.deg), 
             obstime=current_time.tai, 
             location=location)

radec = elaz.transform_to(ICRS)

# %%
print(elaz)
print(radec)

# %%
customSimbad = Simbad()

# %%
customSimbad.add_votable_fields('distance_result', "fluxdata(V)")

# %%
_ra = radec.ra.to_string(u.deg, decimal=True)
_dec = radec.dec.to_string(u.deg, decimal=True)
r = Angle(4.*u.deg).to_string(u.deg, decimal=True)

criteria = f"region(circle,ICRS,{_ra} {_dec},{r}d) & Vmag < 7"
print(criteria)
result_table = customSimbad.query_criteria(criteria)
print(result_table)

# %%
result_table.sort('FLUX_V')

# %%
Angle(result_table['RA'][0], unit=u.hour), Angle(result_table['DEC'][0], unit=u.deg)

# %%
target_radec = SkyCoord(Angle(result_table['RA'][0], unit=u.hour), 
                        Angle(result_table['DEC'][0], unit=u.deg), frame=ICRS)

# %%
target_radec

# %%
plt.hist(result_table['FLUX_V'])

# %%
r = 1. * u.deg
result_table = Simbad.query_region(radec, radius=r)
# c = coordinates.SkyCoord("05h35m17.3s -05d23m28s", frame='icrs')

# %%
print(result_table.columns)

# %%
print(result_table)

# %%
print(az, el)

# %%
Simbad.list_votable_fields()

# %%
Simbad.get_field_description("fluxdata(filtername)")

# %%
Simbad.get_field_description("V")

# %%
Simbad.get_votable_fields()

# %%
Simbad.ROW_LIMIT

# %%
Simbad.query_criteria?

# %%
radec.ra.to_string(u.hour, decimal=False, sep=":")
radec.dec.to_string(u.deg, decimal=False, sep=":")

# %%
Angle(r).to_string(u.deg)
