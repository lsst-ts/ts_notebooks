# %%
import sys
import asyncio
import logging

import numpy as np

from lsst.ts import salobj

import matplotlib.pyplot as plt

from lsst.ts.externalscripts.auxtel.latiss_cwfs_align import LatissCWFSAlign

# %%
stream_handler = logging.StreamHandler(sys.stdout)

logger = logging.getLogger()
logger.addHandler(stream_handler)
logger.level = logging.DEBUG

# %%
cwfs = LatissCWFSAlign(index=1)

# %%
await cwfs.start_task
# Out:
# Read historical data in 0.02 sec
# Read historical data in 0.09 sec
# Read historical data in 0.16 sec
# Read historical data in 0.33 sec
# Read historical data in 0.41 sec
# Read historical data in 0.50 sec
# Read historical data in 0.70 sec
# Read historical data in 1.31 sec
# Read historical data in 3.25 sec
# Read historical data in 3.32 sec
# Read historical data in 3.51 sec
# Read historical data in 0.01 sec

# %%
await cwfs.attcs.slew_object(name="HD 65763", rot_sky=0.)

# %%
await cwfs.latiss.take_engtest(exptime=1., n=1, filter='KPNO_406_828nm', grating='empty_1')

# %%
awiat cwfs.

# %%
await cwfs.attcs.offset_xy(x=(-100-244)*0.1, y=(-854-236)*0.1)

# %%
await cwfs.latiss.take_engtest(exptime=1., n=1, filter='KPNO_406_828nm', grating='empty_1')

# %%
await cwfs.latiss.atarchiver.evt_heartbeat.next(flush=True)

# %%
await cwfs.latiss.take_object(exptime=5., n=1)

# %%
await asyncio.gather(cwfs.latiss.take_engtest(exptime=30., n=1),
                     cwfs.attcs.slew_object(name="HD 83832", rot_sky=-90.),
                     return_exceptions=True)

# %%
await asyncio.gather(cwfs.latiss.take_engtest(exptime=3., n=5),
                     cwfs.attcs.slew_object(name="HD 83832", rot_sky=0.),
                     return_exceptions=True)

# %%
await cwfs.latiss.take_object(exptime=5., n=1)

# %%
await cwfs.attcs.offset_xy(x=-30., y=0.)

# %%
await cwfs.latiss.take_object(exptime=5.,n=1)

# %%
cwfs.exposure_time

# %%
await cwfs.hexapod_offset(offset=1.5)

# %%
cwfs.intra_visit_id = 2020021800031
cwfs.extra_visit_id = 2020021800032

# %%
cwfs.angle = -cwfs.camera_rotation_angle

# %%
await cwfs.run_cwfs()
# Out:
# Running cwfs in 2020021800031/2020021800032.
# /home/saluser/repos/ts_externalscripts/python/lsst/ts/externalscripts/auxtel/latiss_cwfs_align.py:295: FutureWarning: Config field doAddDistortionModel is deprecated: Camera geometry is incorporated when reading the raw files. This option no longer is used, and will be removed after v19.
#   isrConfig.doAddDistortionModel = False
# Using translation class LSST_LATISS
# Checking for header correction file named LATISS-AT_O_20200218_000031.yaml
# AT_O_20200218_000031: Forcing detector serial to ITL-3800C-068
# AT_O_20200218_000031: Forcing SHUTTIME header to be None
# Using translation class LSST_LATISS
# Checking for header correction file named LATISS-AT_O_20200218_000031.yaml
# AT_O_20200218_000031: Forcing detector serial to ITL-3800C-068
# Using translation class LSST_LATISS
# AT_O_20200218_000031: Dark time less than exposure time. Setting dark time to the exposure time.
# /home/saluser/repos/ts_externalscripts/python/lsst/ts/externalscripts/auxtel/latiss_cwfs_align.py:295: FutureWarning: Config field doAddDistortionModel is deprecated: Camera geometry is incorporated when reading the raw files. This option no longer is used, and will be removed after v19.
#   isrConfig.doAddDistortionModel = False
# Exception ignored in: <function SqlRegistry.__del__ at 0x7f92c2164c80>
# Traceback (most recent call last):
#   File "/opt/lsst/software/stack/stack/miniconda3-4.7.10-4d7b902/Linux64/daf_persistence/19.0.0-1-g6fe20d0+6/python/lsst/daf/persistence/registries.py", line 319, in __del__
#     self.conn.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 140261191567104 and this is thread id 140261169805056.
# Exception ignored in: <function SqlRegistry.__del__ at 0x7f92c2164c80>
# Traceback (most recent call last):
#   File "/opt/lsst/software/stack/stack/miniconda3-4.7.10-4d7b902/Linux64/daf_persistence/19.0.0-1-g6fe20d0+6/python/lsst/daf/persistence/registries.py", line 319, in __del__
#     self.conn.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 140261191567104 and this is thread id 140261169805056.
# Using translation class LSST_LATISS
# Checking for header correction file named LATISS-AT_O_20200218_000032.yaml
# AT_O_20200218_000032: Forcing detector serial to ITL-3800C-068
# AT_O_20200218_000032: Forcing SHUTTIME header to be None
# Using translation class LSST_LATISS
# Checking for header correction file named LATISS-AT_O_20200218_000032.yaml
# AT_O_20200218_000032: Forcing detector serial to ITL-3800C-068
# Using translation class LSST_LATISS
# AT_O_20200218_000032: Dark time less than exposure time. Setting dark time to the exposure time.
# Running source detection algorithm
# RemoteTelemetry(ATPtg, 0, timeAndDate) falling behind; read 27 messages
# Running CWFS code.
# WARNING: negative scale parameter,             image is within caustic, zcCol (in um)=
#
# ==============================
# Measured zernike coeficients: [180.02373098623528, -200.85300359193934, 1120.8439706537192]
# De-rotated zernike coeficients: [ 180.02373099 -200.85300359 1120.84397065]
# Hexapod offset: [-1.37422695 -1.53322904 -0.26686761]
# Telescope offsets: [-82.45361725 -91.9937421    0.        ]
# ==============================

# %%
cwfs.show_results()
# Out:
# ==============================
# Measured zernike coeficients: [180.02373098623528, -200.85300359193934, 1120.8439706537192]
# De-rotated zernike coeficients: [ 180.02373099 -200.85300359 1120.84397065]
# Hexapod offset: [-1.37422695 -1.53322904 -0.26686761]
# Telescope offsets: [-82.45361725 -91.9937421    0.        ]
# ==============================

# %%
fig1 = plt.figure(1, figsize=(12,8))

ax11 = fig1.add_subplot(121)

ax11.set_title("defocus 0.8 - intra")
ax11.imshow(cwfs.I1[0].image0)
ax11.contour(cwfs.algo.pMask) 

ax12 = fig1.add_subplot(122)

ax12.set_title("defocus 0.8 - extra")
ax12.imshow(cwfs.I2[0].image0)
ax12.contour(cwfs.algo.pMask)
# Out:
# update_title_pos
# findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0 to DejaVu Sans ('/opt/lsst/software/stack/python/miniconda3-4.7.10/envs/lsst-scipipe-4d7b902/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000.
# findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=12.0 to DejaVu Sans ('/opt/lsst/software/stack/python/miniconda3-4.7.10/envs/lsst-scipipe-4d7b902/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000.
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos

# %%
await cwfs.take_intra_extra()

# %%
cwfs.intra_visit_id, cwfs.extra_visit_id

# %%
cwfs.intra_visit_id = 2020021800139
cwfs.extra_visit_id = 2020021800140

# %%
await cwfs.run_cwfs()
# Out:
# Running cwfs in 2020021800139/2020021800140.
# /home/saluser/repos/ts_externalscripts/python/lsst/ts/externalscripts/auxtel/latiss_cwfs_align.py:295: FutureWarning: Config field doAddDistortionModel is deprecated: Camera geometry is incorporated when reading the raw files. This option no longer is used, and will be removed after v19.
#   isrConfig.doAddDistortionModel = False
# Using translation class LSST_LATISS
# Checking for header correction file named LATISS-AT_O_20200218_000139.yaml
# AT_O_20200218_000139: Forcing detector serial to ITL-3800C-068
# AT_O_20200218_000139: Forcing SHUTTIME header to be None
# Using translation class LSST_LATISS
# Checking for header correction file named LATISS-AT_O_20200218_000139.yaml
# AT_O_20200218_000139: Forcing detector serial to ITL-3800C-068
# Using translation class LSST_LATISS
# AT_O_20200218_000139: Dark time less than exposure time. Setting dark time to the exposure time.
# /home/saluser/repos/ts_externalscripts/python/lsst/ts/externalscripts/auxtel/latiss_cwfs_align.py:295: FutureWarning: Config field doAddDistortionModel is deprecated: Camera geometry is incorporated when reading the raw files. This option no longer is used, and will be removed after v19.
#   isrConfig.doAddDistortionModel = False
# Using translation class LSST_LATISS
# Checking for header correction file named LATISS-AT_O_20200218_000140.yaml
# AT_O_20200218_000140: Forcing detector serial to ITL-3800C-068
# AT_O_20200218_000140: Forcing SHUTTIME header to be None
# Using translation class LSST_LATISS
# Checking for header correction file named LATISS-AT_O_20200218_000140.yaml
# AT_O_20200218_000140: Forcing detector serial to ITL-3800C-068
# Using translation class LSST_LATISS
# AT_O_20200218_000140: Dark time less than exposure time. Setting dark time to the exposure time.
# Running source detection algorithm
# RemoteTelemetry(ATPtg, 0, timeAndDate) falling behind; read 36 messages
# Running CWFS code.
# ==============================
# Measured zernike coeficients: [22.140930827923782, -38.474680269856094, -53.2448823885341]
# De-rotated zernike coeficients: [ 22.14093083 -38.47468027 -53.24488239]
# Hexapod offset: [-0.16901474 -0.29369985  0.01267735]
# Telescope offsets: [-10.14088435 -17.62199096   0.        ]
# ==============================

# %%
cwfs.show_results()
# Out:
# ==============================
# Measured zernike coeficients: [22.140930827923782, -38.474680269856094, -53.2448823885341]
# De-rotated zernike coeficients: [ 22.14093083 -38.47468027 -53.24488239]
# Hexapod offset: [-0.16901474 -0.29369985  0.01267735]
# Telescope offsets: [-10.14088435 -17.62199096   0.        ]
# ==============================

# %%
fig1 = plt.figure(1, figsize=(12,8))

ax11 = fig1.add_subplot(121)

ax11.set_title("defocus 0.8 - intra")
ax11.imshow(cwfs.I1[0].image0)
ax11.contour(cwfs.algo.pMask) 

ax12 = fig1.add_subplot(122)

ax12.set_title("defocus 0.8 - extra")
ax12.imshow(cwfs.I2[0].image0)
ax12.contour(cwfs.algo.pMask)
# Out:
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# Exception ignored in: <function SqlRegistry.__del__ at 0x7f92c2164c80>
# Traceback (most recent call last):
#   File "/opt/lsst/software/stack/stack/miniconda3-4.7.10-4d7b902/Linux64/daf_persistence/19.0.0-1-g6fe20d0+6/python/lsst/daf/persistence/registries.py", line 319, in __del__
#     self.conn.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 140261169805056 and this is thread id 140269284378432.
# Exception ignored in: <function SqlRegistry.__del__ at 0x7f92c2164c80>
# Traceback (most recent call last):
#   File "/opt/lsst/software/stack/stack/miniconda3-4.7.10-4d7b902/Linux64/daf_persistence/19.0.0-1-g6fe20d0+6/python/lsst/daf/persistence/registries.py", line 319, in __del__
#     self.conn.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 140261169805056 and this is thread id 140269284378432.
# Exception ignored in: <function SqlRegistry.__del__ at 0x7f92c2164c80>
# Traceback (most recent call last):
#   File "/opt/lsst/software/stack/stack/miniconda3-4.7.10-4d7b902/Linux64/daf_persistence/19.0.0-1-g6fe20d0+6/python/lsst/daf/persistence/registries.py", line 319, in __del__
#     self.conn.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 140259072509696 and this is thread id 140269284378432.
# Exception ignored in: <function SqlRegistry.__del__ at 0x7f92c2164c80>
# Traceback (most recent call last):
#   File "/opt/lsst/software/stack/stack/miniconda3-4.7.10-4d7b902/Linux64/daf_persistence/19.0.0-1-g6fe20d0+6/python/lsst/daf/persistence/registries.py", line 319, in __del__
#     self.conn.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 140259072509696 and this is thread id 140269284378432.
# Exception ignored in: <function SqlRegistry.__del__ at 0x7f92c2164c80>
# Traceback (most recent call last):
#   File "/opt/lsst/software/stack/stack/miniconda3-4.7.10-4d7b902/Linux64/daf_persistence/19.0.0-1-g6fe20d0+6/python/lsst/daf/persistence/registries.py", line 319, in __del__
#     self.conn.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 140260679874304 and this is thread id 140269284378432.
# Exception ignored in: <function SqlRegistry.__del__ at 0x7f92c2164c80>
# Traceback (most recent call last):
#   File "/opt/lsst/software/stack/stack/miniconda3-4.7.10-4d7b902/Linux64/daf_persistence/19.0.0-1-g6fe20d0+6/python/lsst/daf/persistence/registries.py", line 319, in __del__
#     self.conn.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 140260679874304 and this is thread id 140269284378432.

# %%
await cwfs.hexapod_offset(-0.05593628)

# %% [markdown]
# ==============================
# Measured zernike coeficients: [-29.909079243798278, -51.884799092767814, 234.93235859973277]
# De-rotated zernike coeficients: [ -3.75543624  59.77024424 234.9323586 ]
# Hexapod offset: [ 0.02866745  0.45626141 -0.05593628]
# Telescope offsets: [ 1.72004713 27.37568439  0.        ]
# ==============================

# %%
await cwfs.take_intra_extra()

# %%
cwfs.intra_visit_id = 2020021800160
cwfs.extra_visit_id = 2020021800161

# %%
cwfs.algo.reset(cwfs.I1[0], cwfs.I2[0])

# %%
await cwfs.run_cwfs()
# Out:
# Running cwfs in 2020021800160/2020021800161.
# /home/saluser/repos/ts_externalscripts/python/lsst/ts/externalscripts/auxtel/latiss_cwfs_align.py:295: FutureWarning: Config field doAddDistortionModel is deprecated: Camera geometry is incorporated when reading the raw files. This option no longer is used, and will be removed after v19.
#   isrConfig.doAddDistortionModel = False
# Using translation class LSST_LATISS
# Checking for header correction file named LATISS-AT_O_20200218_000160.yaml
# AT_O_20200218_000160: Forcing detector serial to ITL-3800C-068
# AT_O_20200218_000160: Forcing SHUTTIME header to be None
# Using translation class LSST_LATISS
# Checking for header correction file named LATISS-AT_O_20200218_000160.yaml
# AT_O_20200218_000160: Forcing detector serial to ITL-3800C-068
# Using translation class LSST_LATISS
# AT_O_20200218_000160: Dark time less than exposure time. Setting dark time to the exposure time.
# /home/saluser/repos/ts_externalscripts/python/lsst/ts/externalscripts/auxtel/latiss_cwfs_align.py:295: FutureWarning: Config field doAddDistortionModel is deprecated: Camera geometry is incorporated when reading the raw files. This option no longer is used, and will be removed after v19.
#   isrConfig.doAddDistortionModel = False
# Using translation class LSST_LATISS
# Checking for header correction file named LATISS-AT_O_20200218_000161.yaml
# AT_O_20200218_000161: Forcing detector serial to ITL-3800C-068
# AT_O_20200218_000161: Forcing SHUTTIME header to be None
# Using translation class LSST_LATISS
# Checking for header correction file named LATISS-AT_O_20200218_000161.yaml
# AT_O_20200218_000161: Forcing detector serial to ITL-3800C-068
# Using translation class LSST_LATISS
# AT_O_20200218_000161: Dark time less than exposure time. Setting dark time to the exposure time.
# Running source detection algorithm
# RemoteTelemetry(ATPtg, 0, timeAndDate) falling behind; read 39 messages
# Running CWFS code.
# ==============================
# Measured zernike coeficients: [-42.02496323291741, -61.545516691989604, 21.235975240833433]
# De-rotated zernike coeficients: [-42.02496323 -61.54551669  21.23597524]
# Hexapod offset: [ 0.32080125 -0.4698131  -0.00505618]
# Telescope offsets: [ 19.24807476 -28.18878627   0.        ]
# ==============================

# %%
cwfs.show_results()
# Out:
# ==============================
# Measured zernike coeficients: [-42.02496323291741, -61.545516691989604, 21.235975240833433]
# De-rotated zernike coeficients: [-42.02496323 -61.54551669  21.23597524]
# Hexapod offset: [ 0.32080125 -0.4698131  -0.00505618]
# Telescope offsets: [ 19.24807476 -28.18878627   0.        ]
# ==============================

# %%
fig1 = plt.figure(1, figsize=(12,8))

ax11 = fig1.add_subplot(121)

ax11.set_title("defocus 0.8 - intra")
ax11.imshow(cwfs.I1[0].image0)
ax11.contour(cwfs.algo.pMask) 

ax12 = fig1.add_subplot(122)

ax12.set_title("defocus 0.8 - extra")
ax12.imshow(cwfs.I2[0].image0)
ax12.contour(cwfs.algo.pMask)
# Out:
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos

# %%
await cwfs.run_cwfs()

# %%
offset = {'m1': 0.0,
          'm2': 0.0,
          'x': -0.50677819,
          'y': 0.01802685,
          'z': 0.0,
          'u': 0.0,
          'v': 0.0
          }

await cwfs.attcs.ataos.cmd_offset.set_start(**offset)

# %%
await cwfs.latiss.take_engtest(exptime=.5, n=1, filter='KPNO_406_828nm', grating='empty_1')

# %%
await cwfs.attcs.offset_xy(1.08161108, -30.40669141)

# %%
await cwfs.take_intra_extra()

# %%
cwfs.intra_visit_id = 2020021800167
cwfs.extra_visit_id = 2020021800168

# %%
await cwfs.run_cwfs()
# Out:
# Running cwfs in 2020021800167/2020021800168.
# /home/saluser/repos/ts_externalscripts/python/lsst/ts/externalscripts/auxtel/latiss_cwfs_align.py:295: FutureWarning: Config field doAddDistortionModel is deprecated: Camera geometry is incorporated when reading the raw files. This option no longer is used, and will be removed after v19.
#   isrConfig.doAddDistortionModel = False
# Using translation class LSST_LATISS
# Checking for header correction file named LATISS-AT_O_20200218_000167.yaml
# AT_O_20200218_000167: Forcing detector serial to ITL-3800C-068
# AT_O_20200218_000167: Forcing SHUTTIME header to be None
# Using translation class LSST_LATISS
# Checking for header correction file named LATISS-AT_O_20200218_000167.yaml
# AT_O_20200218_000167: Forcing detector serial to ITL-3800C-068
# Using translation class LSST_LATISS
# AT_O_20200218_000167: Dark time less than exposure time. Setting dark time to the exposure time.
# /home/saluser/repos/ts_externalscripts/python/lsst/ts/externalscripts/auxtel/latiss_cwfs_align.py:295: FutureWarning: Config field doAddDistortionModel is deprecated: Camera geometry is incorporated when reading the raw files. This option no longer is used, and will be removed after v19.
#   isrConfig.doAddDistortionModel = False
# Exception ignored in: <function SqlRegistry.__del__ at 0x7f92c2164c80>
# Traceback (most recent call last):
#   File "/opt/lsst/software/stack/stack/miniconda3-4.7.10-4d7b902/Linux64/daf_persistence/19.0.0-1-g6fe20d0+6/python/lsst/daf/persistence/registries.py", line 319, in __del__
#     self.conn.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 140260654696192 and this is thread id 140260679874304.
# Exception ignored in: <function SqlRegistry.__del__ at 0x7f92c2164c80>
# Traceback (most recent call last):
#   File "/opt/lsst/software/stack/stack/miniconda3-4.7.10-4d7b902/Linux64/daf_persistence/19.0.0-1-g6fe20d0+6/python/lsst/daf/persistence/registries.py", line 319, in __del__
#     self.conn.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 140260654696192 and this is thread id 140260679874304.
# Exception ignored in: <function SqlRegistry.__del__ at 0x7f92c2164c80>
# Traceback (most recent call last):
#   File "/opt/lsst/software/stack/stack/miniconda3-4.7.10-4d7b902/Linux64/daf_persistence/19.0.0-1-g6fe20d0+6/python/lsst/daf/persistence/registries.py", line 319, in __del__
#     self.conn.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 140260654696192 and this is thread id 140260679874304.
# Exception ignored in: <function SqlRegistry.__del__ at 0x7f92c2164c80>
# Traceback (most recent call last):
#   File "/opt/lsst/software/stack/stack/miniconda3-4.7.10-4d7b902/Linux64/daf_persistence/19.0.0-1-g6fe20d0+6/python/lsst/daf/persistence/registries.py", line 319, in __del__
#     self.conn.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 140260654696192 and this is thread id 140260679874304.
# Exception ignored in: <function SqlRegistry.__del__ at 0x7f92c2164c80>
# Traceback (most recent call last):
#   File "/opt/lsst/software/stack/stack/miniconda3-4.7.10-4d7b902/Linux64/daf_persistence/19.0.0-1-g6fe20d0+6/python/lsst/daf/persistence/registries.py", line 319, in __del__
#     self.conn.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 140260663088896 and this is thread id 140260679874304.
# Exception ignored in: <function SqlRegistry.__del__ at 0x7f92c2164c80>
# Traceback (most recent call last):
#   File "/opt/lsst/software/stack/stack/miniconda3-4.7.10-4d7b902/Linux64/daf_persistence/19.0.0-1-g6fe20d0+6/python/lsst/daf/persistence/registries.py", line 319, in __del__
#     self.conn.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 140260663088896 and this is thread id 140260679874304.
# Using translation class LSST_LATISS
# Checking for header correction file named LATISS-AT_O_20200218_000168.yaml
# AT_O_20200218_000168: Forcing detector serial to ITL-3800C-068
# AT_O_20200218_000168: Forcing SHUTTIME header to be None
# Using translation class LSST_LATISS
# Checking for header correction file named LATISS-AT_O_20200218_000168.yaml
# AT_O_20200218_000168: Forcing detector serial to ITL-3800C-068
# Using translation class LSST_LATISS
# AT_O_20200218_000168: Dark time less than exposure time. Setting dark time to the exposure time.
# Running source detection algorithm
# RemoteTelemetry(ATPtg, 0, timeAndDate) falling behind; read 38 messages
# Running CWFS code.
# ==============================
# Measured zernike coeficients: [50.55984397920661, -85.00862441728341, 30.78407500292923]
# De-rotated zernike coeficients: [ 50.55984398 -85.00862442  30.784075  ]
# Hexapod offset: [-0.38595301 -0.6489208  -0.00732954]
# Telescope offsets: [-23.15718045 -38.93524782   0.        ]
# ==============================

# %%
cwfs.show_results()
# Out:
# ==============================
# Measured zernike coeficients: [50.55984397920661, -85.00862441728341, 30.78407500292923]
# De-rotated zernike coeficients: [ 50.55984398 -85.00862442  30.784075  ]
# Hexapod offset: [-0.38595301 -0.6489208  -0.00732954]
# Telescope offsets: [-23.15718045 -38.93524782   0.        ]
# ==============================

# %%
fig1 = plt.figure(1, figsize=(12,8))

ax11 = fig1.add_subplot(121)

ax11.set_title("defocus 0.8 - intra")
ax11.imshow(cwfs.I1[0].image0)
ax11.contour(cwfs.algo.pMask) 

ax12 = fig1.add_subplot(122)

ax12.set_title("defocus 0.8 - extra")
ax12.imshow(cwfs.I2[0].image0)
ax12.contour(cwfs.algo.pMask)
# Out:
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos

# %%
offset = {'m1': 0.0,
          'm2': 0.0,
          'x': 0.0,
          'y': 0.3,
          'z': 0.0,
          'u': 0.0,
          'v': 0.0
          }

await cwfs.attcs.ataos.cmd_offset.set_start(**offset)

# %%
await cwfs.take_intra_extra()

# %%
await cwfs.attcs.ataos.cmd_offset.set_start(**offset)

# %%
await cwfs.take_intra_extra()

# %%
await cwfs.attcs.ataos.cmd_offset.set_start(**offset)

# %%
await cwfs.take_intra_extra()

# %%
await cwfs.attcs.ataos.cmd_offset.set_start(**offset)

# %%
await cwfs.take_intra_extra()

# %%
offset = {'m1': 0.0,
          'm2': 0.0,
          'x': 0.0,
          'y': -0.3*4,
          'z': 0.0,
          'u': 0.0,
          'v': 0.0
          }

await cwfs.attcs.ataos.cmd_offset.set_start(**offset)

# %%
offset = {'m1': 0.0,
          'm2': 0.0,
          'x': 0.0,
          'y': -0.3,
          'z': 0.0,
          'u': 0.0,
          'v': 0.0
          }

await cwfs.attcs.ataos.cmd_offset.set_start(**offset)

# %%
await cwfs.take_intra_extra()

# %%
await cwfs.attcs.ataos.cmd_offset.set_start(**offset)

# %%
await cwfs.take_intra_extra()

# %%
await cwfs.attcs.offset_xy(+60*0.3, 0.)

# %%
await cwfs.latiss.take_engtest(exptime=.5, n=1, filter='KPNO_406_828nm', grating='empty_1')

# %%
await cwfs.attcs.ataos.cmd_offset.set_start(**offset)

# %%
await cwfs.take_intra_extra()

# %%
await cwfs.attcs.ataos.cmd_offset.set_start(**offset)

# %%
await cwfs.attcs.offset_xy(+60*0.3*3, 0.)

# %%
await cwfs.latiss.take_engtest(exptime=.5, n=1, filter='KPNO_406_828nm', grating='empty_1')

# %%
await cwfs.take_intra_extra()

# %%
offset = {'m1': 0.0,
          'm2': 0.0,
          'x': 0.0,
          'y': +0.3*4,
          'z': 0.0,
          'u': 0.0,
          'v': 0.0
          }

await cwfs.attcs.ataos.cmd_offset.set_start(**offset)

# %%
await cwfs.attcs.offset_xy(0., 0.)

# %%
await cwfs.latiss.take_engtest(exptime=.5, n=1, filter='KPNO_406_828nm', grating='empty_1')

# %%
await cwfs.take_intra_extra()

# %%
cwfs.intra_visit_id = 2020021800190
cwfs.extra_visit_id = 2020021800191

# %%
await cwfs.run_cwfs()
# Out:
# Running cwfs in 2020021800190/2020021800191.
# /home/saluser/repos/ts_externalscripts/python/lsst/ts/externalscripts/auxtel/latiss_cwfs_align.py:295: FutureWarning: Config field doAddDistortionModel is deprecated: Camera geometry is incorporated when reading the raw files. This option no longer is used, and will be removed after v19.
#   isrConfig.doAddDistortionModel = False
# Using translation class LSST_LATISS
# Checking for header correction file named LATISS-AT_O_20200218_000190.yaml
# AT_O_20200218_000190: Forcing detector serial to ITL-3800C-068
# AT_O_20200218_000190: Forcing SHUTTIME header to be None
# Using translation class LSST_LATISS
# Checking for header correction file named LATISS-AT_O_20200218_000190.yaml
# AT_O_20200218_000190: Forcing detector serial to ITL-3800C-068
# Using translation class LSST_LATISS
# AT_O_20200218_000190: Dark time less than exposure time. Setting dark time to the exposure time.
# /home/saluser/repos/ts_externalscripts/python/lsst/ts/externalscripts/auxtel/latiss_cwfs_align.py:295: FutureWarning: Config field doAddDistortionModel is deprecated: Camera geometry is incorporated when reading the raw files. This option no longer is used, and will be removed after v19.
#   isrConfig.doAddDistortionModel = False
# Using translation class LSST_LATISS
# Checking for header correction file named LATISS-AT_O_20200218_000191.yaml
# AT_O_20200218_000191: Forcing detector serial to ITL-3800C-068
# AT_O_20200218_000191: Forcing SHUTTIME header to be None
# Using translation class LSST_LATISS
# Checking for header correction file named LATISS-AT_O_20200218_000191.yaml
# AT_O_20200218_000191: Forcing detector serial to ITL-3800C-068
# Using translation class LSST_LATISS
# AT_O_20200218_000191: Dark time less than exposure time. Setting dark time to the exposure time.
# Running source detection algorithm
# RemoteTelemetry(ATPtg, 0, timeAndDate) falling behind; read 36 messages
# Running CWFS code.
# ==============================
# Measured zernike coeficients: [85.45232006542503, -34.290730103274825, 108.54173078988147]
# De-rotated zernike coeficients: [ 85.45232007 -34.2907301  108.54173079]
# Hexapod offset: [-0.65230779 -0.2617613  -0.02584327]
# Telescope offsets: [-39.13846721 -15.70567791   0.        ]
# ==============================

# %%
fig1 = plt.figure(1, figsize=(12,8))

ax11 = fig1.add_subplot(121)

ax11.set_title("defocus 0.8 - intra")
ax11.imshow(cwfs.I1[0].image0)
ax11.contour(cwfs.algo.pMask) 

ax12 = fig1.add_subplot(122)

ax12.set_title("defocus 0.8 - extra")
ax12.imshow(cwfs.I2[0].image0)
ax12.contour(cwfs.algo.pMask)
# Out:
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# Exception ignored in: <function SqlRegistry.__del__ at 0x7f92c2164c80>
# Traceback (most recent call last):
#   File "/opt/lsst/software/stack/stack/miniconda3-4.7.10-4d7b902/Linux64/daf_persistence/19.0.0-1-g6fe20d0+6/python/lsst/daf/persistence/registries.py", line 319, in __del__
#     self.conn.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 140260679874304 and this is thread id 140269284378432.
# Exception ignored in: <function SqlRegistry.__del__ at 0x7f92c2164c80>
# Traceback (most recent call last):
#   File "/opt/lsst/software/stack/stack/miniconda3-4.7.10-4d7b902/Linux64/daf_persistence/19.0.0-1-g6fe20d0+6/python/lsst/daf/persistence/registries.py", line 319, in __del__
#     self.conn.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 140260679874304 and this is thread id 140269284378432.
# Exception ignored in: <function SqlRegistry.__del__ at 0x7f92c2164c80>
# Traceback (most recent call last):
#   File "/opt/lsst/software/stack/stack/miniconda3-4.7.10-4d7b902/Linux64/daf_persistence/19.0.0-1-g6fe20d0+6/python/lsst/daf/persistence/registries.py", line 319, in __del__
#     self.conn.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 140260646303488 and this is thread id 140269284378432.
# Exception ignored in: <function SqlRegistry.__del__ at 0x7f92c2164c80>
# Traceback (most recent call last):
#   File "/opt/lsst/software/stack/stack/miniconda3-4.7.10-4d7b902/Linux64/daf_persistence/19.0.0-1-g6fe20d0+6/python/lsst/daf/persistence/registries.py", line 319, in __del__
#     self.conn.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 140260646303488 and this is thread id 140269284378432.
# Exception ignored in: <function SqlRegistry.__del__ at 0x7f92c2164c80>
# Traceback (most recent call last):
#   File "/opt/lsst/software/stack/stack/miniconda3-4.7.10-4d7b902/Linux64/daf_persistence/19.0.0-1-g6fe20d0+6/python/lsst/daf/persistence/registries.py", line 319, in __del__
#     self.conn.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 140260671481600 and this is thread id 140269284378432.
# Exception ignored in: <function SqlRegistry.__del__ at 0x7f92c2164c80>
# Traceback (most recent call last):
#   File "/opt/lsst/software/stack/stack/miniconda3-4.7.10-4d7b902/Linux64/daf_persistence/19.0.0-1-g6fe20d0+6/python/lsst/daf/persistence/registries.py", line 319, in __del__
#     self.conn.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 140260671481600 and this is thread id 140269284378432.

# %%
await cwfs.attcs.atptg.cmd_pointCloseFile.start()

# %%
await cwfs.hexapod_offset(0.16301038)

# %%
await cwfs.take_intra_extra()

# %%
cwfs.angle = -cwfs.camera_rotation_angle

# %%
cwfs.intra_visit_id = 2020021800035
cwfs.extra_visit_id = 2020021800036

# %%
await cwfs.run_cwfs()
# Out:
# Running cwfs in 2020021800035/2020021800036.
# /home/saluser/repos/ts_externalscripts/python/lsst/ts/externalscripts/auxtel/latiss_cwfs_align.py:295: FutureWarning: Config field doAddDistortionModel is deprecated: Camera geometry is incorporated when reading the raw files. This option no longer is used, and will be removed after v19.
#   isrConfig.doAddDistortionModel = False
# Using translation class LSST_LATISS
# Checking for header correction file named LATISS-AT_O_20200218_000035.yaml
# AT_O_20200218_000035: Forcing detector serial to ITL-3800C-068
# AT_O_20200218_000035: Forcing SHUTTIME header to be None
# Using translation class LSST_LATISS
# Checking for header correction file named LATISS-AT_O_20200218_000035.yaml
# AT_O_20200218_000035: Forcing detector serial to ITL-3800C-068
# Using translation class LSST_LATISS
# AT_O_20200218_000035: Dark time less than exposure time. Setting dark time to the exposure time.
# /home/saluser/repos/ts_externalscripts/python/lsst/ts/externalscripts/auxtel/latiss_cwfs_align.py:295: FutureWarning: Config field doAddDistortionModel is deprecated: Camera geometry is incorporated when reading the raw files. This option no longer is used, and will be removed after v19.
#   isrConfig.doAddDistortionModel = False
# Using translation class LSST_LATISS
# Checking for header correction file named LATISS-AT_O_20200218_000036.yaml
# AT_O_20200218_000036: Forcing detector serial to ITL-3800C-068
# AT_O_20200218_000036: Forcing SHUTTIME header to be None
# Using translation class LSST_LATISS
# Checking for header correction file named LATISS-AT_O_20200218_000036.yaml
# AT_O_20200218_000036: Forcing detector serial to ITL-3800C-068
# Using translation class LSST_LATISS
# AT_O_20200218_000036: Dark time less than exposure time. Setting dark time to the exposure time.
# Running source detection algorithm
# RemoteTelemetry(ATPtg, 0, timeAndDate) falling behind; read 29 messages
# Running CWFS code.
# ==============================
# Measured zernike coeficients: [-84.88813344416633, -2.1150894035463366, -18.72088462445225]
# De-rotated zernike coeficients: [-84.88813344  -2.1150894  -18.72088462]
# Hexapod offset: [ 0.64800102 -0.01614572  0.00445735]
# Telescope offsets: [38.88006112 -0.96874324  0.        ]
# ==============================

# %%
cwfs.show_results()
# Out:
# ==============================
# Measured zernike coeficients: [-84.88813344416633, -2.1150894035463366, -18.72088462445225]
# De-rotated zernike coeficients: [-84.88813344  -2.1150894  -18.72088462]
# Hexapod offset: [ 0.64800102 -0.01614572  0.00445735]
# Telescope offsets: [38.88006112 -0.96874324  0.        ]
# ==============================

# %%
fig1 = plt.figure(1, figsize=(12,8))

ax11 = fig1.add_subplot(121)

ax11.set_title("defocus 0.8 - intra")
ax11.imshow(cwfs.I1[0].image0)
ax11.contour(cwfs.algo.pMask) 

ax12 = fig1.add_subplot(122)

ax12.set_title("defocus 0.8 - extra")
ax12.imshow(cwfs.I2[0].image0)
ax12.contour(cwfs.algo.pMask)
# Out:
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos

# %%
await cwfs.hexapod_offset(0.0170169)

# %%
await cwfs.take_intra_extra()

# %%
cwfs.angle = -cwfs.camera_rotation_angle

# %%
cwfs.intra_visit_id = 2020021800049
cwfs.extra_visit_id = 2020021800050

# %%
await cwfs.run_cwfs()
# Out:
# RuntimeErrorTraceback (most recent call last)
# <ipython-input-35-73398592f668> in <module>
# ----> 1 get_ipython().run_line_magic('timeit', 'asyncio.get_event_loop().run_until_complete(cwfs.run_cwfs())')
#
# /opt/lsst/software/stack/python/miniconda3-4.7.10/envs/lsst-scipipe-4d7b902/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2315                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2316             with self.builtin_trap:
# -> 2317                 result = fn(*args, **kwargs)
#    2318             return result
#    2319
#
# </opt/lsst/software/stack/python/miniconda3-4.7.10/envs/lsst-scipipe-4d7b902/lib/python3.7/site-packages/decorator.py:decorator-gen-60> in timeit(self, line, cell, local_ns)
#
# /opt/lsst/software/stack/python/miniconda3-4.7.10/envs/lsst-scipipe-4d7b902/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /opt/lsst/software/stack/python/miniconda3-4.7.10/envs/lsst-scipipe-4d7b902/lib/python3.7/site-packages/IPython/core/magics/execution.py in timeit(self, line, cell, local_ns)
#    1158             for index in range(0, 10):
#    1159                 number = 10 ** index
# -> 1160                 time_number = timer.timeit(number)
#    1161                 if time_number >= 0.2:
#    1162                     break
#
# /opt/lsst/software/stack/python/miniconda3-4.7.10/envs/lsst-scipipe-4d7b902/lib/python3.7/site-packages/IPython/core/magics/execution.py in timeit(self, number)
#     167         gc.disable()
#     168         try:
# --> 169             timing = self.inner(it, self.timer)
#     170         finally:
#     171             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# /opt/lsst/software/stack/python/miniconda3-4.7.10/envs/lsst-scipipe-4d7b902/lib/python3.7/asyncio/base_events.py in run_until_complete(self, future)
#     569         future.add_done_callback(_run_until_complete_cb)
#     570         try:
# --> 571             self.run_forever()
#     572         except:
#     573             if new_task and future.done() and not future.cancelled():
#
# /opt/lsst/software/stack/python/miniconda3-4.7.10/envs/lsst-scipipe-4d7b902/lib/python3.7/asyncio/base_events.py in run_forever(self)
#     524         self._check_closed()
#     525         if self.is_running():
# --> 526             raise RuntimeError('This event loop is already running')
#     527         if events._get_running_loop() is not None:
#     528             raise RuntimeError(
#
# RuntimeError: This event loop is already running
# Running cwfs in 2020021800049/2020021800050.
# /home/saluser/repos/ts_externalscripts/python/lsst/ts/externalscripts/auxtel/latiss_cwfs_align.py:295: FutureWarning: Config field doAddDistortionModel is deprecated: Camera geometry is incorporated when reading the raw files. This option no longer is used, and will be removed after v19.
#   isrConfig.doAddDistortionModel = False
# Using translation class LSST_LATISS
# Checking for header correction file named LATISS-AT_O_20200218_000049.yaml
# AT_O_20200218_000049: Forcing detector serial to ITL-3800C-068
# AT_O_20200218_000049: Forcing SHUTTIME header to be None
# Using translation class LSST_LATISS
# Checking for header correction file named LATISS-AT_O_20200218_000049.yaml
# AT_O_20200218_000049: Forcing detector serial to ITL-3800C-068
# Using translation class LSST_LATISS
# AT_O_20200218_000049: Dark time less than exposure time. Setting dark time to the exposure time.
# /home/saluser/repos/ts_externalscripts/python/lsst/ts/externalscripts/auxtel/latiss_cwfs_align.py:295: FutureWarning: Config field doAddDistortionModel is deprecated: Camera geometry is incorporated when reading the raw files. This option no longer is used, and will be removed after v19.
#   isrConfig.doAddDistortionModel = False
# Using translation class LSST_LATISS
# Checking for header correction file named LATISS-AT_O_20200218_000050.yaml
# AT_O_20200218_000050: Forcing detector serial to ITL-3800C-068
# AT_O_20200218_000050: Forcing SHUTTIME header to be None
# Using translation class LSST_LATISS
# Checking for header correction file named LATISS-AT_O_20200218_000050.yaml
# AT_O_20200218_000050: Forcing detector serial to ITL-3800C-068
# Using translation class LSST_LATISS
# AT_O_20200218_000050: Dark time less than exposure time. Setting dark time to the exposure time.
# Running source detection algorithm
# RemoteTelemetry(ATPtg, 0, timeAndDate) falling behind; read 37 messages
# Running CWFS code.
# ==============================
# Measured zernike coeficients: [-9.476330114092537, 86.35982298780613, -79.01556664082213]
# De-rotated zernike coeficients: [ -9.47633011  86.35982299 -79.01556664]
# Hexapod offset: [0.0723384  0.65923529 0.01881323]
# Telescope offsets: [ 4.34030387 39.5541174   0.        ]
# ==============================

# %%
cwfs.show_results()
# Out:
# ==============================
# Measured zernike coeficients: [-9.476330114092537, 86.35982298780613, -79.01556664082213]
# De-rotated zernike coeficients: [ -9.47633011  86.35982299 -79.01556664]
# Hexapod offset: [0.0723384  0.65923529 0.01881323]
# Telescope offsets: [ 4.34030387 39.5541174   0.        ]
# ==============================

# %%
fig1 = plt.figure(1, figsize=(12,8))

ax11 = fig1.add_subplot(121)

ax11.set_title("defocus 0.8 - intra")
ax11.imshow(cwfs.I1[0].image0)
ax11.contour(cwfs.algo.pMask) 

ax12 = fig1.add_subplot(122)

ax12.set_title("defocus 0.8 - extra")
ax12.imshow(cwfs.I2[0].image0)
ax12.contour(cwfs.algo.pMask)
# Out:
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# Exception ignored in: <function SqlRegistry.__del__ at 0x7f92c2164c80>
# Traceback (most recent call last):
#   File "/opt/lsst/software/stack/stack/miniconda3-4.7.10-4d7b902/Linux64/daf_persistence/19.0.0-1-g6fe20d0+6/python/lsst/daf/persistence/registries.py", line 319, in __del__
#     self.conn.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 140260637910784 and this is thread id 140269284378432.
# Exception ignored in: <function SqlRegistry.__del__ at 0x7f92c2164c80>
# Traceback (most recent call last):
#   File "/opt/lsst/software/stack/stack/miniconda3-4.7.10-4d7b902/Linux64/daf_persistence/19.0.0-1-g6fe20d0+6/python/lsst/daf/persistence/registries.py", line 319, in __del__
#     self.conn.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 140260637910784 and this is thread id 140269284378432.
# Exception ignored in: <function SqlRegistry.__del__ at 0x7f92c2164c80>
# Traceback (most recent call last):
#   File "/opt/lsst/software/stack/stack/miniconda3-4.7.10-4d7b902/Linux64/daf_persistence/19.0.0-1-g6fe20d0+6/python/lsst/daf/persistence/registries.py", line 319, in __del__
#     self.conn.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 140260637910784 and this is thread id 140269284378432.
# Exception ignored in: <function SqlRegistry.__del__ at 0x7f92c2164c80>
# Traceback (most recent call last):
#   File "/opt/lsst/software/stack/stack/miniconda3-4.7.10-4d7b902/Linux64/daf_persistence/19.0.0-1-g6fe20d0+6/python/lsst/daf/persistence/registries.py", line 319, in __del__
#     self.conn.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 140260637910784 and this is thread id 140269284378432.
# Exception ignored in: <function SqlRegistry.__del__ at 0x7f92c2164c80>
# Traceback (most recent call last):
#   File "/opt/lsst/software/stack/stack/miniconda3-4.7.10-4d7b902/Linux64/daf_persistence/19.0.0-1-g6fe20d0+6/python/lsst/daf/persistence/registries.py", line 319, in __del__
#     self.conn.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 140260669384448 and this is thread id 140269284378432.
# Exception ignored in: <function SqlRegistry.__del__ at 0x7f92c2164c80>
# Traceback (most recent call last):
#   File "/opt/lsst/software/stack/stack/miniconda3-4.7.10-4d7b902/Linux64/daf_persistence/19.0.0-1-g6fe20d0+6/python/lsst/daf/persistence/registries.py", line 319, in __del__
#     self.conn.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 140260669384448 and this is thread id 140269284378432.
# Exception ignored in: <function SqlRegistry.__del__ at 0x7f92c2164c80>
# Traceback (most recent call last):
#   File "/opt/lsst/software/stack/stack/miniconda3-4.7.10-4d7b902/Linux64/daf_persistence/19.0.0-1-g6fe20d0+6/python/lsst/daf/persistence/registries.py", line 319, in __del__
#     self.conn.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 140260679874304 and this is thread id 140269284378432.
# Exception ignored in: <function SqlRegistry.__del__ at 0x7f92c2164c80>
# Traceback (most recent call last):
#   File "/opt/lsst/software/stack/stack/miniconda3-4.7.10-4d7b902/Linux64/daf_persistence/19.0.0-1-g6fe20d0+6/python/lsst/daf/persistence/registries.py", line 319, in __del__
#     self.conn.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 140260679874304 and this is thread id 140269284378432.

# %%
await cwfs.latiss.take_engtest(exptime=5., n=1, filter='KPNO_406_828nm', grating='empty_1')

# %%
await cwfs.hexapod_offset(0.04425861)

# %%
fig1 = plt.figure(1, figsize=(12,8))

ax11 = fig1.add_subplot(121)

ax11.set_title("defocus 0.8 - intra")
ax11.imshow(cwfs.I1[0].image0)
ax11.contour(cwfs.algo.pMask) 

ax12 = fig1.add_subplot(122)

ax12.set_title("defocus 0.8 - extra")
ax12.imshow(cwfs.I2[0].image0)
ax12.contour(cwfs.algo.pMask)

# %%
print("test")

# %%
await cwfs.attcs.slew_object(name="HD 27583", rot_sky=-71.)

# %%
await cwfs.latiss.take_engtest(exptime=5., n=1, filter='KPNO_406_828nm', grating='empty_1')

# %%
await cwfs.attcs.offset_azel(az=30., el=0.)

# %%
await cwfs.latiss.take_engtest(exptime=5., n=1, filter='KPNO_406_828nm', grating='empty_1')

# %%
await cwfs.attcs.offset_azel(az=0., el=30.)

# %%
await cwfs.latiss.take_engtest(exptime=5., n=1, filter='KPNO_406_828nm', grating='empty_1')

# %%
await cwfs.attcs.offset_azel(az=0., el=0.)

# %%
await cwfs.attcs.slew_object(name="HD 27583", rot_sky=-91.)

# %%
await cwfs.latiss.take_engtest(exptime=5., n=1, filter='KPNO_406_828nm', grating='empty_1')

# %%
azel = await cwfs.attcs.atmcs.tel_mount_AzEl_Encoders.aget()
nasmyth = await cwfs.attcs.atmcs.tel_mount_Nasmyth_Encoders.aget()

angle = np.mean(azel.elevationCalculatedAngle)-np.mean(nasmyth.nasmyth2CalculatedAngle)

print(angle)

# %%
offset = {'m1': 0.0,
          'm2': 0.0,
          'x': 0.0,
          'y': 0.2,
          'z': 0.0,
          'u': 0.0,
          'v': 0.0
          }

await cwfs.attcs.ataos.cmd_offset.set_start(**offset)

# %%
await cwfs.latiss.take_engtest(exptime=5., n=1, filter='KPNO_406_828nm', grating='empty_1')

# %%
azel = await cwfs.attcs.atmcs.tel_mount_AzEl_Encoders.aget()
nasmyth = await cwfs.attcs.atmcs.tel_mount_Nasmyth_Encoders.aget()

angle = np.mean(azel.elevationCalculatedAngle)-np.mean(nasmyth.nasmyth2CalculatedAngle)

print(angle)

# %%
offset = {'m1': 0.0,
          'm2': 0.0,
          'x': +0.2,
          'y': -0.2,
          'z': 0.0,
          'u': 0.0,
          'v': 0.0
          }

await cwfs.attcs.ataos.cmd_offset.set_start(**offset)

# %%
await cwfs.latiss.take_engtest(exptime=5., n=1, filter='KPNO_406_828nm', grating='empty_1')

# %%
azel = await cwfs.attcs.atmcs.tel_mount_AzEl_Encoders.aget()
nasmyth = await cwfs.attcs.atmcs.tel_mount_Nasmyth_Encoders.aget()

angle = np.mean(azel.elevationCalculatedAngle)-np.mean(nasmyth.nasmyth2CalculatedAngle)

print(angle)

# %%
offset = {'m1': 0.0,
          'm2': 0.0,
          'x':  -0.2,
          'y': 0.,
          'z': 0.0,
          'u': 0.0,
          'v': 0.0
          }

await cwfs.attcs.ataos.cmd_offset.set_start(**offset)

# %%
await cwfs.attcs.slew_object(name="HD 27583", rot_sky=-85.-3)

# %%
await cwfs.latiss.take_engtest(exptime=5., n=1, filter='KPNO_406_828nm', grating='empty_1')

# %%
azel = await cwfs.attcs.atmcs.tel_mount_AzEl_Encoders.aget()
nasmyth = await cwfs.attcs.atmcs.tel_mount_Nasmyth_Encoders.aget()

angle = np.mean(azel.elevationCalculatedAngle)-np.mean(nasmyth.nasmyth2CalculatedAngle)

print(angle)

# %%
await cwfs.attcs.offset_azel(az=30., el=0.)

# %%
await cwfs.latiss.take_engtest(exptime=5., n=1, filter='KPNO_406_828nm', grating='empty_1')

# %%
azel = await cwfs.attcs.atmcs.tel_mount_AzEl_Encoders.aget()
nasmyth = await cwfs.attcs.atmcs.tel_mount_Nasmyth_Encoders.aget()

angle = np.mean(azel.elevationCalculatedAngle)-np.mean(nasmyth.nasmyth2CalculatedAngle)

print(angle)

# %%
await cwfs.attcs.offset_azel(az=0., el=30.)

# %%
await cwfs.latiss.take_engtest(exptime=5., n=1, filter='KPNO_406_828nm', grating='empty_1')

# %%
azel = await cwfs.attcs.atmcs.tel_mount_AzEl_Encoders.aget()
nasmyth = await cwfs.attcs.atmcs.tel_mount_Nasmyth_Encoders.aget()

angle = np.mean(azel.elevationCalculatedAngle)-np.mean(nasmyth.nasmyth2CalculatedAngle)

print(angle)

# %%
fig1 = plt.figure(1, figsize=(12,8))

ax = fig1.add_subplot(111)

ax.imshow(cwfs.detection_exp.image.array)

# %%
import lsst.afw.display as afwDisplay
afwDisplay.setDefaultBackend("matplotlib")

# %matplotlib widget

plt.rcParams['figure.figsize'] = [7, 6]

disp = afwDisplay.Display(1, reopenPlot=True)

disp.scale("asinh", "zscale")
disp.mtv(cwfs.detection_exp)

# %%
await cwfs.latiss.atheaderservice.cmd_disable.start()

# %%
await cwfs.latiss.atheaderservice.cmd_standby.start()

# %%
await cwfs.latiss.atheaderservice.cmd_exitControl.start()

# %%
await cwfs.attcs.atmcs.cmd_startTracking.start()

# %%
await cwfs.latiss.enable()

# %%
await cwfs.latiss.take_darks?

# %%
await cwfs.latiss.take_darks(exptime=200, ndarks=3)

# %%
await cwfs.latiss.take_bias(nbias=10)

# %%
from lsst.rapid.analysis.bestEffort import BestEffortIsr
REPODIR = '/mnt/dmcs/oods_butler_repo/repo'
bestEffort = BestEffortIsr(REPODIR)
dataId = {'dayObs': '2020-02-17', 'seqNum': 244}
exp = bestEffort.getExposure(dataId)

# %%
print('test')

# %%
await cwfs.attcs.atmcs.cmd_startTraking.start()
